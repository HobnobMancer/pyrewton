# %% [markdown]
# # Parsing CUPP output
#
# The CAZyme prediction tools dbCAN, CUPP and eCAMI write out their output files in different formats, and do not present the data in a standardised manner across all tools. Additionally, the output from the prediction tools does not enable easy parsing of the data by the [Sklearn](https://scikit-learn.org/stable/index.html) library, which performs the statistical analysis of the tools preformances.
#
# This notebook explains the method used by the `pyrewton.cazymes.prediction.parse` submodule to parse the output from the CAZyme prediction tool CUPP.
#
# [CUPP](https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6489277/) is a k-mer based CAZyme prediction tool. The information defining the data included in each field of the output files came from the [README file](https://files.dtu.dk/userportal/#/shared/public/hLin6ni4p-SWuKfp/CUPP_program/) and the raw Python script.
#
# The following data is collected from the CUPP output:
# - protein_accession
# - cazy_family (all predicated CAZy families)
# - cazy_subfamily (all predicated CAZy subfamilies)
# - ec_number (all predicted EC numbers)
# - domain_range (the amino acid domain range of all predicted CAZy (sub)families)
#
#
# ### Notebook structure
#
# A some of the information about CUPP and its data is taken from its README, but predominately the information is taken from the `CUPPprediction.py` Python script.
#
# The section titled 'exploring the output' shows the exploration of the tools output files. This is to demonstrate how the data is constructed and presented, and forms a foundation for explaining the developed method of parsing the data.
#
# The section 'parsing the output' shows the method of parsing the data from the CAZyme prediction tool.
#
# The final section shows any additional parsing that was performed to make the statistical analysis of the tool's performance easier. This typically includes removing duplicates, and combining rows that represent data for the same predicted CAZyme.

# %% [markdown]
# ## Contents
#
# - [Imports](#notebook_imports)
# - [Exploring the CUPP FASTA file](#cupp_fasta)
# - [Exploring the CUPP log file](#cupp_log)
# - [Choosing the CUPP output file to path](#cupp_choice)
# - [Parsing the CUPP log file](#cupp_parse_log)
#     - [Defining the data model](#data_model)
#     - [Getting the predicted domain range](#cupp_domain_range)
#     - [Getting the predicted EC number](#cupp_ec)
#         - [Adding qualitying checking when getting the EC number](#cupp_ec_quality)
#     - [Getting the predicted subfamily](#cupp_subfam)
#         - [Standardising CAZy subfamilies (PL7:2)](#cupp_std_subfam)
# - [Combing functions and populating the data model](#cupp_functions)

# %% [markdown]
# <a id="notebook_imports"></a>

# %%
# Install necessary libraries
# !pip3 install pandas
# !pip3 install numpy

import re

import pandas as pd
import numpy as np

from tqdm.notebook import tqdm
# Out:
# Requirement already satisfied: pandas in /home/em/.local/lib/python3.8/site-packages (1.1.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/em/anaconda3/lib/python3.8/site-packages (from pandas) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /home/em/anaconda3/lib/python3.8/site-packages (from pandas) (2020.1)
# Requirement already satisfied: numpy>=1.15.4 in /home/em/.local/lib/python3.8/site-packages (from pandas) (1.19.4)
# Requirement already satisfied: six>=1.5 in /home/em/anaconda3/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)
# Requirement already satisfied: numpy in /home/em/.local/lib/python3.8/site-packages (1.19.4)

# %% [markdown]
# <a id="cupp_intro"></a>

# %% [markdown]
# ## Understanding the output
#
# CUPP produces two output files (a log file and a FASTA file) that contain the same data, but present it slightly differently.
#
# #### FASTA file
# The format of the data in the output FASTA file for each protein is as follows:
# ```
# > accession | raw_function | best_function | additional_info | subfam \n seq
# ```
#
# For example:
#
# ```
# >QIX00022.1 AMS68_005539|&|AA1:1.10.3.2|AA1:1.10.3.2|AA1:6.1(20.3,124..357)|AA1_3
# ...
# ```
#
# The following defines and the explains what data is included within each field of the output FASTA file.
#
# **Accession**
# This the data contained in the line starting with '>' in the input FASTA file containing the query sequences for CUPP. If the input FASTA file passed to CUPP was written output using `pyrewton` the first item in the accession is the GenBank protein accession number. This is the unique identifier for each protein.
#
# **Raw function** The following definition was taken from the raw Python script for `CUPP.CUPPprediction.py`: The 'raw function' is produced "when consider[ing] all EC functions of a CUPP equally". This is preseted as "predicted_cazy_family : predicted_ec_number".
#
# **Best function** The following definition was taken from the raw Python script for `CUPP.CUPPprediction.py`: the best function is the "most occuring EC function of the CUPP group". It was inferred from the Python script `CUPP.CUPPprediction.py` that the 'CUPP group' refers to the CAZy family k-mer cluster for which the query protein scored most highly. In the FASTA file this is presented as "predicted_cazy_family : predicted_ec_number". **This is the function that is taken from the output files as the CUPP CAZyme and CAZy family prediction.**
#
# **Additional information** This includes several pieces of information that are calculated by CUPP. Owing to the manner that CUPP presents this data in the FASTA file it can be difficult to determine exactly which pieces of data have been provided. The additional data is presented in the following order (and the definitions were taken from the script `CUPP.CUPPprediction.py`):
# - "Ratio of maximum frequencies"
# - "Ratio of maximum frequencies by coverage"
# - "Centre for mass for domain"
# - "Domain range" -- this is identifable by the presense of '...' between two numbers and could potentially be useful when looking for regions of positive selection down the road
# - "Number of important positions in domain" -- very ambgious of meaning
#
# **Subfam** This is the predicted CAZy subfamily for the query protein
#
# **Seq** This is the amino acid sequence of the query protein. It has not been determined why some letters up upper case and other lower case, although it is hypothesised that the upper case letters indicate the start of a k-mer hit found by CUPP.
#
# #### Log file
# The output log file for CUPP presents the same data as the FASTA, but presents the data in a different way. Instead of separating the data by '|' (which is used in the output FASTA file), the data is separated by tabulated white space ('\t').
#
# Additionally, the data is presented in a different order to the output FASTA file:
# - Predicated CAZy family (equivalent to the FASTA file best function)
# - CUPP (k-mer cluster) group which the query protein scored highest for, and the associated score
# - Additional information
# - Raw_function (same as the fasta file (presented as "cazy_fam:ec#"))
# - Best_function (same as the fasta file (presented as "cazy_fam:ec#")) **This is the function that is taken from the output files as the CUPP CAZyme and CAZy family prediction.**
# - Subfam

# %% [markdown]
# <a id="cupp_fasta"></a>

# %% [markdown]
# ### Exploring the CUPP FASTA file
#
# The data in the CUPP FASTA file is separated by '|'.
# Each protein covers two lines of data

# %%
# Reading the CUPP output FASTA file
with open("gca_143535_cupp.fasta", "r") as fh:
    fasta_file = fh.read().splitlines()
for line in fasta_file[:4]:
    print(line)
# Out:
# >XP_001545605.1 BCIN_01g00260|&|AA4:1.1.3.38|AA4:1.1.3.38|AA4:1.1(13.9,122..568)|
# ...
# >XP_024545922.1 BCIN_01g00340|&|GT2:2.4.1.117|GT2:2.4.1.117|GT2:23.1(20.2,116..300)|
# 

# %%
# read the raw text in the fasta file
for line in fasta_file[:4]:
    print(repr(line))
# the data is separated by '|'
# Out:
# '>XP_001545605.1 BCIN_01g00260|&|AA4:1.1.3.38|AA4:1.1.3.38|AA4:1.1(13.9,122..568)|'
# '...'
# '>XP_024545922.1 BCIN_01g00340|&|GT2:2.4.1.117|GT2:2.4.1.117|GT2:23.1(20.2,116..300)|'
# ''

# %% [markdown]
# <a id="cupp_log"></a>

# %% [markdown]
# ### Exploring the CUPP Log file
#
# The data in the CUPP log file is separated by '\t' (tabulated white space). Each protein is contained on a single line

# %%
# read the log file
with open("gca_143535_cupp.fasta.log", "r") as lfh:
    log_file = lfh.read().splitlines()

for line in log_file[:4]:
    print(line)
# Out:
# XP_001545605.1 BCIN_01g00260	AA4	AA4:1.1	13.9	7.39	268	122..568	107	AA4:1.1.3.38	AA4:1.1.3.38
# XP_024545922.1 BCIN_01g00340	GT2	GT2:23.1	20.2	7.74	211	116..300	77	GT2:2.4.1.117	GT2:2.4.1.117
# XP_001547235.1 BCIN_01g00640	AA3	AA3:3.1	64.0	144.16	274	26..553	453			AA3_1
# XP_001547254.1 BCIN_01g00800	AA1	AA1:6.1	10.5	5.13	329	202..455	98	AA1:1.10.3.2	AA1:1.10.3.2	AA1_3

# %%
# read the raw text in the log file
for line in log_file[:4]:
    print(repr(line))
# data is separated by '\t'
# Out:
# 'XP_001545605.1 BCIN_01g00260\tAA4\tAA4:1.1\t13.9\t7.39\t268\t122..568\t107\tAA4:1.1.3.38\tAA4:1.1.3.38\t'
# 'XP_024545922.1 BCIN_01g00340\tGT2\tGT2:23.1\t20.2\t7.74\t211\t116..300\t77\tGT2:2.4.1.117\tGT2:2.4.1.117\t'
# 'XP_001547235.1 BCIN_01g00640\tAA3\tAA3:3.1\t64.0\t144.16\t274\t26..553\t453\t\t\tAA3_1'
# 'XP_001547254.1 BCIN_01g00800\tAA1\tAA1:6.1\t10.5\t5.13\t329\t202..455\t98\tAA1:1.10.3.2\tAA1:1.10.3.2\tAA1_3'

# %% [markdown]
# <a id="cupp_choice"></a>

# %% [markdown]
# ### Choosing the CUPP output file to path
#
# The output FASTA and log files of CUPP contain the same data, therefore, it is unnecessary to parse both output files.
#
# A parser of the CUPP FASTA file would separate the protein data by the '|' separator character. This would parse the individual items of the protein data into a list, in the same order as they appear in the output FASTA file. This would allow the parser to selective retrieve the predicted CAZy families, EC numbers, etc.
#
# However, '|' is a common data separator. A user or external database from which the input FASTA file containing the input query protein sequences for CUPP was retrieved, may include '|' characters in their FASTA files. For example, a protein data line may be written as ">XP_001545605.1|BCIN_01g00260|Botrytis cinerea B05.10|XM_001545555.2" in the CUPP input FASTA file. The entire contents of this protein data line would be included in the CUPP output FASTA file under the 'Accession' field. If the 'Accession' field contains '|', the items withint the 'Accession' field would also be separated and thus disrupt the selective retrieval of data.
#
# The code blocks below demonstrate this theory.

# %%
# Example that would work
protein_data_line = '>XP_024545922.1 BCIN_01g00340|&|GT2:2.4.1.117|GT2:2.4.1.117|GT2:23.1(20.2,116..300)|'
protein_data = protein_data_line.split("|")
protein_data
# Out:
# ['>XP_024545922.1 BCIN_01g00340',
#  '&',
#  'GT2:2.4.1.117',
#  'GT2:2.4.1.117',
#  'GT2:23.1(20.2,116..300)',
#  '']

# %%
print("best function=", protein_data[3])
# Out:
# best function= GT2:2.4.1.117

# %%
# Example that would cause the incorrect data to be retrieved
protein_data_line = '>XP_001545605.1|BCIN_01g00260|Botrytis cinerea B05.10|XM_001545555.2|&|GT2:2.4.1.117|GT2:2.4.1.117|GT2:23.1(20.2,116..300)|'
protein_data = protein_data_line.split("|")
protein_data
# Out:
# ['>XP_001545605.1',
#  'BCIN_01g00260',
#  'Botrytis cinerea B05.10',
#  'XM_001545555.2',
#  '&',
#  'GT2:2.4.1.117',
#  'GT2:2.4.1.117',
#  'GT2:23.1(20.2,116..300)',
#  '']

# %%
print("best function=", protein_data[3])
# Out:
# best function= XM_001545555.2

# %% [markdown]
# Using '|' as a separator is common. Therefore, using '|' to identify separations between individual items of data may be a brittle approach when parsing the output from CUPP.
#
# The data in the output Log file is separated by tabs '\t'. This is less common that '|' and was therefore, deemed the least brittle of the two files to parse. Consequently, a method to parse the CUPP output log file was developed.

# %% [markdown]
# <a id="cupp_parse_log"></a>

# %% [markdown]
# ## Parsing the CUPP log file
#
# The first task is to separate the out the data fields created by CUPP into separate elements in a list.

# %% [markdown]
# <a id="data_model"></a>

# %% [markdown]
# ### Defining the data model
#
# The explanation of the design of the data model is explained in the note book prediction_data_model.ipynb.

# %%
class CazymeDomain:
    """Single CAZyme domain in a protein, predicted by a CAZyme prediction tool.

    Each unique CAZy domain per protein is identifiable by a unique CAZy
    family-subfamily combination.

    Every CAZyme domain has a source CAZyme prediction tool that predicted the CAZyme
    domain, a parent CAZyme protein (represented by the protein accession), and CAZy
    family and subfamily combination. If no CAZy subfamily is predicted, the 
    subfamily will be listed as a null value.

    Hotpep, CUPP and eCAMI predict EC numbers for each CAZyme domain.
    HMMER and CUPP predict amino acid domain ranges.
    Multiple EC numbers and domain ranges can be predicted for a single CAZyme domain,
    therefore, these attritbutes are stored as lists.
    """

    def __init__(
        self,
        prediction_tool,
        protein_accession,
        cazy_family,
        cazy_subfamily=None,
        ec_numbers=None,
        domain_range=None,
    ):
        """Initiate instance
        
        :attr prediction_tool: str, CAZyme prediciton tool which predicted the domain
        :attr protein_accession: str
        :attr cazy_family: str
        :attr cazy_subfamily: str
        :attr ec_numbers: list (list of str, each str contains a unique EC number)
        :attr domain_range: list (list of str, each str contains a unique domain range)
        """
        self.prediction_tool = prediction_tool
        self.protein_accession = protein_accession
        self.cazy_family = cazy_family
        
        # not all CAZyme domans are catalogued under a CAZy subfamily
        if cazy_subfamily is None:
            self.cazy_subfamiy = np.nan
        else:
            self.cazy_subfamily = cazy_subfamily
        
        # EC numbers are not predicted for all CAZyme domains
        if ec_numbers is None:
            self.ec_numbers = []  # enables adding in EC numbers included in another line of the output file
        else:
            self.ec_numbers = ec_numbers
        
        # Not all prediction tools predict CAZyme domains
        if domain_range is None:
            self.domain_range = []  # enables adding domain range listed in another line of the ouput file
        else:
            self.domain_range = domain_range
    
    def __str__(self):
        return f"-CazymeDomain in {self.protein_accession}, fam={self.cazy_family}, subfam={self.cazy_subfamily}-"
    
    def __repr__(self):
        return f"<CazymeDomain parent={self.protein_accession} fam={self.cazy_family}, subfam={self.cazy_subfamily}>"

    
class CazymeProteinPrediction:
    """Single protein and CAZyme/non-CAZyme prediction by a CAZyme prediction tool"""
    
    def __init__(self, prediction_tool, protein_accession, cazyme_classification, cazyme_domains=None):
        """Initate class instance.
        
        :attr prediction_tool: str, name of CAZyme prediction tool
        :attr protein_accession: str
        :attr cazyme_classification: int, 1=CAZyme, 0=non-CAZyme
        :attr cazyme_domains: list of CazymeDomain instances, domain predicted to be in the CAZyme
        """
        self.prediction_tool = prediction_tool
        self.protein_accession = protein_accession
        self.cazyme_classification = cazyme_classification  # CAZyme=1, non-CAZyme=0
        
        # non-CAZymes will have no cazyme_domains
        if cazyme_domains is None:
            self.cazyme_domains = []  # enables adding domain predictions too
        else:
            self.cazyme_domains = cazyme_domains
    
    def __str__(self):
        if self.cazyme_classification == 0:
            return f"-CazymeProteinPrediction, protein={self.protein_accession}, non-CAZyme-"
        else:
            return f"-CazymeProteinPrediction, protein={self.protein_accession}, CAZyme domains={len(self.cazyme_domains)}-"
    
    def __repr__(self):
        return(
            f"<CazymeProteinPrediction, protein={self.protein_accession}, "
            f"cazyme_classification{self.cazyme_classification}>"
        )

# %% [markdown]
# Now lets split up the data in the CUPP log file to prepare it for adding it to the data model. Additionally, we create a dictionary, key by the protein accession and valued by its corresponding CUPPprediction instance. This is to enable quick checking if a CUPPprediction instance has already been created for a protein.

# %%
cupp_predictions = {}  # stores proteins {protein_accession:CUPPprediction_instance}

# first split the line into the individual pieces of data
for line in log_file[:2]:
    prediction_output = line.split("\t")
    print(prediction_output)
# Out:
# ['XP_001545605.1 BCIN_01g00260', 'AA4', 'AA4:1.1', '13.9', '7.39', '268', '122..568', '107', 'AA4:1.1.3.38', 'AA4:1.1.3.38', '']
# ['XP_024545922.1 BCIN_01g00340', 'GT2', 'GT2:23.1', '20.2', '7.74', '211', '116..300', '77', 'GT2:2.4.1.117', 'GT2:2.4.1.117', '']

# %% [markdown]
# <a id="cupp_domain_range"></a>

# %% [markdown]
# ### Getting the predicted domain range
#
# The domain range is stored within the 'additional data' field by CUPP. However, if CUPP does not commute some of the fields within 'additional data' an empty object (such as an empty string) is _not_ written out to the output FASTA or log files.
#
# Reminder of the data included in the 'additional data' field by CUPP:
# - "Ratio of maximum frequencies"
# - "Ratio of maximum frequencies by coverage"
# - "Centre for mass for domain"
# - "Domain range" -- this is identifable by the presense of '...' between two numbers and could potentially be useful when looking for regions of positive selection down the road
# - "Number of important positions in domain" -- very ambgious of meaning
#
# Therefore, if only the domain range is calculated, only the data for the domain range will be included, producing the following output:
# `XP_001545605.1 BCIN_01g00260  AA4  AA4:1.1 15...250`
# If the 'Ratio of maximum frequencies' and domain range are calculated, then two elements of data will be included in the space allocated for 'additional data' within the output FASTA and log files. Also, these elements within the 'additional data' are separated by the same character used to separate the other data fields in the output file (such as '\t' for output log file). Therefore, the following output would be produced:
# `XP_001545605.1 BCIN_01g00260  AA4  AA4:1.1  7.4  15...250`
#
# Therefore, retrieving the predicted domain range can not be achieved by calling for an element in the `prediction_output` list by its index. However, the domain range is easy to identify by its characteristic '..' between two digits. The remaining data can be retrieved based upon its index in the `prediction_output` list.

# %%
for line in log_file[:4]:
    # separate the data fields
    prediction_output = line.split("\t")
    
    for item in prediction_output:
        if item.find("..") != -1:
            domain_range = item
            break
        else:
            domain_range = np.nan
    
    # store the prediction output in a dictionary
    prediction = {
        "protein_accession": prediction_output[0],
        "cazy_family": prediction_output[1],
        "cazy_subfamily": prediction_output[-1],
        "ec_number": prediction_output[-2],
        "domain_range": domain_range,
    }

print("protein_accession =", prediction["protein_accession"])
print("CAZy family =", prediction["cazy_family"])
print("CAZy subfamily =", prediction["cazy_subfamily"])
print("EC# =", prediction["ec_number"])
print("Domain range =", prediction["domain_range"])
# Out:
# protein_accession = XP_001547254.1 BCIN_01g00800
# CAZy family = AA1
# CAZy subfamily = AA1_3
# EC# = AA1:1.10.3.2
# Domain range = 202..455

# %% [markdown]
# This can be written into a single function, and a 'quality' control to check the believed domain range is in the expected format (_digit_.._digit_), to increase the probability of correctly identifying the domain range.

# %%
def get_cupp_domain_range(prediction_output):
    """Retrieve the predicted amino acid range of predicted CAZyme domain from CUPP log file.
    
    :param prediction_output: list of items from log file line.
    
    Return string if domain range given, or null value if a domain range is not given.
    """
    domain_range = []  # store as a string in case multiple domain ranges are given

    for item in prediction_output:
        if item.find("..") != -1:
            domain_range.append(item)

    # check retrieved items are definetly the domain ranges
    for item in domain_range:
        try:
            re.match(r"\d+\.\.\d+", item).group()
        except AttributeError:
            # write as logger in pyrewton
            print(f"RAISED ATTRIBUTE ERROR: {item} misidentified as domain range")
            domain_range.remove(item)

    if len(domain_range) == 0:
        domain_range = np.nan
    
    else:
        domain_range = ", ".join(domain_range)
    
    return domain_range


for line in log_file[:4]:
    # separate the data fields
    prediction_output = line.split("\t")
    domain_range = get_cupp_domain_range(prediction_output)
    print(domain_range)
# Out:
# 122..568
# 116..300
# 26..553
# 202..455

# %% [markdown]
# <a id="cupp_ec"></a>

# %% [markdown]
# ### Getting the predicted EC number
#
# The CAZy family and associated EC number are stored within the same element in the `prediction_output` list. The CAZy family is always listed first, followed by a colon and then the EC number, which allows the retrieval of only the EC number.
#
# The item at position `[-2]` in prediction_output is the 'Best function' predicted by CUPP, the item at position `[-3]` is the raw function. The item listed is the 'Best function' is taken as the predicted CAZy family and associated EC numbers for the protein.

# %%
for line in log_file[:4]:
    # separate the data fields
    prediction_output = line.split("\t")
    
    # retrieve the predicted domain range
    for item in prediction_output:
        if item.find("..") != -1:
            domain_range = item
            break
        else:
            domain_range = np.nan
    
    # retrieve the predicted EC number
    try:
        ec_number = prediction_output[-2].split(":")[1]
    except IndexError:
        ec_number = np.nan
    
    # store the prediction output in a dictionary
    prediction = {
        "protein_accession": prediction_output[0],
        "cazy_family": prediction_output[1],
        "cazy_subfamily": prediction_output[-1],
        "ec_number": ec_number,
        "domain_range": domain_range,
    }

print("protein_accession =", prediction["protein_accession"])
print("CAZy family =", prediction["cazy_family"])
print("CAZy subfamily =", prediction["cazy_subfamily"])
print("EC# =", prediction["ec_number"])
print("Domain range =", prediction["domain_range"])
# Out:
# protein_accession = XP_001547254.1 BCIN_01g00800
# CAZy family = AA1
# CAZy subfamily = AA1_3
# EC# = 1.10.3.2
# Domain range = 202..455

# %% [markdown]
# <a id="cupp_ec_quality"></a>

# %% [markdown]
# ### Adding quality checks when retrieving EC numbers
#
# The retrieval of the predicted EC number appears susceptible to errors. The appear to result from not fully analysing all potential formats that CUPP may write out its predicted EC numbers.
#
# Therefore, first lets look at the EC numbers listed in the CUPP output log file.

# %%
for line in log_file:
    # separate the data fields
    prediction_output = line.split("\t")
    print(prediction_output[-2], repr(prediction_output[-2]))
# Out:
# AA4:1.1.3.38 'AA4:1.1.3.38'
# GT2:2.4.1.117 'GT2:2.4.1.117'
#  ''
# AA1:1.10.3.2 'AA1:1.10.3.2'
#  ''
#  ''
# GT39:2.4.1.109 'GT39:2.4.1.109'
# GT2:2.4.1.16 'GT2:2.4.1.16'
# AA11:1.*.*.* 'AA11:1.*.*.*'
# GH71:3.2.1.59 'GH71:3.2.1.59'
# GH71:3.2.1.59 'GH71:3.2.1.59'
# GH38:3.2.1.24 'GH38:3.2.1.24'
# GH38:3.2.1.24 'GH38:3.2.1.24'
# GT2:2.4.1.16 'GT2:2.4.1.16'
# GT2:2.4.1.16 'GT2:2.4.1.16'
#  ''
# GH47:3.2.1.113 'GH47:3.2.1.113'
#  ''
# GH114:3.2.1.109 'GH114:3.2.1.109'
# GH135:3.2.1.* 'GH135:3.2.1.*'
# GH16:2.4.1.*&3.2.1.*-GH16:3.2.1.39 'GH16:2.4.1.*&3.2.1.*-GH16:3.2.1.39'
# GH47:3.2.1.113 'GH47:3.2.1.113'
# CE12:3.1.1.* 'CE12:3.1.1.*'
# AA1:1.10.3.2 'AA1:1.10.3.2'
#  ''
# GH28:3.2.1.67 'GH28:3.2.1.67'
#  ''
# GH28:3.2.1.15 'GH28:3.2.1.15'
# GH125:3.2.1.* 'GH125:3.2.1.*'
# AA1:1.10.3.2 'AA1:1.10.3.2'
# GH27:3.2.1.49 'GH27:3.2.1.49'
# GH135:3.2.1.* 'GH135:3.2.1.*'
# GT50:2.4.1.* 'GT50:2.4.1.*'
# CE16:3.1.1.6 'CE16:3.1.1.6'
#  ''
# GT20:2.4.1.15 'GT20:2.4.1.15'
#  ''
# CE5:3.1.1.74 'CE5:3.1.1.74'
#  ''
# CE9:3.5.1.25 'CE9:3.5.1.25'
# GH13:2.4.1.25&3.2.1.33 'GH13:2.4.1.25&3.2.1.33'
# GH13:2.4.1.25&3.2.1.33 'GH13:2.4.1.25&3.2.1.33'
#  ''
# CE5:3.1.1.74 'CE5:3.1.1.74'
#  ''
# CE8:3.1.1.11 'CE8:3.1.1.11'
# GH28:3.2.1.* 'GH28:3.2.1.*'
#  ''
# GH76:3.2.1.101 'GH76:3.2.1.101'
#  ''
# GH88:3.2.1.* 'GH88:3.2.1.*'
#  ''
#  ''
#  ''
#  ''
#  ''
# GH71:3.2.1.59 'GH71:3.2.1.59'
# GH71:3.2.1.59 'GH71:3.2.1.59'
#  ''
# GH18:3.2.1.96 'GH18:3.2.1.96'
# GT21:2.4.1.80 'GT21:2.4.1.80'
#  ''
#  ''
# GH27:3.2.1.22-GH27:3.2.1.49 'GH27:3.2.1.22-GH27:3.2.1.49'
# GH45:3.2.1.4 'GH45:3.2.1.4'
# GT39:2.4.1.109 'GT39:2.4.1.109'
#  ''
# AA9:1.*.*.* 'AA9:1.*.*.*'
# GT66:2.4.99.18 'GT66:2.4.99.18'
#  ''
# AA1:1.10.3.2 'AA1:1.10.3.2'
# AA1:1.10.3.2 'AA1:1.10.3.2'
# GH1:3.2.1.21&3.2.1.23 'GH1:3.2.1.21&3.2.1.23'
# GT15:2.4.1.131 'GT15:2.4.1.131'
#  ''
# GH16:3.2.1.6-GH16:3.2.1.73 'GH16:3.2.1.6-GH16:3.2.1.73'
#  ''
#  ''
# GT22:2.4.1.259&2.4.1.261 'GT22:2.4.1.259&2.4.1.261'
# GT24:2.4.1.* 'GT24:2.4.1.*'
# GH13:3.2.1.20-GH13:5.4.99.11 'GH13:3.2.1.20-GH13:5.4.99.11'
# GH28:3.2.1.15 'GH28:3.2.1.15'
#  ''
#  ''
#  ''
# GT48:2.4.1.34 'GT48:2.4.1.34'
# GH72:2.4.1.* 'GH72:2.4.1.*'
#  ''
# CE12:3.1.1.* 'CE12:3.1.1.*'
# GH16:3.2.1.6-GH16:3.2.1.73 'GH16:3.2.1.6-GH16:3.2.1.73'
# GH16:3.2.1.6-GH16:3.2.1.73 'GH16:3.2.1.6-GH16:3.2.1.73'
#  ''
# AA1:1.10.3.2 'AA1:1.10.3.2'
# GH43:3.2.1.99 'GH43:3.2.1.99'
# GH76:3.2.1.101 'GH76:3.2.1.101'
# GH5:3.2.1.45 'GH5:3.2.1.45'
# GT20:2.4.1.15 'GT20:2.4.1.15'
# GH93:3.2.1.* 'GH93:3.2.1.*'
# GH2:3.2.1.23 'GH2:3.2.1.23'
# GH71:3.2.1.59 'GH71:3.2.1.59'
# PL1:4.2.2.10 'PL1:4.2.2.10'
#  ''
# GH11:3.2.1.8 'GH11:3.2.1.8'
#  ''
# AA3:1.1.3.13 'AA3:1.1.3.13'
#  ''
# GH5:3.2.1.78 'GH5:3.2.1.78'
#  ''
#  ''
# GH28:3.2.1.15 'GH28:3.2.1.15'
# GT22:2.4.1.* 'GT22:2.4.1.*'
#  ''
# GH27:3.2.1.22 'GH27:3.2.1.22'
#  ''
#  ''
# GH10:3.2.1.8 'GH10:3.2.1.8'
#  ''
# GH12:3.2.1.151 'GH12:3.2.1.151'
# CE8:3.1.1.11 'CE8:3.1.1.11'
#  ''
# GH5:3.2.1.4 'GH5:3.2.1.4'
# GT32:2.4.1.* 'GT32:2.4.1.*'
#  ''
# CE8:3.1.1.11 'CE8:3.1.1.11'
# GH81:3.2.1.39 'GH81:3.2.1.39'
#  ''
#  ''
# PL1:4.2.2.2 'PL1:4.2.2.2'
# AA9:1.*.*.* 'AA9:1.*.*.*'
# GT76:2.4.1.* 'GT76:2.4.1.*'
#  ''
# GT90:2.4.1.*&2.4.2.* 'GT90:2.4.1.*&2.4.2.*'
#  ''
#  ''
#  ''
# GH15:3.2.1.3 'GH15:3.2.1.3'
# GH71:3.2.1.59 'GH71:3.2.1.59'
# PL3:4.2.2.2 'PL3:4.2.2.2'
# GT62:2.4.1.* 'GT62:2.4.1.*'
#  ''
#  ''
# GT2:2.4.1.16 'GT2:2.4.1.16'
# GH15:3.2.1.3 'GH15:3.2.1.3'
# GH15:3.2.1.3 'GH15:3.2.1.3'
# GH28:3.2.1.15 'GH28:3.2.1.15'
# GH35:3.2.1.23 'GH35:3.2.1.23'
# GT2:2.4.1.* 'GT2:2.4.1.*'
#  ''
#  ''
# GT4:2.4.1.131 'GT4:2.4.1.131'
# GH43:3.2.1.99 'GH43:3.2.1.99'
# GH47:3.2.1.113 'GH47:3.2.1.113'
# GH2:3.2.1.25 'GH2:3.2.1.25'
# GH16:3.2.1.39 'GH16:3.2.1.39'
# GT1:2.4.1.173 'GT1:2.4.1.173'
#  ''
#  ''
#  ''
# GH28:3.2.1.67 'GH28:3.2.1.67'
#  ''
# GT69:2.4.1.* 'GT69:2.4.1.*'
#  ''
# AA1:1.10.3.2 'AA1:1.10.3.2'
#  ''
#  ''
# GH72:2.4.1.* 'GH72:2.4.1.*'
# AA7:1.1.3.* 'AA7:1.1.3.*'
#  ''
# GH10:3.2.1.8 'GH10:3.2.1.8'
# AA8:1.1.99.18 'AA8:1.1.99.18'
#  ''
#  ''
# GH64:3.2.1.39 'GH64:3.2.1.39'
# GH3:Unknown 'GH3:Unknown'
# GH76:3.2.1.101 'GH76:3.2.1.101'
# GH115:3.2.1.*-GH115:3.2.1.131 'GH115:3.2.1.*-GH115:3.2.1.131'
#  ''
# GH28:3.2.1.67 'GH28:3.2.1.67'
#  ''
# GH89:3.2.1.50 'GH89:3.2.1.50'
# GT71:2.4.1.* 'GT71:2.4.1.*'
# GT71:2.4.1.* 'GT71:2.4.1.*'
# GT1:2.4.1.173 'GT1:2.4.1.173'
# AA9:1.*.*.* 'AA9:1.*.*.*'
#  ''
#  ''
# GH55:3.2.1.58 'GH55:3.2.1.58'
# AA7:1.1.3.* 'AA7:1.1.3.*'
#  ''
#  ''
#  ''
# GH43:3.2.1.145 'GH43:3.2.1.145'
# GH79:3.2.1.*&3.2.1.31 'GH79:3.2.1.*&3.2.1.31'
#  ''
# GH28:3.2.1.40 'GH28:3.2.1.40'
# GT62:2.4.1.* 'GT62:2.4.1.*'
# GH125:3.2.1.* 'GH125:3.2.1.*'
# GH76:3.2.1.101 'GH76:3.2.1.101'
#  ''
# CE16:3.1.1.6 'CE16:3.1.1.6'
#  ''
#  ''
#  ''
# GH47:3.2.1.113 'GH47:3.2.1.113'
# GH5:3.2.1.75 'GH5:3.2.1.75'
# GH3:3.2.1.21 'GH3:3.2.1.21'
# GH31:3.2.1.177 'GH31:3.2.1.177'
# AA13:1.*.*.* 'AA13:1.*.*.*'
# GH64:3.2.1.39 'GH64:3.2.1.39'
# GT71:2.4.1.* 'GT71:2.4.1.*'
# GT15:2.4.1.131 'GT15:2.4.1.131'
# GH47:3.2.1.113 'GH47:3.2.1.113'
# GH132:3.2.1.* 'GH132:3.2.1.*'
# GH132:3.2.1.* 'GH132:3.2.1.*'
# AA6:1.6.5.6 'AA6:1.6.5.6'
# CE16:3.1.1.6 'CE16:3.1.1.6'
# GH78:3.2.1.40 'GH78:3.2.1.40'
#  ''
#  ''
#  ''
# AA9:1.*.*.* 'AA9:1.*.*.*'
# GT33:2.4.1.142 'GT33:2.4.1.142'
# GH71:3.2.1.59 'GH71:3.2.1.59'
# GH18:3.2.1.14 'GH18:3.2.1.14'
# GT90:2.4.1.*&2.4.2.* 'GT90:2.4.1.*&2.4.2.*'
# GT22:2.4.1.* 'GT22:2.4.1.*'
# GH18:3.2.1.14 'GH18:3.2.1.14'
# GT20:3.1.3.12 'GT20:3.1.3.12'
# GT20:3.1.3.12 'GT20:3.1.3.12'
# GT20:3.1.3.12 'GT20:3.1.3.12'
# CE5:3.1.1.74 'CE5:3.1.1.74'
# GT2:2.4.1.16 'GT2:2.4.1.16'
#  ''
#  ''
# GH15:3.2.1.3 'GH15:3.2.1.3'
# GH15:3.2.1.3 'GH15:3.2.1.3'
# GH5:3.2.1.164 'GH5:3.2.1.164'
# GH71:3.2.1.59 'GH71:3.2.1.59'
# GH55:3.2.1.58 'GH55:3.2.1.58'
#  ''
# GT69:2.4.1.* 'GT69:2.4.1.*'
# GT69:2.4.1.* 'GT69:2.4.1.*'
# GT69:2.4.1.* 'GT69:2.4.1.*'
# AA3:1.1.3.13 'AA3:1.1.3.13'
# CE16:3.1.1.6 'CE16:3.1.1.6'
# GH16:3.2.1.35 'GH16:3.2.1.35'
# GH16:3.2.1.35 'GH16:3.2.1.35'
# AA11:1.*.*.* 'AA11:1.*.*.*'
#  ''
#  ''
#  ''
# GH20:3.2.1.52 'GH20:3.2.1.52'
# GH20:3.2.1.52 'GH20:3.2.1.52'
# GH16:2.4.1.*&3.2.1.*-GH16:3.2.1.39 'GH16:2.4.1.*&3.2.1.*-GH16:3.2.1.39'
#  ''
# GH78:Unknown 'GH78:Unknown'
# GH47:3.2.1.113 'GH47:3.2.1.113'
# GH47:3.2.1.113 'GH47:3.2.1.113'
#  ''
# GH132:3.2.1.* 'GH132:3.2.1.*'
# GH1:3.2.1.21 'GH1:3.2.1.21'
# GH1:3.2.1.21 'GH1:3.2.1.21'
# GH95:3.2.1.63 'GH95:3.2.1.63'
# AA1:1.10.3.2 'AA1:1.10.3.2'
#  ''
# GH43:3.2.1.37 'GH43:3.2.1.37'
# GT1:2.4.1.173 'GT1:2.4.1.173'
# GT90:2.4.1.*&2.4.2.* 'GT90:2.4.1.*&2.4.2.*'
# GH51:3.2.1.55 'GH51:3.2.1.55'
# GH17:2.4.1.* 'GH17:2.4.1.*'
#  ''
#  ''
#  ''
#  ''
# AA3:Unknown 'AA3:Unknown'
# GH5:3.2.1.4 'GH5:3.2.1.4'
#  ''
#  ''
# GH13:2.4.1.* 'GH13:2.4.1.*'
# GH13:2.4.1.* 'GH13:2.4.1.*'
# CE8:3.1.1.11 'CE8:3.1.1.11'
# AA1:1.10.3.2 'AA1:1.10.3.2'
# PL1:4.2.2.10 'PL1:4.2.2.10'
# GT32:2.4.1.* 'GT32:2.4.1.*'
#  ''
#  ''
#  ''
#  ''
# GT15:2.4.1.131 'GT15:2.4.1.131'
# GH16:3.2.1.6 'GH16:3.2.1.6'
# GH95:3.2.1.63 'GH95:3.2.1.63'
# GT32:2.4.1.* 'GT32:2.4.1.*'
# GH76:3.2.1.101 'GH76:3.2.1.101'
# GH53:3.2.1.89 'GH53:3.2.1.89'
#  ''
# GH18:3.2.1.14 'GH18:3.2.1.14'
# GH18:3.2.1.14 'GH18:3.2.1.14'
# GH76:3.2.1.101 'GH76:3.2.1.101'
#  ''
#  ''
# GH131:3.2.1.* 'GH131:3.2.1.*'
# GH131:3.2.1.* 'GH131:3.2.1.*'
# GT2:2.4.1.16 'GT2:2.4.1.16'
# GH37:3.2.1.28 'GH37:3.2.1.28'
#  ''
#  ''
# GH16:3.2.1.39 'GH16:3.2.1.39'
# AA1:1.10.3.2 'AA1:1.10.3.2'
# GH76:3.2.1.101 'GH76:3.2.1.101'
#  ''
# GT1:2.4.1.173 'GT1:2.4.1.173'
#  ''
# GH16:3.2.1.6-GH16:3.2.1.73 'GH16:3.2.1.6-GH16:3.2.1.73'
# AA5:1.1.3.9 'AA5:1.1.3.9'
# AA5:1.1.3.9 'AA5:1.1.3.9'
#  ''
# GH51:3.2.1.55 'GH51:3.2.1.55'
# GH65:3.2.1.28 'GH65:3.2.1.28'
#  ''
# GH16:3.2.1.6-GH16:3.2.1.73 'GH16:3.2.1.6-GH16:3.2.1.73'
# AA1:1.10.3.2 'AA1:1.10.3.2'
# AA1:1.10.3.2 'AA1:1.10.3.2'
# AA1:1.10.3.2 'AA1:1.10.3.2'
#  ''
#  ''
# GT32:2.4.1.* 'GT32:2.4.1.*'
# AA9:1.*.*.* 'AA9:1.*.*.*'
# AA9:1.*.*.* 'AA9:1.*.*.*'
#  ''
#  ''
#  ''
#  ''
#  ''
#  ''
#  ''
#  ''
# GH55:3.2.1.58 'GH55:3.2.1.58'
# GH55:3.2.1.58 'GH55:3.2.1.58'
#  ''
#  ''
# GT8:2.4.1.186 'GT8:2.4.1.186'
# GH1:3.2.1.21 'GH1:3.2.1.21'
#  ''
# GH127:3.2.1.185 'GH127:3.2.1.185'
#  ''
#  ''
# GH28:3.2.1.171 'GH28:3.2.1.171'
#  ''
#  ''
# PL3:4.2.2.2 'PL3:4.2.2.2'
#  ''
# GH32:3.2.1.26 'GH32:3.2.1.26'
# GH28:3.2.1.40 'GH28:3.2.1.40'
# GH1:3.2.1.21 'GH1:3.2.1.21'
#  ''
# GH55:3.2.1.58 'GH55:3.2.1.58'
#  ''
# GT2:2.4.1.83 'GT2:2.4.1.83'
#  ''
# GH35:3.2.1.23 'GH35:3.2.1.23'
#  ''
#  ''
#  ''
# GT1:2.4.2.40 'GT1:2.4.2.40'
# AA9:1.*.*.* 'AA9:1.*.*.*'
# GH31:3.2.1.20 'GH31:3.2.1.20'
#  ''
# GH35:3.2.1.23 'GH35:3.2.1.23'
# GT15:2.4.1.131 'GT15:2.4.1.131'
# GH5:3.2.1.78 'GH5:3.2.1.78'
# GH28:3.2.1.171 'GH28:3.2.1.171'
#  ''
# GT2:2.4.1.16 'GT2:2.4.1.16'
# GT2:2.4.1.16 'GT2:2.4.1.16'
#  ''
# GH16:3.2.1.39 'GH16:3.2.1.39'
# GH125:3.2.1.* 'GH125:3.2.1.*'
#  ''
# GT62:2.4.1.* 'GT62:2.4.1.*'
#  ''
# AA3:Unknown 'AA3:Unknown'
# AA8:1.1.99.18 'AA8:1.1.99.18'
#  ''
# GH15:3.2.1.3 'GH15:3.2.1.3'
#  ''
# AA9:1.*.*.* 'AA9:1.*.*.*'
# GH28:3.2.1.173 'GH28:3.2.1.173'
# GT58:2.4.1.258 'GT58:2.4.1.258'
#  ''
# GH5:3.2.1.4 'GH5:3.2.1.4'
# GT2:2.4.1.16 'GT2:2.4.1.16'
# GT2:2.4.1.16 'GT2:2.4.1.16'
#  ''
#  ''
# GH131:3.2.1.* 'GH131:3.2.1.*'
# GH16:3.2.1.6-GH16:3.2.1.73 'GH16:3.2.1.6-GH16:3.2.1.73'
# GH5:3.2.1.149 'GH5:3.2.1.149'
# GH45:3.2.1.4 'GH45:3.2.1.4'
# AA1:1.10.3.2 'AA1:1.10.3.2'
# GT57:2.4.1.* 'GT57:2.4.1.*'
#  ''
# GH12:3.2.1.151 'GH12:3.2.1.151'
# GH72:2.4.1.* 'GH72:2.4.1.*'
# GH28:3.2.1.171 'GH28:3.2.1.171'
# GH5:3.2.1.58 'GH5:3.2.1.58'
# GH76:3.2.1.101 'GH76:3.2.1.101'
# GH16:2.4.1.*&3.2.1.*-GH16:3.2.1.39 'GH16:2.4.1.*&3.2.1.*-GH16:3.2.1.39'
# GT4:2.4.1.132&2.4.1.257 'GT4:2.4.1.132&2.4.1.257'
#  ''
#  ''
# GH78:3.2.1.174-GH78:3.2.1.40 'GH78:3.2.1.174-GH78:3.2.1.40'
# AA3:Unknown 'AA3:Unknown'
# GT1:2.4.1.173 'GT1:2.4.1.173'
# GH78:3.2.1.174 'GH78:3.2.1.174'
#  ''
# GT71:2.4.1.* 'GT71:2.4.1.*'
# AA5:1.1.3.9 'AA5:1.1.3.9'
# CE5:3.1.1.74 'CE5:3.1.1.74'
# AA3:Unknown 'AA3:Unknown'
#  ''
#  ''
#  ''
# GH28:3.2.1.15 'GH28:3.2.1.15'
# GH28:3.2.1.15 'GH28:3.2.1.15'
# GH28:3.2.1.15 'GH28:3.2.1.15'
# GH28:3.2.1.15 'GH28:3.2.1.15'
# GH28:3.2.1.15 'GH28:3.2.1.15'
#  ''
# GH28:3.2.1.15 'GH28:3.2.1.15'
# CE8:3.1.1.11 'CE8:3.1.1.11'
# GT71:2.4.1.* 'GT71:2.4.1.*'
# PL1:4.2.2.2 'PL1:4.2.2.2'
# GH5:3.2.1.4 'GH5:3.2.1.4'
#  ''
#  ''
#  ''
#  ''
# AA1:1.10.3.2 'AA1:1.10.3.2'
# GH51:3.2.1.55 'GH51:3.2.1.55'
#  ''
#  ''
#  ''
# GH72:2.4.1.* 'GH72:2.4.1.*'
# CE9:3.5.1.25 'CE9:3.5.1.25'
#  ''
# GH62:3.2.1.55 'GH62:3.2.1.55'
# CE5:3.1.1.72 'CE5:3.1.1.72'
# GT1:2.4.1.173 'GT1:2.4.1.173'
#  ''
# GH47:3.2.1.113 'GH47:3.2.1.113'
# CE1:3.1.1.72 'CE1:3.1.1.72'
# AA3:1.1.99.18 'AA3:1.1.99.18'
# GH11:3.2.1.8 'GH11:3.2.1.8'
# GH71:3.2.1.59 'GH71:3.2.1.59'
# GT57:2.4.1.* 'GT57:2.4.1.*'
# GH13:2.4.1.18 'GH13:2.4.1.18'
# GH13:2.4.1.18 'GH13:2.4.1.18'
# GT3:2.4.1.11 'GT3:2.4.1.11'
# GH3:3.2.1.21 'GH3:3.2.1.21'
# GH16:2.4.1.*&3.2.1.*-GH16:3.2.1.39 'GH16:2.4.1.*&3.2.1.*-GH16:3.2.1.39'
# CE5:3.1.1.74 'CE5:3.1.1.74'
# AA9:1.*.*.* 'AA9:1.*.*.*'
#  ''
# GT39:2.4.1.109 'GT39:2.4.1.109'
# GT35:2.4.1.1 'GT35:2.4.1.1'
# GT59:2.4.1.256 'GT59:2.4.1.256'
#  ''
# GH72:2.4.1.* 'GH72:2.4.1.*'
# GH76:3.2.1.101 'GH76:3.2.1.101'
# GT1:2.4.1.173 'GT1:2.4.1.173'
# GH71:3.2.1.59 'GH71:3.2.1.59'
# GT69:2.4.1.* 'GT69:2.4.1.*'
# GH18:3.2.1.14 'GH18:3.2.1.14'
# GH63:3.2.1.106 'GH63:3.2.1.106'
# GH5:3.2.1.4 'GH5:3.2.1.4'
#  ''
# GH1:3.2.1.21&3.2.1.23 'GH1:3.2.1.21&3.2.1.23'
# GH16:3.2.1.6-GH16:3.2.1.73 'GH16:3.2.1.6-GH16:3.2.1.73'
#  ''
# GH47:3.2.1.113 'GH47:3.2.1.113'
# GH47:3.2.1.113 'GH47:3.2.1.113'
# GH32:3.2.1.7 'GH32:3.2.1.7'

# %% [markdown]
# The above shows that when no EC number is predicted an empty string is provided (in the same manner as discussed when retrieving the predicted CAZy subfamily). It is better to store missing data as a null value instead. Furthermore, sometimes instead of writing out an empty string the word 'Unknown' is written out. For standardisation of the output this to will be converted to a null value.
#
# Additionally, it is more common practise to annotate missing digits in an EC number with `-` rather than `*`. Changing `*` or `-` would also bring the EC number output from CUPP in line with the other CAZyme prediction tools.
#
# For human readability, when multiple EC numbers are predicted, the '&' will be changed to separate the EC numbers by a comma and match the formating of presenting multiple predicted CAZy subfamilies.
#
# Another issue with the retrieval of the predicted EC numbers is that the above method does not retrieval _all_ predicted EC numbers. If multiple EC numbers are predicted these predictions may be separated by '-'.
#
# For example, protein XP_001561324.1 BCIN_01g06010, has the following output in the log file:
# ```
# ['XP_001561324.1 BCIN_01g06010', 'GH16', 'GH16:21.1', '14.8', '4.11', '123', '89..206', '56', 'GH16:2.4.1.*&3.2.1.*-GH16:3.2.1.39', 'GH16:2.4.1.*&3.2.1.*-GH16:3.2.1.39', '']
# ```
# Where, `GH16:2.4.1.*&3.2.1.*-GH16:3.2.1.39` and `GH16:2.4.1.*&3.2.1.*-GH16:3.2.1.39`, contain multiple listed EC numbers, separated by '-'.
#
# Therefore, additional checks for multiple predicated EC numbers and quality checking of EC number formating to ensure only the EC number is retrieved was added to the method of parsing the log file.
#
# The below examples look at the first few lines to highlight some important examples of data.

# %%
for line in log_file[462:]:
    # separate the data fields
    prediction_output = line.split("\t")
    
    # retrieve the predicted EC number
    ec_data = prediction_output[-2].split(":")

    if len(ec_data) == 1:  # no EC number predicted
        ec_number = np.nan

    elif len(ec_data) == 2:
        # element 0 is the CAZy family
        all_ec_numbers = []
        ec_split = ec_data[1].split("&")  # if multiple EC numbers are predicted, separate them

        for item in ec_split:
            # check formating, somtimes 'Unknown' is written in stead of an EC number
            try:
                re.match(r"\d+?\.(\d+?|\*)\.(\d+?|\*)\.(\d+?|\*)", item)
                item = item.replace("*","-")  # standardise missing digit format
            except AttributeError:
                pass
            all_ec_numbers.append(item)

        if len(all_ec_numbers) == 0:
            ec_number = np.nan
        else:
            ec_number = ", ".join(all_ec_numbers)
        print("Checking EC# parsing\nec_split=", ec_split, "\nall_ec_numbers=", all_ec_numbers, "\nec_number=", ec_number)
# Out:
# Checking EC# parsing
# ec_split= ['2.4.1.109']
# all_ec_numbers= ['2.4.1.109']
# ec_number= 2.4.1.109
# Checking EC# parsing
# ec_split= ['2.4.1.1']
# all_ec_numbers= ['2.4.1.1']
# ec_number= 2.4.1.1
# Checking EC# parsing
# ec_split= ['2.4.1.256']
# all_ec_numbers= ['2.4.1.256']
# ec_number= 2.4.1.256
# Checking EC# parsing
# ec_split= ['2.4.1.*']
# all_ec_numbers= ['2.4.1.-']
# ec_number= 2.4.1.-
# Checking EC# parsing
# ec_split= ['3.2.1.101']
# all_ec_numbers= ['3.2.1.101']
# ec_number= 3.2.1.101
# Checking EC# parsing
# ec_split= ['2.4.1.173']
# all_ec_numbers= ['2.4.1.173']
# ec_number= 2.4.1.173
# Checking EC# parsing
# ec_split= ['3.2.1.59']
# all_ec_numbers= ['3.2.1.59']
# ec_number= 3.2.1.59
# Checking EC# parsing
# ec_split= ['2.4.1.*']
# all_ec_numbers= ['2.4.1.-']
# ec_number= 2.4.1.-
# Checking EC# parsing
# ec_split= ['3.2.1.14']
# all_ec_numbers= ['3.2.1.14']
# ec_number= 3.2.1.14
# Checking EC# parsing
# ec_split= ['3.2.1.106']
# all_ec_numbers= ['3.2.1.106']
# ec_number= 3.2.1.106
# Checking EC# parsing
# ec_split= ['3.2.1.4']
# all_ec_numbers= ['3.2.1.4']
# ec_number= 3.2.1.4
# Checking EC# parsing
# ec_split= ['3.2.1.21', '3.2.1.23']
# all_ec_numbers= ['3.2.1.21', '3.2.1.23']
# ec_number= 3.2.1.21, 3.2.1.23
# Checking EC# parsing
# ec_split= ['3.2.1.113']
# all_ec_numbers= ['3.2.1.113']
# ec_number= 3.2.1.113
# Checking EC# parsing
# ec_split= ['3.2.1.113']
# all_ec_numbers= ['3.2.1.113']
# ec_number= 3.2.1.113
# Checking EC# parsing
# ec_split= ['3.2.1.7']
# all_ec_numbers= ['3.2.1.7']
# ec_number= 3.2.1.7

# %% [markdown]
# From this we can define a function to retrieved the predicted EC numbers for the CAZy family that CUPP has listed as the 'Best function' for the protein.

# %%
def get_cupp_ec_number(prediction_output):
    """Retrieve predicted EC numbers from CUPP log file.
    
    EC numbers are represented as "CAZy_fam:EC_number" in the log file.
    If multiple EC numbers are predicated and the CAZy families of each are
    given then these are separated by '-'. If multiple EC numbers are predicated
    for the same CAZy family, these are separated by '&'.
    
    :param prediciton_output: list of items from log file line.
    
    Return string if EC numbers are given, or null value if not.
    """       
    # retrieve the data from the CUPP 'Best function' prediction
    ec_data = prediction_output[-2].split(":")
    
    if len(ec_data) == 1:  # Result of ":" not being present, caused by no EC number predictions
        ec_number = np.nan
        return ec_number

    # create empty list to store all predicted EC numbers
    all_ec_numbers = []

    for item in ec_data:
        # check if the item may be an EC number, which start with a digit
        try:
            re.match(r"\d.+", item).group()
        except AttributeError:  # not an EC number
            continue

        # if multiple best function and/or EC number predictions were made they may
        # be separated by a dash '-'
        dash_separated_data = item.split("-")

        for data in dash_separated_data:
            # if multiple EC numbers are predicated they are separate by '&
            split_data = data.split("&")
            
            for string in split_data:
                # check if the string is an EC number
                try:
                    re.match(r"\d+?\.(\d+?|\*)\.(\d+?|\*)\.(\d+?|\*)", string). group()
                    all_ec_numbers.append(string)
                except AttributeError:  # not an EC number
                    continue
                    
    # standardise missing digits in the EC numbers from '*' to '-'                
    index = 0
    for index in range(len(all_ec_numbers)):
        all_ec_numbers[index] = all_ec_numbers[index].replace("*","-")
        # Sometimes 'Unknown' is written out by CUPP, ensure this is removed
        if all_ec_numbers[index].find("Unknown") != -1:
            all_ec_numbers.remove(all_ec_numbers[index])
                    
    # write out the EC numbers in easy human readable format or create null value if none were predicted
    if len(all_ec_numbers) == 0:
        ec_number = np.nan
    else:
        ec_number = ", ".join(all_ec_numbers) 

    return ec_number

for line in log_file:
    # separate the data fields
    prediction_output = line.split("\t")
    ecs = get_cupp_ec_number(prediction_output)
    print(ecs)
# Out:
# 1.1.3.38
# 2.4.1.117
# nan
# 1.10.3.2
# nan
# nan
# 2.4.1.109
# 2.4.1.16
# 1.-.-.-
# 3.2.1.59
# 3.2.1.59
# 3.2.1.24
# 3.2.1.24
# 2.4.1.16
# 2.4.1.16
# nan
# 3.2.1.113
# nan
# 3.2.1.109
# 3.2.1.-
# 2.4.1.-, 3.2.1.-, 3.2.1.39
# 3.2.1.113
# 3.1.1.-
# 1.10.3.2
# nan
# 3.2.1.67
# nan
# 3.2.1.15
# 3.2.1.-
# 1.10.3.2
# 3.2.1.49
# 3.2.1.-
# 2.4.1.-
# 3.1.1.6
# nan
# 2.4.1.15
# nan
# 3.1.1.74
# nan
# 3.5.1.25
# 2.4.1.25, 3.2.1.33
# 2.4.1.25, 3.2.1.33
# nan
# 3.1.1.74
# nan
# 3.1.1.11
# 3.2.1.-
# nan
# 3.2.1.101
# nan
# 3.2.1.-
# nan
# nan
# nan
# nan
# nan
# 3.2.1.59
# 3.2.1.59
# nan
# 3.2.1.96
# 2.4.1.80
# nan
# nan
# 3.2.1.22, 3.2.1.49
# 3.2.1.4
# 2.4.1.109
# nan
# 1.-.-.-
# 2.4.99.18
# nan
# 1.10.3.2
# 1.10.3.2
# 3.2.1.21, 3.2.1.23
# 2.4.1.131
# nan
# 3.2.1.6, 3.2.1.73
# nan
# nan
# 2.4.1.259, 2.4.1.261
# 2.4.1.-
# 3.2.1.20, 5.4.99.11
# 3.2.1.15
# nan
# nan
# nan
# 2.4.1.34
# 2.4.1.-
# nan
# 3.1.1.-
# 3.2.1.6, 3.2.1.73
# 3.2.1.6, 3.2.1.73
# nan
# 1.10.3.2
# 3.2.1.99
# 3.2.1.101
# 3.2.1.45
# 2.4.1.15
# 3.2.1.-
# 3.2.1.23
# 3.2.1.59
# 4.2.2.10
# nan
# 3.2.1.8
# nan
# 1.1.3.13
# nan
# 3.2.1.78
# nan
# nan
# 3.2.1.15
# 2.4.1.-
# nan
# 3.2.1.22
# nan
# nan
# 3.2.1.8
# nan
# 3.2.1.151
# 3.1.1.11
# nan
# 3.2.1.4
# 2.4.1.-
# nan
# 3.1.1.11
# 3.2.1.39
# nan
# nan
# 4.2.2.2
# 1.-.-.-
# 2.4.1.-
# nan
# 2.4.1.-, 2.4.2.-
# nan
# nan
# nan
# 3.2.1.3
# 3.2.1.59
# 4.2.2.2
# 2.4.1.-
# nan
# nan
# 2.4.1.16
# 3.2.1.3
# 3.2.1.3
# 3.2.1.15
# 3.2.1.23
# 2.4.1.-
# nan
# nan
# 2.4.1.131
# 3.2.1.99
# 3.2.1.113
# 3.2.1.25
# 3.2.1.39
# 2.4.1.173
# nan
# nan
# nan
# 3.2.1.67
# nan
# 2.4.1.-
# nan
# 1.10.3.2
# nan
# nan
# 2.4.1.-
# 1.1.3.-
# nan
# 3.2.1.8
# 1.1.99.18
# nan
# nan
# 3.2.1.39
# nan
# 3.2.1.101
# 3.2.1.-, 3.2.1.131
# nan
# 3.2.1.67
# nan
# 3.2.1.50
# 2.4.1.-
# 2.4.1.-
# 2.4.1.173
# 1.-.-.-
# nan
# nan
# 3.2.1.58
# 1.1.3.-
# nan
# nan
# nan
# 3.2.1.145
# 3.2.1.-, 3.2.1.31
# nan
# 3.2.1.40
# 2.4.1.-
# 3.2.1.-
# 3.2.1.101
# nan
# 3.1.1.6
# nan
# nan
# nan
# 3.2.1.113
# 3.2.1.75
# 3.2.1.21
# 3.2.1.177
# 1.-.-.-
# 3.2.1.39
# 2.4.1.-
# 2.4.1.131
# 3.2.1.113
# 3.2.1.-
# 3.2.1.-
# 1.6.5.6
# 3.1.1.6
# 3.2.1.40
# nan
# nan
# nan
# 1.-.-.-
# 2.4.1.142
# 3.2.1.59
# 3.2.1.14
# 2.4.1.-, 2.4.2.-
# 2.4.1.-
# 3.2.1.14
# 3.1.3.12
# 3.1.3.12
# 3.1.3.12
# 3.1.1.74
# 2.4.1.16
# nan
# nan
# 3.2.1.3
# 3.2.1.3
# 3.2.1.164
# 3.2.1.59
# 3.2.1.58
# nan
# 2.4.1.-
# 2.4.1.-
# 2.4.1.-
# 1.1.3.13
# 3.1.1.6
# 3.2.1.35
# 3.2.1.35
# 1.-.-.-
# nan
# nan
# nan
# 3.2.1.52
# 3.2.1.52
# 2.4.1.-, 3.2.1.-, 3.2.1.39
# nan
# nan
# 3.2.1.113
# 3.2.1.113
# nan
# 3.2.1.-
# 3.2.1.21
# 3.2.1.21
# 3.2.1.63
# 1.10.3.2
# nan
# 3.2.1.37
# 2.4.1.173
# 2.4.1.-, 2.4.2.-
# 3.2.1.55
# 2.4.1.-
# nan
# nan
# nan
# nan
# nan
# 3.2.1.4
# nan
# nan
# 2.4.1.-
# 2.4.1.-
# 3.1.1.11
# 1.10.3.2
# 4.2.2.10
# 2.4.1.-
# nan
# nan
# nan
# nan
# 2.4.1.131
# 3.2.1.6
# 3.2.1.63
# 2.4.1.-
# 3.2.1.101
# 3.2.1.89
# nan
# 3.2.1.14
# 3.2.1.14
# 3.2.1.101
# nan
# nan
# 3.2.1.-
# 3.2.1.-
# 2.4.1.16
# 3.2.1.28
# nan
# nan
# 3.2.1.39
# 1.10.3.2
# 3.2.1.101
# nan
# 2.4.1.173
# nan
# 3.2.1.6, 3.2.1.73
# 1.1.3.9
# 1.1.3.9
# nan
# 3.2.1.55
# 3.2.1.28
# nan
# 3.2.1.6, 3.2.1.73
# 1.10.3.2
# 1.10.3.2
# 1.10.3.2
# nan
# nan
# 2.4.1.-
# 1.-.-.-
# 1.-.-.-
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 3.2.1.58
# 3.2.1.58
# nan
# nan
# 2.4.1.186
# 3.2.1.21
# nan
# 3.2.1.185
# nan
# nan
# 3.2.1.171
# nan
# nan
# 4.2.2.2
# nan
# 3.2.1.26
# 3.2.1.40
# 3.2.1.21
# nan
# 3.2.1.58
# nan
# 2.4.1.83
# nan
# 3.2.1.23
# nan
# nan
# nan
# 2.4.2.40
# 1.-.-.-
# 3.2.1.20
# nan
# 3.2.1.23
# 2.4.1.131
# 3.2.1.78
# 3.2.1.171
# nan
# 2.4.1.16
# 2.4.1.16
# nan
# 3.2.1.39
# 3.2.1.-
# nan
# 2.4.1.-
# nan
# nan
# 1.1.99.18
# nan
# 3.2.1.3
# nan
# 1.-.-.-
# 3.2.1.173
# 2.4.1.258
# nan
# 3.2.1.4
# 2.4.1.16
# 2.4.1.16
# nan
# nan
# 3.2.1.-
# 3.2.1.6, 3.2.1.73
# 3.2.1.149
# 3.2.1.4
# 1.10.3.2
# 2.4.1.-
# nan
# 3.2.1.151
# 2.4.1.-
# 3.2.1.171
# 3.2.1.58
# 3.2.1.101
# 2.4.1.-, 3.2.1.-, 3.2.1.39
# 2.4.1.132, 2.4.1.257
# nan
# nan
# 3.2.1.174, 3.2.1.40
# nan
# 2.4.1.173
# 3.2.1.174
# nan
# 2.4.1.-
# 1.1.3.9
# 3.1.1.74
# nan
# nan
# nan
# nan
# 3.2.1.15
# 3.2.1.15
# 3.2.1.15
# 3.2.1.15
# 3.2.1.15
# nan
# 3.2.1.15
# 3.1.1.11
# 2.4.1.-
# 4.2.2.2
# 3.2.1.4
# nan
# nan
# nan
# nan
# 1.10.3.2
# 3.2.1.55
# nan
# nan
# nan
# 2.4.1.-
# 3.5.1.25
# nan
# 3.2.1.55
# 3.1.1.72
# 2.4.1.173
# nan
# 3.2.1.113
# 3.1.1.72
# 1.1.99.18
# 3.2.1.8
# 3.2.1.59
# 2.4.1.-
# 2.4.1.18
# 2.4.1.18
# 2.4.1.11
# 3.2.1.21
# 2.4.1.-, 3.2.1.-, 3.2.1.39
# 3.1.1.74
# 1.-.-.-
# nan
# 2.4.1.109
# 2.4.1.1
# 2.4.1.256
# nan
# 2.4.1.-
# 3.2.1.101
# 2.4.1.173
# 3.2.1.59
# 2.4.1.-
# 3.2.1.14
# 3.2.1.106
# 3.2.1.4
# nan
# 3.2.1.21, 3.2.1.23
# 3.2.1.6, 3.2.1.73
# nan
# 3.2.1.113
# 3.2.1.113
# 3.2.1.7

# %% [markdown]
# <a id="cupp_subfam"></a>

# %% [markdown]
# ### Getting the predicted CAZy subfamily
#
# Sometimes when no subfamily is predicted, an empty string is written out the output log file. However, it is better if the resulting Pandas dataframe contains a null value instead.
#
# At this stage we can also create an empty dataframe, to which the data from each parsed protein is added.

# %%
# build an empty dataframe
cupp_df = pd.DataFrame(columns=[
    "protein_accession",
    "cazy_family",
    "cazy_subfamily",
    "ec_number",
    "domain_range",
])

for line in log_file[:10]:
    # separate the data fields
    prediction_output = line.split("\t")
    
    # retrieve the predicted domain range if given
    for item in prediction_output:
        if item.find("..") != -1:
            domain_range = item
            break
        else:
            domain_range = np.nan
    
    # retrieve the predicted EC number
    try:
        ec_number = prediction_output[-2].split(":")[1]
    except IndexError:
        ec_number = np.nan

    # store the prediction output in a dictionary
    prediction = {
        "protein_accession": [prediction_output[0]],
        "cazy_family": [prediction_output[1]],
        "cazy_subfamily": [prediction_output[-1]],
        "ec_number": ec_number,
        "domain_range": [domain_range],
    }

    # if no CAZy subfamily was predicted, change empty string to null value
    if len(prediction["cazy_subfamily"][0]) == 0:
        prediction["cazy_subfamily"][0] = np.nan

    # create dataframe to represent the current working protein
    prediction_df = pd.DataFrame(prediction)
    # add protein to CUPP dataframe
    cupp_df = cupp_df.append(prediction_df)

cupp_df
# Out:
#               protein_accession cazy_family cazy_subfamily  ec_number  \
# 0  XP_001545605.1 BCIN_01g00260         AA4            NaN   1.1.3.38
# 0  XP_024545922.1 BCIN_01g00340         GT2            NaN  2.4.1.117
# 0  XP_001547235.1 BCIN_01g00640         AA3          AA3_1        NaN
# 0  XP_001547254.1 BCIN_01g00800         AA1          AA1_3   1.10.3.2
# 0  XP_024546029.1 BCIN_01g01760        GH18            NaN        NaN
# 0  XP_024546029.1 BCIN_01g01760         PL7          PL7:2        NaN
# 0  XP_001548518.1 BCIN_01g02310        GT39            NaN  2.4.1.109
# 0  XP_001548545.1 BCIN_01g02520         GT2            NaN   2.4.1.16
# 0  XP_001549934.1 BCIN_01g02970        AA11            NaN    1.*.*.*
# 0  XP_024546135.1 BCIN_01g03210        GH71            NaN   3.2.1.59
#
#   domain_range
# 0     122..568
# 0     116..300
# 0      26..553
# 0     202..455
# 0     116..258
# 0    989..1040
# 0      62..264
# 0     213..452
# 0      55..160
# 0      71..381

# %% [markdown]
# <a id="cupp_std_subfam"></a>

# %% [markdown]
# ### Standardising CAZy subfamilies (PL7:2)
#
# Sometimes the CAZy subfamily is not written in the standard CAZy format of family_subfam#. For example, for protein "XP_024546029.1 BCIN_01g01760" the CAZy subfamily is listed as 'PL7:2'.
#
# Looking further through the CUPP output log file, there are several instances of a this occuring, and often occuring for CAZy families for which CAZy has not created a subfamily with number outputted by CUPP. For example, protein XP_001549864.1 BCIN_03g07360 is predicted to have the subfamily 'PL1:4', however, there is not CAZy subfamily 'PL1:4'.
#
# It was hypothesised that listing a CAZy subfamily with a colon instead of the traditional CAZy underscore was done to indicate when the predict CAZy subfamily is one created by CUPP and is not in CAZy.
#
# Looking at lines 2890 and 2914 in the `CUPP.CUPPprediction.py` script, the `:` in the predicated subfamily is replaced by `_` when writing the output FASTA file. Therefore, the predicted CAZy subfamily is written as 'PL7_2' in the output FASTA file. However, in line 2909, when writing out to the log file, the replacement of `:` to `_` is not performed. Hence, the predicted CAZy subfamily is written as 'PL7:2' in the output log file.
#
# For standardistion, the colon in the predicted CAZy subfamily was changed to an underscore.
#
# Moreover, when looking through the log file, multiple subfamilies can be predicted for a given protein. These subfamilies are separated by '+'. To improve human readability this was changed to separate the subfamilies by commas (', '). For example, CUPP's analysis of protein sequences from the genome GCA143535.1 predicted two CAZy subfamilies within the GH13 CAZyme domain of the protein XP_001552718.2.
# `XP_001552718.2 BCIN_02g05690	GH13	GH13:0.2	15.7	5.93	151	70..391	76	GH13:3.2.1.10&3.2.1.20	GH13:3.2.1.20-GH13:5.4.99.11	GH13:31+GH13:40`

# %%
for line in log_file[:10]:
    # separate the data fields
    prediction_output = line.split("\t")

    # retrieve predicated CAZy subfamily
    subfam = prediction_output[-1] 
    # if no CAZy subfamily was predicted, change empty string to null value
    if len(subfam) == 0:
        subfam = np.nan
    else:
        # write subfamilies using CAZy standard format
        subfam = subfam.replace(":","_")
        subfam = subfam.replace("+", ", ")  # separate multiple subfams with ', ' not '+'

    print("subfam=", subfam)
# Out:
# subfam= nan
# subfam= nan
# subfam= AA3_1
# subfam= AA1_3
# subfam= nan
# subfam= PL7_2
# subfam= nan
# subfam= nan
# subfam= nan
# subfam= nan

# %% [markdown]
# <a id="cupp_functions"></a>

# %% [markdown]
# ### Combing functions and populating the data model, and adding non-CAZymes
#
# The above can be combined into functions, that are then included in `pyrewton.cazymes.prediction.parse`. When it comes to evaluating CUPP's performance when differentiating between CAZymes and non-CAZymes, a binary classification of CAZymes (1) and non-CAZyme (0) is needed for each protein. If a protein is included in the CUPP output CUPP has predicted that the protein is a CAZyme, and thus an additional column with a value of 1 can be added to the standardised CUPP output, to represent the cazyme/non-cazyme classification of proteins by CUPP.
#
# For the evaluation CUPP's performance the information of none CAZymes is also needed. CUPP only includes the data for proteins in it's log file that have classified as CAZymes therefore, the remaining protein sequences are retrieved from the FASTA file.

# %%
def parse_cupp_output(log_file_path, fasta_path):
    """Parse the output log file from CUPP and write out a dataframe.
    
    Retrieves the protein accession, predicted CAZy families, CAZy families EC
    numbers and domain ranges.
    
    :param log_file_path: Path, path to the output log file
    :fasta path: Path, path to the FASTA containing the query sequences for CUPP
    
    Return a list of CUPPprediction instances, where each instance represented one protein.
    """
    # open the CUPP output log file
    with open(log_file_path, "r") as lfh:
        log_file = lfh.read().splitlines()
    
    cupp_predictions = {}  # stores proteins {protein_accession:CUPPprediction_instance}

    for line in tqdm(log_file, desc="parsing cupp output"):
        # separate the data fields
        prediction_output = line.split("\t")

        # retrieve the predicted domain range if given
        domain_range = get_cupp_domain_range(prediction_output)  # list of strs
        
        # retrieve predicted EC number if given
        ec_numbers = get_cupp_ec_number(prediction_output)  # list of strs
        
        # retrieve predicted CAZy subfamily if given
        cazy_subfamily = prediction_output[-1] 
        # if no CAZy subfamily was predicted, change empty string to null value
        if len(cazy_subfamily) == 0:
            cazy_subfamily = np.nan
        else:
            # write subfamilies using CAZy standard format
            cazy_subfamily = cazy_subfamily.replace(":","_")
            cazy_subfamily = cazy_subfamily.replace("+", ", ")  # separate multiple subfams with ', ' not '+'

        # retrieve the protein accession and check if it already has a corresponding CUPPprediction instance
        protein_accession = prediction_output[0]

        # retrieve the CAZyme classification and predicted CAZy family
        cazyme_classification = 1  # all proteins included in CUPP log file are identified as CAZymes
        cazy_family = prediction_output[1]  # This is selected from the CUPP 'Best function'
        
        # check if a CUPPprediction instance already exists for the protein
        try:
            existing_prediction = cupp_predictions[protein_accession]
            print("existing=", existing_prediction)
            
            # check if the CAZyme domain has been been parsed before
            print("existing domains=", len(existing_prediction.cazyme_domains), existing_prediction.cazyme_domains)
            existing_cazyme_domains = existing_prediction.cazyme_domains
            
            existance = False
            for domain in existing_cazyme_domains:
                if (domain.cazy_family == cazy_family) and (domain.cazy_subfamily == cazy_subfamily):
                    for ec in ec_numbers:
                            domain.ec_numbers.append(ec)
                    for drange in domain_range:
                            domain.domain_range.append(drange)
                    existance = True
            
            if existance is False:
                # create new CAZyme domain
                new_cazyme_domain = CazymeDomain(
                    protein_accession,
                    cazy_family,
                    cazy_subfamily,
                    ec_numbers,
                    domain_range,
                )
                existing_prediction.cazyme_domains.append(new_cazyme_domain)
        
        except KeyError:  # raised if there is not instance for the protein

            new_cazyme_domain = CazymeDomain(
                protein_accession,
                cazy_family,
                cazy_subfamily,
                ec_numbers,
                domain_range,
            )
            
            new_protein = CazymeProteinPrediction(
                "CUPP",
                protein_accession,
                cazyme_classification,
                [new_cazyme_domain],
            )
            
            cupp_predictions[protein_accession] = new_protein
    
    print("len1=", len(list(cupp_predictions.values())))

    # add non-CAZymes
    cupp_predictions = add_non_cazymes(fasta_path, cupp_predictions)
    
    cupp_predictions = list(cupp_predictions.values())

    return cupp_predictions


def get_cupp_domain_range(prediction_output):
    """Retrieve the predicted amino acid range of predicted CAZyme domain from CUPP log file.
    
    :param prediction_output: list of items from log file line.
    
    List of predicted domain ranges or null value in a list if not.
    """
    domain_range = []  # store as a list in case multiple domain ranges are given

    for item in prediction_output:
        if item.find("..") != -1:
            domain_range.append(item)

    # check retrieved items are definetly the domain ranges
    for item in domain_range:
        try:
            re.match(r"\d+\.\.\d+", item).group()
        except AttributeError:
            # write as logger in pyrewton
            print(f"RAISED ATTRIBUTE ERROR: {item} misidentified as domain range")
            domain_range.remove(item)

    if len(domain_range) == 0:
        domain_range = [np.nan]
    
    return domain_range


def get_cupp_ec_number(prediction_output):
    """Retrieve predicted EC numbers from CUPP log file.
    
    EC numbers are represented as "CAZy_fam:EC_number" in the log file.
    If multiple EC numbers are predicated and the CAZy families of each are
    given then these are separated by '-'. If multiple EC numbers are predicated
    for the same CAZy family, these are separated by '&'.
    
    :param prediciton_output: list of items from log file line.
    
    List of predicted EC numbers or null value in a list if not.
    """       
    # retrieve the data from the CUPP 'Best function' prediction
    ec_data = prediction_output[-2].split(":")
    
    if len(ec_data) == 1:  # Result of ":" not being present, caused by no EC number predictions
        ec_number = np.nan
        return ec_number

    # create empty list to store all predicted EC numbers
    all_ec_numbers = []

    for item in ec_data:
        # check if the item may be an EC number, which start with a digit
        try:
            re.match(r"\d.+", item).group()
        except AttributeError:  # not an EC number
            continue

        # if multiple best function and/or EC number predictions were made they may
        # be separated by a dash '-'
        dash_separated_data = item.split("-")

        for data in dash_separated_data:
            # if multiple EC numbers are predicated they are separate by '&
            split_data = data.split("&")
            
            for string in split_data:
                # check if the string is an EC number
                try:
                    re.match(r"\d+?\.(\d+?|\*)\.(\d+?|\*)\.(\d+?|\*)", string). group()
                    all_ec_numbers.append(string)
                except AttributeError:  # not an EC number
                    continue
                    
    # standardise missing digits in the EC numbers from '*' to '-'                
    index = 0
    for index in range(len(all_ec_numbers)):
        all_ec_numbers[index] = all_ec_numbers[index].replace("*","-")
        # Sometimes 'Unknown' is written out by CUPP, ensure this is removed
        if all_ec_numbers[index].find("Unknown") != -1:
            all_ec_numbers.remove(all_ec_numbers[index])
                    
    # write out the EC numbers in easy human readable format or create null value if none were predicted
    if len(all_ec_numbers) == 0:
        all_ec_numbers = [np.nan]

    return all_ec_numbers


def add_non_cazymes(fasta_path, cupp_predictions):
    """Add proteins that CUPP identified as non-CAZymes to the collection of CUPPprediction instances.
    
    :param fasta_path: Path, FASTA file used as input for CUPP.
    :param cupp_predictions: dict, key=protein_accession, value=CUPPprediction instance
    
    Return a dictionary valued by protein accessions and keyed by their respective CUPPprediction instance.
    """
    print("len=", len(list(cupp_predictions.values())))
    # open the FASTA path
    with open(fasta_path) as fh:
        fasta = fh.read().splitlines()

    for line in tqdm(fasta, desc="Adding non-CAZymes"):
        if line.startswith(">"):
            protein_accession = line[1:].strip()
            
            # check if the protein has been listed as a CAZyme by CUPP
            try:
                cupp_predictions[protein_accession]
            except KeyError:
                # raised if protein not in cupp_predictions, inferring proten was not labelled as CAZyme
                cazyme_classification = 0
                cupp_predictions[protein_accession] = CazymeProteinPrediction(
                    "CUPP",
                    protein_accession,
                    cazyme_classification,
                )
        
    return cupp_predictions
    

fasta_path = "genbank_proteins_txid73501_GCA_008080495_1.fasta"
result = parse_cupp_output("gca_008080495_cupp.fasta.log", fasta_path)

print("type=", type(result))
print("len=", len(result))
print("index 0=", result[0])

for i in result:
    print(i)
# Out:
# HBox(children=(HTML(value='parsing cupp output'), FloatProgress(value=0.0, max=282.0), HTML(value='')))
# existing= -CazymeProteinPrediction, protein=ATY67037.1 A9K55_000868, CAZyme domains=1-
# existing domains= 1 [<CazymeDomain parent=GT41 fam=nan, subfam=nan>]
# existing= -CazymeProteinPrediction, protein=ATY61276.1 A9K55_005467, CAZyme domains=1-
# existing domains= 1 [<CazymeDomain parent=GH13 fam=GH13_25, subfam=['2.4.1.25', '3.2.1.33']>]
# existing= -CazymeProteinPrediction, protein=ATY62702.1 A9K55_007186, CAZyme domains=1-
# existing domains= 1 [<CazymeDomain parent=CE3 fam=nan, subfam=nan>]
#
# len1= 279
# len= 279
# HBox(children=(HTML(value='Adding non-CAZymes'), FloatProgress(value=0.0, max=93219.0), HTML(value='')))
# type= <class 'list'>
# len= 9287
# index 0= -CazymeProteinPrediction, protein=ATY67280.1 A9K55_000020, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY67280.1 A9K55_000020, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY67467.1 A9K55_000078, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY67289.1 A9K55_000120, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY67290.1 A9K55_000123, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY67196.1 A9K55_000147, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY67226.1 A9K55_000162, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY67472.1 A9K55_000170, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY67327.1 A9K55_000335, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY67309.1 A9K55_000364, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY67094.1 A9K55_000365, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY67306.1 A9K55_000368, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY67468.1 A9K55_000369, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY67182.1 A9K55_000377, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY67425.1 A9K55_000448, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY67138.1 A9K55_000458, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66532.1 A9K55_000490, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66529.1 A9K55_000499, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66624.1 A9K55_000551, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66680.1 A9K55_000566, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY67020.1 A9K55_000635, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66542.1 A9K55_000689, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66876.1 A9K55_000707, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66875.1 A9K55_000708, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66476.1 A9K55_000717, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66787.1 A9K55_000725, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66426.1 A9K55_000730, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66848.1 A9K55_000810, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66850.1 A9K55_000812, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66859.1 A9K55_000837, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY67037.1 A9K55_000868, CAZyme domains=2-
# -CazymeProteinPrediction, protein=ATY66491.1 A9K55_000968, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66664.1 A9K55_000997, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66615.1 A9K55_001055, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66603.1 A9K55_001057, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66516.1 A9K55_001083, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66509.1 A9K55_001088, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66936.1 A9K55_001125, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66592.1 A9K55_001130, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66444.1 A9K55_001136, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65680.1 A9K55_001196, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65896.1 A9K55_001225, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65915.1 A9K55_001243, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65374.1 A9K55_001258, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66369.1 A9K55_001372, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65772.1 A9K55_001383, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65765.1 A9K55_001438, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66259.1 A9K55_001445, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66100.1 A9K55_001509, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66055.1 A9K55_001568, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66268.1 A9K55_001628, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65888.1 A9K55_001650, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66193.1 A9K55_001662, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66192.1 A9K55_001663, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66363.1 A9K55_001686, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65484.1 A9K55_001719, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65579.1 A9K55_001757, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65637.1 A9K55_001791, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65808.1 A9K55_001888, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65544.1 A9K55_001962, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65455.1 A9K55_002001, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65626.1 A9K55_002055, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65556.1 A9K55_002072, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65449.1 A9K55_002120, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65604.1 A9K55_002147, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY58674.1 A9K55_002216, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY59781.1 A9K55_002229, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY59031.1 A9K55_002235, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY59023.1 A9K55_002239, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY59638.1 A9K55_002266, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY58902.1 A9K55_002275, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY58512.1 A9K55_002300, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY58705.1 A9K55_002399, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY59065.1 A9K55_002427, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY58448.1 A9K55_002445, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY59188.1 A9K55_002493, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY59194.1 A9K55_002495, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY58475.1 A9K55_002501, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY58478.1 A9K55_002502, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY59714.1 A9K55_002507, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY59688.1 A9K55_002509, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY58330.1 A9K55_002569, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY58880.1 A9K55_002660, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY59363.1 A9K55_002695, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY58636.1 A9K55_002806, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY58965.1 A9K55_002873, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY59250.1 A9K55_003000, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY59185.1 A9K55_003013, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY58486.1 A9K55_003070, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY58571.1 A9K55_003088, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY59691.1 A9K55_003110, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY59698.1 A9K55_003119, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY58848.1 A9K55_003123, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY58531.1 A9K55_003145, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY58528.1 A9K55_003146, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY59525.1 A9K55_003304, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY59202.1 A9K55_003353, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY58396.1 A9K55_003368, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY59093.1 A9K55_003437, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY58895.1 A9K55_003453, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY58949.1 A9K55_003474, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY58781.1 A9K55_003492, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY58494.1 A9K55_003598, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY58323.1 A9K55_003619, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY59671.1 A9K55_003678, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY58803.1 A9K55_003729, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY58579.1 A9K55_003748, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64150.1 A9K55_003806, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65185.1 A9K55_003819, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65020.1 A9K55_003841, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64517.1 A9K55_003852, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64047.1 A9K55_003887, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64671.1 A9K55_003892, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65223.1 A9K55_003996, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64043.1 A9K55_004035, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63999.1 A9K55_004051, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64478.1 A9K55_004080, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64479.1 A9K55_004081, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65106.1 A9K55_004092, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64248.1 A9K55_004102, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64179.1 A9K55_004244, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64503.1 A9K55_004410, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65081.1 A9K55_004414, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64461.1 A9K55_004439, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63982.1 A9K55_004448, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64570.1 A9K55_004478, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65116.1 A9K55_004517, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64088.1 A9K55_004548, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64005.1 A9K55_004587, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64015.1 A9K55_004633, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64012.1 A9K55_004638, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64437.1 A9K55_004647, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63856.1 A9K55_004657, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65191.1 A9K55_004703, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64416.1 A9K55_004740, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65055.1 A9K55_004754, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64233.1 A9K55_004845, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64186.1 A9K55_004865, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64187.1 A9K55_004866, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64188.1 A9K55_004867, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65205.1 A9K55_004870, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63987.1 A9K55_004917, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65212.1 A9K55_004964, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64700.1 A9K55_005048, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64850.1 A9K55_005139, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64843.1 A9K55_005141, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64752.1 A9K55_005144, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64802.1 A9K55_005156, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64693.1 A9K55_005188, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64695.1 A9K55_005189, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64918.1 A9K55_005214, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64919.1 A9K55_005215, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64924.1 A9K55_005237, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64774.1 A9K55_005248, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64941.1 A9K55_005307, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64953.1 A9K55_005326, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64976.1 A9K55_005332, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61215.1 A9K55_005410, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60550.1 A9K55_005457, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61276.1 A9K55_005467, CAZyme domains=2-
# -CazymeProteinPrediction, protein=ATY60491.1 A9K55_005473, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60162.1 A9K55_005494, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60851.1 A9K55_005503, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60239.1 A9K55_005612, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60504.1 A9K55_005694, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY59950.1 A9K55_005726, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60772.1 A9K55_005735, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60733.1 A9K55_005759, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60620.1 A9K55_005793, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60372.1 A9K55_005930, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60094.1 A9K55_005934, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60408.1 A9K55_005935, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60044.1 A9K55_005991, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60878.1 A9K55_005992, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY59933.1 A9K55_006003, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60662.1 A9K55_006052, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY59890.1 A9K55_006062, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60591.1 A9K55_006069, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61301.1 A9K55_006085, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60251.1 A9K55_006130, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60133.1 A9K55_006186, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61140.1 A9K55_006190, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY59985.1 A9K55_006197, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY59904.1 A9K55_006242, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60726.1 A9K55_006259, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60246.1 A9K55_006265, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60146.1 A9K55_006444, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60986.1 A9K55_006566, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60976.1 A9K55_006569, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60681.1 A9K55_006585, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61117.1 A9K55_006602, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60613.1 A9K55_006643, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60261.1 A9K55_006695, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61147.1 A9K55_006704, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60186.1 A9K55_006733, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60072.1 A9K55_006792, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61069.1 A9K55_006802, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60330.1 A9K55_006814, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60312.1 A9K55_006832, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60416.1 A9K55_006911, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60629.1 A9K55_006921, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63210.1 A9K55_006963, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61824.1 A9K55_006988, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63573.1 A9K55_007006, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63301.1 A9K55_007013, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63305.1 A9K55_007018, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62740.1 A9K55_007050, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63588.1 A9K55_007112, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62702.1 A9K55_007186, CAZyme domains=2-
# -CazymeProteinPrediction, protein=ATY63228.1 A9K55_007204, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63227.1 A9K55_007205, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61835.1 A9K55_007236, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62798.1 A9K55_007286, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61788.1 A9K55_007308, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62242.1 A9K55_007385, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62132.1 A9K55_007428, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61914.1 A9K55_007445, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62742.1 A9K55_007512, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62663.1 A9K55_007537, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62551.1 A9K55_007577, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61863.1 A9K55_007583, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61865.1 A9K55_007591, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62109.1 A9K55_007617, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63255.1 A9K55_007626, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61595.1 A9K55_007720, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62856.1 A9K55_007728, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61694.1 A9K55_007741, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61893.1 A9K55_007772, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61890.1 A9K55_007781, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63104.1 A9K55_007786, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61850.1 A9K55_007851, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61741.1 A9K55_007939, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63087.1 A9K55_007963, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61965.1 A9K55_007977, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61957.1 A9K55_007981, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62614.1 A9K55_008059, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61576.1 A9K55_008166, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62757.1 A9K55_008177, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62039.1 A9K55_008189, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62092.1 A9K55_008237, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61926.1 A9K55_008281, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63344.1 A9K55_008387, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61753.1 A9K55_008467, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62412.1 A9K55_008485, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63636.1 A9K55_008500, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62684.1 A9K55_008523, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62235.1 A9K55_008585, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62233.1 A9K55_008587, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62465.1 A9K55_008672, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62578.1 A9K55_008696, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63039.1 A9K55_008757, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61678.1 A9K55_008828, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61989.1 A9K55_008846, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63528.1 A9K55_008918, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63601.1 A9K55_008940, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62175.1 A9K55_008949, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63319.1 A9K55_008952, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62278.1 A9K55_008962, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62277.1 A9K55_008963, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63412.1 A9K55_008981, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62020.1 A9K55_008982, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63454.1 A9K55_009028, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63688.1 A9K55_009031, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62564.1 A9K55_009060, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62087.1 A9K55_009066, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62143.1 A9K55_009133, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63360.1 A9K55_009150, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63468.1 A9K55_009166, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62933.1 A9K55_009229, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62385.1 A9K55_009239, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63705.1 A9K55_009247, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63703.1 A9K55_009249, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61355.1 A9K55_009281, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62147.1 A9K55_009282, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62125.1 A9K55_009287, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61851.1 A9K55_009292, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63066.1 A9K55_009341, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61713.1 A9K55_009342, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61718.1 A9K55_009347, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62981.1 A9K55_009358, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY67253.1 A9K55_000001, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67102.1 A9K55_000002, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67103.1 A9K55_000003, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67107.1 A9K55_000004, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67108.1 A9K55_000005, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67105.1 A9K55_000006, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67106.1 A9K55_000007, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67255.1 A9K55_000008, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67256.1 A9K55_000009, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67167.1 A9K55_000010, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67166.1 A9K55_000011, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67168.1 A9K55_000012, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67482.1 A9K55_000013, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67165.1 A9K55_000014, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67164.1 A9K55_000015, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67481.1 A9K55_000016, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67479.1 A9K55_000019, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67282.1 A9K55_000021, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67284.1 A9K55_000022, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67286.1 A9K55_000023, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67277.1 A9K55_000024, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67072.1 A9K55_000025, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67278.1 A9K55_000026, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67279.1 A9K55_000027, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67084.1 A9K55_000028, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67085.1 A9K55_000029, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67337.1 A9K55_000030, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67333.1 A9K55_000031, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67505.1 A9K55_000032, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67504.1 A9K55_000033, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67331.1 A9K55_000034, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67330.1 A9K55_000035, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67329.1 A9K55_000036, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67502.1 A9K55_000037, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67359.1 A9K55_000038, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67358.1 A9K55_000039, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67162.1 A9K55_000040, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67163.1 A9K55_000041, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67160.1 A9K55_000042, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67161.1 A9K55_000043, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67159.1 A9K55_000044, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67344.1 A9K55_000045, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67149.1 A9K55_000046, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67312.1 A9K55_000047, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67429.1 A9K55_000048, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67360.1 A9K55_000049, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67433.1 A9K55_000050, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67432.1 A9K55_000051, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67410.1 A9K55_000052, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67434.1 A9K55_000053, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67412.1 A9K55_000054, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67411.1 A9K55_000055, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67414.1 A9K55_000056, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67413.1 A9K55_000057, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67431.1 A9K55_000058, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67430.1 A9K55_000059, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67270.1 A9K55_000060, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67210.1 A9K55_000061, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67271.1 A9K55_000062, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67213.1 A9K55_000063, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67272.1 A9K55_000064, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67245.1 A9K55_000065, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67273.1 A9K55_000066, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67214.1 A9K55_000067, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67109.1 A9K55_000068, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67110.1 A9K55_000069, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67334.1 A9K55_000070, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67408.1 A9K55_000071, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67407.1 A9K55_000072, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67406.1 A9K55_000073, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67343.1 A9K55_000074, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67113.1 A9K55_000075, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67336.1 A9K55_000076, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67335.1 A9K55_000077, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67086.1 A9K55_000079, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67068.1 A9K55_000080, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67069.1 A9K55_000081, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67066.1 A9K55_000082, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67067.1 A9K55_000083, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67212.1 A9K55_000084, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67070.1 A9K55_000085, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67209.1 A9K55_000086, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67211.1 A9K55_000087, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67208.1 A9K55_000088, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67295.1 A9K55_000089, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67515.1 A9K55_000090, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67257.1 A9K55_000091, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67302.1 A9K55_000092, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67301.1 A9K55_000093, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67298.1 A9K55_000094, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67297.1 A9K55_000095, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67514.1 A9K55_000096, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67299.1 A9K55_000097, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67339.1 A9K55_000098, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67338.1 A9K55_000099, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67263.1 A9K55_000100, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67262.1 A9K55_000101, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67261.1 A9K55_000102, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67260.1 A9K55_000103, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67266.1 A9K55_000104, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67265.1 A9K55_000105, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67098.1 A9K55_000106, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67264.1 A9K55_000107, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67259.1 A9K55_000108, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67258.1 A9K55_000109, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67487.1 A9K55_000110, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67488.1 A9K55_000111, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67489.1 A9K55_000112, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67490.1 A9K55_000113, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67491.1 A9K55_000114, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67492.1 A9K55_000115, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67493.1 A9K55_000116, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67494.1 A9K55_000117, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67485.1 A9K55_000118, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67486.1 A9K55_000119, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67288.1 A9K55_000121, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67449.1 A9K55_000122, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67292.1 A9K55_000124, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67291.1 A9K55_000125, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67293.1 A9K55_000126, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67451.1 A9K55_000127, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67452.1 A9K55_000128, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67294.1 A9K55_000129, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67511.1 A9K55_000130, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67512.1 A9K55_000131, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67509.1 A9K55_000132, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67510.1 A9K55_000133, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67508.1 A9K55_000134, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67375.1 A9K55_000135, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67506.1 A9K55_000136, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67507.1 A9K55_000137, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67513.1 A9K55_000138, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67376.1 A9K55_000139, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67202.1 A9K55_000140, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67201.1 A9K55_000141, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67274.1 A9K55_000142, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67200.1 A9K55_000143, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67089.1 A9K55_000144, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67198.1 A9K55_000145, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67197.1 A9K55_000146, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67206.1 A9K55_000148, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67205.1 A9K55_000149, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67077.1 A9K55_000150, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67078.1 A9K55_000151, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67079.1 A9K55_000152, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67080.1 A9K55_000153, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67073.1 A9K55_000154, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67456.1 A9K55_000155, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67457.1 A9K55_000156, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67458.1 A9K55_000157, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67463.1 A9K55_000158, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67464.1 A9K55_000159, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67236.1 A9K55_000160, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67224.1 A9K55_000161, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67225.1 A9K55_000163, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67223.1 A9K55_000164, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67222.1 A9K55_000165, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67235.1 A9K55_000166, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67234.1 A9K55_000167, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67233.1 A9K55_000168, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67232.1 A9K55_000169, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67473.1 A9K55_000171, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67470.1 A9K55_000172, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67471.1 A9K55_000173, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67476.1 A9K55_000174, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67477.1 A9K55_000175, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67474.1 A9K55_000176, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67475.1 A9K55_000177, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67478.1 A9K55_000178, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67148.1 A9K55_000179, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67131.1 A9K55_000180, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67104.1 A9K55_000181, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67134.1 A9K55_000184, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67133.1 A9K55_000185, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67254.1 A9K55_000186, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67132.1 A9K55_000187, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67136.1 A9K55_000188, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67135.1 A9K55_000189, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67347.1 A9K55_000190, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67348.1 A9K55_000191, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67503.1 A9K55_000192, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67418.1 A9K55_000193, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67419.1 A9K55_000194, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67420.1 A9K55_000195, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67351.1 A9K55_000196, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67422.1 A9K55_000197, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67423.1 A9K55_000198, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67424.1 A9K55_000199, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67392.1 A9K55_000200, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67393.1 A9K55_000201, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67394.1 A9K55_000202, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67395.1 A9K55_000203, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67396.1 A9K55_000204, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67397.1 A9K55_000205, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67398.1 A9K55_000206, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67399.1 A9K55_000207, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67400.1 A9K55_000208, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67401.1 A9K55_000209, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67124.1 A9K55_000210, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67123.1 A9K55_000211, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67122.1 A9K55_000212, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67121.1 A9K55_000213, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67128.1 A9K55_000214, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67127.1 A9K55_000215, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67126.1 A9K55_000216, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67125.1 A9K55_000217, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67130.1 A9K55_000218, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67129.1 A9K55_000219, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67311.1 A9K55_000220, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67207.1 A9K55_000221, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67188.1 A9K55_000222, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67310.1 A9K55_000223, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67307.1 A9K55_000224, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67308.1 A9K55_000225, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67305.1 A9K55_000226, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67221.1 A9K55_000227, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67303.1 A9K55_000228, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67304.1 A9K55_000229, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67427.1 A9K55_000230, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67518.1 A9K55_000231, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67520.1 A9K55_000232, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67519.1 A9K55_000233, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67522.1 A9K55_000234, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67521.1 A9K55_000235, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67374.1 A9K55_000236, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67524.1 A9K55_000237, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67390.1 A9K55_000238, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67377.1 A9K55_000239, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67317.1 A9K55_000240, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67318.1 A9K55_000241, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67319.1 A9K55_000242, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67320.1 A9K55_000243, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67314.1 A9K55_000244, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67315.1 A9K55_000245, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67316.1 A9K55_000246, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67101.1 A9K55_000247, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67356.1 A9K55_000248, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67357.1 A9K55_000249, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67529.1 A9K55_000250, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67083.1 A9K55_000251, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67267.1 A9K55_000252, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67528.1 A9K55_000253, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67353.1 A9K55_000254, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67527.1 A9K55_000255, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67526.1 A9K55_000256, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67346.1 A9K55_000257, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67525.1 A9K55_000258, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67345.1 A9K55_000259, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67370.1 A9K55_000260, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67371.1 A9K55_000261, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67368.1 A9K55_000262, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67369.1 A9K55_000263, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67283.1 A9K55_000264, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67285.1 A9K55_000265, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67372.1 A9K55_000266, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67373.1 A9K55_000267, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67111.1 A9K55_000268, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67112.1 A9K55_000269, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67174.1 A9K55_000270, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67173.1 A9K55_000271, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67176.1 A9K55_000272, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67175.1 A9K55_000273, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67170.1 A9K55_000274, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67169.1 A9K55_000275, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67172.1 A9K55_000276, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67171.1 A9K55_000277, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67100.1 A9K55_000278, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67099.1 A9K55_000279, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67189.1 A9K55_000280, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67190.1 A9K55_000281, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67191.1 A9K55_000282, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67192.1 A9K55_000283, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67480.1 A9K55_000284, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67193.1 A9K55_000285, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67194.1 A9K55_000286, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67195.1 A9K55_000287, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67187.1 A9K55_000288, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67454.1 A9K55_000289, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67229.1 A9K55_000290, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67228.1 A9K55_000291, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67250.1 A9K55_000292, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67227.1 A9K55_000293, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67252.1 A9K55_000294, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67251.1 A9K55_000295, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67231.1 A9K55_000296, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67230.1 A9K55_000297, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67249.1 A9K55_000298, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67248.1 A9K55_000299, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67378.1 A9K55_000300, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67296.1 A9K55_000301, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67379.1 A9K55_000302, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67391.1 A9K55_000303, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67300.1 A9K55_000304, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67402.1 A9K55_000305, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67450.1 A9K55_000306, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67409.1 A9K55_000307, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67321.1 A9K55_000308, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67287.1 A9K55_000309, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67064.1 A9K55_000310, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67530.1 A9K55_000311, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67404.1 A9K55_000312, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67405.1 A9K55_000313, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67147.1 A9K55_000314, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67403.1 A9K55_000315, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67428.1 A9K55_000316, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67531.1 A9K55_000317, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67275.1 A9K55_000318, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67276.1 A9K55_000319, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67498.1 A9K55_000320, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67497.1 A9K55_000321, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67341.1 A9K55_000322, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67496.1 A9K55_000323, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67237.1 A9K55_000324, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67499.1 A9K55_000325, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67342.1 A9K55_000326, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67501.1 A9K55_000328, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67500.1 A9K55_000329, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67322.1 A9K55_000330, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67323.1 A9K55_000331, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67324.1 A9K55_000332, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67325.1 A9K55_000333, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67326.1 A9K55_000334, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67495.1 A9K55_000336, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67328.1 A9K55_000337, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67246.1 A9K55_000338, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67247.1 A9K55_000339, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67241.1 A9K55_000340, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67240.1 A9K55_000341, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67243.1 A9K55_000342, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67242.1 A9K55_000343, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67238.1 A9K55_000344, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67268.1 A9K55_000345, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67239.1 A9K55_000346, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67269.1 A9K55_000347, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67483.1 A9K55_000348, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67244.1 A9K55_000349, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67217.1 A9K55_000350, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67218.1 A9K55_000351, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67215.1 A9K55_000352, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67216.1 A9K55_000353, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67219.1 A9K55_000354, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67220.1 A9K55_000355, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67523.1 A9K55_000356, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67071.1 A9K55_000357, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67516.1 A9K55_000358, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67517.1 A9K55_000359, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67097.1 A9K55_000360, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67313.1 A9K55_000361, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67096.1 A9K55_000362, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67095.1 A9K55_000363, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67093.1 A9K55_000366, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67092.1 A9K55_000367, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67183.1 A9K55_000370, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67184.1 A9K55_000371, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67185.1 A9K55_000372, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67186.1 A9K55_000373, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67179.1 A9K55_000374, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67180.1 A9K55_000375, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67181.1 A9K55_000376, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67177.1 A9K55_000378, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67178.1 A9K55_000379, non-CAZyme-
# ...
# -CazymeProteinPrediction, protein=ATY63294.1 A9K55_009129, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY63297.1 A9K55_009130, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY63298.1 A9K55_009131, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY62144.1 A9K55_009132, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY62145.1 A9K55_009134, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY62140.1 A9K55_009136, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY62139.1 A9K55_009137, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY62142.1 A9K55_009138, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY62141.1 A9K55_009139, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY62138.1 A9K55_009140, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY62137.1 A9K55_009141, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY63362.1 A9K55_009142, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY63363.1 A9K55_009143, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY63364.1 A9K55_009144, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY61607.1 A9K55_009145, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY61608.1 A9K55_009146, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY61609.1 A9K55_009147, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY61610.1 A9K55_009148, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY61611.1 A9K55_009149, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY63361.1 A9K55_009151, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY61925.1 A9K55_009152, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY61924.1 A9K55_009153, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY61923.1 A9K55_009154, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY61922.1 A9K55_009155, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY62587.1 A9K55_009156, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY62586.1 A9K55_009157, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY62219.1 A9K55_009158, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY62583.1 A9K55_009159, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY61921.1 A9K55_009160, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY61920.1 A9K55_009161, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY62152.1 A9K55_009162, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY63469.1 A9K55_009163, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY62150.1 A9K55_009164, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY62151.1 A9K55_009165, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY63659.1 A9K55_009167, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY62148.1 A9K55_009168, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY62149.1 A9K55_009169, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY63675.1 A9K55_009170, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY63470.1 A9K55_009171, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY62429.1 A9K55_009172, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY62428.1 A9K55_009173, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY62431.1 A9K55_009174, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY62430.1 A9K55_009175, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY62436.1 A9K55_009176, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY62432.1 A9K55_009177, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY62442.1 A9K55_009178, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY62441.1 A9K55_009179, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY62321.1 A9K55_009180, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY62320.1 A9K55_009181, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY62866.1 A9K55_009182, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY62867.1 A9K55_009183, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY62868.1 A9K55_009184, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY62869.1 A9K55_009185, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY62862.1 A9K55_009186, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY62863.1 A9K55_009187, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY62864.1 A9K55_009188, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY62865.1 A9K55_009189, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY62860.1 A9K55_009190, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY62861.1 A9K55_009191, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY63687.1 A9K55_009192, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY61703.1 A9K55_009193, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY61702.1 A9K55_009194, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY61701.1 A9K55_009195, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY61700.1 A9K55_009196, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY61699.1 A9K55_009197, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY63685.1 A9K55_009198, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY61698.1 A9K55_009199, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY61697.1 A9K55_009200, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY61696.1 A9K55_009201, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY62545.1 A9K55_009202, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY62544.1 A9K55_009203, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY63537.1 A9K55_009204, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY63536.1 A9K55_009205, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY63535.1 A9K55_009206, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY63534.1 A9K55_009207, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY63533.1 A9K55_009208, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY63532.1 A9K55_009209, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY63531.1 A9K55_009210, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY63530.1 A9K55_009211, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY62285.1 A9K55_009212, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY62286.1 A9K55_009213, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY62287.1 A9K55_009214, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY61704.1 A9K55_009215, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY61400.1 A9K55_009216, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY62283.1 A9K55_009217, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY62284.1 A9K55_009218, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY61401.1 A9K55_009219, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY62281.1 A9K55_009220, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY62282.1 A9K55_009221, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY63604.1 A9K55_009222, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY62513.1 A9K55_009223, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY62517.1 A9K55_009224, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY62934.1 A9K55_009225, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY63603.1 A9K55_009226, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY62503.1 A9K55_009228, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY63606.1 A9K55_009230, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY63605.1 A9K55_009231, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY62383.1 A9K55_009232, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY62384.1 A9K55_009233, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY62381.1 A9K55_009234, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY62382.1 A9K55_009235, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY62386.1 A9K55_009236, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY62387.1 A9K55_009237, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY63731.1 A9K55_009238, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY62726.1 A9K55_009240, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY63709.1 A9K55_009241, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY63702.1 A9K55_009242, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY63701.1 A9K55_009243, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY63700.1 A9K55_009244, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY63699.1 A9K55_009245, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY63706.1 A9K55_009246, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY63704.1 A9K55_009248, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY63708.1 A9K55_009250, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY63707.1 A9K55_009251, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY62504.1 A9K55_009252, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY62505.1 A9K55_009253, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY62506.1 A9K55_009254, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY63214.1 A9K55_009255, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY62507.1 A9K55_009256, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY62508.1 A9K55_009257, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY62509.1 A9K55_009258, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY62510.1 A9K55_009259, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY62511.1 A9K55_009260, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY62512.1 A9K55_009261, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY61569.1 A9K55_009262, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY61568.1 A9K55_009263, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY61571.1 A9K55_009264, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY61570.1 A9K55_009265, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY61573.1 A9K55_009266, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY61572.1 A9K55_009267, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY61574.1 A9K55_009268, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY62331.1 A9K55_009269, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY61396.1 A9K55_009270, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY61395.1 A9K55_009271, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY63488.1 A9K55_009272, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY63489.1 A9K55_009273, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY63476.1 A9K55_009274, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY63477.1 A9K55_009275, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY63474.1 A9K55_009276, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY63475.1 A9K55_009277, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY63471.1 A9K55_009278, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY63472.1 A9K55_009279, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY61354.1 A9K55_009280, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY62146.1 A9K55_009283, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY62099.1 A9K55_009284, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY63640.1 A9K55_009285, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY62126.1 A9K55_009286, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY62123.1 A9K55_009288, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY62122.1 A9K55_009289, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY61443.1 A9K55_009290, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY61442.1 A9K55_009291, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY61853.1 A9K55_009293, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY61854.1 A9K55_009294, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY61855.1 A9K55_009295, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY61840.1 A9K55_009296, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY62647.1 A9K55_009297, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY63349.1 A9K55_009298, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY61849.1 A9K55_009299, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY61866.1 A9K55_009300, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY61867.1 A9K55_009301, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY61949.1 A9K55_009302, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY61950.1 A9K55_009303, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY61947.1 A9K55_009304, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY61948.1 A9K55_009305, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY62542.1 A9K55_009306, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY62543.1 A9K55_009307, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY61945.1 A9K55_009308, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY61946.1 A9K55_009309, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY63734.1 A9K55_009310, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY62546.1 A9K55_009311, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY62514.1 A9K55_009312, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY63336.1 A9K55_009313, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY62516.1 A9K55_009314, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY62515.1 A9K55_009315, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY63379.1 A9K55_009316, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY62518.1 A9K55_009317, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY62540.1 A9K55_009318, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY62529.1 A9K55_009319, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY63134.1 A9K55_009320, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY63133.1 A9K55_009321, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY61841.1 A9K55_009322, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY61842.1 A9K55_009323, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY61843.1 A9K55_009324, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY61844.1 A9K55_009325, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY61845.1 A9K55_009326, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY61846.1 A9K55_009327, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY61847.1 A9K55_009328, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY61848.1 A9K55_009329, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY61839.1 A9K55_009330, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY61398.1 A9K55_009331, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY63071.1 A9K55_009332, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY63070.1 A9K55_009333, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY63069.1 A9K55_009334, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY63068.1 A9K55_009335, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY62220.1 A9K55_009336, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY63074.1 A9K55_009337, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY63073.1 A9K55_009338, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY63072.1 A9K55_009339, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY63067.1 A9K55_009340, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY61714.1 A9K55_009343, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY61711.1 A9K55_009344, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY61712.1 A9K55_009345, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY61717.1 A9K55_009346, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY61715.1 A9K55_009348, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY61716.1 A9K55_009349, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY61719.1 A9K55_009350, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY61720.1 A9K55_009351, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY62983.1 A9K55_009352, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY62982.1 A9K55_009353, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY62985.1 A9K55_009354, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY62984.1 A9K55_009355, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY62979.1 A9K55_009356, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY62978.1 A9K55_009357, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY62980.1 A9K55_009359, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY62977.1 A9K55_009360, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY62976.1 A9K55_009361, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY61649.1 A9K55_009362, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY61650.1 A9K55_009363, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY61651.1 A9K55_009364, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY61652.1 A9K55_009365, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY61645.1 A9K55_009366, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY61646.1 A9K55_009367, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY61647.1 A9K55_009368, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY61648.1 A9K55_009369, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY61653.1 A9K55_009371, non-CAZyme-

# %% [markdown]
# From looking at the printed out class representation strings (for example, at the protein ATY62702.1) we can see that each of the multiple CAZyme domains predicted in each protein are collected under a single `CazymeProteinPrediction` instance.
