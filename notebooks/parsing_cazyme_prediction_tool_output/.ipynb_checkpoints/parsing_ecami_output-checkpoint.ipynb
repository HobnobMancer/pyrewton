# %% [markdown]
# # Parsing eCAMI output
#
# The CAZyme prediction tools dbCAN, CUPP and eCAMI write out their output files in different formats, and do not present the data in a standardised manner across all tools. Additionally, the output from the prediction tools does not enable easy parsing of the data by the [Sklearn](https://scikit-learn.org/stable/index.html) library, which performs the statistical analysis of the tools preformances.
#
# This notebook explains the theorlogy and method used by the `pyrewton.cazymes.prediction.parse` submodule to parse the output from the CAZyme prediction tool **eCAMI**.
#
# [eCAMI](https://academic.oup.com/bioinformatics/article/36/7/2068/5651014?login=true) is a k-mer based CAZyme prediction tool. The information defining the data included in each field of the output files came from the [README](https://github.com/zhanglabNKU/eCAMI) and the Python script `prediction.py`.
#
# The following data is collected from the eCAMI output:
# - protein_accession
# - cazy_family (all predicated CAZy families)
# - cazy_subfamily (all predicated CAZy subfamilies)
# - ec_number (all predicted EC numbers)
#
# ### Notebook structure
#
# The section titled **'exploring the output'** shows the exploration of the tools output files. This is to demonstrate how the data is constructed and presented, and forms a foundation for explaining the developed method of parsing the data.
#
# The section **'parsing the output'** shows the method of parsing the data from the CAZyme prediction tool.
#
# The final section shows any additional parsing that was performed to make the statistical analysis of the tool's performance easier. This typically includes removing duplicates, and combining rows that represent data for the same predicted CAZyme.

# %% [markdown]
# ## Contents
#
# - [Imports](#notebook_imports)
# - [Exploring the eCAMI output text file](#text_file)
# - [Defining the data model](#data_model)
# - [Getting the predicted CAZy family for the CAZyme domain](#cazy_fam)
# - [Getting the predicted CAZy subfamily for the CAZyme domain](#cazy_subfam)
# - [Getting the predicted EC numbers](#ecnum)
# - [Combining data for a single protein](#combining_proteins)
# - [Adding non-CAZymes](#no_caz)
# - [Final functions](#final)

# %% [markdown]
# <a id="notebook_imports"></a>

# %% [markdown]
# # Imports

# %%
# Install necessary libraries
# !pip3 install pandas
# !pip3 install numpy

import re

import pandas as pd
import numpy as np

from tqdm.notebook import tqdm
# Out:
# Requirement already satisfied: pandas in /home/em/.local/lib/python3.8/site-packages (1.1.4)
# Requirement already satisfied: pytz>=2017.2 in /home/em/anaconda3/lib/python3.8/site-packages (from pandas) (2020.1)
# Requirement already satisfied: numpy>=1.15.4 in /home/em/.local/lib/python3.8/site-packages (from pandas) (1.19.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/em/anaconda3/lib/python3.8/site-packages (from pandas) (2.8.1)
# Requirement already satisfied: six>=1.5 in /home/em/anaconda3/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)
# Requirement already satisfied: numpy in /home/em/.local/lib/python3.8/site-packages (1.19.4)

# %% [markdown]
# <a id="text_file"></a>

# %% [markdown]
# ## Exploring the eCAMI output text file
#
# eCAMI produces a single output file, which is a plain text file in the style of a FASTA-like file. The definitions and explanations of the data in the output file is taken from the multiple REAMEs in the eCAMI [GitHub repository](https://github.com/zhanglabNKU/eCAMI)  -- there is a `readme.md` file each in the `examples/prediction` and `examples/clustering` directories.
#
# Each predicted CAZyme can be predicted to be annotated with multiple CAZy families. Each unique CAZy familiy/CAZy subfamily combination is interpreted as a unique CAZyme domain prediction. Each CAZyme domain prediction is listed as a separate item in the output text file from eCAMI.
#
# Each CAZyme domain prediction is stored across two lines, with the first line starting with '>'.
#
# For example:
#
# ```
# >ATY67280.1 A9K55_000020 	GH17:43	GH17:24|3.2.1.-:1
# LHKVFPGM(369),HKVFPGMD(370),KVFPGMDY(371),VFPGMDYT(372),FPGMDYTP(373),PPSQNNVT(392),PSQNNVTR(393),SQNNVTRD(394),QNNVTRDV(395),NNVTRDVA(396),NVTRDVAV(397),VTRDVAVL(398),TRDVAVLS(399),RDVAVLSQ(400),DVAVLSQL(401),AVLSQLTN(403),IRLYGTDC(412),RLYGTDCN(413),LYGTDCNQ(414),YGTDCNQT(415),GTDCNQTQ(416),TDCNQTQM(417),IVANEILF(476),VANEILFR(477),LPVATSDL(510),PVATSDLG(511),VATSDLGD(512),ATSDLGDD(513),TSDLGDDW(514),IMANIHPF(532),MANIHPFF(533),ISETGWPS(573),NGTNYFWF(618),GTNYFWFE(619),TNYFWFEA(620),NYFWFEAF(621),YFWFEAFD(622),FWFEAFDE(623),WFEAFDEP(624),FEAFDEPW(625),EAFDEPWK(626),WEDKWGLL(643),GVKIPDCG(659),VKIPDCGG(660),
# ```
#
# The first line (denoted with the '>' prefix, contains the following:
# - 'protein_name' the protein accession, taken straight from the description/identifier line from the input FASTA file of all query protein sequences parsed by eCAMI
# - 'fam_name:group_number' -- this is the `GH17:43` in the above example
#     - the 'fam_name' is the CAZy family assigned to the CAZyme by ecAMI
#     - the 'group_number' is the cluster number (which acts as an ID number for the kmer cluster) for the respective CAZy family
# - 'subfam_name_of_the_group:subfam_name_count' -- in the above example this is `GH17:24|3.2.1.-:1`
#     - this data is extracted from the kmer library
#     - each 'label' (where each label is separated with a '|') is taken from the 'known labels' of CAZymes used to create the kmer clusters. Specifically, to create the kmer clusters, eCAMI parses a FASTA file of all protein sequences to be used for the clustering. In the protein data line (the line prefixed with '>') for each protein contains the protein name/accession and 'known labels' of that proteins. These known labels include CAZy family, CAZy subfamily and EC number annotations/labels. When the kmer cluster is created, the known lables of the proteins included in the cluster are stored within the cluster as a `kmer_message` (this name was taken from the `prediction.py` script from eCAMI). This `kmer_message` is then written out as the 'subfam_name_of_the_group:subfam_name_count' in the output file.
#     - the 'subfam_name_count' is the number of times the respective known label appears in the kmer cluster
#
# The second line contains the kmers from the predicted CAZy family's kmer cluster that were found in the query protein sequence, and includes the amino acid starting position of the kmer in the quer protein sequence, in brackets.
#
# To determine the CAZy family annotation predictions for each query protein sequence, eCAMI performs its search of all kmers in every CAZyme cluster they have created. eCAMI scores the number of kmers for each CAZy family that appear in the query protein sequence, and scores the sum frequency of the kmers from the cluster. To be more explicit, during the generation of the kmer clusters, a frequency score is calculated for each identified kmer, and this is stored along side the kmer amino acid sequence in the kmer library. Then for each CAZy family, and for each of its charactistic kmers found in the query protein sequence, the sum of these kmer frequencies from the cluster library is calculated, and this assigned to a variabled called `number_score`. As long for the associated CAZy family the `score` is greater than the `important_k_mer_number` (the minimum number of times kmers for a family need to appear in the query protein sequence), and the `number_score` is greater than `beta` (the minimum sum of the kmer frequencies, default is 2) then the CAZy family and its associated score is stored within the `sort_fam`, which is a list of lists, with each internal list representing one unqiue CAZy family. These CAZy families are then ranked by their `score`. The highest scoring CAZy family is listed as the `first_fam` and is written to the ouput file in the formate displayed above.
#
# To find other predicted CAZyme domains (CAZy family annotations), eCAMI then retrieves the `kmer_message` for the `first_fam`. It then iterates through the 'known labels' in the `kmer_message`, and for each CAZy family found in the 'known labels', checks if the CAZy family is in `sort_fam`. If it is then the CAZy family is written out to the output file for the query protein sequence in the same format written out above, often with an extremely similar `kmer_message` to the first CAZy family.
#
# <div class="alert-warning">
# <p></p>
# <b>Note:</b> For CAZy families in the `kmer_message` but not in the `sort_fam`, these CAZy families are **not** written out to the output file. Likewise, CAZy families in the `sort_fam` not in the `kmer_message`, these CAZy families are **not** written out to the output file.
# <p></p>
# </div>
#
# This is why it is possible to find an output like follows in the output file of eCAMI (where the lines of kmers have been removed:
# ```
# >ATY67289.1 A9K55_000120     CBM48:20    CBM48:339|GH13_8:324|2.4.1.18:32|GH13:4|GT4:2
#
# >ATY67289.1 A9K55_000120     GH13:203    GH13_8:577|CBM48:328|2.4.1.18:32|GH13:13|GT4:1
# ```
# In this example, 'GT4' has been listed in both `kmer_messages`, and the `kmer_messages` share similar content, but the family 'GT4' is not listed in 'fam_name:group_number' for the protein in the output file. Therefore, the actualy CAZy family prediction from eCAMI is written out in the 'fam_name:group_number' field. This field always contains a CAZy family, and not a subfamily. However, to retrieve a potential subfamily prediction, we can check the `kmer_message` on the respective row and check if it is the child of the CAZy family listed in the 'fam_name:group_number' field. If it is, then we can retrive it as the CAZy subfamily prediction.
#
# The EC numbers listed for each predicted CAZyme domain (unique CAZy family) are not predicted EC numbers. To predict the EC numbers can be done using eCAMI but that is not of interest to this project. However, the EC numbers from the `kmer_message` will be retrieved and assigned to their respective CAZyme domain. But, it will be noted that these associations are potentially weak and only indicative and there is not the same confidence level in them as would be if using eCAMI to specifically predict the EC numbers. These EC numbers are retrieved chiefly for the reason that other researchers may want them, thus the functionality is included now to save potential time in the future.
#
#
# <div class="alert-warning">
# <p></p>
# <b>Note:</b> **NOTE:** In the eCAMI README the `important_k_mer_number` is said to be default to 3, this is incorrect. In the script `eCAMI.prediction.py` it is set at a default value of 5
# <p></p>
# </div>
#
# <div class="alert-success">
# <p></p>
# <p>Therefore, all the desired data we want from eCAMI is in the lines prefixed with '>'.</p>
# <p></p>
# </div>

# %% [markdown]
# <a id="data_model"></a>

# %% [markdown]
# ## Defining the data model
#
# The explanation of the design of the data model is explained in the note book prediction_data_model.ipynb.

# %%
class CazymeDomain:
    """Single CAZyme domain in a protein, predicted by a CAZyme prediction tool.

    Each unique CAZy domain per protein is identifiable by a unique CAZy
    family-subfamily combination.

    Every CAZyme domain has a source CAZyme prediction tool that predicted the CAZyme
    domain, a parent CAZyme protein (represented by the protein accession), and CAZy
    family and subfamily combination. If no CAZy subfamily is predicted, the 
    subfamily will be listed as a null value.

    Hotpep, CUPP and eCAMI predict EC numbers for each CAZyme domain.
    HMMER and CUPP predict amino acid domain ranges.
    Multiple EC numbers and domain ranges can be predicted for a single CAZyme domain,
    therefore, these attritbutes are stored as lists.
    """

    def __init__(
        self,
        prediction_tool,
        protein_accession,
        cazy_family,
        cazy_subfamily=None,
        ec_numbers=None,
        domain_range=None,
    ):
        """Initiate instance
        
        :attr prediction_tool: str, CAZyme prediciton tool which predicted the domain
        :attr protein_accession: str
        :attr cazy_family: str
        :attr cazy_subfamily: str
        :attr ec_numbers: list (list of str, each str contains a unique EC number)
        :attr domain_range: list (list of str, each str contains a unique domain range)
        """
        self.prediction_tool = prediction_tool
        self.protein_accession = protein_accession
        self.cazy_family = cazy_family
        
        # not all CAZyme domans are catalogued under a CAZy subfamily
        if cazy_subfamily is None:
            self.cazy_subfamiy = np.nan
        else:
            self.cazy_subfamily = cazy_subfamily
        
        # EC numbers are not predicted for all CAZyme domains
        if ec_numbers is None:
            self.ec_numbers = []  # enables adding in EC numbers included in another line of the output file
        else:
            self.ec_numbers = ec_numbers
        
        # Not all prediction tools predict CAZyme domains
        if domain_range is None:
            self.domain_range = []  # enables adding domain range listed in another line of the ouput file
        else:
            self.domain_range = domain_range
    
    def __str__(self):
        return f"-CazymeDomain in {self.protein_accession}, fam={self.cazy_family}, subfam={self.cazy_subfamily}-"
    
    def __repr__(self):
        return f"<CazymeDomain parent={self.protein_accession} fam={self.cazy_family}, subfam={self.cazy_subfamily}>"

    
class CazymeProteinPrediction:
    """Single protein and CAZyme/non-CAZyme prediction by a CAZyme prediction tool"""
    
    def __init__(self, prediction_tool, protein_accession, cazyme_classification, cazyme_domains=None):
        """Initate class instance.
        
        :attr prediction_tool: str, name of CAZyme prediction tool
        :attr protein_accession: str
        :attr cazyme_classification: int, 1=CAZyme, 0=non-CAZyme
        :attr cazyme_domains: list of CazymeDomain instances, domain predicted to be in the CAZyme
        """
        self.prediction_tool = prediction_tool
        self.protein_accession = protein_accession
        self.cazyme_classification = cazyme_classification  # CAZyme=1, non-CAZyme=0
        
        # non-CAZymes will have no cazyme_domains
        if cazyme_domains is None:
            self.cazyme_domains = []  # allows addition of CAZyme domains as they are parsed
        else:
            self.cazyme_domains = cazyme_domains
    
    def __str__(self):
        if self.cazyme_classification == 0:
            return f"-CazymeProteinPrediction, protein={self.protein_accession}, non-CAZyme-"
        else:
            return(
                f"-CazymeProteinPrediction, protein={self.protein_accession}, "
                f"CAZyme domains={len(self.cazyme_domains)}-"
            )
    
    def __repr__(self):
        return(
            f"<CazymeProteinPrediction, protein={self.protein_accession}, "
            f"cazyme_classification{self.cazyme_classification}>"
        )

# %% [markdown]
# <a id="explore_one"></a>

# %% [markdown]
# ## Exploring the first line of protein data
#
# First lets check out the data is separated and presented when using Python to read the text file. Spliting up the data weill prepare it for adding it to the data model. Additionally, we create a dictionary, keyed by protein accession and valued by its corresponding ECAMIprediciton instance. This is to enable quickly checking if a ECAMIprediction instance has already been created for a protein.

# %%
# Read the output file from eCAMI
with open("8080495_output.txt", "r") as fh:
    ecami_file = fh.read().splitlines()

for line in ecami_file[:4]:
    print(line)
# Out:
# >ATY67280.1 A9K55_000020 	GH17:43	GH17:24|3.2.1.-:1
# LHKVFPGM(369),HKVFPGMD(370),KVFPGMDY(371),VFPGMDYT(372),FPGMDYTP(373),PPSQNNVT(392),PSQNNVTR(393),SQNNVTRD(394),QNNVTRDV(395),NNVTRDVA(396),NVTRDVAV(397),VTRDVAVL(398),TRDVAVLS(399),RDVAVLSQ(400),DVAVLSQL(401),AVLSQLTN(403),IRLYGTDC(412),RLYGTDCN(413),LYGTDCNQ(414),YGTDCNQT(415),GTDCNQTQ(416),TDCNQTQM(417),IVANEILF(476),VANEILFR(477),LPVATSDL(510),PVATSDLG(511),VATSDLGD(512),ATSDLGDD(513),TSDLGDDW(514),IMANIHPF(532),MANIHPFF(533),ISETGWPS(573),NGTNYFWF(618),GTNYFWFE(619),TNYFWFEA(620),NYFWFEAF(621),YFWFEAFD(622),FWFEAFDE(623),WFEAFDEP(624),FEAFDEPW(625),EAFDEPWK(626),WEDKWGLL(643),GVKIPDCG(659),VKIPDCGG(660),
# >ATY67467.1 A9K55_000078 	GT90:15	GT90:8
# RRGRHPPP(101),RGRHPPPG(102),GRHPPPGF(103),RHPPPGFD(104),AQDPCLQP(311),QDPCLQPH(312),DPCLQPHL(313),PCLQPHLR(314),PLFGGSKL(341),LPDVDGNS(503),DGNSYSAR(507),GNSYSARW(508),NSYSARWR(509),SMPLKATI(523),MPLKATIY(524),TPWVHFVP(540),PWVHFVPF(541),WVHFVPFD(542),LYVWRLLL(592),YVWRLLLE(593),

# %% [markdown]
# We are only interested in first line, which is identifable by starting with a '>'

# %%
# Read the output file from eCAMI
with open("8080495_output.txt", "r") as fh:
    ecami_file = fh.read().splitlines()

for line in ecami_file[:4]:
    if line.startswith('>'):
        print(line)
# Out:
# >ATY67280.1 A9K55_000020 	GH17:43	GH17:24|3.2.1.-:1
# >ATY67467.1 A9K55_000078 	GT90:15	GT90:8

# %%
# Read the output file from eCAMI
with open("8080495_output.txt", "r") as fh:
    ecami_file = fh.read().splitlines()

ecami_predictions = {}  # stores proteins {protein_accession:ECAMIprediction_instance}

for line in ecami_file[:4]:
    if not line.startswith('>'):  # only want the first line for a protien not the listed k-mers
        continue
    
    prediction_output = line.split("\t")
    print(prediction_output)
# Out:
# ['>ATY67280.1 A9K55_000020 ', 'GH17:43', 'GH17:24|3.2.1.-:1']
# ['>ATY67467.1 A9K55_000078 ', 'GT90:15', 'GT90:8']

# %% [markdown]
# <a id="cazy_fam"></a>

# %% [markdown]
# ## Getting the predicted CAZy family for the CAZyme domain
#
# The CAZy family of the CAZyme domain of interest in the line starting with '>' is stored in the second element in `prediction_output` list.

# %%
# Read the output file from eCAMI
with open("8080495_output.txt", "r") as fh:
    ecami_file = fh.read().splitlines()

ecami_predictions = {}  # stores proteins {protein_accession:ECAMIprediction_instance}

for line in ecami_file[:8]:
    if not line.startswith('>'):  # only want the first line for a protien not the listed k-mers
        continue
    
    prediction_output = line.split("\t")
    
    # retrieve the CAZy family
    cazy_fam = prediction_output[1]
    print("cazy_fam=", cazy_fam)
# Out:
# cazy_fam= GH17:43
# cazy_fam= GT90:15
# cazy_fam= CBM48:20
# cazy_fam= GH13:203

# %% [markdown]
# The CAZy family is stored in the format "fam_name:group_number", where the group_number is the number of the k-mer group, which is data that is not needed for evaluating the performance of eCAMI. We can remove the k-mer group number by spliting the "fam_name:group_number" string at the colon, and retrieving the first item.

# %%
# Read the output file from eCAMI
with open("8080495_output.txt", "r") as fh:
    ecami_file = fh.read().splitlines()

ecami_predictions = {}  # stores proteins {protein_accession:ECAMIprediction_instance}

for line in ecami_file[:8]:
    if not line.startswith('>'):  # only want the first line for a protien not the listed k-mers
        continue
    
    prediction_output = line.split("\t")
    
    # retrieve the CAZy family
    cazy_fam = prediction_output[1].split(":")[0]
    print("cazy_fam=", cazy_fam)
# Out:
# cazy_fam= GH17
# cazy_fam= GT90
# cazy_fam= CBM48
# cazy_fam= GH13

# %% [markdown]
# <a id="cazy_subfam"></a>

# %% [markdown]
# ## Getting the predicted CAZy subfamily
#
# **Note:** For details about why the CAZy subfamily is retrieved from please refere back to the section [
# Exploring the eCAMI output text file](#text_file).
#
# The CAZy subfamily is stored in the third element of the first protein line (when the line is split up by tabs), this referred to as the 'subfam_name_of_the_group:subfam_name_count' in the eCAMI documentation. This string is composed of known labels associated with the proteins used to create the kmer cluster library, which was then used to predicted the CAZy families of our query protein sequences.
#
# Therefore, in the line
# `>ATY67289.1 A9K55_000120     GH13:203    GH13_8:577|CBM48:328|2.4.1.18:32|GH13:13|GT4:1`, the string `GH13_8:577|CBM48:328|2.4.1.18:32|GH13:13|GT4:1`
# contains the CAZy subfamily of the CAZyme domain represented by the line.
#
# We need to check if the third element of the `prediction_output` list contains any subfamiles (identified by the general format `\D{2,3}\d+_\d+`) and that the parent family matches the family listed in the second element of the `prediction_output` list.

# %%
# Read the output file from eCAMI
with open("8080495_output.txt", "r") as fh:
    ecami_file = fh.read().splitlines()

ecami_predictions = {}  # stores proteins {protein_accession:ECAMIprediction_instance}

for line in ecami_file[:8]:
    if not line.startswith('>'):  # only want the first line for a protien not the listed k-mers
        continue
    
    prediction_output = line.split("\t")
    
    # retrieve the CAZy family
    cazy_fam = prediction_output[1].split(":")[0]
    
    # retrieve the CAZy subfamily
    subfam_group = prediction_output[2]
    print(subfam_group)
# Out:
# GH17:24|3.2.1.-:1
# GT90:8
# CBM48:339|GH13_8:324|2.4.1.18:32|GH13:4|GT4:2
# GH13_8:577|CBM48:328|2.4.1.18:32|GH13:13|GT4:1

# %% [markdown]
# The items in the "subfam_name_of_the_group:subfam_name_count" section are separated by '|'. Therefore, we need to separte the predicted items and then check which are CAZy subfamilies.

# %%
# Read the output file from eCAMI
with open("8080495_output.txt", "r") as fh:
    ecami_file = fh.read().splitlines()

ecami_predictions = {}  # stores proteins {protein_accession:CazymeProteinPrediction_instance}

for line in ecami_file[:8]:
    if not line.startswith('>'):  # only want the first line for a protien not the listed k-mers
        continue
    
    prediction_output = line.split("\t")
    
    # retrieve the CAZy family
    cazy_fam = prediction_output[1].split(":")[0]
    
    # retrieve the CAZy subfamily
    subfam_group = prediction_output[2]
    subfam_group = subfam_group.split("|")
    print(subfam_group)
# Out:
# ['GH17:24', '3.2.1.-:1']
# ['GT90:8']
# ['CBM48:339', 'GH13_8:324', '2.4.1.18:32', 'GH13:4', 'GT4:2']
# ['GH13_8:577', 'CBM48:328', '2.4.1.18:32', 'GH13:13', 'GT4:1']

# %% [markdown]
# The EC numbers and CAZy (sub)families are also stored with the associated group number, e.g. the group number of the predicted EC number. These group numbers are separated by a colon from the EC numbers and CAZy (sub)families.

# %%
# Read the output file from eCAMI
with open("8080495_output.txt", "r") as fh:
    ecami_file = fh.read().splitlines()

ecami_predictions = {}  # stores proteins {protein_accession:CazymeProteinPrediction_instance}

for line in ecami_file[:8]:
    if not line.startswith('>'):  # only want the first line for a protien not the listed k-mers
        continue
    
    prediction_output = line.split("\t")
    
    # retrieve the CAZy family
    cazy_family = prediction_output[1].split(":")[0]
    
    # retrieve the CAZy subfamily
    subfam_group = prediction_output[2]
    subfam_group = subfam_group.split("|")
    cazy_subfamilies = []  # store all listed predicted CAZy subfamilies
    # check if the subfam_group contains a predicted CAZy subfamily
    for item in subfam_group:
        # remove the group number of the predicted item
        item = item.split(":")[0]
        try:
            re.match(r"\D{2,3}\d+_\d+", item)
            # check if the subfamily belongs to the CAZy family listed for the current CAZyme domain
            if item[:item.find("_")] == cazy_family:
                cazy_subfamilies.append(item)
        except AttributeError:  # raised if the item is not a CAZy subfamily
            pass
    
    print("cazy_family=", cazy_family)
    print("cazy_subfamilies=", cazy_subfamilies)
# Out:
# cazy_family= GH17
# cazy_subfamilies= []
# cazy_family= GT90
# cazy_subfamilies= []
# cazy_family= CBM48
# cazy_subfamilies= []
# cazy_family= GH13
# cazy_subfamilies= ['GH13_8']

# %% [markdown]
# <a id="ecnum"></a>

# %% [markdown]
# ## Getting the EC numbers
#
# As noted and explained in the section [Exploring the eCAMI output text file](#text_file), these are not the EC numbers specifically predicted by eCAMI. To predict the EC numbers of the query proteins, the analysis would need to be run again using the 'EC' kmer library. However, the EC numbers listed in the `kmer_message` (for this definition see the section 'Exploring the eCAMI output text file')....
#
# The predicted EC numbers for the current working CAZyme domain are listed in the subfam_group (the third element of the `prediction_output` list), along with the CAZy subfamilies. Therefore, the identification of the EC numbers can be achieved at the same time as getting the CAZy subfamilies. If digits are missing in the EC number, they are replaced with a dash, from this we are able to check by the format of the string if a string includes an EC number.

# %%
# Read the output file from eCAMI
with open("8080495_output.txt", "r") as fh:
    ecami_file = fh.read().splitlines()

ecami_predictions = {}  # stores proteins {protein_accession:ECAMIprediction_instance}

for line in ecami_file[:8]:
    if not line.startswith('>'):  # only want the first line for a protien not the listed k-mers
        continue
    
    prediction_output = line.split("\t")
    
    # retrieve the CAZy family
    cazy_family = prediction_output[1].split(":")[0]
    
    # retrieve the CAZy subfamily and EC numbers
    subfam_group = prediction_output[2]
    subfam_group = subfam_group.split("|")

    cazy_subfamilies = []  # store all listed predicted CAZy subfamilies
    ec_numbers = []  # store all predicted EC numbers

    # check if the subfam_group contains a predicted CAZy subfamily
    for item in subfam_group:
        # remove the group number of the predicted item
        item = item.split(":")[0]

        # check if the item contains a CAZy subfamily
        try:
            re.match(r"\D{2,3}\d+_\d+", item).group()
            # check if the subfamily belongs to the CAZy family listed for the current CAZyme domain
            if item[:item.find("_")] == cazy_family:
                cazy_subfamilies.append(item)
        except AttributeError:  # raised if the item is not a CAZy subfamily
            pass
        
        # check if item contains an EC number
        try:
            re.match(r"\d+\.(\d+|-)\.(\d+|-)\.(\d+|-)", item).group()
            ec_numbers.append(item)
        except AttributeError:  # raised if the item is not an EC number
            pass
    
    print("cazy_family=", cazy_family)
    print("cazy_subfamilies=", cazy_subfamilies)
    print("ec_numbers=", ec_numbers)
# Out:
# cazy_family= GH17
# cazy_subfamilies= []
# ec_numbers= ['3.2.1.-']
# cazy_family= GT90
# cazy_subfamilies= []
# ec_numbers= []
# cazy_family= CBM48
# cazy_subfamilies= []
# ec_numbers= ['2.4.1.18']
# cazy_family= GH13
# cazy_subfamilies= ['GH13_8']
# ec_numbers= ['2.4.1.18']

# %% [markdown]
# <a id="combining_proteins"></a>

# %% [markdown]
# ## Combining data for a single protein
#
# As discussed before, a unique protein can be listed multiple times in the eCAMI output file. To combine data together so a single ECAMIprediction instance for a protein, we check if a corresponding key (defined by the protein's accession) is in the ecami_prediction dictionary.

# %%
# Read the output file from eCAMI
with open("8080495_output.txt", "r") as fh:
    ecami_file = fh.read().splitlines()

ecami_predictions = {}  # stores proteins {protein_accession:CazymeProteinPrediction_instance}

for line in tqdm(ecami_file, desc="Parsing eCAMI output"):
    if not line.startswith('>'):  # only want the first line for a protien not the listed k-mers
        continue
    
    prediction_output = line.split("\t")
    
    # retrieve protein accession, removing the '>' prefix and stripping white space
    protein_accession = prediction_output[0][1:].strip()
    cazyme_classification = 1
    
    # retrieve the CAZy family
    cazy_family = prediction_output[1].split(":")[0]
    
    # retrieve the CAZy subfamily and EC numbers
    subfam_group = prediction_output[2]
    subfam_group = subfam_group.split("|")

    cazy_subfamilies = []  # store all listed predicted CAZy subfamilies
    ec_numbers = []  # store all predicted EC numbers

    # check if the subfam_group contains a predicted CAZy subfamily
    for item in subfam_group:
        # remove the group number of the predicted item
        item = item.split(":")[0]

        # check if the item contains a CAZy subfamily
        try:
            re.match(r"\D{2,3}\d+_\d+", item).group()
            # check if the subfamily belongs to the CAZy family listed for the current CAZyme domain
            if item[:item.find("_")] == cazy_family:
                cazy_subfamilies.append(item)
            continue  # it was a CAZy subfamily, don't need to check if it was an EC#
    
        except AttributeError:  # raised if the item is not a CAZy subfamily
            pass
        
        # check if item contains an EC number
        try:
            re.match(r"\d+\.(\d+|-)\.(\d+|-)\.(\d+|-)", item).group()
            ec_numbers.append(item)
        except AttributeError:  # raised if the item is not an EC number
            # check if it was a CAZy family, this is for detecting unexpected data types
            try:
                re.match(r"\D{2,3}\d+", item).group()
            except AttributeError:
                print(
                    f"WARNING -- unexpected data type of item '{item}' for protein {protein_accession} "
                    "by eCAMI. Not adding data to parsed data from eCAMI."
                )
    
    # add ECAMIprediction instance to ecami_prediction
    cazyme_classification = 1  # all proteins included in eCAMI output file are identified as CAZymes
    
    if len(cazy_subfamilies) == 0:
        cazy_subfamilies = [np.nan]
    else:
        cazy_subfamilies = ", ".join(cazy_subfamilies)  # convert to string
        
    if len(ec_numbers) == 0:
        ec_numbers = [np.nan]
    
    try:
        # add new predicted CAZyme domain to an existing ECAMIprediction instance
        existing_prediction = ecami_predictions[protein_accession]
        print("existing_prediction=", existing_prediction)
        
        # check if the CAZyme domain has already been passed
        existing_cazyme_domains = existing_prediction.cazyme_domains
        existance = False  # becomes true if existing instance found
        for domain in existing_cazyme_domains:
            if (domain.cazy_family == cazy_family) and (domain.cazy_subfamily == cazy_subfamily):
                domain.ec_numbers.append(np.nan)
                existance = True
                print(f"WARNING -- existing cazyme domain found, {protein_accession}, {domain.cazy_family}, {domain.cazy_subfamily}")
                break
        
        if existance is False:
            # create new CAZyme domain
            new_cazyme_domain = CazymeDomain(
                "eCAMI",
                protein_accession,
                cazy_family,
                cazy_subfamilies,
                ec_numbers,
            )
            existing_prediction.cazyme_domains.append(new_cazyme_domain)
        print("existing_prediction=[2]", existing_prediction)
    
    except KeyError:  # raised if no corresponding ECAMIprediction instance was found

            new_cazyme_domain = CazymeDomain(
                "eCAMI",
                protein_accession,
                cazy_family,
                cazy_subfamilies,
                ec_numbers,
            )
            
            new_protein = CazymeProteinPrediction(
                "eCAMI",
                protein_accession,
                cazyme_classification,
            )
    
            new_protein.cazyme_domains = [new_cazyme_domain]
            
            ecami_predictions[protein_accession] = new_protein



print("length=", len(list(ecami_predictions.values())))
# Out:
# HBox(children=(HTML(value='Parsing eCAMI output'), FloatProgress(value=0.0, max=644.0), HTML(value='')))
# existing_prediction= -CazymeProteinPrediction, protein=ATY67289.1 A9K55_000120, CAZyme domains=1-
# existing_prediction=[2] -CazymeProteinPrediction, protein=ATY67289.1 A9K55_000120, CAZyme domains=2-
# existing_prediction= -CazymeProteinPrediction, protein=ATY66529.1 A9K55_000499, CAZyme domains=1-
# existing_prediction=[2] -CazymeProteinPrediction, protein=ATY66529.1 A9K55_000499, CAZyme domains=2-
# existing_prediction= -CazymeProteinPrediction, protein=ATY66664.1 A9K55_000997, CAZyme domains=1-
# existing_prediction=[2] -CazymeProteinPrediction, protein=ATY66664.1 A9K55_000997, CAZyme domains=2-
# existing_prediction= -CazymeProteinPrediction, protein=ATY66444.1 A9K55_001136, CAZyme domains=1-
# existing_prediction=[2] -CazymeProteinPrediction, protein=ATY66444.1 A9K55_001136, CAZyme domains=2-
# existing_prediction= -CazymeProteinPrediction, protein=ATY65637.1 A9K55_001791, CAZyme domains=1-
# existing_prediction=[2] -CazymeProteinPrediction, protein=ATY65637.1 A9K55_001791, CAZyme domains=2-
# existing_prediction= -CazymeProteinPrediction, protein=ATY59023.1 A9K55_002239, CAZyme domains=1-
# existing_prediction=[2] -CazymeProteinPrediction, protein=ATY59023.1 A9K55_002239, CAZyme domains=2-
# existing_prediction= -CazymeProteinPrediction, protein=ATY59188.1 A9K55_002493, CAZyme domains=1-
# existing_prediction=[2] -CazymeProteinPrediction, protein=ATY59188.1 A9K55_002493, CAZyme domains=2-
# existing_prediction= -CazymeProteinPrediction, protein=ATY59188.1 A9K55_002493, CAZyme domains=2-
# existing_prediction=[2] -CazymeProteinPrediction, protein=ATY59188.1 A9K55_002493, CAZyme domains=3-
# existing_prediction= -CazymeProteinPrediction, protein=ATY58486.1 A9K55_003070, CAZyme domains=1-
# existing_prediction=[2] -CazymeProteinPrediction, protein=ATY58486.1 A9K55_003070, CAZyme domains=2-
# existing_prediction= -CazymeProteinPrediction, protein=ATY59698.1 A9K55_003119, CAZyme domains=1-
# existing_prediction=[2] -CazymeProteinPrediction, protein=ATY59698.1 A9K55_003119, CAZyme domains=2-
# existing_prediction= -CazymeProteinPrediction, protein=ATY58848.1 A9K55_003123, CAZyme domains=1-
# existing_prediction=[2] -CazymeProteinPrediction, protein=ATY58848.1 A9K55_003123, CAZyme domains=2-
# existing_prediction= -CazymeProteinPrediction, protein=ATY58848.1 A9K55_003123, CAZyme domains=2-
# existing_prediction=[2] -CazymeProteinPrediction, protein=ATY58848.1 A9K55_003123, CAZyme domains=3-
# existing_prediction= -CazymeProteinPrediction, protein=ATY65223.1 A9K55_003996, CAZyme domains=1-
# existing_prediction=[2] -CazymeProteinPrediction, protein=ATY65223.1 A9K55_003996, CAZyme domains=2-
# existing_prediction= -CazymeProteinPrediction, protein=ATY65223.1 A9K55_003996, CAZyme domains=2-
# existing_prediction=[2] -CazymeProteinPrediction, protein=ATY65223.1 A9K55_003996, CAZyme domains=3-
# existing_prediction= -CazymeProteinPrediction, protein=ATY64248.1 A9K55_004102, CAZyme domains=1-
# existing_prediction=[2] -CazymeProteinPrediction, protein=ATY64248.1 A9K55_004102, CAZyme domains=2-
# existing_prediction= -CazymeProteinPrediction, protein=ATY64693.1 A9K55_005188, CAZyme domains=1-
# existing_prediction=[2] -CazymeProteinPrediction, protein=ATY64693.1 A9K55_005188, CAZyme domains=2-
# existing_prediction= -CazymeProteinPrediction, protein=ATY64918.1 A9K55_005214, CAZyme domains=1-
# existing_prediction=[2] -CazymeProteinPrediction, protein=ATY64918.1 A9K55_005214, CAZyme domains=2-
# existing_prediction= -CazymeProteinPrediction, protein=ATY64953.1 A9K55_005326, CAZyme domains=1-
# existing_prediction=[2] -CazymeProteinPrediction, protein=ATY64953.1 A9K55_005326, CAZyme domains=2-
# existing_prediction= -CazymeProteinPrediction, protein=ATY64976.1 A9K55_005332, CAZyme domains=1-
# existing_prediction=[2] -CazymeProteinPrediction, protein=ATY64976.1 A9K55_005332, CAZyme domains=2-
# existing_prediction= -CazymeProteinPrediction, protein=ATY61215.1 A9K55_005410, CAZyme domains=1-
# existing_prediction=[2] -CazymeProteinPrediction, protein=ATY61215.1 A9K55_005410, CAZyme domains=2-
# existing_prediction= -CazymeProteinPrediction, protein=ATY61276.1 A9K55_005467, CAZyme domains=1-
# existing_prediction=[2] -CazymeProteinPrediction, protein=ATY61276.1 A9K55_005467, CAZyme domains=2-
# existing_prediction= -CazymeProteinPrediction, protein=ATY60620.1 A9K55_005793, CAZyme domains=1-
# existing_prediction=[2] -CazymeProteinPrediction, protein=ATY60620.1 A9K55_005793, CAZyme domains=2-
# existing_prediction= -CazymeProteinPrediction, protein=ATY59890.1 A9K55_006062, CAZyme domains=1-
# existing_prediction=[2] -CazymeProteinPrediction, protein=ATY59890.1 A9K55_006062, CAZyme domains=2-
# existing_prediction= -CazymeProteinPrediction, protein=ATY61069.1 A9K55_006802, CAZyme domains=1-
# existing_prediction=[2] -CazymeProteinPrediction, protein=ATY61069.1 A9K55_006802, CAZyme domains=2-
# existing_prediction= -CazymeProteinPrediction, protein=ATY61824.1 A9K55_006988, CAZyme domains=1-
# existing_prediction=[2] -CazymeProteinPrediction, protein=ATY61824.1 A9K55_006988, CAZyme domains=2-
# existing_prediction= -CazymeProteinPrediction, protein=ATY62856.1 A9K55_007728, CAZyme domains=1-
# existing_prediction=[2] -CazymeProteinPrediction, protein=ATY62856.1 A9K55_007728, CAZyme domains=2-
# existing_prediction= -CazymeProteinPrediction, protein=ATY61893.1 A9K55_007772, CAZyme domains=1-
# existing_prediction=[2] -CazymeProteinPrediction, protein=ATY61893.1 A9K55_007772, CAZyme domains=2-
# existing_prediction= -CazymeProteinPrediction, protein=ATY63454.1 A9K55_009028, CAZyme domains=1-
# existing_prediction=[2] -CazymeProteinPrediction, protein=ATY63454.1 A9K55_009028, CAZyme domains=2-
# existing_prediction= -CazymeProteinPrediction, protein=ATY62564.1 A9K55_009060, CAZyme domains=1-
# existing_prediction=[2] -CazymeProteinPrediction, protein=ATY62564.1 A9K55_009060, CAZyme domains=2-
# existing_prediction= -CazymeProteinPrediction, protein=ATY61851.1 A9K55_009292, CAZyme domains=1-
# existing_prediction=[2] -CazymeProteinPrediction, protein=ATY61851.1 A9K55_009292, CAZyme domains=2-
# existing_prediction= -CazymeProteinPrediction, protein=ATY61851.1 A9K55_009292, CAZyme domains=2-
# existing_prediction=[2] -CazymeProteinPrediction, protein=ATY61851.1 A9K55_009292, CAZyme domains=3-
# existing_prediction= -CazymeProteinPrediction, protein=ATY61718.1 A9K55_009347, CAZyme domains=1-
# existing_prediction=[2] -CazymeProteinPrediction, protein=ATY61718.1 A9K55_009347, CAZyme domains=2-
# existing_prediction= -CazymeProteinPrediction, protein=ATY61718.1 A9K55_009347, CAZyme domains=2-
# existing_prediction=[2] -CazymeProteinPrediction, protein=ATY61718.1 A9K55_009347, CAZyme domains=3-
#
# length= 289

# %% [markdown]
# From the print out we can see we are picking up when multiple CAZyme domains are predicted for the same protein. Remember that each CAZyme domain prediction covers 2 lines, therefore, the 644 lines from the output file contains 322 predicted CAZyme domains, some of which are from the same CAZyme.

# %% [markdown]
# <a id="no_caz"></a>

# %% [markdown]
# ## Addining non-CAZymes
#
# The eCAMI output includes all the proteins that eCAMI has predicted at CAZymes. For evaluating the non-CAZyme/CAZyme differentiation performance we need the CAZyme and non-CAZyme classification. Therefore, we can parse the FASTA file that containing the protein sequences used as input by eCAMI and add those that have not been including in the eCAMI output file as non-CAZymes.

# %%
# Read the output file from eCAMI
with open("8080495_output.txt", "r") as fh:
    ecami_file = fh.read().splitlines()

ecami_predictions = {}  # stores proteins {protein_accession:CazymeProteinPrediction_instance}

for line in tqdm(ecami_file, desc="Parsing eCAMI output"):
    if not line.startswith('>'):  # only want the first line for a protien not the listed k-mers
        continue
    
    prediction_output = line.split("\t")
    
    # retrieve protein accession, removing the '>' prefix and stripping white space
    protein_accession = prediction_output[0][1:].strip()
    cazyme_classification = 1
    
    # retrieve the CAZy family
    cazy_family = prediction_output[1].split(":")[0]
    
    # retrieve the CAZy subfamily and EC numbers
    subfam_group = prediction_output[2]
    subfam_group = subfam_group.split("|")

    cazy_subfamilies = []  # store all listed predicted CAZy subfamilies
    ec_numbers = []  # store all predicted EC numbers

    # check if the subfam_group contains a predicted CAZy subfamily
    for item in subfam_group:
        # remove the group number of the predicted item
        item = item.split(":")[0]

        # check if the item contains a CAZy subfamily
        try:
            re.match(r"\D{2,3}\d+_\d+", item).group()
            # check if the subfamily belongs to the CAZy family listed for the current CAZyme domain
            if item[:item.find("_")] == cazy_family:
                cazy_subfamilies.append(item)
            continue  # it was a CAZy subfamily, don't need to check if it was an EC#
    
        except AttributeError:  # raised if the item is not a CAZy subfamily
            pass
        
        # check if item contains an EC number
        try:
            re.match(r"\d+\.(\d+|-)\.(\d+|-)\.(\d+|-)", item).group()
            ec_numbers.append(item)
        except AttributeError:  # raised if the item is not an EC number
            # check if it was a CAZy family, this is for detecting unexpected data types
            try:
                re.match(r"\D{2,3}\d+", item).group()
            except AttributeError:
                print(
                    f"WARNING -- unexpected data type of item '{item}' for protein {protein_accession} "
                    "by eCAMI. Not adding data to parsed data from eCAMI."
                )
    
    # add ECAMIprediction instance to ecami_prediction
    cazyme_classification = 1  # all proteins included in eCAMI output file are identified as CAZymes
    
    if len(cazy_subfamilies) == 0:
        cazy_subfamilies = [np.nan]
    else:
        cazy_subfamilies = ", ".join(cazy_subfamilies)  # convert to string
        
    if len(ec_numbers) == 0:
        ec_numbers = [np.nan]
    
    try:
        # add new predicted CAZyme domain to an existing ECAMIprediction instance
        existing_prediction = ecami_predictions[protein_accession]
        
        # check if the CAZyme domain has already been passed
        existing_cazyme_domains = existing_prediction.cazyme_domains
        existance = False  # becomes true if existing instance found
        for domain in existing_cazyme_domains:
            if (domain.cazy_family == cazy_family) and (domain.cazy_subfamily == cazy_subfamily):
                domain.ec_numbers.append(np.nan)
                existance = True
                print(f"WARNING -- existing cazyme domain found, {protein_accession}, {domain.cazy_family}, {domain.cazy_subfamily}")
                break
        
        if existance is False:
            # create new CAZyme domain
            new_cazyme_domain = CazymeDomain(
                "eCAMI",
                protein_accession,
                cazy_family,
                cazy_subfamilies,
                ec_numbers,
            )
            existing_prediction.cazyme_domains.append(new_cazyme_domain)
    
    except KeyError:  # raised if no corresponding ECAMIprediction instance was found

            new_cazyme_domain = CazymeDomain(
                "eCAMI",
                protein_accession,
                cazy_family,
                cazy_subfamilies,
                ec_numbers,
            )
            
            new_protein = CazymeProteinPrediction(
                "eCAMI",
                protein_accession,
                cazyme_classification,
            )
    
            new_protein.cazyme_domains = [new_cazyme_domain]
            
            ecami_predictions[protein_accession] = new_protein

print("length pre-non-CAZymes =", len(list(ecami_predictions.values())))
            
# Add non-CAZymes
# open the FASTA file containing the input protein sequences
with open("genbank_proteins_txid73501_GCA_008080495_1.fasta", "r") as fh:
    fasta = fh.read().splitlines()
count = 0
for line in tqdm(fasta, desc="Adding non-CAZymes"):
    if line.startswith(">"):
        count += 1
        # remove '>' prefix and white space
        protein_accession = line[1:].strip()
        
        # check if the protein is already listed in the eCAMI predictions
        try:
            ecami_predictions[protein_accession]
        except KeyError:  # raised of protein not in ecami_predictions
            cazyme_classification = 0
            ecami_predictions[protein_accession] = CazymeProteinPrediction(
                "eCAMI",
                protein_accession,
                cazyme_classification,
            )

print("proteins parsed =", len(list(ecami_predictions.values())))
print("proteins in the input FASTA file=", count)
# Out:
# HBox(children=(HTML(value='Parsing eCAMI output'), FloatProgress(value=0.0, max=644.0), HTML(value='')))
# length pre-non-CAZymes = 289
# HBox(children=(HTML(value='Adding non-CAZymes'), FloatProgress(value=0.0, max=93219.0), HTML(value='')))
# proteins parsed = 9287
# proteins in the input FASTA file= 9287

# %% [markdown]
# From counting the proteins in the FASTA file we can see that all proteins are retrieved, and every protein is represented by a `CazymeProteinPrediction` instance.

# %% [markdown]
# <a id="final"></a>

# %% [markdown]
# ## Final functions
#
# We can see above that all the proteins that were contained in the FASTA file, which was used as input by eCAMI, are parsed by the method above. Now we can break this up into functions that are suitable for dropping straigt into `pyrewton` and are easier to follow.

# %%
def parse_ecami_output(ecami_output_path, fasta_path):
    """Parse the output from eCAMI, retrieving predicted CAZyme domains, CAZy (sub)families and EC numbers.
    
    :param ecami_output_path: Path, output text file from eCAMI
    :param fasta_path: Path, FASTA file used as input by eCAMI
    
    Returns a list of ECAMIprediction instances. One instance per protein in the FASTA file used as eCAMI input"""
    # Read the output file from eCAMI
    with open(ecami_output_path, "r") as fh:
        ecami_file = fh.read().splitlines()

    ecami_predictions = {}  # stores proteins {protein_accession:ECAMIprediction_instance}

    for line in tqdm(ecami_file, desc="Parsing eCAMI output"):
        if not line.startswith('>'):  # only want the first line for a protien not the listed k-mers
            continue

        prediction_output = line.split("\t")

        # retrieve protein accession, removing the '>' prefix and stripping white space
        protein_accession = prediction_output[0][1:].strip()

        # retrieve the CAZy family
        cazy_family = prediction_output[1].split(":")[0].strip()

        # retrieve the children CAZy subfamily of the CAZy family and EC number annotations
        cazy_subfamilies, ec_numbers = get_subfamily_ec_numbers(prediction_output[2], cazy_family)

        # add ECAMIprediction instance to ecami_prediction
        cazyme_classification = 1  # all proteins included in eCAMI output file are identified as CAZymes

        try:
            # add new predicted CAZyme domain to an existing ECAMIprediction instance
            existing_prediction = ecami_predictions[protein_accession]

            # check if the CAZyme domain has already been passed
            existing_cazyme_domains = existing_prediction.cazyme_domains
            existance = False
            while existance is False:
                for domain in existing_cazyme_domains:
                    if (domain.cazy_family == cazy_family) and (domain.cazy_subfamily == cazy_subfamily):
                        # Domain has been parsed previously, check if additional EC numbers were retrieved
                        for ec in ec_numbers:
                            if ec not in domain.ec_numbers:
                                domain.ec_numbers.append(ec)
                        existance = True
                # come to the end of existing domains and none match the new CAZyme domain
                break
                

            if existance is False:
                # create new CAZyme domain
                new_cazyme_domain = CazymeDomain(
                    prediction_tool="eCAMI",
                    protein_accession=protein_accession,
                    cazy_family=cazy_family,
                    cazy_subfamily=cazy_subfamilies,
                    ec_numbers=ec_numbers,
                )
                existing_prediction.cazyme_domains.append(new_cazyme_domain)

        except KeyError:  # raised if no corresponding ECAMIprediction instance was found
                new_cazyme_domain = CazymeDomain(
                    prediction_tool="eCAMI",
                    protein_accession=protein_accession,
                    cazy_family=cazy_family,
                    cazy_subfamily=cazy_subfamilies,
                    ec_numbers=ec_numbers,
                )

                new_protein = CazymeProteinPrediction(
                    prediction_tool="eCAMI",
                    protein_accession=protein_accession,
                    cazyme_classification=cazyme_classification,
                )

                new_protein.cazyme_domains.append(new_cazyme_domain)
                
                ecami_predictions[protein_accession] = new_protein

    ecami_predictions = add_non_cazymes(ecami_predictions, fasta_path)
    
    return list(ecami_predictions.values())

                
def get_subfamily_ec_numbers(subfam_group, cazy_family):
    """Retrieve the predicted CAZy subfamily and associated EC numbers.
    
    Retrieves only the child CAZy subfamilies for the CAZy familiy of the current working
    CAZyme domain in the protein. Returns the CAZy subfamilies as a string, and EC numbers
    as a list of string, with each string containing a unique EC number. The 'subfam_group'
    refers to the 'subfam_name_of_the_group:subfam_name_count' in the eCAMI output file.
    
    :param subfam_group: string, the 'subfam_name_of_the_group:subfam_name_count'
    :param cazy_family: string, CAZy family for the current working CAZyme domain
    
    Return the CAZy subfamily for the CAZyme domain (str) and list of associated EC numbers.
    """
    cazy_subfamilies = []  # store all listed predicted CAZy subfamilies
    ec_numbers = []  # store all predicted EC numbers

    # individual items are separated by "|"
    subfam_group = subfam_group.split("|")

    # check if the subfam_group contains a predicted CAZy subfamily
    for item in subfam_group:
        # remove the group number of the predicted item
        item = item.split(":")[0]

        # check if the item contains a CAZy subfamily
        try:
            re.match(r"\D{2,3}\d+_\d+", item).group()
            # check if the subfamily belongs to the CAZy family listed for the current CAZyme domain
            if item[:item.find("_")] == cazy_family:
                cazy_subfamilies.append(item)

        except AttributeError:  # raised if the item is not a CAZy subfamily
            pass

        # check if item contains an EC number
        try:
            re.match(r"\d+\.(\d+|-)\.(\d+|-)\.(\d+|-)", item).group()
            ec_numbers.append(item)

        except AttributeError:  # raised if the item is not an EC number
            pass

    cazy_subfamilies = ", ".join(cazy_subfamilies)  # convert to string

    return cazy_subfamilies, ec_numbers


def add_non_cazymes(ecami_predictions, fasta_path):
    """Add non-CAZymes to the parsed eCAMI output.
    
    The eCAMI output only includes the protein it predicts are CAZymes. Therefore, this function
    goes through the FASTA file that was used as input by eCAMI and adds the proteins not
    classified as CAZymes to the parsed proteins.
    
    :param ecami_predictions: dict, keyed by protein accession and valued by ECAMIprediction instance
    :param fasta_path: Path, FASTA file used as input by eCAMI
    
    Return a dictionary keyed by protein accession and valued by corresponding ECAMIprediction instance.
    """
    # Add non-CAZymes
    # open the FASTA file containing the input protein sequences
    with open(fasta_path, "r") as fh:
        fasta = fh.read().splitlines()

    for line in tqdm(fasta, desc="Adding non-CAZymes"):
        if line.startswith(">"):

            # remove '>' prefix and white space
            protein_accession = line[1:].strip()

            # check if the protein is already listed in the eCAMI predictions
            try:
                ecami_predictions[protein_accession]

            except KeyError:  # raised of protein not in ecami_predictions
                cazyme_classification = 0
                ecami_predictions[protein_accession] = CazymeProteinPrediction(
                    "eCAMI",
                    protein_accession,
                    cazyme_classification,
                )
    
    return ecami_predictions

results = parse_ecami_output("8080495_output.txt", "genbank_proteins_txid73501_GCA_008080495_1.fasta")
print("proteins parsed=", len(results))
print("proteins in the input FASTA file=", 9287)
print("output=", results[0])
# Out:
# HBox(children=(HTML(value='Parsing eCAMI output'), FloatProgress(value=0.0, max=644.0), HTML(value='')))
# HBox(children=(HTML(value='Adding non-CAZymes'), FloatProgress(value=0.0, max=93219.0), HTML(value='')))
# proteins parsed= 9287
# proteins in the input FASTA file= 9287
# output= -CazymeProteinPrediction, protein=ATY67280.1 A9K55_000020, CAZyme domains=1-

# %% [markdown]
# From before we know there are 9,287 proteins in the FASTA file that was parsed by eCAMI, so we can see that all proteins are now stored in the list `results`. We can iterate through the results to makes sure that we retained the CAZyme domain predictions.

# %%
for result in results:
    print(f"{result.protein_accession}, classification={result.cazyme_classification}, domains={len(result.cazyme_domains)}")
# Out:
# ATY67280.1 A9K55_000020, classification=1, domains=1
# ATY67467.1 A9K55_000078, classification=1, domains=1
# ATY67289.1 A9K55_000120, classification=1, domains=2
# ATY67196.1 A9K55_000147, classification=1, domains=1
# ATY67226.1 A9K55_000162, classification=1, domains=1
# ATY67472.1 A9K55_000170, classification=1, domains=1
# ATY67327.1 A9K55_000335, classification=1, domains=1
# ATY67094.1 A9K55_000365, classification=1, domains=1
# ATY67306.1 A9K55_000368, classification=1, domains=1
# ATY67182.1 A9K55_000377, classification=1, domains=1
# ATY67158.1 A9K55_000434, classification=1, domains=1
# ATY67425.1 A9K55_000448, classification=1, domains=1
# ATY67138.1 A9K55_000458, classification=1, domains=1
# ATY66529.1 A9K55_000499, classification=1, domains=2
# ATY66624.1 A9K55_000551, classification=1, domains=1
# ATY67020.1 A9K55_000635, classification=1, domains=1
# ATY66542.1 A9K55_000689, classification=1, domains=1
# ATY66876.1 A9K55_000707, classification=1, domains=1
# ATY66875.1 A9K55_000708, classification=1, domains=1
# ATY66476.1 A9K55_000717, classification=1, domains=1
# ATY66787.1 A9K55_000725, classification=1, domains=1
# ATY66426.1 A9K55_000730, classification=1, domains=1
# ATY66389.1 A9K55_000757, classification=1, domains=1
# ATY66848.1 A9K55_000810, classification=1, domains=1
# ATY66850.1 A9K55_000812, classification=1, domains=1
# ATY66859.1 A9K55_000837, classification=1, domains=1
# ATY67037.1 A9K55_000868, classification=1, domains=1
# ATY66664.1 A9K55_000997, classification=1, domains=2
# ATY66615.1 A9K55_001055, classification=1, domains=1
# ATY66603.1 A9K55_001057, classification=1, domains=1
# ATY66509.1 A9K55_001088, classification=1, domains=1
# ATY66592.1 A9K55_001130, classification=1, domains=1
# ATY66444.1 A9K55_001136, classification=1, domains=2
# ATY65680.1 A9K55_001196, classification=1, domains=1
# ATY65896.1 A9K55_001225, classification=1, domains=1
# ATY65374.1 A9K55_001258, classification=1, domains=1
# ATY66370.1 A9K55_001371, classification=1, domains=1
# ATY66369.1 A9K55_001372, classification=1, domains=1
# ATY66284.1 A9K55_001429, classification=1, domains=1
# ATY65765.1 A9K55_001438, classification=1, domains=1
# ATY66259.1 A9K55_001445, classification=1, domains=1
# ATY66100.1 A9K55_001509, classification=1, domains=1
# ATY66055.1 A9K55_001568, classification=1, domains=1
# ATY66268.1 A9K55_001628, classification=1, domains=1
# ATY65888.1 A9K55_001650, classification=1, domains=1
# ATY66193.1 A9K55_001662, classification=1, domains=1
# ATY66192.1 A9K55_001663, classification=1, domains=1
# ATY66363.1 A9K55_001686, classification=1, domains=1
# ATY65484.1 A9K55_001719, classification=1, domains=1
# ATY65579.1 A9K55_001757, classification=1, domains=1
# ATY65637.1 A9K55_001791, classification=1, domains=2
# ATY65640.1 A9K55_001792, classification=1, domains=1
# ATY65808.1 A9K55_001888, classification=1, domains=1
# ATY65399.1 A9K55_001907, classification=1, domains=1
# ATY66047.1 A9K55_001951, classification=1, domains=1
# ATY65544.1 A9K55_001962, classification=1, domains=1
# ATY65455.1 A9K55_002001, classification=1, domains=1
# ATY66131.1 A9K55_002034, classification=1, domains=1
# ATY65626.1 A9K55_002055, classification=1, domains=1
# ATY65556.1 A9K55_002072, classification=1, domains=1
# ATY65793.1 A9K55_002088, classification=1, domains=1
# ATY65449.1 A9K55_002120, classification=1, domains=1
# ATY65605.1 A9K55_002146, classification=1, domains=1
# ATY58674.1 A9K55_002216, classification=1, domains=1
# ATY59781.1 A9K55_002229, classification=1, domains=1
# ATY59031.1 A9K55_002235, classification=1, domains=1
# ATY59023.1 A9K55_002239, classification=1, domains=2
# ATY59638.1 A9K55_002266, classification=1, domains=1
# ATY58902.1 A9K55_002275, classification=1, domains=1
# ATY58512.1 A9K55_002300, classification=1, domains=1
# ATY58705.1 A9K55_002399, classification=1, domains=1
# ATY59065.1 A9K55_002427, classification=1, domains=1
# ATY58448.1 A9K55_002445, classification=1, domains=1
# ATY59188.1 A9K55_002493, classification=1, domains=3
# ATY59194.1 A9K55_002495, classification=1, domains=1
# ATY58475.1 A9K55_002501, classification=1, domains=1
# ATY58478.1 A9K55_002502, classification=1, domains=1
# ATY59714.1 A9K55_002507, classification=1, domains=1
# ATY59688.1 A9K55_002509, classification=1, domains=1
# ATY59508.1 A9K55_002516, classification=1, domains=1
# ATY59222.1 A9K55_002533, classification=1, domains=1
# ATY58330.1 A9K55_002569, classification=1, domains=1
# ATY58880.1 A9K55_002660, classification=1, domains=1
# ATY59363.1 A9K55_002695, classification=1, domains=1
# ATY59702.1 A9K55_002790, classification=1, domains=1
# ATY58636.1 A9K55_002806, classification=1, domains=1
# ATY59250.1 A9K55_003000, classification=1, domains=1
# ATY59185.1 A9K55_003013, classification=1, domains=1
# ATY58486.1 A9K55_003070, classification=1, domains=2
# ATY58571.1 A9K55_003088, classification=1, domains=1
# ATY59691.1 A9K55_003110, classification=1, domains=1
# ATY59698.1 A9K55_003119, classification=1, domains=2
# ATY58848.1 A9K55_003123, classification=1, domains=3
# ATY58531.1 A9K55_003145, classification=1, domains=1
# ATY58528.1 A9K55_003146, classification=1, domains=1
# ATY58396.1 A9K55_003368, classification=1, domains=1
# ATY59093.1 A9K55_003437, classification=1, domains=1
# ATY58895.1 A9K55_003453, classification=1, domains=1
# ATY58615.1 A9K55_003532, classification=1, domains=1
# ATY58494.1 A9K55_003598, classification=1, domains=1
# ATY59671.1 A9K55_003678, classification=1, domains=1
# ATY58803.1 A9K55_003729, classification=1, domains=1
# ATY58579.1 A9K55_003748, classification=1, domains=1
# ATY64150.1 A9K55_003806, classification=1, domains=1
# ATY65020.1 A9K55_003841, classification=1, domains=1
# ATY64517.1 A9K55_003852, classification=1, domains=1
# ATY64049.1 A9K55_003885, classification=1, domains=1
# ATY64047.1 A9K55_003887, classification=1, domains=1
# ATY64671.1 A9K55_003892, classification=1, domains=1
# ATY65223.1 A9K55_003996, classification=1, domains=3
# ATY65222.1 A9K55_003997, classification=1, domains=1
# ATY64043.1 A9K55_004035, classification=1, domains=1
# ATY64478.1 A9K55_004080, classification=1, domains=1
# ATY64479.1 A9K55_004081, classification=1, domains=1
# ATY64475.1 A9K55_004085, classification=1, domains=1
# ATY65106.1 A9K55_004092, classification=1, domains=1
# ATY64248.1 A9K55_004102, classification=1, domains=2
# ATY64179.1 A9K55_004244, classification=1, domains=1
# ATY64503.1 A9K55_004410, classification=1, domains=1
# ATY65081.1 A9K55_004414, classification=1, domains=1
# ATY64461.1 A9K55_004439, classification=1, domains=1
# ATY63982.1 A9K55_004448, classification=1, domains=1
# ATY64570.1 A9K55_004478, classification=1, domains=1
# ATY65116.1 A9K55_004517, classification=1, domains=1
# ATY64088.1 A9K55_004548, classification=1, domains=1
# ATY64117.1 A9K55_004560, classification=1, domains=1
# ATY64005.1 A9K55_004587, classification=1, domains=1
# ATY64015.1 A9K55_004633, classification=1, domains=1
# ATY64437.1 A9K55_004647, classification=1, domains=1
# ATY65191.1 A9K55_004703, classification=1, domains=1
# ATY64416.1 A9K55_004740, classification=1, domains=1
# ATY65055.1 A9K55_004754, classification=1, domains=1
# ATY64233.1 A9K55_004845, classification=1, domains=1
# ATY64186.1 A9K55_004865, classification=1, domains=1
# ATY63987.1 A9K55_004917, classification=1, domains=1
# ATY63993.1 A9K55_004919, classification=1, domains=1
# ATY64700.1 A9K55_005048, classification=1, domains=1
# ATY64850.1 A9K55_005139, classification=1, domains=1
# ATY64843.1 A9K55_005141, classification=1, domains=1
# ATY64752.1 A9K55_005144, classification=1, domains=1
# ATY64802.1 A9K55_005156, classification=1, domains=1
# ATY64693.1 A9K55_005188, classification=1, domains=2
# ATY64918.1 A9K55_005214, classification=1, domains=2
# ATY64924.1 A9K55_005237, classification=1, domains=1
# ATY64774.1 A9K55_005248, classification=1, domains=1
# ATY64941.1 A9K55_005307, classification=1, domains=1
# ATY65010.1 A9K55_005325, classification=1, domains=1
# ATY64953.1 A9K55_005326, classification=1, domains=2
# ATY64976.1 A9K55_005332, classification=1, domains=2
# ATY64996.1 A9K55_005365, classification=1, domains=1
# ATY64776.1 A9K55_005375, classification=1, domains=1
# ATY61215.1 A9K55_005410, classification=1, domains=2
# ATY61276.1 A9K55_005467, classification=1, domains=2
# ATY60491.1 A9K55_005473, classification=1, domains=1
# ATY60162.1 A9K55_005494, classification=1, domains=1
# ATY60851.1 A9K55_005503, classification=1, domains=1
# ATY59887.1 A9K55_005594, classification=1, domains=1
# ATY61113.1 A9K55_005625, classification=1, domains=1
# ATY60504.1 A9K55_005694, classification=1, domains=1
# ATY60772.1 A9K55_005735, classification=1, domains=1
# ATY60733.1 A9K55_005759, classification=1, domains=1
# ATY60620.1 A9K55_005793, classification=1, domains=2
# ATY61243.1 A9K55_005879, classification=1, domains=1
# ATY61188.1 A9K55_005900, classification=1, domains=1
# ATY60372.1 A9K55_005930, classification=1, domains=1
# ATY60094.1 A9K55_005934, classification=1, domains=1
# ATY60408.1 A9K55_005935, classification=1, domains=1
# ATY60044.1 A9K55_005991, classification=1, domains=1
# ATY60878.1 A9K55_005992, classification=1, domains=1
# ATY59933.1 A9K55_006003, classification=1, domains=1
# ATY60662.1 A9K55_006052, classification=1, domains=1
# ATY60260.1 A9K55_006056, classification=1, domains=1
# ATY59890.1 A9K55_006062, classification=1, domains=2
# ATY60591.1 A9K55_006069, classification=1, domains=1
# ATY61301.1 A9K55_006085, classification=1, domains=1
# ATY60251.1 A9K55_006130, classification=1, domains=1
# ATY60133.1 A9K55_006186, classification=1, domains=1
# ATY61140.1 A9K55_006190, classification=1, domains=1
# ATY59987.1 A9K55_006195, classification=1, domains=1
# ATY59985.1 A9K55_006197, classification=1, domains=1
# ATY60723.1 A9K55_006254, classification=1, domains=1
# ATY60726.1 A9K55_006259, classification=1, domains=1
# ATY60246.1 A9K55_006265, classification=1, domains=1
# ATY60146.1 A9K55_006444, classification=1, domains=1
# ATY60986.1 A9K55_006566, classification=1, domains=1
# ATY60976.1 A9K55_006569, classification=1, domains=1
# ATY60681.1 A9K55_006585, classification=1, domains=1
# ATY61117.1 A9K55_006602, classification=1, domains=1
# ATY59877.1 A9K55_006614, classification=1, domains=1
# ATY59959.1 A9K55_006641, classification=1, domains=1
# ATY60613.1 A9K55_006643, classification=1, domains=1
# ATY61006.1 A9K55_006682, classification=1, domains=1
# ATY60261.1 A9K55_006695, classification=1, domains=1
# ATY61147.1 A9K55_006704, classification=1, domains=1
# ATY60186.1 A9K55_006733, classification=1, domains=1
# ATY60914.1 A9K55_006785, classification=1, domains=1
# ATY61069.1 A9K55_006802, classification=1, domains=2
# ATY60330.1 A9K55_006814, classification=1, domains=1
# ATY60312.1 A9K55_006832, classification=1, domains=1
# ATY60866.1 A9K55_006860, classification=1, domains=1
# ATY60416.1 A9K55_006911, classification=1, domains=1
# ATY60629.1 A9K55_006921, classification=1, domains=1
# ATY63210.1 A9K55_006963, classification=1, domains=1
# ATY61824.1 A9K55_006988, classification=1, domains=2
# ATY63573.1 A9K55_007006, classification=1, domains=1
# ATY63305.1 A9K55_007018, classification=1, domains=1
# ATY62740.1 A9K55_007050, classification=1, domains=1
# ATY63588.1 A9K55_007112, classification=1, domains=1
# ATY62702.1 A9K55_007186, classification=1, domains=1
# ATY63228.1 A9K55_007204, classification=1, domains=1
# ATY63227.1 A9K55_007205, classification=1, domains=1
# ATY61835.1 A9K55_007236, classification=1, domains=1
# ATY61836.1 A9K55_007237, classification=1, domains=1
# ATY62798.1 A9K55_007286, classification=1, domains=1
# ATY61788.1 A9K55_007308, classification=1, domains=1
# ATY62458.1 A9K55_007344, classification=1, domains=1
# ATY62242.1 A9K55_007385, classification=1, domains=1
# ATY62132.1 A9K55_007428, classification=1, domains=1
# ATY61914.1 A9K55_007445, classification=1, domains=1
# ATY62742.1 A9K55_007512, classification=1, domains=1
# ATY62663.1 A9K55_007537, classification=1, domains=1
# ATY62551.1 A9K55_007577, classification=1, domains=1
# ATY61863.1 A9K55_007583, classification=1, domains=1
# ATY61865.1 A9K55_007591, classification=1, domains=1
# ATY62109.1 A9K55_007617, classification=1, domains=1
# ATY63255.1 A9K55_007626, classification=1, domains=1
# ATY61595.1 A9K55_007720, classification=1, domains=1
# ATY62856.1 A9K55_007728, classification=1, domains=2
# ATY61893.1 A9K55_007772, classification=1, domains=2
# ATY61890.1 A9K55_007781, classification=1, domains=1
# ATY61850.1 A9K55_007851, classification=1, domains=1
# ATY61741.1 A9K55_007939, classification=1, domains=1
# ATY63087.1 A9K55_007963, classification=1, domains=1
# ATY61965.1 A9K55_007977, classification=1, domains=1
# ATY61957.1 A9K55_007981, classification=1, domains=1
# ATY62614.1 A9K55_008059, classification=1, domains=1
# ATY62721.1 A9K55_008098, classification=1, domains=1
# ATY61576.1 A9K55_008166, classification=1, domains=1
# ATY62757.1 A9K55_008177, classification=1, domains=1
# ATY62039.1 A9K55_008189, classification=1, domains=1
# ATY62092.1 A9K55_008237, classification=1, domains=1
# ATY61926.1 A9K55_008281, classification=1, domains=1
# ATY62784.1 A9K55_008286, classification=1, domains=1
# ATY63618.1 A9K55_008330, classification=1, domains=1
# ATY63447.1 A9K55_008365, classification=1, domains=1
# ATY63344.1 A9K55_008387, classification=1, domains=1
# ATY61753.1 A9K55_008467, classification=1, domains=1
# ATY62412.1 A9K55_008485, classification=1, domains=1
# ATY63636.1 A9K55_008500, classification=1, domains=1
# ATY62685.1 A9K55_008522, classification=1, domains=1
# ATY62684.1 A9K55_008523, classification=1, domains=1
# ATY62235.1 A9K55_008585, classification=1, domains=1
# ATY62233.1 A9K55_008587, classification=1, domains=1
# ATY62465.1 A9K55_008672, classification=1, domains=1
# ATY62578.1 A9K55_008696, classification=1, domains=1
# ATY63039.1 A9K55_008757, classification=1, domains=1
# ATY62951.1 A9K55_008799, classification=1, domains=1
# ATY61678.1 A9K55_008828, classification=1, domains=1
# ATY62908.1 A9K55_008835, classification=1, domains=1
# ATY61989.1 A9K55_008846, classification=1, domains=1
# ATY63528.1 A9K55_008918, classification=1, domains=1
# ATY63601.1 A9K55_008940, classification=1, domains=1
# ATY62175.1 A9K55_008949, classification=1, domains=1
# ATY63319.1 A9K55_008952, classification=1, domains=1
# ATY62278.1 A9K55_008962, classification=1, domains=1
# ATY63412.1 A9K55_008981, classification=1, domains=1
# ATY62020.1 A9K55_008982, classification=1, domains=1
# ATY63454.1 A9K55_009028, classification=1, domains=2
# ATY63688.1 A9K55_009031, classification=1, domains=1
# ATY62564.1 A9K55_009060, classification=1, domains=2
# ATY62143.1 A9K55_009133, classification=1, domains=1
# ATY63360.1 A9K55_009150, classification=1, domains=1
# ATY63468.1 A9K55_009166, classification=1, domains=1
# ATY62933.1 A9K55_009229, classification=1, domains=1
# ATY62385.1 A9K55_009239, classification=1, domains=1
# ATY63705.1 A9K55_009247, classification=1, domains=1
# ATY63703.1 A9K55_009249, classification=1, domains=1
# ATY63707.1 A9K55_009251, classification=1, domains=1
# ATY61355.1 A9K55_009281, classification=1, domains=1
# ATY62147.1 A9K55_009282, classification=1, domains=1
# ATY62125.1 A9K55_009287, classification=1, domains=1
# ATY61851.1 A9K55_009292, classification=1, domains=3
# ATY61853.1 A9K55_009293, classification=1, domains=1
# ATY63072.1 A9K55_009339, classification=1, domains=1
# ATY63066.1 A9K55_009341, classification=1, domains=1
# ATY61713.1 A9K55_009342, classification=1, domains=1
# ATY62565.1 A9K55_009061, classification=0, domains=0
# ATY62086.1 A9K55_009062, classification=0, domains=0
# ATY61438.1 A9K55_009063, classification=0, domains=0
# ATY62085.1 A9K55_009064, classification=0, domains=0
# ATY62084.1 A9K55_009065, classification=0, domains=0
# ATY62087.1 A9K55_009066, classification=0, domains=0
# ATY61441.1 A9K55_009067, classification=0, domains=0
# ATY61440.1 A9K55_009068, classification=0, domains=0
# ATY61439.1 A9K55_009069, classification=0, domains=0
# ATY62083.1 A9K55_009070, classification=0, domains=0
# ATY63733.1 A9K55_009071, classification=0, domains=0
# ATY61789.1 A9K55_009072, classification=0, domains=0
# ATY62646.1 A9K55_009073, classification=0, domains=0
# ATY61790.1 A9K55_009074, classification=0, domains=0
# ATY61791.1 A9K55_009075, classification=0, domains=0
# ATY61792.1 A9K55_009076, classification=0, domains=0
# ATY61793.1 A9K55_009077, classification=0, domains=0
# ATY61794.1 A9K55_009078, classification=0, domains=0
# ATY61795.1 A9K55_009079, classification=0, domains=0
# ATY62644.1 A9K55_009080, classification=0, domains=0
# ATY62645.1 A9K55_009081, classification=0, domains=0
# ATY63428.1 A9K55_009082, classification=0, domains=0
# ATY63427.1 A9K55_009083, classification=0, domains=0
# ATY63430.1 A9K55_009084, classification=0, domains=0
# ATY63429.1 A9K55_009085, classification=0, domains=0
# ATY63424.1 A9K55_009086, classification=0, domains=0
# ATY63423.1 A9K55_009087, classification=0, domains=0
# ATY63426.1 A9K55_009088, classification=0, domains=0
# ATY63425.1 A9K55_009089, classification=0, domains=0
# ATY63432.1 A9K55_009090, classification=0, domains=0
# ATY63431.1 A9K55_009091, classification=0, domains=0
# ATY62199.1 A9K55_009092, classification=0, domains=0
# ATY62200.1 A9K55_009093, classification=0, domains=0
# ATY62197.1 A9K55_009094, classification=0, domains=0
# ATY62198.1 A9K55_009095, classification=0, domains=0
# ATY62203.1 A9K55_009096, classification=0, domains=0
# ATY62204.1 A9K55_009097, classification=0, domains=0
# ATY62201.1 A9K55_009098, classification=0, domains=0
# ATY62202.1 A9K55_009099, classification=0, domains=0
# ATY62195.1 A9K55_009100, classification=0, domains=0
# ATY62196.1 A9K55_009101, classification=0, domains=0
# ATY63191.1 A9K55_009102, classification=0, domains=0
# ATY63192.1 A9K55_009103, classification=0, domains=0
# ATY63193.1 A9K55_009104, classification=0, domains=0
# ATY63194.1 A9K55_009105, classification=0, domains=0
# ATY63187.1 A9K55_009106, classification=0, domains=0
# ATY63188.1 A9K55_009107, classification=0, domains=0
# ATY63189.1 A9K55_009108, classification=0, domains=0
# ATY63190.1 A9K55_009109, classification=0, domains=0
# ATY63195.1 A9K55_009110, classification=0, domains=0
# ATY63196.1 A9K55_009111, classification=0, domains=0
# ATY63288.1 A9K55_009112, classification=0, domains=0
# ATY62080.1 A9K55_009113, classification=0, domains=0
# ATY62079.1 A9K55_009114, classification=0, domains=0
# ATY62078.1 A9K55_009116, classification=0, domains=0
# ATY62077.1 A9K55_009117, classification=0, domains=0
# ATY63287.1 A9K55_009118, classification=0, domains=0
# ATY62075.1 A9K55_009119, classification=0, domains=0
# ATY62082.1 A9K55_009120, classification=0, domains=0
# ATY62081.1 A9K55_009121, classification=0, domains=0
# ATY63291.1 A9K55_009122, classification=0, domains=0
# ATY63292.1 A9K55_009123, classification=0, domains=0
# ATY63289.1 A9K55_009124, classification=0, domains=0
# ATY63290.1 A9K55_009125, classification=0, domains=0
# ATY63295.1 A9K55_009126, classification=0, domains=0
# ATY63296.1 A9K55_009127, classification=0, domains=0
# ATY63293.1 A9K55_009128, classification=0, domains=0
# ATY63294.1 A9K55_009129, classification=0, domains=0
# ATY63297.1 A9K55_009130, classification=0, domains=0
# ATY63298.1 A9K55_009131, classification=0, domains=0
# ATY62144.1 A9K55_009132, classification=0, domains=0
# ATY62145.1 A9K55_009134, classification=0, domains=0
# ATY62140.1 A9K55_009136, classification=0, domains=0
# ATY62139.1 A9K55_009137, classification=0, domains=0
# ATY62142.1 A9K55_009138, classification=0, domains=0
# ATY62141.1 A9K55_009139, classification=0, domains=0
# ATY62138.1 A9K55_009140, classification=0, domains=0
# ATY62137.1 A9K55_009141, classification=0, domains=0
# ATY63362.1 A9K55_009142, classification=0, domains=0
# ATY63363.1 A9K55_009143, classification=0, domains=0
# ATY63364.1 A9K55_009144, classification=0, domains=0
# ATY61607.1 A9K55_009145, classification=0, domains=0
# ATY61608.1 A9K55_009146, classification=0, domains=0
# ATY61609.1 A9K55_009147, classification=0, domains=0
# ATY61610.1 A9K55_009148, classification=0, domains=0
# ATY61611.1 A9K55_009149, classification=0, domains=0
# ATY63361.1 A9K55_009151, classification=0, domains=0
# ATY61925.1 A9K55_009152, classification=0, domains=0
# ATY61924.1 A9K55_009153, classification=0, domains=0
# ATY61923.1 A9K55_009154, classification=0, domains=0
# ATY61922.1 A9K55_009155, classification=0, domains=0
# ATY62587.1 A9K55_009156, classification=0, domains=0
# ATY62586.1 A9K55_009157, classification=0, domains=0
# ATY62219.1 A9K55_009158, classification=0, domains=0
# ATY62583.1 A9K55_009159, classification=0, domains=0
# ATY61921.1 A9K55_009160, classification=0, domains=0
# ATY61920.1 A9K55_009161, classification=0, domains=0
# ATY62152.1 A9K55_009162, classification=0, domains=0
# ATY63469.1 A9K55_009163, classification=0, domains=0
# ATY62150.1 A9K55_009164, classification=0, domains=0
# ATY62151.1 A9K55_009165, classification=0, domains=0
# ATY63659.1 A9K55_009167, classification=0, domains=0
# ATY62148.1 A9K55_009168, classification=0, domains=0
# ATY62149.1 A9K55_009169, classification=0, domains=0
# ATY63675.1 A9K55_009170, classification=0, domains=0
# ATY63470.1 A9K55_009171, classification=0, domains=0
# ATY62429.1 A9K55_009172, classification=0, domains=0
# ATY62428.1 A9K55_009173, classification=0, domains=0
# ATY62431.1 A9K55_009174, classification=0, domains=0
# ATY62430.1 A9K55_009175, classification=0, domains=0
# ATY62436.1 A9K55_009176, classification=0, domains=0
# ATY62432.1 A9K55_009177, classification=0, domains=0
# ATY62442.1 A9K55_009178, classification=0, domains=0
# ATY62441.1 A9K55_009179, classification=0, domains=0
# ATY62321.1 A9K55_009180, classification=0, domains=0
# ATY62320.1 A9K55_009181, classification=0, domains=0
# ATY62866.1 A9K55_009182, classification=0, domains=0
# ATY62867.1 A9K55_009183, classification=0, domains=0
# ATY62868.1 A9K55_009184, classification=0, domains=0
# ATY62869.1 A9K55_009185, classification=0, domains=0
# ATY62862.1 A9K55_009186, classification=0, domains=0
# ATY62863.1 A9K55_009187, classification=0, domains=0
# ATY62864.1 A9K55_009188, classification=0, domains=0
# ATY62865.1 A9K55_009189, classification=0, domains=0
# ATY62860.1 A9K55_009190, classification=0, domains=0
# ATY62861.1 A9K55_009191, classification=0, domains=0
# ATY63687.1 A9K55_009192, classification=0, domains=0
# ATY61703.1 A9K55_009193, classification=0, domains=0
# ATY61702.1 A9K55_009194, classification=0, domains=0
# ATY61701.1 A9K55_009195, classification=0, domains=0
# ATY61700.1 A9K55_009196, classification=0, domains=0
# ATY61699.1 A9K55_009197, classification=0, domains=0
# ATY63685.1 A9K55_009198, classification=0, domains=0
# ATY61698.1 A9K55_009199, classification=0, domains=0
# ATY61697.1 A9K55_009200, classification=0, domains=0
# ATY61696.1 A9K55_009201, classification=0, domains=0
# ATY62545.1 A9K55_009202, classification=0, domains=0
# ATY62544.1 A9K55_009203, classification=0, domains=0
# ATY63537.1 A9K55_009204, classification=0, domains=0
# ATY63536.1 A9K55_009205, classification=0, domains=0
# ATY63535.1 A9K55_009206, classification=0, domains=0
# ATY63534.1 A9K55_009207, classification=0, domains=0
# ATY63533.1 A9K55_009208, classification=0, domains=0
# ATY63532.1 A9K55_009209, classification=0, domains=0
# ATY63531.1 A9K55_009210, classification=0, domains=0
# ATY63530.1 A9K55_009211, classification=0, domains=0
# ATY62285.1 A9K55_009212, classification=0, domains=0
# ATY62286.1 A9K55_009213, classification=0, domains=0
# ATY62287.1 A9K55_009214, classification=0, domains=0
# ATY61704.1 A9K55_009215, classification=0, domains=0
# ATY61400.1 A9K55_009216, classification=0, domains=0
# ATY62283.1 A9K55_009217, classification=0, domains=0
# ATY62284.1 A9K55_009218, classification=0, domains=0
# ATY61401.1 A9K55_009219, classification=0, domains=0
# ATY62281.1 A9K55_009220, classification=0, domains=0
# ATY62282.1 A9K55_009221, classification=0, domains=0
# ATY63604.1 A9K55_009222, classification=0, domains=0
# ATY62513.1 A9K55_009223, classification=0, domains=0
# ATY62517.1 A9K55_009224, classification=0, domains=0
# ATY62934.1 A9K55_009225, classification=0, domains=0
# ATY63603.1 A9K55_009226, classification=0, domains=0
# ATY62503.1 A9K55_009228, classification=0, domains=0
# ATY63606.1 A9K55_009230, classification=0, domains=0
# ATY63605.1 A9K55_009231, classification=0, domains=0
# ATY62383.1 A9K55_009232, classification=0, domains=0
# ATY62384.1 A9K55_009233, classification=0, domains=0
# ATY62381.1 A9K55_009234, classification=0, domains=0
# ATY62382.1 A9K55_009235, classification=0, domains=0
# ATY62386.1 A9K55_009236, classification=0, domains=0
# ATY62387.1 A9K55_009237, classification=0, domains=0
# ATY63731.1 A9K55_009238, classification=0, domains=0
# ATY62726.1 A9K55_009240, classification=0, domains=0
# ATY63709.1 A9K55_009241, classification=0, domains=0
# ATY63702.1 A9K55_009242, classification=0, domains=0
# ATY63701.1 A9K55_009243, classification=0, domains=0
# ATY63700.1 A9K55_009244, classification=0, domains=0
# ATY63699.1 A9K55_009245, classification=0, domains=0
# ATY63706.1 A9K55_009246, classification=0, domains=0
# ATY63704.1 A9K55_009248, classification=0, domains=0
# ATY63708.1 A9K55_009250, classification=0, domains=0
# ATY62504.1 A9K55_009252, classification=0, domains=0
# ATY62505.1 A9K55_009253, classification=0, domains=0
# ATY62506.1 A9K55_009254, classification=0, domains=0
# ATY63214.1 A9K55_009255, classification=0, domains=0
# ATY62507.1 A9K55_009256, classification=0, domains=0
# ATY62508.1 A9K55_009257, classification=0, domains=0
# ATY62509.1 A9K55_009258, classification=0, domains=0
# ATY62510.1 A9K55_009259, classification=0, domains=0
# ATY62511.1 A9K55_009260, classification=0, domains=0
# ATY62512.1 A9K55_009261, classification=0, domains=0
# ATY61569.1 A9K55_009262, classification=0, domains=0
# ATY61568.1 A9K55_009263, classification=0, domains=0
# ATY61571.1 A9K55_009264, classification=0, domains=0
# ATY61570.1 A9K55_009265, classification=0, domains=0
# ATY61573.1 A9K55_009266, classification=0, domains=0
# ATY61572.1 A9K55_009267, classification=0, domains=0
# ATY61574.1 A9K55_009268, classification=0, domains=0
# ATY62331.1 A9K55_009269, classification=0, domains=0
# ATY61396.1 A9K55_009270, classification=0, domains=0
# ATY61395.1 A9K55_009271, classification=0, domains=0
# ATY63488.1 A9K55_009272, classification=0, domains=0
# ATY63489.1 A9K55_009273, classification=0, domains=0
# ATY63476.1 A9K55_009274, classification=0, domains=0
# ATY63477.1 A9K55_009275, classification=0, domains=0
# ATY63474.1 A9K55_009276, classification=0, domains=0
# ATY63475.1 A9K55_009277, classification=0, domains=0
# ATY63471.1 A9K55_009278, classification=0, domains=0
# ATY63472.1 A9K55_009279, classification=0, domains=0
# ATY61354.1 A9K55_009280, classification=0, domains=0
# ATY62146.1 A9K55_009283, classification=0, domains=0
# ATY62099.1 A9K55_009284, classification=0, domains=0
# ATY63640.1 A9K55_009285, classification=0, domains=0
# ATY62126.1 A9K55_009286, classification=0, domains=0
# ATY62123.1 A9K55_009288, classification=0, domains=0
# ATY62122.1 A9K55_009289, classification=0, domains=0
# ATY61443.1 A9K55_009290, classification=0, domains=0
# ATY61442.1 A9K55_009291, classification=0, domains=0
# ATY61854.1 A9K55_009294, classification=0, domains=0
# ATY61855.1 A9K55_009295, classification=0, domains=0
# ATY61840.1 A9K55_009296, classification=0, domains=0
# ATY62647.1 A9K55_009297, classification=0, domains=0
# ATY63349.1 A9K55_009298, classification=0, domains=0
# ATY61849.1 A9K55_009299, classification=0, domains=0
# ATY61866.1 A9K55_009300, classification=0, domains=0
# ATY61867.1 A9K55_009301, classification=0, domains=0
# ATY61949.1 A9K55_009302, classification=0, domains=0
# ATY61950.1 A9K55_009303, classification=0, domains=0
# ATY61947.1 A9K55_009304, classification=0, domains=0
# ATY61948.1 A9K55_009305, classification=0, domains=0
# ATY62542.1 A9K55_009306, classification=0, domains=0
# ATY62543.1 A9K55_009307, classification=0, domains=0
# ATY61945.1 A9K55_009308, classification=0, domains=0
# ATY61946.1 A9K55_009309, classification=0, domains=0
# ATY63734.1 A9K55_009310, classification=0, domains=0
# ATY62546.1 A9K55_009311, classification=0, domains=0
# ATY62514.1 A9K55_009312, classification=0, domains=0
# ATY63336.1 A9K55_009313, classification=0, domains=0
# ATY62516.1 A9K55_009314, classification=0, domains=0
# ATY62515.1 A9K55_009315, classification=0, domains=0
# ATY63379.1 A9K55_009316, classification=0, domains=0
# ATY62518.1 A9K55_009317, classification=0, domains=0
# ATY62540.1 A9K55_009318, classification=0, domains=0
# ATY62529.1 A9K55_009319, classification=0, domains=0
# ATY63134.1 A9K55_009320, classification=0, domains=0
# ATY63133.1 A9K55_009321, classification=0, domains=0
# ATY61841.1 A9K55_009322, classification=0, domains=0
# ATY61842.1 A9K55_009323, classification=0, domains=0
# ATY61843.1 A9K55_009324, classification=0, domains=0
# ATY61844.1 A9K55_009325, classification=0, domains=0
# ATY61845.1 A9K55_009326, classification=0, domains=0
# ATY61846.1 A9K55_009327, classification=0, domains=0
# ATY61847.1 A9K55_009328, classification=0, domains=0
# ATY61848.1 A9K55_009329, classification=0, domains=0
# ATY61839.1 A9K55_009330, classification=0, domains=0
# ATY61398.1 A9K55_009331, classification=0, domains=0
# ATY63071.1 A9K55_009332, classification=0, domains=0
# ATY63070.1 A9K55_009333, classification=0, domains=0
# ATY63069.1 A9K55_009334, classification=0, domains=0
# ATY63068.1 A9K55_009335, classification=0, domains=0
# ATY62220.1 A9K55_009336, classification=0, domains=0
# ATY63074.1 A9K55_009337, classification=0, domains=0
# ATY63073.1 A9K55_009338, classification=0, domains=0
# ATY63067.1 A9K55_009340, classification=0, domains=0
# ATY61714.1 A9K55_009343, classification=0, domains=0
# ATY61711.1 A9K55_009344, classification=0, domains=0
# ATY61712.1 A9K55_009345, classification=0, domains=0
# ATY61717.1 A9K55_009346, classification=0, domains=0
# ATY61715.1 A9K55_009348, classification=0, domains=0
# ATY61719.1 A9K55_009350, classification=0, domains=0
# ATY61720.1 A9K55_009351, classification=0, domains=0
# ATY62983.1 A9K55_009352, classification=0, domains=0
# ATY62982.1 A9K55_009353, classification=0, domains=0
# ATY62985.1 A9K55_009354, classification=0, domains=0
# ATY62984.1 A9K55_009355, classification=0, domains=0
# ATY62979.1 A9K55_009356, classification=0, domains=0
# ATY62978.1 A9K55_009357, classification=0, domains=0
# ATY62980.1 A9K55_009359, classification=0, domains=0
# ATY62977.1 A9K55_009360, classification=0, domains=0
# ATY62976.1 A9K55_009361, classification=0, domains=0
# ATY61649.1 A9K55_009362, classification=0, domains=0
# ATY61650.1 A9K55_009363, classification=0, domains=0
# ATY61651.1 A9K55_009364, classification=0, domains=0
# ATY61652.1 A9K55_009365, classification=0, domains=0
# ATY61645.1 A9K55_009366, classification=0, domains=0
# ATY61646.1 A9K55_009367, classification=0, domains=0
# ATY61647.1 A9K55_009368, classification=0, domains=0
# ATY61648.1 A9K55_009369, classification=0, domains=0
# ATY61653.1 A9K55_009371, classification=0, domains=0
