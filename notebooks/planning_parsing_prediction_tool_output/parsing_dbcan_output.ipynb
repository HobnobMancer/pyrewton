# %% [markdown]
# # Parsing the output from dbCAN
#
# The CAZyme prediction tools write out their output files in different formats, and do not present the data in a standardised manner across all tools. Additionally, the output from the prediction tools does not enable easy parsing of the data by the [Sklearn](https://scikit-learn.org/stable/index.html) library, which performs the statistical analysis of the tools preformances.
#
# This notebook explains the theorlogy and method used by the `pyrewton.cazymes.prediction.parse` submodule to parse the output from the CAZyme prediction tool dbCAN.
#
# [dbCAN](https://pubmed.ncbi.nlm.nih.gov/29771380/) is a CAZyme prediction tool that incorporates 3 protein function prediction tools:
# - [DIAMOND](https://pubmed.ncbi.nlm.nih.gov/25402007/) - predicts protein function based on sequence identitiy, and is very similar in approach to BLAST.
# - [HMMER](https://pubmed.ncbi.nlm.nih.gov/29905871/) - predicts protein function based upon sequence identity measured by comparing hidden Markov models (HMMs)
# - [Hotpep](https://link.springer.com/article/10.1186/s12859-017-1625-9) - k-mer based protein function prediction
#
# The prediction outputs from DIAMOND, HMMER and Hotpep are separated and the consensus result (results that at least two of the results agree on) are collected and defined as the dbCAN consensus result (as is the practise of the dbCAN developers).
#
# ### Notebook structure
#
# The section titled 'exploring the output' shows the exploration of the tools output files. This is to demonstrate how the data is constructed and presented, and forms a foundation for explaining the developed method of parsing the data.
#
# The section 'parsing the output' shows the method of parsing the data from the CAZyme prediction tool.
#
# The final section shows any additional parsing that was performed to make the statistical analysis of the tool's performance easier. This typically includes removing duplicates, and combining rows that represent data for the same predicted CAZyme.

# %% [markdown]
# ## Contents
#
# - [Imports](#notebook_imports)
# - [Exploring the output file of dbCAN](#outputfiles)
#     - [Overview.txt output file](#exp_over)
#     - [HMMER.out output file](#exp_hmmer)
#     - [DIAMOND.out output file](#exp_diamond)
#     - [Hotpep.out output file](#exp_hotpep)
#     - [uniIinput output file](#exp_uniinput)
# - [Choosing the dbCAN output data and files to parse](#choice)
# _______________________________________________________________________________________________
# - [Parsing the overview.txt file](#par_over)
# - [Defining the data model](#model)
#     - [HMMER](#hmmer)
#         - [Parsing HMMER data from overview.txt](#over_hmmer)
#     - [Hotpep](#hotpep)
#         - [Parsing Hotpep data from overview.txt](#over_hotpep)
#         - [Parsing the Hotpep.out file](#hotpep_out)
#     - [DIAMOND](#diamond)
#         - [Parsing DIAMOND data from overview.txt](#over_diamond)
#     - [dbCAN (consensus result)](#dbcan)
#         - [Retrieving the HMMER, Hotpep and DIAMOND data for each line in the overview.txt file](#retrieve_hmmer_hotpep_diamond)
#         - [Getting the dbCAN consensus](#dbcan_con)
#     - [Retrieve non-CAZymes](#non-caz)
# - [The Final Functions](#final_fun)

# %% [markdown]
# <a id="notebook_imports"></a>

# %% [markdown]
# ## Imports

# %%
# Install necessary libraries
# !pip3 install pandas
# !pip3 install numpy

import re

import pandas as pd
import numpy as np

from tqdm.notebook import tqdm
# Out:
# Requirement already satisfied: pandas in /home/em/.local/lib/python3.8/site-packages (1.1.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/em/anaconda3/lib/python3.8/site-packages (from pandas) (2.8.1)
# Requirement already satisfied: numpy>=1.15.4 in /home/em/.local/lib/python3.8/site-packages (from pandas) (1.19.4)
# Requirement already satisfied: pytz>=2017.2 in /home/em/anaconda3/lib/python3.8/site-packages (from pandas) (2020.1)
# Requirement already satisfied: six>=1.5 in /home/em/anaconda3/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)
# Requirement already satisfied: numpy in /home/em/.local/lib/python3.8/site-packages (1.19.4)

# %% [markdown]
# <a id="outputfiles"></a>

# %% [markdown]
# ## Exploring the output files of dbCAN
#
# dbCAN produces several output files. This section of the notebook explores what data is included in each, what data we want to retrieve and explain which file were selected for retrieving data.
#
# The output files produced by dbCAN are:
# - overview.txt
# - diamond.out
# - hmmer.out
# - Hotpep.out

# %% [markdown]
# <a id="exp_over"></a>

# %% [markdown]
# ### Overview.txt output file
#
# As its name infers, the overview.txt file summarises the predictions from HMMER, DIAMOND and Hotpep. Each row contains a unique protein and contains for the following information:
# - "HMMER" - predicted CAZy (sub)families and amino acid domain range
# - "DIAMOND" - predicted CAZy (sub)families
# - "Hotpep" - predicted CAZy(sub)families and the number of the associated k-mer group

# %%
with open ("overview.txt", "r") as ofh:
    overview_file = ofh.read().splitlines()
    
for line in overview_file[:5]:
    print(line)
# Out:
# Gene ID	HMMER	Hotpep	DIAMOND	#ofTools
# ATY58323.1	CE5(83-249)	-	CE5	2
# ATY58330.1	AA11(50-241)	AA11(2)	AA11	3
# ATY58395.1	AA7(55-488)	-	-	1
# ATY58396.1	AA6(3-198)	AA6(1)	-	2

# %% [markdown]
# Lets check how the data is separated.

# %%
with open ("overview.txt", "r") as ofh:
    overview_file = ofh.read().splitlines()
    
for line in overview_file[:5]:
    print(repr(line))
# Out:
# 'Gene ID\tHMMER\tHotpep\tDIAMOND\t#ofTools'
# 'ATY58323.1\tCE5(83-249)\t-\tCE5\t2'
# 'ATY58330.1\tAA11(50-241)\tAA11(2)\tAA11\t3'
# 'ATY58395.1\tAA7(55-488)\t-\t-\t1'
# 'ATY58396.1\tAA6(3-198)\tAA6(1)\t-\t2'

# %% [markdown]
# We can see here that the data is separated by tabulated white space, which makes it easy for to parse the data into a simple dataframe to help us read the data that is containined in the overview.txt file

# %%
with open ("overview.txt", "r") as ofh:
    overview_file = ofh.read().splitlines()

df_data = []

for line in overview_file[:20]:
    line = line.split("\t")
    df_data.append(line)

df = pd.DataFrame(df_data, columns=["Gene ID","HMMER","Hotpep","DIAMOND","#ofTools"])
df
# Out:
#        Gene ID                         HMMER                      Hotpep  \
# 0      Gene ID                         HMMER                      Hotpep
# 1   ATY58323.1                   CE5(83-249)                           -
# 2   ATY58330.1                  AA11(50-241)                     AA11(2)
# 3   ATY58395.1                   AA7(55-488)                           -
# 4   ATY58396.1                    AA6(3-198)                      AA6(1)
# 5   ATY58475.1                 AA3_2(28-645)                      AA3(6)
# 6   ATY58478.1                  GH16(79-222)                    GH16(14)
# 7   ATY58486.1                  GH18(30-280)  GH18(92)+CBM1(13)+CBM19(1)
# 8   ATY58494.1               GH5_24(160-472)                     GH5(55)
# 9   ATY58512.1                  GH55(20-743)                     GH55(5)
# 10  ATY58528.1                  GH16(62-283)                           -
# 11  ATY58531.1                   GH64(3-372)            GH64(5)+CBM6(29)
# 12  ATY58532.1                   CE5(73-247)                           -
# 13  ATY58571.1                  GH76(27-411)                     GH76(7)
# 14  ATY58579.1                 GH38(431-690)                     GH38(5)
# 15  ATY58636.1  GT2_Glyco_tranf_2_3(265-498)                           -
# 16  ATY58637.1                 GH12(501-652)                           -
# 17  ATY58653.1                 CE10(413-656)                           -
# 18  ATY58674.1                   GH75(8-230)                     GH75(2)
# 19  ATY58687.1                 CE10(428-676)                           -
#
#       DIAMOND  #ofTools
# 0     DIAMOND  #ofTools
# 1         CE5         2
# 2        AA11         3
# 3           -         1
# 4           -         2
# 5         AA3         3
# 6        GH16         3
# 7   CBM1+GH18         3
# 8      GH5_24         3
# 9        GH55         3
# 10       GH16         2
# 11       GH64         3
# 12        CE5         2
# 13       GH76         3
# 14       GH38         3
# 15        GT2         2
# 16       GH12         2
# 17          -         1
# 18       GH75         3
# 19          -         1

# %% [markdown]
# From this we can see more clearly what data is included in the overview.txt file, and shows what was said before:
# - "HMMER" - predicted CAZy (sub)families and amino acid domain range
# - "DIAMOND" - predicted CAZy (sub)families
# - "Hotpep" - predicted CAZy(sub)families and the number of the associated k-mer group
#
# The '#ofTools' lists the number of tools (out of HMMER, DIAMOND and Hotpep) say a protein is a CAZyme.
#
# The last check is to see if a unique protein is contained per line, and we can see below that a unique protein is contained in each row.

# %%
with open ("overview.txt", "r") as ofh:
    overview_file = ofh.read().splitlines()

df_data = []

for line in overview_file[:20]:
    line = line.split("\t")
    df_data.append(line)

df = pd.DataFrame(df_data, columns=["Gene ID","HMMER","Hotpep","DIAMOND","#ofTools"])

# check for duplicates
dup_rows = df.duplicated(keep=False, subset="Gene ID")
df[dup_rows]
# Out:
# Empty DataFrame
# Columns: [Gene ID, HMMER, Hotpep, DIAMOND, #ofTools]
# Index: []

# %% [markdown]
# <a id="exp_hmmer"></a>

# %% [markdown]
# ### HMMER.out output file
#
# The HMMER output file contains more information about the data producsed by HMMER during the analysis of the input FASTA file containing protein sequences.
#
# First, lets take a look at the data and how it is separated.

# %%
with open ("hmmer.out", "r") as ofh:
    hmmer_file = ofh.read().splitlines()
    
for line in hmmer_file[:5]:
    print(repr(line))
# Out:
# 'HMM Profile\tProfile Length\tGene ID\tGene Length\tE Value\tProfile Start\tProfile End\tGene Start\tGene End\tCoverage'
# 'CE5.hmm\t189\tATY58323.1\t250\t1.2e-42\t2\t188\t83\t249\t0.9841269841269841'
# 'AA11.hmm\t191\tATY58330.1\t441\t2.6e-68\t1\t188\t50\t241\t0.9790575916230366'
# 'AA7.hmm\t458\tATY58395.1\t499\t3e-47\t8\t453\t55\t488\t0.9716157205240175'
# 'AA6.hmm\t195\tATY58396.1\t201\t3.9e-81\t1\t193\t3\t198\t0.9846153846153847'

# %% [markdown]
# The data is separated by tabulated white space ('\t'), which means the data can be parsed and produce a dataframe again to help make it clearer what data is in the hmmer.out file.

# %%
with open ("hmmer.out", "r") as ofh:
    hmmer_file = ofh.read().splitlines()

df_data = []
column_names = hmmer_file[0].split("\t")

for line in hmmer_file[1:20]:
    line = line.split("\t")
    df_data.append(line)

df = pd.DataFrame(df_data, columns=column_names)
df
# Out:
#                 HMM Profile Profile Length     Gene ID Gene Length   E Value  \
# 0                   CE5.hmm            189  ATY58323.1         250   1.2e-42
# 1                  AA11.hmm            191  ATY58330.1         441   2.6e-68
# 2                   AA7.hmm            458  ATY58395.1         499     3e-47
# 3                   AA6.hmm            195  ATY58396.1         201   3.9e-81
# 4                 AA3_2.hmm            568  ATY58475.1         649   1.5e-96
# 5                  GH16.hmm            189  ATY58478.1         556   5.6e-25
# 6                  GH18.hmm            296  ATY58486.1         406   9.8e-27
# 7                GH5_24.hmm            315  ATY58494.1         505  9.3e-148
# 8                  GH55.hmm            740  ATY58512.1         745  5.2e-205
# 9                  GH16.hmm            189  ATY58528.1         364   6.7e-21
# 10                 GH64.hmm            367  ATY58531.1         376  4.4e-113
# 11                  CE5.hmm            189  ATY58532.1         286   2.1e-38
# 12                 GH76.hmm            358  ATY58571.1         469  5.5e-104
# 13                 GH38.hmm            269  ATY58579.1        1228   1.2e-87
# 14  GT2_Glyco_tranf_2_3.hmm            230  ATY58636.1         790     1e-19
# 15                 GH12.hmm            156  ATY58637.1         653     1e-20
# 16                 CE10.hmm            341  ATY58653.1         682   4.4e-18
# 17                 GH75.hmm            220  ATY58674.1         232   4.9e-84
# 18                 CE10.hmm            341  ATY58687.1         687   9.4e-16
#
#    Profile Start Profile End Gene Start Gene End            Coverage
# 0              2         188         83      249  0.9841269841269841
# 1              1         188         50      241  0.9790575916230366
# 2              8         453         55      488  0.9716157205240175
# 3              1         193          3      198  0.9846153846153847
# 4              2         567         28      645  0.9947183098591549
# 5             52         176         79      222   0.656084656084656
# 6              3         201         30      280   0.668918918918919
# 7              1         312        160      472  0.9873015873015873
# 8             11         739         20      743  0.9837837837837838
# 9             10         189         62      283  0.9470899470899471
# 10             2         367          3      372  0.9945504087193461
# 11             2         187         73      247  0.9788359788359788
# 12             7         355         27      411  0.9720670391061452
# 13             1         256        431      690  0.9479553903345725
# 14             2         229        265      498  0.9869565217391304
# 15            20         156        501      652  0.8717948717948718
# 16            87         311        413      656   0.656891495601173
# 17             4         219          8      230  0.9772727272727273
# 18            81         326        428      676   0.718475073313783

# %% [markdown]
# Next, we can check that a unique protein is contained in each row by checking for duplicates.

# %%
with open ("hmmer.out", "r") as ofh:
    hmmer_file = ofh.read().splitlines()

df_data = []
column_names = hmmer_file[0].split("\t")

for line in hmmer_file:
    line = line.split("\t")
    df_data.append(line)

df = pd.DataFrame(df_data, columns=column_names)
print("number of proteins in hmmer.out =", len(df["Gene ID"]))

# check for duplicates
dup_rows = df.duplicated(keep=False, subset="Gene ID")
df[dup_rows]
# Out:
# number of proteins in hmmer.out = 337
#                 HMM Profile Profile Length     Gene ID Gene Length   E Value  \
# 35                 GH18.hmm            296  ATY59188.1        1774   1.9e-53
# 36                CBM66.hmm            155  ATY59188.1        1774   1.5e-27
# 49                 GH54.hmm            316  ATY59698.1         496  5.9e-131
# 50                CBM42.hmm            136  ATY59698.1         496     5e-50
# 57              GH43_34.hmm            280  ATY59890.1         514   1.9e-97
# 58                CBM66.hmm            155  ATY59890.1         514   2.8e-23
# 77                CBM66.hmm            155  ATY60367.1         555   2.1e-19
# 78                CBM66.hmm            155  ATY60367.1         555   4.7e-25
# 82   GT2_Chitin_synth_1.hmm            163  ATY60416.1         923   6.6e-71
# 83   GT2_Chitin_synth_2.hmm            527  ATY60416.1         923   1.1e-22
# 90                GH142.hmm            479  ATY60620.1         839  3.7e-173
# 91                CBM13.hmm            188  ATY60620.1         839   1.6e-20
# 169                GH15.hmm            361  ATY62564.1         650   1.5e-79
# 170               CBM20.hmm             90  ATY62564.1         650   6.1e-29
# 194                GT57.hmm            481  ATY63255.1         589   7.1e-91
# 195                GT57.hmm            481  ATY63255.1         589   6.1e-55
# 292  GT2_Chitin_synth_1.hmm            163  ATY66192.1        1173   4.2e-76
# 293  GT2_Chitin_synth_2.hmm            527  ATY66192.1        1173   3.7e-22
#
#     Profile Start Profile End Gene Start Gene End             Coverage
# 35              5         282        518      863   0.9358108108108109
# 36              2         155       1301     1461   0.9870967741935484
# 49              1         315         25      333   0.9936708860759493
# 50              2         135        351      490   0.9779411764705882
# 57              1         280         55      335   0.9964285714285714
# 58              2         154        351      508   0.9806451612903225
# 77              4         150        219      369   0.9419354838709677
# 78              3         152        388      547   0.9612903225806452
# 82              1         163        230      398   0.9938650306748467
# 83            203         404        375      584  0.38140417457305503
# 90             15         477         47      522    0.964509394572025
# 91              8         135        699      831    0.675531914893617
# 169             4         359         70      481   0.9833795013850416
# 170             1          89        550      641   0.9777777777777777
# 194             3         229         63      294   0.4698544698544699
# 195           228         480        333      565   0.5239085239085239
# 292             1         163        487      649   0.9938650306748467
# 293           204         432        627      867  0.43263757115749524

# %% [markdown]
# From this we can see that instead of containing a unique protein per row, HMMER lists all the CAZy families predicted for a protein on separate lines.
#
# **What data is stored in hmmer.out**
# The information defining the fields in the HMMER output file were taken from the HMMER [documentation](http://eddylab.org/software/hmmer/Userguide.pdf) and [Read The Docs](https://hmmer-web-docs.readthedocs.io/en/latest/result.html?highlight=profile%20start#alignments).
#
# **HMM Profile**
# Is the name of the HMM profile that models the CAZy family HMMER has predicted CAZy would catalogue the query protein under.
#
# **Profile length**
# This has been interpretted as the length in amino acids of the HMM profile listed under 'HMM Profile'.
#
# **Gene ID**
# This is the accession of the query protein represented in the line of the hmmer.out file.
#
# **E Value**
# This is the E value score of the alignemnt, this how HMMER ranks the matches between query proteins and HMM models.
#
# **Profile Start/End and Gene Start/End**
# These have been interrepreted to be in relation to what the HMMER documentation lists as the 'Query start/end': "The start/end of the MEA alignment of this domain/hit with respect to the profile HMM, which directly relates to the query sequence for phmmer. For hmmsearch, the number corresponds to the match states that HMMER determined from the initial input alignment." - from [ReadTheDocs](https://hmmer-web-docs.readthedocs.io/en/latest/result.html?highlight=profile%20start#alignments)
#
# The 'Gene Start' and 'Gene End' match the amino acid domain ranges that are listed in the overview.txt file.
#
# **Coverage**
# "The fraction of total residues that are shared is reported as the coverage in theesl-alimapoutput." - from [documentation](http://eddylab.org/software/hmmer/Userguide.pdf)
#
# **What data is needed from the hmmer.out file**
#
# For the evaluation performed by `pyrewton` only the predicted CAZy families are needed. For down stream analysis, the predicted domain ranges may also be informative. `pyrewton` uses the E value and coverage cut offs determined by dbCAN, and thus are not needed for the evaluation of the performance of dbCAN by `pyrewton`, although some users may find the data informative. Therefore, they are able to find the data in hmmer.out, but the only data wanted from HMMER is the predicted CAZy (sub)families and their associated domain range.

# %% [markdown]
# <a id="exp_diamond"></a>

# %% [markdown]
# ### diamond.out output file
#
# The DIAMOND output file contains more information about the data produced by DIAMOND during the analysis of the input FASTA file containing protein sequences.
#
# Let's take an inital look at the data and check how the data is separated.

# %%
with open ("diamond.out", "r") as ofh:
    diamond_file = ofh.read().splitlines()
    
for line in diamond_file[:5]:
    print(repr(line))
# Out:
# 'Gene ID\tCAZy ID\t% Identical\tLength\tMismatches\tGap Open\tGene Start\tGene End\tCAZy Start\tCAZy End\tE Value\tBit Score'
# 'ATY67280.1\tATY67280.1|GH17|\t100.0\t670\t0\t0\t1\t670\t1\t670\t0.0e+00\t1354.7'
# 'ATY67467.1\tATY67467.1|GT90|\t100.0\t625\t0\t0\t1\t625\t1\t625\t0.0e+00\t1303.9'
# 'ATY67289.1\tATY67289.1|CBM48|GH13_8|\t100.0\t691\t0\t0\t1\t691\t1\t691\t0.0e+00\t1440.2'
# 'ATY67196.1\tATY67196.1|GH18|\t100.0\t365\t0\t0\t1\t365\t1\t365\t4.6e-211\t736.5'

# %% [markdown]
# Again the data is separated by tabulated white space ('\t'), which means the data can be parsed and produce a dataframe again to help make it clearer to see what data is included in the diamond.out file. The names of the columns are stored in the first line of the file.

# %%
with open ("diamond.out", "r") as ofh:
    diamond_file = ofh.read().splitlines()

df_data = []
column_names = diamond_file[0].split("\t")

for line in diamond_file[1:20]:
    line = line.split("\t")
    df_data.append(line)

df = pd.DataFrame(df_data, columns=column_names)
df
# Out:
#        Gene ID                   CAZy ID % Identical Length Mismatches  \
# 0   ATY67280.1          ATY67280.1|GH17|       100.0    670          0
# 1   ATY67467.1          ATY67467.1|GT90|       100.0    625          0
# 2   ATY67289.1  ATY67289.1|CBM48|GH13_8|       100.0    691          0
# 3   ATY67196.1          ATY67196.1|GH18|       100.0    365          0
# 4   ATY67205.1    EAA64118.1|CBM20|GH15|        46.4    539        263
# 5   ATY67226.1          ATY67226.1|GH18|       100.0    482          0
# 6   ATY67472.1         ATY67472.1|AA3_2|       100.0    587          0
# 7   ATY67423.1           AXG41146.1|GH6|        37.6    710        414
# 8   ATY67327.1          ATY67327.1|GT32|       100.0    396          0
# 9   ATY67309.1          ATY67309.1|GT20|       100.0    602          0
# 10  ATY67094.1          ATY67094.1|GH20|       100.0    581          0
# 11  ATY67306.1          ATY67306.1|GH17|       100.0    414          0
# 12  ATY67468.1          ATY67468.1|GH29|       100.0    476          0
# 13  ATY67182.1         ATY67182.1|GH114|       100.0    375          0
# 14  ATY67158.1         ATY67158.1|CBM50|       100.0    493          0
# 15  ATY67425.1          ATY67425.1|GH36|       100.0    745          0
# 16  ATY67142.1          EAA29319.1|GH93|        60.7    471        136
# 17  ATY67138.1         ATY67138.1|AA3_2|       100.0    617          0
# 18  ATY66872.1           ATY66872.1|AA1|       100.0    724          0
#
#    Gap Open Gene Start Gene End CAZy Start CAZy End   E Value Bit Score
# 0         0          1      670          1      670   0.0e+00    1354.7
# 1         0          1      625          1      625   0.0e+00    1303.9
# 2         0          1      691          1      691   0.0e+00    1440.2
# 3         0          1      365          1      365  4.6e-211     736.5
# 4         8         18      541        707     1234  3.0e-140     501.9
# 5         0          1      482          1      482  1.5e-286     987.6
# 6         0          1      587          1      587   0.0e+00    1204.1
# 7        10        179      882        180      866  3.1e-118     429.5
# 8         0          1      396          1      396  1.9e-226     787.7
# 9         0          1      602          1      602   0.0e+00    1220.3
# 10        0          1      581          1      581   0.0e+00    1199.9
# 11        0          1      414          1      414  3.4e-194     680.6
# 12        0          1      476          1      476  3.0e-287     989.9
# 13        0          1      375          1      375  5.1e-229     796.2
# 14        0          1      493          1      493  9.1e-295    1015.0
# 15        0          1      745          1      745   0.0e+00    1529.2
# 16        6          1      441          1      452  1.2e-155     552.7
# 17        0          1      617          1      617   0.0e+00    1257.7
# 18        0          1      724          1      724   0.0e+00    1505.0

# %% [markdown]
# We can check if each row contains a unique protein, by parsing the complete diamond.out file and check for duplicates.

# %%
with open ("diamond.out", "r") as ofh:
    diamond_file = ofh.read().splitlines()

df_data = []
column_names = diamond_file[0].split("\t")

for line in diamond_file:
    line = line.split("\t")
    df_data.append(line)

df = pd.DataFrame(df_data, columns=column_names)

# check for duplicates
dup_rows = df.duplicated(keep=False, subset="Gene ID")
df[dup_rows]
# Out:
# Empty DataFrame
# Columns: [Gene ID, CAZy ID, % Identical, Length, Mismatches, Gap Open, Gene Start, Gene End, CAZy Start, CAZy End, E Value, Bit Score]
# Index: []

# %% [markdown]
# The above shows there is a unique protein per row, thus all CAZy families listed in the 'CAZy ID' column contains all CAZy families predicted to be in a CAZyme. Multiple CAZy families predicted for a CAZyme indicates multiple CAZyme domains are predicted to be present in a protein.
#
# **What data is stored in diamond.out**
# The explanations for the data in the diamond.out is primarly taken from the [DIAMOND documentation](https://github.com/bbuchfink/diamond/wiki/1.-Tutorial). Quotes are directlt taken from the DIAMOND documentation.
#
# **Gene ID**
# This has been interpretted to be the column that DIAMOND lists as the 'Query accession' in its documentation. "The accession of the sequence that was the search query against the database, as specified in the input FASTA file after the > character until the first blank."
#
# **Sequence identity**
# "The percentage of identical amino acid residues that were aligned against each other in the local alignment."
#
# **Length**
# "The total length of the local alignment, which including matching and mismatching positions of query and subject, as well as gap positions in the query and subject."
#
# **Mismatches**
# "The number of non-identical amino acid residues aligned against each other."
#
# **Gap Open**
# This has been interpretted to be what DIAMOND lists as 'Gene Openings' in its documentation. "The number of gap openings."
#
# **Gene Start**
# This has been interpretted to be what DIAMOND lists as the 'Query start' in its documentation. "The starting coordinate of the local alignment in the query (1-based)."
#
# **Gene End**
# This has be interpretted to be what DIAMOND lists as the 'Gene end' in its documentation. "The ending coordinate of the local alignment in the query (1-based)."
#
# **CAZy Start**
# This has been interpretted to be what DIAMOND list as the 'Target start' in the documentation. "The starting coordinate of the local alignment in the target (1-based)."
#
# **CAZy End**
# This has been interpretted to be what DIAMOND lists as 'Target end' in its documentation. "The ending coordinate of the local alignment in the target (1-based)."
#
# **E-value**
# "The expected value of the hit quantifies the number of alignments of similar or better quality that you expect to find searching this query against a database of random sequences the same size as the actual target database. This number is most useful for measuring the significance of a hit. By default, DIAMOND will report all alignments with e-value < 0.001, meaning that a hit of this quality will be found by chance on average once per 1,000 queries."
#
# **Bit score**
# "The bit score is a scoring matrix independent measure of the (local) similarity of the two aligned sequences, with higher numbers meaning more similar. It is always >= 0 for local Smith Waterman alignments."
#
# **What data do we want?**
# The 'Length' and 'Start/End' columns included the length of the entire protein, not predictions of the CAZyme domain locations, therefore, their data is not informative. The remaining columns, apart from the 'CAZy ID' provide information on the score of the alignment, which is not informative for the evaluation `pyrewton` performs. `pyrewton` uses the default E-value/bit-score cut offs. This may be informative data depending on the personal needs of the user, but becuase it is not needed by `pyrewton` it is not collected. The only needed data is the predicted CAZy families.

# %% [markdown]
# <a id="exp_hotpep"></a>

# %% [markdown]
# ### Hotpep.out output file
#
# The Hotpep output file contains more information about the data produced by Hotpep, from the analysis of the input FASTA file containing protein sequences.
#
# Let's take an inital look at the data and check how the data is separated.

# %%
with open ("Hotpep.out", "r") as ofh:
    hotpep_file = ofh.read().splitlines()
    
for line in hotpep_file[:5]:
    print(repr(line))
# Out:
# 'CAZy Family\tPPR Subfamily\tGene ID\tFrequency\tHits\tSignature Peptides\tEC number'
# 'CE16\t2\tATY65081.1\t6.91\t12\tTGGRRF,VTFGDS,IGTNDL,WIGTND,TFGDSY,DSYTDE,FGDSYT,NYAVAG,GDSYTD,LVTFGD,YNYAVA,GTNDLG\t3.1.1.6:22'
# 'CE3\t10\tATY62702.1\t9.55\t16\tDCIHPT,DYWYDF,SGKTIQ,FAAWSG,WSGKTI,VGDSIT,AGTNDM,GTNDMN,GDSITV,CIHPTN,VLAVDF,AAWSGK,LAVDFT,DSITVG,GDYWYD,AWSGKT\tNA'
# 'CE4\t143\tATY63454.1\t12.6\t26\tHQVASH,ALTFDD,GECLGD,SHTWSH,MRPPYS,PTYMRP,TVGECL,VGECLG,VTVGEC,GYFPTY,TYMRPP,ECLGDP,YFPTYM,ASHTWS,LGYFPT,HTWSHQ,FPTYMR,FDDGPY,IALTFD,YMRPPY,GHQVAS,LTFDDG,TFDDGP,AKATFF,QVASHT,VASHTW\tNA'
# 'CE4\t143\tATY64953.1\t7.92\t15\tVTVGEC,ALTFDD,AKATFF,TYMRPP,YMRPPY,EMAFRN,PTYMRP,VGECLG,TVGECL,GECLGD,ECLGDP,LTFDDG,NEMAFR,TFDDGP,KATFFI\tNA'

# %% [markdown]
# The individual fields of data are separated by tabulated white space ('\t'), which allows us to separate them out and produce a dataframe to help understand/visualise what data is stored in the Hotpep output file.

# %%
with open ("Hotpep.out", "r") as ofh:
    hotpep_file = ofh.read().splitlines()

df_data = []
column_names = hotpep_file[0].split("\t")

for line in hotpep_file[1:20]:
    line = line.split("\t")
    df_data.append(line)

df = pd.DataFrame(df_data, columns=column_names)
df
# Out:
#    CAZy Family PPR Subfamily     Gene ID Frequency Hits  \
# 0         CE16             2  ATY65081.1      6.91   12
# 1          CE3            10  ATY62702.1      9.55   16
# 2          CE4           143  ATY63454.1      12.6   26
# 3          CE4           143  ATY64953.1      7.92   15
# 4          CE5            15  ATY65055.1       7.8   12
# 5          CE9            25  ATY66875.1      13.9   36
# 6          GH0             2  ATY64043.1      27.4   38
# 7          GH0            23  ATY60133.1      5.81    6
# 8          GH0            68  ATY62132.1      17.9   30
# 9          GH0           115  ATY63707.1      9.81   24
# 10         GH0           115  ATY65793.1      8.64   20
# 11         GH0           115  ATY62951.1      8.01   20
# 12         GH0           115  ATY61188.1      6.64   17
# 13         GH0           115  ATY62721.1      6.54   19
# 14         GH0           115  ATY65605.1      3.13    7
# 15         GH1             8  ATY58880.1      9.05   25
# 16       GH114             6  ATY66369.1      9.16   14
# 17       GH125             2  ATY66363.1      16.2   36
# 18       GH125             2  ATY66542.1      11.1   27
#
#                                    Signature Peptides  \
# 0   TGGRRF,VTFGDS,IGTNDL,WIGTND,TFGDSY,DSYTDE,FGDS...
# 1   DCIHPT,DYWYDF,SGKTIQ,FAAWSG,WSGKTI,VGDSIT,AGTN...
# 2   HQVASH,ALTFDD,GECLGD,SHTWSH,MRPPYS,PTYMRP,TVGE...
# 3   VTVGEC,ALTFDD,AKATFF,TYMRPP,YMRPPY,EMAFRN,PTYM...
# 4   LEGYSQ,AVKGVF,GYSQGA,VKGVFL,GLACNV,DAVKGV,AFDA...
# 5   MITHLF,KFTNCR,THLFNA,GAESLG,IAGSSI,TMITHL,HHRN...
# 6   SNWRGP,TVREDY,LKERLF,VREDYS,GLGASH,ERLFGL,WWVN...
# 7           GDGVTD,DGVTDD,AKGDGV,GAKGDG,GVTDDT,KGDGVT
# 8   MVYTYN,RDEMVY,PWRGLG,YKNAIT,GRGRTV,IDWTAA,YNQG...
# 9   VRAPTT,VANRLT,GDGLKQ,ITQMIR,NPGLMQ,ANRLTG,CVRA...
# 10  QMIRDG,RFILAI,ATACYA,RLTGWV,GATACY,DGAATC,CYAS...
# 11  VRAPTT,SNGCVR,NPGLMQ,NGCVRA,ANRLTG,CVRAPT,ESNG...
# 12  HRFILA,RFILAV,GIATHC,ANRLTG,TGWVNA,GVDHRF,NPGL...
# 13  IATHCY,VRAPTT,GIATHC,GDGLKQ,NPGLMQ,SNGCVR,NGCV...
# 14   GLMQSH,NPGLMQ,SDVANR,DVANRL,PGLMQS,YYRAAR,MQSHNG
# 15  WSLMDN,TAAYQI,HWDLPQ,VACDHY,YFAWSL,YQIEGA,AWSL...
# 16  ICYFSA,VNEQCA,CDAIDP,KVGDSW,YFSAGT,KGCDAI,CYFS...
# 17  EWLRDS,GAINTQ,ECKYEL,AWPMSL,AYEVDG,ELDSLA,LARL...
# 18  WANGLF,ECKYEL,AYEVDG,ELDSLA,MDDANI,LGLIHE,FRPS...
#
#                                             EC number
# 0                                          3.1.1.6:22
# 1                                                  NA
# 2                                                  NA
# 3                                                  NA
# 4                                         3.1.1.74:26
# 5                                         3.5.1.25:14
# 6                                                  NA
# 7                                                  NA
# 8                                                  NA
# 9                                                  NA
# 10                                                 NA
# 11                                                 NA
# 12                                                 NA
# 13                                                 NA
# 14                                                 NA
# 15  3.2.1.21:2152, 3.2.1.-:269, 3.2.1.38:49, 3.2.1...
# 16                                                 NA
# 17                                                 NA
# 18                                                 NA

# %% [markdown]
# We can also check if a unique protein is contain a unique protein, but looking for duplicates in the is dataframe. The data below shows that the Hotpep output contains a unique protein per line.

# %%
with open ("Hotpep.out", "r") as ofh:
    hotpep_file = ofh.read().splitlines()

df_data = []
column_names = hotpep_file[0].split("\t")

for line in hotpep_file[1:20]:
    line = line.split("\t")
    df_data.append(line)

df = pd.DataFrame(df_data, columns=column_names)

# check for duplicates
dup_rows = df.duplicated(keep=False, subset="Gene ID")
df[dup_rows]
# Out:
# Empty DataFrame
# Columns: [CAZy Family, PPR Subfamily, Gene ID, Frequency, Hits, Signature Peptides, EC number]
# Index: []

# %% [markdown]
# **What data is stored in the Hotpep.out file**
#
# **CAZy Family**
# This is the predicted CAZy family.
#
# **PPR subfamily**
# This was interpretted as the group number of k-mer group for the predicted CAZy family.
#
# **Gene ID**
# The accession of the query protein.
#
# **Frequency**
# This is potentially the frequency at which CAZyme signature k-mers appear in the query protein.
#
# **Hits**
# This is potentially the number of CAZyme signature k-mers found in the protein.
#
# **Signature Peptides**
# The k-mers that Hotpep catalogues as signature k-mers of CAZy families and where found in the query protein.
#
# **EC number**
# Predicted EC numbers for the query protein.
#
# **What data is wanted from the Hotpep.out file**
#
# For the evaluation of `pyrewton` only the predicted CAZy family. For downstream analysis of the predicted CAZymes, and may be of interest for may researchers are the predicted EC numbers. Therefore, the predicted CAZy families and EC numbers from the Hotpep output are wanted.

# %% [markdown]
# <a id="exp_uniinput"></a>

# %% [markdown]
# ### uniInput output file
#
# The final output file from dbCAN is the file 'uniInput' which is a copy of the FASTA file of protein sequences used as the input for dbCAN.
#
# There is no data in the 'uniInput' output file that is informative of the CAZyme prediction of dbCAN.

# %% [markdown]
# <a id="choice"></a>

# %% [markdown]
# ## Choosing the dbCAN output data and files to parse
#
# The output wanted from dbCAN:
#
# **dbCAN**
# - Consensus result (result at that at least two tools agree)
#
# **HMMER**
# - Predicted CAZy (sub)families
# - Amino acid domain range
#
# **DIAMOND**
# - Predicted CAZy (sub)families
#
# **Hotpep**
# - Predicted CAZy (sub)families
# - EC numbers
#
# All the wanted data can be retrieved from the overview.txt file, except the EC numbers from Hotpep which requires parsing the Hotpep.out file. To minimise the number of files that need to be parsed the wanted data will be retrieved from the overview.txt file, then add in the EC numbers from the Hotpep.out file.

# %% [markdown]
# <a id="par_over"></a>

# %% [markdown]
# ## Parsing the overview.txt file
#
# This section of the notebook covers parsing the overview.txt file. The parsing of each prediction tool (HMMER, Hotpep and DIAMOND) is discussed in the order they appear in the overview.txt file, finishing with finding the consensus dbCAN result.

# %% [markdown]
# <a id="model"></a>

# %% [markdown]
# ### Defining the data model
#
# The explanation of the design of the data model is explained in the note book prediction_data_model.ipynb.
#
# The same data model is used for every CAZyme prediction tool.
#
# For **HMMER** the data we want to retrieve is:
# - The protein accession (which is the 'Gene ID')
# - The CAZy (sub)families HMMER has predicted CAZy would catalogue the protein under
# - Predicted amino acid domain ranges of the predicted CAZy domains (each domain is represented as a CAZy family prediction, thus predicting two CAZy families indicates predicting two CAZyme domains)
#
# For **Hotpep** the data we want to retrieve is:
# - The protein accession (which is the 'Gene ID')
# - The CAZy (sub)families HMMER has predicted CAZy would catalogue the protein under
# - Predicted EC numbers of the predicted CAZy domains (each domain is represented as a CAZy family prediction, thus predicting two CAZy families indicates predicting two CAZyme domains)
#
# The data from **dbCAN and DIAMOND** includes:
# - The protein accession
# - CAZy family of each domain
# - CAZy subfamily of each domain (if not in a subfamily, the subfamily is listed as a null value)

# %%
class CazymeDomain:
    """Single CAZyme domain in a protein, predicted by a CAZyme prediction tool.
    
    Each unique predicted CAZy family-subfamily combination by a CAZyme prediction
    tool for a query protein sequence is viewed as a CAZyme domain.]
    
    Every CAZyme domain has a source CAZyme prediction tool that predicted the CAZyme
    domain, a parent CAZyme protein (represented by the protein accession), and CAZy
    family and subfamily combination. If no CAZy subfamily is predicted, the 
    subfamily will be listed as a null value.

    Hotpep, CUPP and eCAMI predict EC numbers for each CAZyme domain. HMMER and CUPP
    predict amino acid domain ranges. Multiple EC numbers and domain ranges can be
    predicted for a single CAZyme domain, therefore, these attritbutes are stored as
    lists.
    
    If an item of data is not or was not predicted by a CAZyme prediction tool, the
    respective data will be stored as a null value.
    """
    
    def __init__(
        self,
        prediction_tool,
        protein_accession,
        cazy_family,
        cazy_subfamily=None,
        ec_numbers=None,
        domain_range=None,
    ):
        """Initiate instance
        
        :attr prediction_tool: str, CAZyme prediciton tool which predicted the domain
        :attr protein_accession: str
        :attr cazy_family: str
        :attr cazy_subfamily: str
        :attr ec_numbers: list (list of str, each str contains a unique EC number)
        :attr domain_range: list (list of str, each str contains a unique domain range)
        """
        self.prediction_tool = prediction_tool
        self.protein_accession = protein_accession
        self.cazy_family = cazy_family
        
        # not all CAZyme domans are catalogued under a CAZy subfamily
        if cazy_subfamily is None:
            self.cazy_subfamiy = np.nan
        else:
            self.cazy_subfamily = cazy_subfamily
        
        # EC numbers are not predicted for all CAZyme domains
        if ec_numbers is None:
            self.ec_numbers = []  # enables adding in EC numbers included in another line of the output file
        else:
            self.ec_numbers = ec_numbers
        
        # Not all prediction tools predict CAZyme domains
        if domain_range is None:
            self.domain_range = []  # enables adding domain range listed in another line of the ouput file
        else:
            self.domain_range = domain_range
    
    def __str__(self):
        return f"-CazymeDomain in {self.protein_accession}, fam={self.cazy_family}, subfam={self.cazy_subfamily}-"
    
    def __repr__(self):
        return f"<CazymeDomain parent={self.protein_accession} fam={self.cazy_family}, subfam={self.cazy_subfamily}>"

    
class CazymeProteinPrediction:
    """Single protein and CAZyme/non-CAZyme prediction by a CAZyme prediction tool"""
    
    def __init__(self, prediction_tool, protein_accession, cazyme_classification, cazyme_domains=None):
        """Initate class instance.
        
        :attr prediction_tool: str, name of CAZyme prediction tool
        :attr protein_accession: str
        :attr cazyme_classification: int, 1=CAZyme, 0=non-CAZyme
        :attr cazyme_domains: list of CazymeDomain instances, or null value if none are given
        """
        self.prediction_tool = prediction_tool
        self.protein_accession = protein_accession
        self.cazyme_classification = cazyme_classification  # CAZyme=1, non-CAZyme=0
        
        # non-CAZymes will have no CAZyme domains
        if cazyme_domains is None:
            self.cazyme_domains = np.nan
        else:
            self.cazyme_domains = cazyme_domains
    
    def __str__(self):
        if self.cazyme_classification == 0:
            return f"-CazymeProteinPrediction, protein={self.protein_accession}, non-CAZyme-"
        else:
            return f"-CazymeProteinPrediction, protein={self.protein_accession}, CAZyme domains={len(self.cazyme_domains)}-"
    
    def __repr__(self):
        return f"<CazymeProteinPrediction, protein={self.protein_accession}>"

    def get_cazyme_classification_dicts(self):
        """Returns a dictionary that contains the protein accession and its CAZyme/non-CAZyme classification.
        
        This dictionary is used to create the cazyme_classification dataframe for evaluating the performance
        of the CAZyme prediction tools in terms of differnetiating between CAZymes (identified with a score of 1)
        and non-CAZymes (identified with a score of 0). The CAZy classes under which the protein is classifed are
        retrieved as well to enable evaluating the CAZyme/non-CAZyme differneitation per CAZy class, and obsever
        differences between this performance between classes. A score of 0 incidates a protein was not classified
        under the class, a score of 1 indicates the protein as classified under the class.
        """
        cazyme_classification_dict = {
            "protein_accession": self.protein_accession,
            "cazyme_classification": self.cazyme_classification,
            "GH": 0,
            "GT": 0,
            "CE": 0,
            "PL": 0,
            "AA": 0,
            "CBM": 0,
        }
        
        # check which CAZy classes the predicted CAZyme domains were classified under
        for domain in cazyme_domains:
            if domain.cazy_family[:3] == "CBM":
                cazyme_classification_dict["CBM"] = 1
            else:
                cazyme_classification_dict[family[:2]] = 1

        return cazyme_classification_dict

    def get_cazy_family_dict(self):
        """Return a dictionary of the predicted CAZy families for a protein.
        
        This dictionary is used to create a dataframe of CAZy family predictions for evaluating the performance
        of the prediction tools to predict the CAZy family of a CAZyme. The dictionary is keyed by the CAZy
        classes, and valued by a list of the corresponding families predicted for the CAZyme. The is to enable
        evaluating the CAZy family prediction performance per class."""
        cazy_family_dict = {
            "GH": [],
            "GT": [],
            "CE": [],
            "PL": [],
            "AA": [],
            "CBM": [],
        }
        
        for domain in self.cazyme_domains:
            if domain.cazy_family[:3] == "CBM":
                cazy_family_dict["CBM"].append(domain.cazy_family)
            else:
                cazy_family_dict[domain.cazy_family[:2].append(domain.cazy_family)]
        
        return cazy_family_dict

# %% [markdown]
# <a id="hmmer"></a>

# %% [markdown]
# ## HMMER
#
# For HMMER the data we want to retrieve is:
# - The protein accession (which is the 'Gene ID')
# - The CAZy (sub)families HMMER has predicted CAZy would catalogue the protein under
# - Predicted amino acid domain ranges of the predicted CAZy domains (each domain is represented as a CAZy family prediction, thus predicting two CAZy families indicates predicting two CAZyme domains)

# %% [markdown]
# <a id="over_hmmer"></a>

# %% [markdown]
# ### Parsing HMMER data from overview.txt
#
# For HMMER the data we want to retrieve is:
# - The protein accession (which is the 'Gene ID')
# - The CAZy (sub)families HMMER has predicted CAZy would catalogue the protein under
# - Predicted amino acid domain ranges of the predicted CAZy domains (each domain is represented as a CAZy family prediction, thus predicting two CAZy families indicates predicting two CAZyme domains)
#
# Lets take a closer look at how the data from HMMER is presented in the overview.txt file.

# %%
# Check how text is separated in overview.txt
with open ("overview.txt", "r") as ofh:
    overview_file = ofh.read().splitlines()

data_ov = []
for line in overview_file[1:]:  # skip the first line becuase this is the 'column' titles
    line = line.split("\t")
    hmmer = line[1]
    print(hmmer)
# Out:
# CE5(83-249)
# AA11(50-241)
# AA7(55-488)
# AA6(3-198)
# AA3_2(28-645)
# GH16(79-222)
# GH18(30-280)
# GH5_24(160-472)
# GH55(20-743)
# GH16(62-283)
# GH64(3-372)
# CE5(73-247)
# GH76(27-411)
# GH38(431-690)
# GT2_Glyco_tranf_2_3(265-498)
# GH12(501-652)
# CE10(413-656)
# GH75(8-230)
# CE10(428-676)
# GH29(148-504)
# GT66(23-667)
# GH18(42-300)
# GH1(124-596)
# AA3_1(23-560)
# AA3_3(8-607)
# CE10(83-315)
# CE10(146-417)
# GH16(41-301)
# CE5(30-241)
# GH18(200-546)
# GH13_5(37-380)
# GH81(318-1002)
# GH18(38-369)
# GT90(554-821)
# GH18(518-863)+CBM66(1301-1461)
# GH72(25-328)
# GT90(508-783)
# GT15(80-356)
# AA12(828-1219)
# CE10(33-280)
# AA3(43-784)
# GT21(51-358)
# CE10(101-249)
# CE4(66-197)
# GT2_Glyco_trans_2_3(441-704)
# AA1_2(41-367)
# GT1(191-513)
# GH54(25-333)+CBM42(351-490)
# GT4(218-349)
# AA7(99-558)
# CE10(73-319)
# AA7(124-328)
# GT1(271-534)
# AA3_1(233-765)
# GH43_34(55-335)+CBM66(351-508)
# AA3_2(40-423)
# AA4(66-300)
# GT2_Chitin_synth_2(254-541)
# GH128(46-257)
# GH47(115-578)
# GT2_Chitin_synth_2(1205-1712)
# GH16(82-216)
# GT17(55-346)
# GH55(31-773)
# GT4(360-514)
# AA1_3(48-355)
# AA11(21-220)
# CE10(94-277)
# GT22(5-397)
# GH16(92-316)
# AA5(125-631)
# GT4(303-486)
# GH92(263-771)
# CBM66(219-369)+CBM66(388-547)
# GH16(47-298)
# GH152(853-1119)
# GH76(39-404)
# GT2_Chitin_synth_1(230-398)+GT2_Chitin_synth_2(375-584)
# GH31(161-601)
# GH18(37-366)
# GH55(27-760)
# PL35(369-546)
# GH2(43-897)
# AA1_2(142-499)
# GH142(47-522)+CBM13(699-831)
# GH76(25-413)
# GH47(108-582)
# GH16(81-240)
# GH84(195-505)
# GH76(29-404)
# CE10(122-419)
# AA11(18-215)
# GH20(166-496)
# GH135(20-279)
# GT2_Chitin_synth_2(1059-1567)
# AA7(295-491)
# GT34(145-409)
# GH16(61-292)
# AA7(30-231)
# AA7(124-575)
# CE10(127-385)
# GH18(106-449)
# GT64(91-332)
# GH3(95-316)
# GH89(67-726)
# CE1(50-253)
# GH18(42-328)
# GH13_25(1081-1532)
# AA7(29-244)
# GH16(32-279)
# GT69(59-316)
# PL20(24-258)
# CE10(54-296)
# GH31(249-805)
# GT2_Glycos_transf_2(123-306)
# GH79(47-498)
# AA3_2(62-640)
# GH18(31-268)
# GH18(504-851)
# GT2_Chitin_synth_2(647-1171)
# GT20(14-478)
# GH16(151-361)
# AA7(215-420)
# GH16(107-267)
# GH16(127-463)
# GT2_Glyco_trans_2_3(535-745)
# GH15(289-664)
# GH18(485-834)
# GT59(63-596)
# GT15(105-375)
# GH18(36-239)
# GH72(193-502)
# GH2(5-751)
# GH16(72-285)
# GT22(12-405)
# GH13_40(433-662)
# GT39(52-297)
# GH47(39-514)
# GH5_11(126-461)
# AA2(96-336)
# GT32(86-166)
# GH132(216-513)
# GT22(17-476)
# GH5_5(23-315)
# GH76(88-487)
# AA12(29-425)
# GT39(60-304)
# GH13_40(33-392)
# CE10(161-311)
# AA3_2(38-621)
# GT22(36-466)
# GT50(149-427)
# GH3(70-291)
# GT25(69-322)
# CE10(157-596)
# CE10(411-634)
# GH136(20-477)
# GH20(184-559)
# GT1(252-585)
# AA7(123-576)
# GH3(101-332)
# GT58(41-406)
# GH15(70-481)+CBM20(550-641)
# GH5_15(98-402)
# AA7(123-315)
# GT20(159-616)
# AA7(150-336)
# GT2_Glyco_tranf_2_3(73-308)
# GH16(159-464)
# GT2_Glyco_trans_2_3(555-767)
# CE3(75-276)
# GH154(15-401)
# GH88(99-501)
# GH47(35-577)
# GH3(34-245)
# AA3_2(8-574)
# AA9(4-240)
# AA7(48-486)
# GH64(72-443)
# GT15(115-414)
# GH16(100-304)
# GH18(21-386)
# CE10(684-889)
# GT69(108-348)
# GT71(245-484)
# GH63(585-796)
# GT57(63-294)+GT57(333-565)
# AA7(131-328)
# GH3(101-324)
# GH35(154-484)
# GT90(318-590)
# GT39(63-301)
# CE10(57-359)
# GH16(101-316)
# CE4(120-244)
# GH18(137-342)
# CE10(100-355)
# AA11(40-213)
# GH18(50-285)
# GH3(99-310)
# GH79(34-504)
# GT17(69-361)
# GH37(51-626)
# GT1(189-483)
# GT1(183-465)
# CE1(23-284)
# GH55(30-725)
# CE10(88-354)
# GT35(232-943)
# GH92(264-783)
# GT1(116-473)
# GH128(136-348)
# GT34(66-292)
# GH55(444-1131)
# AA3_2(13-531)
# GH63(521-974)
# GH31(239-721)
# CE10(35-230)
# GH89(67-749)
# CE10(77-371)
# GH55(221-970)
# GH72(18-298)
# GT90(334-606)
# GH16(56-317)
# GT69(141-417)
# GT17(53-343)
# GH72(18-332)
# PL8_4(433-675)
# GT57(17-491)
# GT4(403-563)
# GT33(50-466)
# AA3_2(3-543)
# GH3(78-292)
# GH76(28-402)
# GH2(61-504)
# GH92(756-1255)
# AA7(91-514)
# AA7(34-461)
# GH2(105-721)
# GH18(140-489)
# GH55(195-950)
# GH5_12(15-548)
# GT24(1167-1414)
# GH18(30-353)
# GT20(132-552)
# GH17(163-408)
# GT48(1031-1811)
# GH35(36-357)
# GH47(171-665)
# CE4(65-197)
# AA7(39-261)
# CE10(116-282)
# CBM21(376-480)
# GT2_Chitin_synth_2(274-630)
# AA1_3(44-354)
# CE5(31-227)
# CE16(30-353)
# GH47(187-647)
# GH17(99-295)
# GH16(72-212)
# AA7(216-412)
# GH128(44-279)
# GH79(27-411)
# GH18(540-890)
# GH76(29-399)
# GH76(31-393)
# GT62(84-347)
# GH28(134-443)
# GH76(28-424)
# GT76(23-430)
# GH128(51-266)
# GT2_Chitin_synth_1(258-420)
# GH18(183-537)
# CE5(24-216)
# CE10(121-439)
# GH25(26-209)
# CE10(66-336)
# PL7_4(25-233)
# GH72(4-322)
# CE10(96-255)
# GT90(306-595)
# AA1_3(106-390)
# GH3(97-317)
# GT2_Chitin_synth_1(487-649)+GT2_Chitin_synth_2(627-867)
# GH32(60-375)
# AA7(54-251)
# GT2_Glycos_transf_2(11-180)
# GH18(2-356)
# GH125(85-520)
# GH114(92-285)
# GH75(12-253)
# GH18(169-514)
# GH5_9(351-674)
# GH16(72-234)
# GT62(99-363)
# GH65(390-752)
# AA2(121-226)
# GH125(70-503)
# CE10(84-235)
# GT8(8-284)
# GT3(19-657)
# GT90(538-800)
# GT25(87-313)
# GH2(47-939)
# GH2(131-880)
# GH92(254-773)
# GH16(79-218)
# GT8(11-224)
# CE9(56-449)
# GH3(86-311)
# CE4(262-368)
# GH5_27(55-386)
# GH20(185-530)
# CE10(54-365)
# AA3_2(20-610)
# GH114(30-258)
# GH18(42-260)
# GH18(100-449)
# GH17(390-657)
# GH13_8(235-529)
# GT20(111-582)
# GT32(121-224)
# AA7(32-451)
# GH36(38-728)
# GT90(333-605)
# GH29(48-370)
# AA3_2(11-578)
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -

# %% [markdown]
# The CAZy familiy is immediately followed by its predicting amino acid domain range in parentheses.
#
# If multple CAZyme domains are predicted (represented by predicting multiple CAZy families), the domains/CAZy families are separated by '+'.
#
# Sometimes proteins predicated as containing GT2 domains are given the CAZy family "GT2_Chitin_synth_2". No reason for this has been found. For this reason and for standardisation, the names of the predicted CAZy families need to be standardised to GT2, and the same performed in case this occurs for other families as well.
#
# Additionally, when no CAZy domains are predicated to be within the protein sequence a result of '-' is provided. It will be better for the final dataframe if this is converted to a true null value.
#
# Lastly, sometimes HMMER predicates the CAZy subfamily. Unlike with eCAMI and CUPP the subfamily is not passed to a separate column, although this is helpful when it comes to evaluating the tools performances. Therefore, when HMMER predicates the CAZy subfamily this result needs to be passed to retrieve the CAZy family and then store the CAZy family and subfamily separately.
#
# If HMMER predicts the protein is not a CAZyme then "-" is the only thing that is written.
#
# HMMER can predict multiple CAZyme domains are in a protein. This is indicated by listing multiple CAZy families for a protein, where each CAZy family presents a different CAZyme domain in the protein. Each domain has a CAZy family, potentially a CAZy subfamily, and amino acid domain range. Each domain is represented by a single HMMERCazymeDomain instance. Each protein is represented by a single HMMERprediction instance, which stores all the CAZyme domains (the HMMERCazymeDomain instances) predicted to be in the protein.
#
# To be able to check if a protein has been parsed from the overview.txt file, the data will be stored in a dictionary. The `overview_dict` will be keyed by protein accessions, and valued by another dictionary, keyed by the name of the CAZyme prediction tools (dbCAN, HMMER, DIAMOND, Hotpep), which is then valued by the respective data model for presenting the prediction tools prediction for the respective protein. To illustrate:
# ```
# overview_dict = {
#     "ATY60367.1": {"HMMER": <HMMERprediction-instance>},
#     "ATY60372.1": {"HMMER": <HMMERprediction-instance>},
# }
# ```
# This will allow also CAZyme prediction tool data models for each protein to be stored together. To illustrate again:
# ```
# overview_dict = {
#     "ATY60367.1": {
#         "HMMER": <HMMERprediction-instance>,
#         "DIAMOND": <DIAMONDprediction-instance>,
#     },
#     "ATY60372.1": {
#         "HMMER": <HMMERprediction-instance>,
#         "DIAMOND": <DIAMONDprediction-instance>,
#     },
# }
# ```
#
# Another thing to note is that sometimes multiple domain ranges are predicted for the same domain. For example:
# `protein=ATY60416.1, fams=['GT2', 'GT2'], subfams=[nan, nan], ranges=['230-398', '375-584']`
# Luckily each line of the overview.txt file contains a unique protein. Therefore, while parsing a single line, when retrieving each predicted CAZyme domain it needs to be checked if the CAZy (sub)family has already been captured. If it has then the additional/alternative predicted amino acid domain range needs to be added to the already captured domain ranges. Consequently, the domain ranges are stored in lists to enable storing all predicted domain ranges for a single CAZyme domain to be stored together.
#
# To keep all predicted data for each CAZyme domain within the protein together, a `HMMERCazymeDomain` instance is created for each predicted CAZyme domain in the protein. The instance includes the CAZy family, subfamily (a null value if not given) and a predicted domain range (a null value if not given, although it always appears to be given).
#
# Multiple domain ranges can be predicted for a single domain, the `HMMERCazymeDomain` instances will be stored in a dictionary keyed by a string containing the CAZy family and subfamily, and valued by the corresponding `HMMERCazymeDomain` instance. After each predicted CAZyme domain is processed this dictionary will be checked to see if the CAZyme domain (identified by its CAZy family and subfamily) has already been catalogued. If it has then the additional domain range prediction will be added to the domain range prediction of the existing `HMMERCazymeDomain` instance. To allow this, the domain range of each CAZyme domain will be stored as a list, and each predicted domain range for the CAZyme domain stored as a separate string in the list.

# %%
# Check how text is separated in overview.txt
with open ("overview.txt", "r") as ofh:
    overview_file = ofh.read().splitlines()

overview_dict = {}

for line in tqdm(overview_file[1:], desc="Parsing overview.txt"):  # skip the first line becuase this is the 'column' titles
    line = line.split("\t")
    
    protein_accession = line[0]
    
    # check if the protein was classified as a non-CAZyme
    if line[1] == "-":
        cazyme_classification = 0  # non-CAZyme
        
        overview_dict[protein_accession] = {
            "HMMER": CazymeProteinPrediction(
                "HMMER",
                protein_accession,
                cazyme_classification,
            )
        }
        continue
    
    # create CazymeProteinPrediction instance to represent the prediction for the current working protein
    cazyme_classification = 1
    parent_cazyme = CazymeProteinPrediction("HMMER", protein_accession, cazyme_classification)

    # get prediction for HMMER and separate the predicted CAZyme domains
    hmmer_predictions = line[1].split("+")
    
    # create empty dictionary to store CAZyme domains {family: HMMERCazymeDomain instance}
    cazyme_domains = {}
    
    # parse each of the predicted CAZyme domains
    for predicted_domain in hmmer_predictions:

        # separate the CAZy family and amino acid domain range
        predicted_domain = predicted_domain.split("(")
        
        # get the CAZy (sub)family of the predicted domain
        domain_name = predicted_domain[0]
        
        if domain_name.find("_") != -1:  # found in unusal name formating or CAZy subfamily
            try:
                re.match(r"\D{2,3}\d+?_\D", domain_name).group  # check for unusal name formating
                cazy_family = domain_name[:domain_name.find("_")]
                cazy_subfamily = np.nan

            except AttributeError:  # raised if not unusal format but a CAZy subfamily
                cazy_family = domain_name[:domain_name.find("_")]
                cazy_subfamily = domain_name
        
        else:
            cazy_family = domain_name
            cazy_subfamily = np.nan

        # get the predicted amino acid domain range
        domain_range = predicted_domain[1][:-1] # exclude the final ")"
        
        # create identifier for the CAZyme domain to check if it has already been catalogued
        domain_identifier = f"{cazy_family}-{cazy_subfamily}"
        
        # check if the CAZyme domain has already been cataglouged
        try:
            existing_domain = cazyme_domains[domain_identifier]
            
            # CAZyme domain already catalogued, check if the retrieved domain range is the same as in the instance
            if domain_range not in existing_domain.domain_range:
                # append the new domain_range
                existing_domain.domain_range.append(domain_range)
                print("multiple domain ranges=", existing_domain, existing_domain.domain_range, protein_accession)
        
        except KeyError:  # raised if the CAZyme domain has not yet been catalogued
            cazyme_domains[domain_identifier] = CazymeDomain(
                prediction_tool="HMMER",
                protein_accession=protein_accession,
                cazy_family=cazy_family,
                cazy_subfamily=cazy_subfamily,
                domain_range=[domain_range],
            )
    
    # add CAZyme domains to the parent CAZyme
    parent_cazyme.cazyme_domains = list(cazyme_domains.values())
    
    # add the protein to the dictionary of all parsed proteins
    try:
        overview_dict[protein_accession]
        
        try:
            overview_dict[protein_accession]["HMMER"]
            print("WARNING -- PROTEIN ALREADY CATALOGUED WITH HMMER PREDICTION")
        
        except KeyError:  # raised it not HMMER prediction catagloued yet
            overview_dict[protein_accession]["HMMER"] = parent_cazyme
    
    except KeyError:  # raised if not protein yet catalogued
        overview_dict[protein_accession] = {"HMMER": parent_cazyme}
        
    print(parent_cazyme)

print("number of parsed proteins=", len(list(overview_dict.values())))
# Out:
# HBox(children=(HTML(value='Parsing overview.txt'), FloatProgress(value=0.0, max=445.0), HTML(value='')))
# -CazymeProteinPrediction, protein=ATY58323.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY58330.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY58395.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY58396.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY58475.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY58478.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY58486.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY58494.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY58512.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY58528.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY58531.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY58532.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY58571.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY58579.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY58636.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY58637.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY58653.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY58674.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY58687.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY58705.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY58803.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY58848.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY58880.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY58895.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY58902.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY58910.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY58915.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY58949.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY58965.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY59023.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY59031.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY59065.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY59093.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY59185.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY59188.1, CAZyme domains=2-
# -CazymeProteinPrediction, protein=ATY59194.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY59202.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY59250.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY59363.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY59524.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY59596.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY59638.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY59663.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY59671.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY59673.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY59688.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY59691.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY59698.1, CAZyme domains=2-
# -CazymeProteinPrediction, protein=ATY59714.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY59728.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY59756.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY59775.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY59781.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY59860.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY59890.1, CAZyme domains=2-
# -CazymeProteinPrediction, protein=ATY59904.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY59918.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY59933.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY59950.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY59985.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60044.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60072.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60094.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60133.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60146.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60162.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60186.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60187.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60246.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60251.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60261.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60312.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60330.1, CAZyme domains=1-
# multiple domain ranges= -CazymeDomain in ATY60367.1, fam=CBM66, subfam=nan- ['219-369', '388-547'] ATY60367.1
# -CazymeProteinPrediction, protein=ATY60367.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60372.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60381.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60408.1, CAZyme domains=1-
# multiple domain ranges= -CazymeDomain in ATY60416.1, fam=GT2, subfam=nan- ['230-398', '375-584'] ATY60416.1
# -CazymeProteinPrediction, protein=ATY60416.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60491.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60504.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60550.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60555.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60591.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60613.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60620.1, CAZyme domains=2-
# -CazymeProteinPrediction, protein=ATY60629.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60662.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60681.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60726.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60733.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60734.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60772.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60851.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60853.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60878.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60943.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60976.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60986.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61013.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61023.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61046.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61069.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61117.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61140.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61147.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61152.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61215.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61276.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61280.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61301.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61355.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61441.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61486.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61576.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61595.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61630.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61694.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61713.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61718.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61741.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61753.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61788.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61822.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61824.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61835.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61836.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61850.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61851.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61863.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61865.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61890.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61893.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61914.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61926.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61957.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61965.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61989.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62020.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62039.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62050.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62087.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62092.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62109.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62125.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62132.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62143.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62147.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62175.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62231.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62233.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62235.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62242.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62277.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62278.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62287.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62309.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62338.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62385.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62412.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62433.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62465.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62551.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62564.1, CAZyme domains=2-
# -CazymeProteinPrediction, protein=ATY62578.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62592.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62614.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62660.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62663.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62684.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62685.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62702.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62739.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62740.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62742.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62757.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62798.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62856.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62900.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62933.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62981.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63039.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63066.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63199.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63210.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63227.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63228.1, CAZyme domains=1-
# multiple domain ranges= -CazymeDomain in ATY63255.1, fam=GT57, subfam=nan- ['63-294', '333-565'] ATY63255.1
# -CazymeProteinPrediction, protein=ATY63255.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63301.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63305.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63319.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63344.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63360.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63375.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63412.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63454.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63468.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63517.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63528.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63573.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63588.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63601.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63636.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63688.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63703.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63705.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63786.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63856.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63886.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63982.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63987.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63993.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63999.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64005.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64012.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64015.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64043.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64047.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64050.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64088.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64132.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64150.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64179.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64186.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64187.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64188.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64233.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64248.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64353.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64416.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64437.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64461.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64478.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64479.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64503.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64517.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64570.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64579.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64630.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64671.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64693.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64695.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64700.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64752.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64774.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64802.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64843.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64850.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64919.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64924.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64953.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64976.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64989.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64996.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65010.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65020.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65055.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65081.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65106.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65116.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65185.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65188.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65191.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65205.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65223.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65449.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65455.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65484.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65544.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65556.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65579.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65604.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65626.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65637.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65665.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65674.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65680.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65728.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65765.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65808.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65886.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65888.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65896.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66055.1, CAZyme domains=1-
# multiple domain ranges= -CazymeDomain in ATY66192.1, fam=GT2, subfam=nan- ['487-649', '627-867'] ATY66192.1
# -CazymeProteinPrediction, protein=ATY66192.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66193.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66198.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66259.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66268.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66363.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66369.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66426.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66444.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66476.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66491.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66509.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66529.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66531.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66542.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66551.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66592.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66603.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66615.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66624.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66664.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66787.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66848.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66850.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66859.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66875.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66876.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66975.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY67020.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY67094.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY67122.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY67138.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY67182.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY67196.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY67226.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY67280.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY67289.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY67309.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY67327.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY67358.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY67425.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY67467.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY67468.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY67472.1, CAZyme domains=1-
#
# number of parsed proteins= 445

# %% [markdown]
# From prining the class representative strings we can see that the multiple CAZyme domains are stored under a parent CAZyme (for example see protein ATY59188.1).
#
# By comparing the number of protein accessions listed in the `overview_dict` and the number of proteins in the overview.txt file, we can see that all proteins were parsed.
#
# To improve the robustness of the method we can add 'quality' checks to check the expected data is retrieved. This is achieved by using regular expressions, for example, to ensure a believed CAZy subfamily is in the correct format for a CAZy subfamily.

# %%
# Check how text is separated in overview.txt
with open ("overview.txt", "r") as ofh:
    overview_file = ofh.read().splitlines()

overview_dict = {}

for line in tqdm(overview_file[1:], desc="Parsing overview.txt"):  # skip the first line becuase this is the 'column' titles
    line = line.split("\t")
    
    protein_accession = line[0]
    
    # check if the protein was classified as a non-CAZyme
    if line[1] == "-":
        cazyme_classification = 0  # non-CAZyme
        
        overview_dict[protein_accession] = {
            "HMMER": CazymeProteinPrediction(
                "HMMER",
                protein_accession,
                cazyme_classification,
            )
        }
        continue
    
    # create HMMERprediction instance to represent the prediction for the current working protein
    cazyme_classification = 1
    parent_cazyme = CazymeProteinPrediction("HMMER", protein_accession, cazyme_classification)

    # get prediction for HMMER and separate the predicted CAZyme domains
    hmmer_predictions = line[1].split("+")
    
    # create empty dictionary to store CAZyme domains {family: HMMERCazymeDomain instance}
    cazyme_domains = {}
    
    # parse each of the predicted CAZyme domains
    for predicted_domain in hmmer_predictions:

        # separate the CAZy family and amino acid domain range
        predicted_domain = predicted_domain.split("(")
        
        # get the CAZy (sub)family of the predicted domain
        domain_name = predicted_domain[0]
        
        # check if an unusal CAZy family format  or CAZy subfamily is given
        if domain_name.find("_") != -1:  # found in unusal name formating or CAZy subfamily
        
            try:
                re.match(r"\D{2,3}\d+?_\D", domain_name).group()
                cazy_family = domain_name[:domain_name.find("_")]
                cazy_subfamily = np.nan

            except AttributeError:  # raised if not unusal format
                
                try:
                    # check it is a CAZy subfamily
                    re.match(r"\D{2,3}\d+?_\d+", domain_name).group()
                    cazy_family = domain_name[:domain_name.find("_")]
                    cazy_subfamily = np.nan
                
                except AttributeError:  # raised if doesn't match expected CAZy subfamily
                    print(
                        f"WARNING -- UNKNOWN DATA TYPE OF {domain_name} FOR {protein_accession}\n"
                        "Not adding as a domain."
                    )
                    continue
        
        else:
            # potentially have a CAZy family
            try:
                re.match(r"\D{2,3}\d+", domain_name).group()
                cazy_family = domain_name
                cazy_subfamily = np.nan
                
            except AttributeError:  # raised if doesn't match expected CAZy family
                print(
                    f"WARNING -- UNKNOWN DATA TYPE OF {domain_name} FOR {protein_accession}\n"
                    "Not adding as a domain."
                )
                continue

        # get the predicted amino acid domain range
        domain_range = predicted_domain[1][:-1] # exclude the final ")"
        # check domain_range is in the correct format
        try:
            re.match(r"\d+?-\d+", domain_range).group()
        except AttributeError:  # raised if not the correct format
            print(
                f"WARNING -- UNKNOWN DATA TYPE OF {domain_range} FOR {protein_accession}\n"
                f"Not adding domain range for the domain {cazy_family}-{cazy_subfamily}"
            )
            domain_range = np.nan
        
        # create identifier for the CAZyme domain to check if it has already been catalogued
        domain_identifier = f"{cazy_family}-{cazy_subfamily}"
        
        # check if the CAZyme domain has already been cataglouged
        try:
            existing_domain = cazyme_domains[domain_identifier]
            
            # CAZyme domain already catalogued, check if the retrieved domain range is the same as in the instance
            if domain_range not in existing_domain.domain_range:
                # append the new domain_range
                existing_domain.domain_range.append(domain_range)
                print("multiple domain ranges=", existing_domain, existing_domain.domain_range, protein_accession)
        
        except KeyError:  # raised if the CAZyme domain has not yet been catalogued
            cazyme_domains[domain_identifier] = CazymeDomain(
                prediction_tool="HMMER",
                protein_accession=protein_accession,
                cazy_family=cazy_family,
                cazy_subfamily=cazy_subfamily,
                domain_range=[domain_range],
            )
    
    # add CAZyme domains to the parent CAZyme
    parent_cazyme.cazyme_domains = list(cazyme_domains.values())
    
    # add the protein to the dictionary of all parsed proteins
    try:
        overview_dict[protein_accession]
        
        try:
            overview_dict[protein_accession]["HMMER"]
            print("WARNING -- PROTEIN ALREADY CATALOGUED WITH HMMER PREDICTION")
        
        except KeyError:  # raised it not HMMER prediction catagloued yet
            overview_dict[protein_accession]["HMMER"] = parent_cazyme
    
    except KeyError:  # raised if not protein yet catalogued
        overview_dict[protein_accession] = {"HMMER": parent_cazyme}
        
    print(parent_cazyme)

print("number of parsed proteins=", len(list(overview_dict.values())))
# Out:
# HBox(children=(HTML(value='Parsing overview.txt'), FloatProgress(value=0.0, max=445.0), HTML(value='')))
# -CazymeProteinPrediction, protein=ATY58323.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY58330.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY58395.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY58396.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY58475.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY58478.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY58486.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY58494.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY58512.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY58528.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY58531.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY58532.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY58571.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY58579.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY58636.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY58637.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY58653.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY58674.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY58687.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY58705.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY58803.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY58848.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY58880.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY58895.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY58902.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY58910.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY58915.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY58949.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY58965.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY59023.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY59031.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY59065.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY59093.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY59185.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY59188.1, CAZyme domains=2-
# -CazymeProteinPrediction, protein=ATY59194.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY59202.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY59250.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY59363.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY59524.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY59596.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY59638.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY59663.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY59671.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY59673.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY59688.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY59691.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY59698.1, CAZyme domains=2-
# -CazymeProteinPrediction, protein=ATY59714.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY59728.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY59756.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY59775.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY59781.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY59860.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY59890.1, CAZyme domains=2-
# -CazymeProteinPrediction, protein=ATY59904.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY59918.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY59933.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY59950.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY59985.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60044.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60072.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60094.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60133.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60146.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60162.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60186.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60187.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60246.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60251.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60261.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60312.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60330.1, CAZyme domains=1-
# multiple domain ranges= -CazymeDomain in ATY60367.1, fam=CBM66, subfam=nan- ['219-369', '388-547'] ATY60367.1
# -CazymeProteinPrediction, protein=ATY60367.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60372.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60381.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60408.1, CAZyme domains=1-
# multiple domain ranges= -CazymeDomain in ATY60416.1, fam=GT2, subfam=nan- ['230-398', '375-584'] ATY60416.1
# -CazymeProteinPrediction, protein=ATY60416.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60491.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60504.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60550.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60555.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60591.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60613.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60620.1, CAZyme domains=2-
# -CazymeProteinPrediction, protein=ATY60629.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60662.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60681.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60726.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60733.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60734.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60772.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60851.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60853.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60878.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60943.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60976.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60986.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61013.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61023.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61046.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61069.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61117.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61140.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61147.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61152.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61215.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61276.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61280.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61301.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61355.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61441.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61486.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61576.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61595.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61630.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61694.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61713.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61718.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61741.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61753.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61788.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61822.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61824.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61835.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61836.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61850.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61851.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61863.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61865.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61890.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61893.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61914.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61926.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61957.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61965.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61989.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62020.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62039.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62050.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62087.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62092.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62109.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62125.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62132.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62143.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62147.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62175.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62231.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62233.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62235.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62242.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62277.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62278.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62287.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62309.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62338.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62385.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62412.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62433.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62465.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62551.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62564.1, CAZyme domains=2-
# -CazymeProteinPrediction, protein=ATY62578.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62592.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62614.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62660.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62663.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62684.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62685.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62702.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62739.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62740.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62742.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62757.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62798.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62856.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62900.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62933.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62981.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63039.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63066.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63199.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63210.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63227.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63228.1, CAZyme domains=1-
# multiple domain ranges= -CazymeDomain in ATY63255.1, fam=GT57, subfam=nan- ['63-294', '333-565'] ATY63255.1
# -CazymeProteinPrediction, protein=ATY63255.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63301.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63305.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63319.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63344.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63360.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63375.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63412.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63454.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63468.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63517.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63528.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63573.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63588.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63601.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63636.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63688.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63703.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63705.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63786.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63856.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63886.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63982.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63987.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63993.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63999.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64005.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64012.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64015.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64043.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64047.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64050.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64088.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64132.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64150.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64179.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64186.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64187.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64188.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64233.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64248.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64353.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64416.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64437.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64461.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64478.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64479.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64503.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64517.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64570.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64579.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64630.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64671.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64693.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64695.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64700.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64752.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64774.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64802.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64843.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64850.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64919.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64924.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64953.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64976.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64989.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64996.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65010.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65020.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65055.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65081.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65106.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65116.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65185.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65188.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65191.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65205.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65223.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65449.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65455.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65484.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65544.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65556.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65579.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65604.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65626.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65637.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65665.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65674.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65680.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65728.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65765.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65808.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65886.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65888.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65896.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66055.1, CAZyme domains=1-
# multiple domain ranges= -CazymeDomain in ATY66192.1, fam=GT2, subfam=nan- ['487-649', '627-867'] ATY66192.1
# -CazymeProteinPrediction, protein=ATY66192.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66193.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66198.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66259.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66268.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66363.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66369.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66426.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66444.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66476.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66491.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66509.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66529.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66531.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66542.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66551.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66592.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66603.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66615.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66624.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66664.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66787.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66848.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66850.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66859.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66875.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66876.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66975.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY67020.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY67094.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY67122.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY67138.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY67182.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY67196.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY67226.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY67280.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY67289.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY67309.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY67327.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY67358.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY67425.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY67467.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY67468.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY67472.1, CAZyme domains=1-
#
# number of parsed proteins= 445

# %% [markdown]
# To make the code easier to read, we can pass out each of the different tasks (such as retrieving the subfamily, domain range, etc.) to separate functions.
#
# Although it is not necessary to explicity write out the positional attributes of the CazymeDomain class, but it is neater to write out all attributes and explicitly assign their values, instead of only explicitly assigning the values of the optional attributes (i.e. `domain_range`)>

# %%
def parse_hmmer():
    """Parse data from HMMER presented in the overview.txt file"""
    # Check how text is separated in overview.txt
    with open ("overview.txt", "r") as ofh:
        overview_file = ofh.read().splitlines()

    overview_dict = {}

    for line in tqdm(overview_file[1:], desc="Parsing overview.txt"):  # skip the first line becuase this is the 'column' titles
        line = line.split("\t")

        protein_accession = line[0]

        # check if the protein was classified as a non-CAZyme
        if line[1] == "-":
            cazyme_classification = 0  # non-CAZyme

            overview_dict[protein_accession] = {
                "HMMER": CazymeProteinPrediction(
                    "HMMER",
                    protein_accession,
                    cazyme_classification,
                )
            }
            continue

        # create HMMERprediction instance to represent the prediction for the current working protein
        cazyme_classification = 1
        parent_cazyme = CazymeProteinPrediction("HMMER", protein_accession, cazyme_classification)

        # get prediction for HMMER and separate the predicted CAZyme domains
        hmmer_predictions = line[1].split("+")

        # create empty dictionary to store CAZyme domains {family: HMMERCazymeDomain instance}
        cazyme_domains = get_cazyme_domains(hmmer_predictions, protein_accession)

        # add CAZyme domains to the parent CAZyme
        parent_cazyme.cazyme_domains = list(cazyme_domains.values())

        # add the protein to the dictionary of all parsed proteins
        try:
            overview_dict[protein_accession]

            try:
                overview_dict[protein_accession]["HMMER"]
                print("WARNING -- PROTEIN ALREADY CATALOGUED WITH HMMER PREDICTION")

            except KeyError:  # raised it not HMMER prediction catagloued yet
                overview_dict[protein_accession]["HMMER"] = parent_cazyme

        except KeyError:  # raised if not protein yet catalogued
            overview_dict[protein_accession] = {"HMMER": parent_cazyme}

        print(parent_cazyme)

    return overview_dict


def get_cazyme_domains(hmmer_predictions, protein_accession):
    """Retrieve predicted CAZyme domains, predited to be in a CAZyme by HMMER
    
    :param hmmer_predictions: list, data from HMMER from overview.txt file
    :param protein_accession: str
    
    Return dictionary, keyed by protein accession and valued by CazymeDomain instance.
    """
    cazyme_domains = {}

    # parse each of the predicted CAZyme domains
    for predicted_domain in hmmer_predictions:

        # separate the CAZy family and amino acid domain range
        predicted_domain = predicted_domain.split("(")

        # get the CAZy (sub)family of the predicted domain
        domain_name = predicted_domain[0]

        # check if an unusal CAZy family format  or CAZy subfamily is given
        if domain_name.find("_") != -1:  # found in unusal name formating or CAZy subfamily

            try:
                re.match(r"\D{2,3}\d+?_\D", domain_name).group()
                cazy_family = domain_name[:domain_name.find("_")]
                cazy_subfamily = np.nan

            except AttributeError:  # raised if not unusal format

                try:
                    # check it is a CAZy subfamily
                    re.match(r"\D{2,3}\d+?_\d+", domain_name).group()
                    cazy_family = domain_name[:domain_name.find("_")]
                    cazy_subfamily = np.nan

                except AttributeError:  # raised if doesn't match expected CAZy subfamily
                    print(
                        f"WARNING -- UNKNOWN DATA TYPE OF {domain_name} FOR {protein_accession}\n"
                        "Not adding as a domain."
                    )
                    continue

        else:
            # potentially have a CAZy family
            try:
                re.match(r"\D{2,3}\d+", domain_name).group()
                cazy_family = domain_name
                cazy_subfamily = np.nan

            except AttributeError:  # raised if doesn't match expected CAZy family
                print(
                    f"WARNING -- UNKNOWN DATA TYPE OF {domain_name} FOR {protein_accession}\n"
                    "Not adding as a domain."
                )
                continue

        # get the predicted amino acid domain range
        domain_range = predicted_domain[1][:-1] # exclude the final ")"
        # check domain_range is in the correct format
        try:
            re.match(r"\d+?-\d+", domain_range).group()
        except AttributeError:  # raised if not the correct format
            print(
                f"WARNING -- UNKNOWN DATA TYPE OF {domain_range} FOR {protein_accession}\n"
                f"Not adding domain range for the domain {cazy_family}-{cazy_subfamily}"
            )
            domain_range = np.nan

        # create identifier for the CAZyme domain to check if it has already been catalogued
        domain_identifier = f"{cazy_family}-{cazy_subfamily}"

        # check if the CAZyme domain has already been cataglouged
        try:
            existing_domain = cazyme_domains[domain_identifier]

            # CAZyme domain already catalogued, check if the retrieved domain range is the same as in the instance
            if domain_range not in existing_domain.domain_range:
                # append the new domain_range
                existing_domain.domain_range.append(domain_range)
                print("multiple domain ranges=", existing_domain, existing_domain.domain_range, protein_accession)

        except KeyError:  # raised if the CAZyme domain has not yet been catalogued
            cazyme_domains[domain_identifier] = CazymeDomain(
                prediction_tool="HMMER",
                protein_accession=protein_accession,
                cazy_family=cazy_family,
                cazy_subfamily=cazy_subfamily,
                domain_range=[domain_range],
            )

    return cazyme_domains

overview_dict = parse_hmmer()
print("number of parsed proteins=", len(list(overview_dict.values())))
# Out:
# HBox(children=(HTML(value='Parsing overview.txt'), FloatProgress(value=0.0, max=445.0), HTML(value='')))
# -CazymeProteinPrediction, protein=ATY58323.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY58330.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY58395.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY58396.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY58475.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY58478.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY58486.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY58494.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY58512.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY58528.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY58531.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY58532.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY58571.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY58579.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY58636.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY58637.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY58653.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY58674.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY58687.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY58705.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY58803.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY58848.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY58880.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY58895.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY58902.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY58910.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY58915.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY58949.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY58965.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY59023.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY59031.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY59065.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY59093.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY59185.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY59188.1, CAZyme domains=2-
# -CazymeProteinPrediction, protein=ATY59194.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY59202.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY59250.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY59363.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY59524.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY59596.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY59638.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY59663.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY59671.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY59673.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY59688.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY59691.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY59698.1, CAZyme domains=2-
# -CazymeProteinPrediction, protein=ATY59714.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY59728.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY59756.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY59775.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY59781.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY59860.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY59890.1, CAZyme domains=2-
# -CazymeProteinPrediction, protein=ATY59904.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY59918.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY59933.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY59950.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY59985.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60044.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60072.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60094.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60133.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60146.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60162.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60186.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60187.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60246.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60251.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60261.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60312.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60330.1, CAZyme domains=1-
# multiple domain ranges= -CazymeDomain in ATY60367.1, fam=CBM66, subfam=nan- ['219-369', '388-547'] ATY60367.1
# -CazymeProteinPrediction, protein=ATY60367.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60372.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60381.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60408.1, CAZyme domains=1-
# multiple domain ranges= -CazymeDomain in ATY60416.1, fam=GT2, subfam=nan- ['230-398', '375-584'] ATY60416.1
# -CazymeProteinPrediction, protein=ATY60416.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60491.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60504.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60550.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60555.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60591.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60613.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60620.1, CAZyme domains=2-
# -CazymeProteinPrediction, protein=ATY60629.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60662.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60681.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60726.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60733.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60734.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60772.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60851.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60853.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60878.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60943.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60976.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60986.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61013.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61023.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61046.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61069.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61117.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61140.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61147.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61152.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61215.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61276.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61280.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61301.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61355.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61441.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61486.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61576.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61595.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61630.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61694.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61713.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61718.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61741.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61753.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61788.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61822.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61824.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61835.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61836.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61850.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61851.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61863.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61865.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61890.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61893.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61914.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61926.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61957.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61965.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61989.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62020.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62039.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62050.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62087.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62092.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62109.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62125.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62132.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62143.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62147.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62175.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62231.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62233.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62235.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62242.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62277.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62278.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62287.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62309.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62338.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62385.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62412.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62433.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62465.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62551.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62564.1, CAZyme domains=2-
# -CazymeProteinPrediction, protein=ATY62578.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62592.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62614.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62660.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62663.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62684.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62685.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62702.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62739.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62740.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62742.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62757.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62798.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62856.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62900.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62933.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62981.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63039.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63066.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63199.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63210.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63227.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63228.1, CAZyme domains=1-
# multiple domain ranges= -CazymeDomain in ATY63255.1, fam=GT57, subfam=nan- ['63-294', '333-565'] ATY63255.1
# -CazymeProteinPrediction, protein=ATY63255.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63301.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63305.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63319.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63344.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63360.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63375.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63412.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63454.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63468.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63517.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63528.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63573.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63588.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63601.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63636.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63688.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63703.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63705.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63786.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63856.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63886.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63982.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63987.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63993.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63999.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64005.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64012.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64015.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64043.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64047.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64050.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64088.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64132.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64150.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64179.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64186.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64187.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64188.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64233.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64248.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64353.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64416.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64437.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64461.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64478.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64479.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64503.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64517.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64570.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64579.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64630.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64671.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64693.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64695.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64700.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64752.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64774.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64802.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64843.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64850.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64919.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64924.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64953.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64976.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64989.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64996.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65010.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65020.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65055.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65081.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65106.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65116.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65185.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65188.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65191.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65205.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65223.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65449.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65455.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65484.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65544.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65556.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65579.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65604.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65626.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65637.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65665.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65674.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65680.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65728.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65765.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65808.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65886.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65888.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65896.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66055.1, CAZyme domains=1-
# multiple domain ranges= -CazymeDomain in ATY66192.1, fam=GT2, subfam=nan- ['487-649', '627-867'] ATY66192.1
# -CazymeProteinPrediction, protein=ATY66192.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66193.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66198.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66259.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66268.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66363.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66369.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66426.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66444.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66476.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66491.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66509.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66529.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66531.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66542.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66551.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66592.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66603.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66615.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66624.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66664.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66787.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66848.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66850.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66859.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66875.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66876.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66975.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY67020.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY67094.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY67122.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY67138.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY67182.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY67196.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY67226.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY67280.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY67289.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY67309.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY67327.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY67358.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY67425.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY67467.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY67468.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY67472.1, CAZyme domains=1-
#
# number of parsed proteins= 445

# %% [markdown]
# <a id="hotpep"></a>

# %% [markdown]
# ## Hotpep
#
# For Hotpep the data we want to retrieve is:
# - The protein accession (which is the 'Gene ID')
# - The CAZy (sub)families HMMER has predicted CAZy would catalogue the protein under
# - Predicted EC numbers of the predicted CAZy domains (each domain is represented as a CAZy family prediction, thus predicting two CAZy families indicates predicting two CAZyme domains)

# %% [markdown]
# <a id="over_diamond"></a>

# %% [markdown]
# ### Parsing Hotpep data from overview.txt
#
# For Hotpep the data we want to retrieve is:
#
# - The protein accession (which is the 'Gene ID')
# - The CAZy (sub)families HMMER has predicted CAZy would catalogue the protein under
# - Predicted EC numbers of the predicted CAZy domains (each domain is represented as a CAZy family prediction, thus predicting two CAZy families indicates predicting two CAZyme domains)
#
# However, on the CAZy family and subfamily can be retrieved from the overview.txt file.
# To start lets look at how the Hotpep data is presented in the overview.txt file.

# %%
# Check how text is separated in overview.txt
with open ("overview.txt", "r") as ofh:
    overview_file = ofh.read().splitlines()

for line in overview_file[1:]:  # skip the first line becuase this is the 'column' titles
    line = line.split("\t")
    hotpep = line[2]
    print(line[0], hotpep)
# Out:
# ATY58323.1 -
# ATY58330.1 AA11(2)
# ATY58395.1 -
# ATY58396.1 AA6(1)
# ATY58475.1 AA3(6)
# ATY58478.1 GH16(14)
# ATY58486.1 GH18(92)+CBM1(13)+CBM19(1)
# ATY58494.1 GH5(55)
# ATY58512.1 GH55(5)
# ATY58528.1 -
# ATY58531.1 GH64(5)+CBM6(29)
# ATY58532.1 -
# ATY58571.1 GH76(7)
# ATY58579.1 GH38(5)
# ATY58636.1 -
# ATY58637.1 -
# ATY58653.1 -
# ATY58674.1 GH75(2)
# ATY58687.1 -
# ATY58705.1 GH29(53)
# ATY58803.1 GT66(1)
# ATY58848.1 GH18(42)+CBM12(19)+CBM16(5)+CBM5(17)
# ATY58880.1 GH1(8)
# ATY58895.1 AA3(18)
# ATY58902.1 AA3(14)
# ATY58910.1 -
# ATY58915.1 -
# ATY58949.1 GH16(41)
# ATY58965.1 -
# ATY59023.1 GH18(45)+CBM18(6)
# ATY59031.1 GH13(23)+CBM20(17)
# ATY59065.1 GH81(1)+CBM6(13)
# ATY59093.1 GH18(51)+CBM18(12)+CBM5(14)
# ATY59185.1 GT90(8)
# ATY59188.1 GH18(102)+CBM18(5)
# ATY59194.1 GH72(3)
# ATY59202.1 -
# ATY59250.1 GT15(1)
# ATY59363.1 AA12(1)
# ATY59524.1 -
# ATY59596.1 -
# ATY59638.1 GT21(11)
# ATY59663.1 -
# ATY59671.1 -
# ATY59673.1 -
# ATY59688.1 AA1(4)
# ATY59691.1 GT1(76)
# ATY59698.1 GH54(1)+CBM13(36)+CBM42(1)
# ATY59714.1 GT4(169)
# ATY59728.1 -
# ATY59756.1 -
# ATY59775.1 -
# ATY59781.1 -
# ATY59860.1 -
# ATY59890.1 GH43(21)+CBM66(6)
# ATY59904.1 -
# ATY59918.1 -
# ATY59933.1 -
# ATY59950.1 -
# ATY59985.1 GH47(2)
# ATY60044.1 GT2(161)
# ATY60072.1 -
# ATY60094.1 GT17(3)
# ATY60133.1 GH0(23)+GH55(2)
# ATY60146.1 GT4(109)
# ATY60162.1 AA1(12)
# ATY60186.1 AA11(1)
# ATY60187.1 -
# ATY60246.1 GT22(3)
# ATY60251.1 -
# ATY60261.1 AA5(5)
# ATY60312.1 GT4(145)
# ATY60330.1 GH92(9)
# ATY60367.1 -
# ATY60372.1 -
# ATY60381.1 GH152(8)
# ATY60408.1 GH76(6)
# ATY60416.1 GT2(9)
# ATY60491.1 GH31(6)
# ATY60504.1 CBM18(12)
# ATY60550.1 -
# ATY60555.1 -
# ATY60591.1 GH2(10)+CBM51(5)+CBM67(4)
# ATY60613.1 AA1(4)
# ATY60620.1 GH142(2)+CBM13(77)
# ATY60629.1 GH76(10)
# ATY60662.1 GH47(2)
# ATY60681.1 GH16(22)
# ATY60726.1 GH84(14)
# ATY60733.1 GH76(10)
# ATY60734.1 -
# ATY60772.1 AA11(1)
# ATY60851.1 GH20(74)
# ATY60853.1 -
# ATY60878.1 GT2(161)
# ATY60943.1 -
# ATY60976.1 GT34(7)
# ATY60986.1 GH16(53)
# ATY61013.1 -
# ATY61023.1 -
# ATY61046.1 -
# ATY61069.1 GH18(45)+CBM18(6)
# ATY61117.1 GT64(6)
# ATY61140.1 GH3(13)
# ATY61147.1 GH89(8)
# ATY61152.1 -
# ATY61215.1 GH18(91)+CBM1(18)+CBM19(1)
# ATY61276.1 GH133(2)
# ATY61280.1 -
# ATY61301.1 GH16(25)
# ATY61355.1 GT69(2)
# ATY61441.1 -
# ATY61486.1 -
# ATY61576.1 GH31(20)
# ATY61595.1 -
# ATY61630.1 -
# ATY61694.1 AA3(7)
# ATY61713.1 GH18(44)
# ATY61718.1 GH18(102)+CBM18(5)
# ATY61741.1 GT2(161)
# ATY61753.1 GT20(2)+CBM20(39)
# ATY61788.1 -
# ATY61822.1 -
# ATY61824.1 GH16(23)+CBM18(8)
# ATY61835.1 GH16(37)+CBM4(2)+CBM54(1)+CBM6(15)
# ATY61836.1 GT0(19)
# ATY61850.1 GH15(27)
# ATY61851.1 GH18(102)+CBM18(5)
# ATY61863.1 GT59(2)
# ATY61865.1 GT15(1)
# ATY61890.1 -
# ATY61893.1 GH72(2)+CBM43(12)
# ATY61914.1 GH2(21)
# ATY61926.1 -
# ATY61957.1 GT22(9)
# ATY61965.1 GH13(29)
# ATY61989.1 GT39(2)
# ATY62020.1 GH47(2)
# ATY62039.1 GH5(124)
# ATY62050.1 -
# ATY62087.1 -
# ATY62092.1 GH132(3)
# ATY62109.1 GT22(5)
# ATY62125.1 GH5(81)
# ATY62132.1 GH0(68)+GH76(24)
# ATY62143.1 AA12(1)
# ATY62147.1 GT39(2)
# ATY62175.1 GH13(7)
# ATY62231.1 -
# ATY62233.1 AA3(27)
# ATY62235.1 GT22(6)
# ATY62242.1 GT50(1)
# ATY62277.1 GH3(11)
# ATY62278.1 -
# ATY62287.1 -
# ATY62309.1 -
# ATY62338.1 -
# ATY62385.1 GH20(17)
# ATY62412.1 GT1(76)
# ATY62433.1 -
# ATY62465.1 GH3(13)+CBM1(30)
# ATY62551.1 GT58(1)
# ATY62564.1 GH15(14)+CBM20(5)
# ATY62578.1 GH5(134)
# ATY62592.1 -
# ATY62614.1 GT20(6)+CBM20(39)
# ATY62660.1 -
# ATY62663.1 -
# ATY62684.1 GH16(37)+CBM4(2)+CBM54(1)+CBM6(15)
# ATY62685.1 GT0(19)
# ATY62702.1 CE3(10)
# ATY62739.1 GH154(8)
# ATY62740.1 GH88(11)
# ATY62742.1 GH47(3)
# ATY62757.1 GH3(40)+CBM6(3)
# ATY62798.1 AA3(19)
# ATY62856.1 AA9(8)+CBM18(16)
# ATY62900.1 -
# ATY62933.1 GH64(5)+CBM6(29)
# ATY62981.1 GT15(1)
# ATY63039.1 -
# ATY63066.1 GH18(16)+CBM12(11)+CBM2(6)
# ATY63199.1 -
# ATY63210.1 GT69(4)
# ATY63227.1 GT71(16)
# ATY63228.1 GH63(2)
# ATY63255.1 GT57(1)
# ATY63301.1 -
# ATY63305.1 GH3(92)
# ATY63319.1 GH35(5)
# ATY63344.1 GT90(3)
# ATY63360.1 GT39(3)
# ATY63375.1 -
# ATY63412.1 CBM10(1)+CBM2(60)+CBM5(61)
# ATY63454.1 CE4(143)+CBM18(7)
# ATY63468.1 -
# ATY63517.1 -
# ATY63528.1 AA11(2)
# ATY63573.1 GH18(64)
# ATY63588.1 GH3(13)+CBM1(30)
# ATY63601.1 GH79(8)
# ATY63636.1 GT17(3)
# ATY63688.1 GH37(4)
# ATY63703.1 -
# ATY63705.1 -
# ATY63786.1 -
# ATY63856.1 -
# ATY63886.1 -
# ATY63982.1 GT35(1)
# ATY63987.1 GH92(9)
# ATY63993.1 -
# ATY63999.1 -
# ATY64005.1 GT34(5)
# ATY64012.1 GH55(2)
# ATY64015.1 AA3(9)
# ATY64043.1 GH0(2)
# ATY64047.1 GH31(24)
# ATY64050.1 -
# ATY64088.1 GH89(8)
# ATY64132.1 -
# ATY64150.1 GH55(2)
# ATY64179.1 GH72(4)
# ATY64186.1 GT90(4)
# ATY64187.1 -
# ATY64188.1 -
# ATY64233.1 GT17(3)
# ATY64248.1 GH72(2)+CBM43(12)
# ATY64353.1 -
# ATY64416.1 GT57(2)
# ATY64437.1 -
# ATY64461.1 GT33(2)
# ATY64478.1 AA3(11)
# ATY64479.1 GH3(63)+CBM1(30)
# ATY64503.1 GH76(19)
# ATY64517.1 GH2(52)+CBM42(2)+CBM67(18)
# ATY64570.1 GH92(14)
# ATY64579.1 -
# ATY64630.1 -
# ATY64671.1 GH2(70)
# ATY64693.1 GH18(45)+CBM18(6)+CBM2(6)
# ATY64695.1 GH55(2)
# ATY64700.1 GH5(27)
# ATY64752.1 GT24(1)
# ATY64774.1 -
# ATY64802.1 GT20(4)
# ATY64843.1 GH17(32)
# ATY64850.1 GT48(1)
# ATY64919.1 GH35(1)
# ATY64924.1 GH47(1)
# ATY64953.1 CE4(143)+CBM18(7)
# ATY64976.1 AA7(3)+CBM18(20)
# ATY64989.1 -
# ATY64996.1 CBM21(4)
# ATY65010.1 -
# ATY65020.1 AA1(12)
# ATY65055.1 CE5(15)
# ATY65081.1 CE16(2)
# ATY65106.1 GH47(2)
# ATY65116.1 GH17(19)
# ATY65185.1 -
# ATY65188.1 -
# ATY65191.1 GH128(4)
# ATY65205.1 -
# ATY65223.1 GH18(102)+CBM18(5)
# ATY65449.1 GH76(7)
# ATY65455.1 GH76(6)
# ATY65484.1 GT62(1)
# ATY65544.1 -
# ATY65556.1 GH76(7)
# ATY65579.1 GT76(3)
# ATY65604.1 -
# ATY65626.1 GT2(2)
# ATY65637.1 GH18(45)+CBM18(6)
# ATY65665.1 -
# ATY65674.1 -
# ATY65680.1 GH25(83)
# ATY65728.1 -
# ATY65765.1 PL7(23)
# ATY65808.1 GH72(1)
# ATY65886.1 -
# ATY65888.1 GT90(3)
# ATY65896.1 AA1(22)
# ATY66055.1 GH3(13)+CBM1(30)
# ATY66192.1 GT2(9)
# ATY66193.1 GH32(26)
# ATY66198.1 -
# ATY66259.1 GT2(122)
# ATY66268.1 GH18(20)+CBM12(6)+CBM16(5)+CBM5(14)
# ATY66363.1 GH125(2)
# ATY66369.1 GH114(6)
# ATY66426.1 GH75(2)
# ATY66444.1 GH18(45)+CBM18(6)
# ATY66476.1 GH5(20)
# ATY66491.1 -
# ATY66509.1 GT62(6)
# ATY66529.1 GH65(13)+CBM32(118)
# ATY66531.1 -
# ATY66542.1 GH125(2)
# ATY66551.1 -
# ATY66592.1 GT8(69)
# ATY66603.1 GT3(1)
# ATY66615.1 GT90(8)
# ATY66624.1 GT25(49)
# ATY66664.1 GH2(10)+CBM51(5)+CBM67(4)
# ATY66787.1 GH2(46)
# ATY66848.1 GH92(9)
# ATY66850.1 -
# ATY66859.1 GT8(34)
# ATY66875.1 CE9(25)
# ATY66876.1 -
# ATY66975.1 -
# ATY67020.1 -
# ATY67094.1 GH20(33)
# ATY67122.1 -
# ATY67138.1 AA3(20)
# ATY67182.1 -
# ATY67196.1 -
# ATY67226.1 GH18(7)
# ATY67280.1 GH17(22)
# ATY67289.1 GH13(94)+CBM48(20)
# ATY67309.1 -
# ATY67327.1 GT32(35)
# ATY67358.1 -
# ATY67425.1 GH36(16)
# ATY67467.1 GT90(3)
# ATY67468.1 -
# ATY67472.1 AA3(16)
# ATY63707.1 GH0(115)
# ATY65793.1 GH0(115)
# ATY62951.1 GH0(115)
# ATY61188.1 GH0(115)
# ATY62721.1 GH0(115)
# ATY65605.1 GH0(115)
# ATY67306.1 GH17(19)
# ATY63087.1 GH17(29)
# ATY64918.1 GH27(18)
# ATY59702.1 GH36(24)
# ATY58696.1 AA0(4)
# ATY65374.1 AA1(22)
# ATY65915.1 AA1(22)
# ATY64049.1 AA1(23)
# ATY66872.1 AA1(39)
# ATY66100.1 GT31(26)
# ATY64941.1 GT31(26)
# ATY59959.1 GT31(29)
# ATY66131.1 GT31(51)
# ATY60866.1 GT31(54)
# ATY67037.1 GT41(17)
# ATY61678.1 CBM10(1)+CBM2(60)
# ATY58989.1 CBM10(1)+CBM2(60)
# ATY60723.1 CBM12(5)+CBM13(12)
# ATY59222.1 CBM14(14)
# ATY66389.1 CBM18(25)
# ATY67114.1 CBM5(49)
# ATY64357.1 CBM5(49)
# ATY59304.1 CBM57(16)
# ATY59125.1 CBM57(16)
# ATY64151.1 CBM57(16)
# ATY60075.1 CBM57(16)
# ATY59281.1 CBM57(16)
# ATY67205.1 -
# ATY67423.1 -
# ATY67158.1 -
# ATY67142.1 -
# ATY66871.1 -
# ATY66532.1 -
# ATY66650.1 -
# ATY67063.1 -
# ATY66815.1 -
# ATY66513.1 -
# ATY66936.1 -
# ATY66588.1 -
# ATY66605.1 -
# ATY65351.1 -
# ATY66370.1 -
# ATY66292.1 -
# ATY65856.1 -
# ATY65614.1 -
# ATY65640.1 -
# ATY65715.1 -
# ATY65800.1 -
# ATY66201.1 -
# ATY59704.1 -
# ATY58302.1 -
# ATY59753.1 -
# ATY59367.1 -
# ATY58953.1 -
# ATY58554.1 -
# ATY59000.1 -
# ATY58522.1 -
# ATY59100.1 -
# ATY58615.1 -
# ATY58749.1 -
# ATY64072.1 -
# ATY65221.1 -
# ATY65222.1 -
# ATY64270.1 -
# ATY63768.1 -
# ATY65096.1 -
# ATY65135.1 -
# ATY64613.1 -
# ATY63956.1 -
# ATY64438.1 -
# ATY63857.1 -
# ATY64414.1 -
# ATY64183.1 -
# ATY64808.1 -
# ATY60156.1 -
# ATY61008.1 -
# ATY61113.1 -
# ATY60691.1 -
# ATY61197.1 -
# ATY60299.1 -
# ATY60767.1 -
# ATY59795.1 -
# ATY60923.1 -
# ATY60283.1 -
# ATY60286.1 -
# ATY61131.1 -
# ATY60572.1 -
# ATY62873.1 -
# ATY61476.1 -
# ATY63559.1 -
# ATY61542.1 -
# ATY62188.1 -
# ATY62193.1 -
# ATY62194.1 -
# ATY63571.1 -
# ATY62227.1 -
# ATY62896.1 -
# ATY63166.1 -
# ATY62297.1 -
# ATY61491.1 -
# ATY62667.1 -
# ATY62782.1 -
# ATY62784.1 -
# ATY63618.1 -
# ATY63554.1 -
# ATY63408.1 -
# ATY63733.1 -
# ATY61789.1 -
# ATY61853.1 -
# ATY63072.1 -
# ATY61716.1 -
# ATY62977.1 -

# %% [markdown]
# Immediately, after the CAZy family is the number of the k-mer group of the CAZy family in the Hotpep, and this number is not needed. The k-mer group number is written in parentheses. This allows an easy separation of the CAZy family/subfamily from the k-mer group number.
#
# Hotpep can predict a protein has multiple CAZyme domains. Each CAZyme domain in a protein is identified by predicting a different CAZy (sub)family). For example, predicting the CAZy (sub)families GH3_1 and CBM2 in a protein indicates the protein has two CAZyme domains, one belonging to the CAZy family GH3, subfamily GH3_1 and the other domain belongs to the CAZy family CBM2. Each CAZyme domain will be stored in a `DIAMONDCazymeDomain` instance, which will then be stored in a parent `DIAMONDprediction` instance, which stores all the data for the parent protein.
#
# Additionally, if Hotpep predicts a protein is not a CAZyme only "-" is given.
#
# As with parsing HMMER, the each protein is stored as a HOTPEPprediction instance, stored in a dictionary keyed by the protein accession and valued by a dictionary, containing the key `Hotpep` and valued by a HOTPEPprediction instance.

# %%
# Check how text is separated in overview.txt
with open ("overview.txt", "r") as ofh:
    overview_file = ofh.read().splitlines()

# create an empty dictionary store all dbCAN, HMMER, Hotpep and DIAMOND prediction data
# {protein_accession: {prediciton_tool: CazymeProteinPrediction}}
overview_dict = {}

for line in tqdm(overview_file[1:], desc="Parsing overview.txt"):  # skip the first line becuase this is the 'column' titles
    line = line.split("\t")
    
    # retrieve and separate the Hotpep CAZyme domains
    hotpep_predictions = line[2].split("+")

    protein_accession = line[0]
    
    # check if the protein was classified as a non-CAZyme
    if hotpep_predictions[0] == "-":
        cazyme_classification = 0
        
        try:
            overview_dict[protein_accession]
            
            try:
                overview_dict[protein_accession]["Hotpep"]
                
                print(f"WARNING -- HOTPEP PREDICTION ALREADY PROVIDED FOR {protein_accession}")
            
            except KeyError:  # raised if Hotpep prediction not yet catalogued for the protein
                overview_dict[protein_accession]["Hotpep"] = CazymeProteinPrediction(
                    "Hotpep",
                    protein_accesion,
                    cazyme_classification,
                )
        
        except KeyError:  # raised if protein is not yet catalogued
            overview_dict[protein_accession] = {
                "Hotpep": CazymeProteinPrediction(
                    "Hotpep",
                    protein_accession,
                    cazyme_classification,
                )
            }
        
        continue  # go to next protein
    
    # create CazymeProteinPrediction instance to represent the prediction for the current working protein
    cazyme_classification = 1
    parent_cazyme = CazymeProteinPrediction("Hotpep", protein_accession, cazyme_classification)
    
    cazyme_domains = []

    # parse each of the predicted CAZyme domains
    for predicted_domain in hotpep_predictions:

        # remove k-mer group number
        predicted_domain = predicted_domain.split("(")[0]

        # check if CAZy subfamily is predicted
        if predicted_domain.find("_") != -1:  # found CAZy subfamily
            cazy_family = predicted_domain[:predicted_domain.find("_")]
            cazy_subfamily = predicted_domain
        
        else:  # found CAZy family
            cazy_family = predicted_domain
            cazy_subfamily = np.nan
        
        # create DIAMONDCazymeDomain
        domain = CazymeDomain(
            prediction_tool="Hotpep",
            protein_accession="protein_accession",
            cazy_family="cazy_family",
            cazy_subfamily="cazy_subfamily",
        )

        cazyme_domains.append(domain)
    
    # add domains to the protein
    parent_cazyme.cazyme_domains = cazyme_domains
    
    # add the protein to the dictionary of all parsed proteins
    try:
        overview_dict[protein_accession]
        
        try:
            overview_dict[protein_accession]["HOTPEP"]

            print(f"WARNING -- HOTPEP PREDICTION ALREADY PROVIDED FOR {protein_accession}")
        
        except KeyError:  # raised it not HMMER prediction catagloued yet
            overview_dict[protein_accession]["HOTPEP"] = parent_cazyme
    
    except KeyError:  # raised if not protein yet catalogued
        overview_dict[protein_accession] = {"HOTPEP": parent_cazyme}
        
    print("resulting protein=", parent_cazyme)

print("number of parsed proteins=", len(list(overview_dict.values())))
# Out:
# HBox(children=(HTML(value='Parsing overview.txt'), FloatProgress(value=0.0, max=445.0), HTML(value='')))
# resulting protein= -CazymeProteinPrediction, protein=ATY58330.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY58396.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY58475.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY58478.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY58486.1, CAZyme domains=3-
# resulting protein= -CazymeProteinPrediction, protein=ATY58494.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY58512.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY58531.1, CAZyme domains=2-
# resulting protein= -CazymeProteinPrediction, protein=ATY58571.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY58579.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY58674.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY58705.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY58803.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY58848.1, CAZyme domains=4-
# resulting protein= -CazymeProteinPrediction, protein=ATY58880.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY58895.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY58902.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY58949.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY59023.1, CAZyme domains=2-
# resulting protein= -CazymeProteinPrediction, protein=ATY59031.1, CAZyme domains=2-
# resulting protein= -CazymeProteinPrediction, protein=ATY59065.1, CAZyme domains=2-
# resulting protein= -CazymeProteinPrediction, protein=ATY59093.1, CAZyme domains=3-
# resulting protein= -CazymeProteinPrediction, protein=ATY59185.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY59188.1, CAZyme domains=2-
# resulting protein= -CazymeProteinPrediction, protein=ATY59194.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY59250.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY59363.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY59638.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY59688.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY59691.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY59698.1, CAZyme domains=3-
# resulting protein= -CazymeProteinPrediction, protein=ATY59714.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY59890.1, CAZyme domains=2-
# resulting protein= -CazymeProteinPrediction, protein=ATY59985.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY60044.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY60094.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY60133.1, CAZyme domains=2-
# resulting protein= -CazymeProteinPrediction, protein=ATY60146.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY60162.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY60186.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY60246.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY60261.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY60312.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY60330.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY60381.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY60408.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY60416.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY60491.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY60504.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY60591.1, CAZyme domains=3-
# resulting protein= -CazymeProteinPrediction, protein=ATY60613.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY60620.1, CAZyme domains=2-
# resulting protein= -CazymeProteinPrediction, protein=ATY60629.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY60662.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY60681.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY60726.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY60733.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY60772.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY60851.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY60878.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY60976.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY60986.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY61069.1, CAZyme domains=2-
# resulting protein= -CazymeProteinPrediction, protein=ATY61117.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY61140.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY61147.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY61215.1, CAZyme domains=3-
# resulting protein= -CazymeProteinPrediction, protein=ATY61276.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY61301.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY61355.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY61576.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY61694.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY61713.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY61718.1, CAZyme domains=2-
# resulting protein= -CazymeProteinPrediction, protein=ATY61741.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY61753.1, CAZyme domains=2-
# resulting protein= -CazymeProteinPrediction, protein=ATY61824.1, CAZyme domains=2-
# resulting protein= -CazymeProteinPrediction, protein=ATY61835.1, CAZyme domains=4-
# resulting protein= -CazymeProteinPrediction, protein=ATY61836.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY61850.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY61851.1, CAZyme domains=2-
# resulting protein= -CazymeProteinPrediction, protein=ATY61863.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY61865.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY61893.1, CAZyme domains=2-
# resulting protein= -CazymeProteinPrediction, protein=ATY61914.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY61957.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY61965.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY61989.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY62020.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY62039.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY62092.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY62109.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY62125.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY62132.1, CAZyme domains=2-
# resulting protein= -CazymeProteinPrediction, protein=ATY62143.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY62147.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY62175.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY62233.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY62235.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY62242.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY62277.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY62385.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY62412.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY62465.1, CAZyme domains=2-
# resulting protein= -CazymeProteinPrediction, protein=ATY62551.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY62564.1, CAZyme domains=2-
# resulting protein= -CazymeProteinPrediction, protein=ATY62578.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY62614.1, CAZyme domains=2-
# resulting protein= -CazymeProteinPrediction, protein=ATY62684.1, CAZyme domains=4-
# resulting protein= -CazymeProteinPrediction, protein=ATY62685.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY62702.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY62739.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY62740.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY62742.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY62757.1, CAZyme domains=2-
# resulting protein= -CazymeProteinPrediction, protein=ATY62798.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY62856.1, CAZyme domains=2-
# resulting protein= -CazymeProteinPrediction, protein=ATY62933.1, CAZyme domains=2-
# resulting protein= -CazymeProteinPrediction, protein=ATY62981.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY63066.1, CAZyme domains=3-
# resulting protein= -CazymeProteinPrediction, protein=ATY63210.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY63227.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY63228.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY63255.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY63305.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY63319.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY63344.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY63360.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY63412.1, CAZyme domains=3-
# resulting protein= -CazymeProteinPrediction, protein=ATY63454.1, CAZyme domains=2-
# resulting protein= -CazymeProteinPrediction, protein=ATY63528.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY63573.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY63588.1, CAZyme domains=2-
# resulting protein= -CazymeProteinPrediction, protein=ATY63601.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY63636.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY63688.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY63982.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY63987.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY64005.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY64012.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY64015.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY64043.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY64047.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY64088.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY64150.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY64179.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY64186.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY64233.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY64248.1, CAZyme domains=2-
# resulting protein= -CazymeProteinPrediction, protein=ATY64416.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY64461.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY64478.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY64479.1, CAZyme domains=2-
# resulting protein= -CazymeProteinPrediction, protein=ATY64503.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY64517.1, CAZyme domains=3-
# resulting protein= -CazymeProteinPrediction, protein=ATY64570.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY64671.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY64693.1, CAZyme domains=3-
# resulting protein= -CazymeProteinPrediction, protein=ATY64695.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY64700.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY64752.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY64802.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY64843.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY64850.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY64919.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY64924.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY64953.1, CAZyme domains=2-
# resulting protein= -CazymeProteinPrediction, protein=ATY64976.1, CAZyme domains=2-
# resulting protein= -CazymeProteinPrediction, protein=ATY64996.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY65020.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY65055.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY65081.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY65106.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY65116.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY65191.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY65223.1, CAZyme domains=2-
# resulting protein= -CazymeProteinPrediction, protein=ATY65449.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY65455.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY65484.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY65556.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY65579.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY65626.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY65637.1, CAZyme domains=2-
# resulting protein= -CazymeProteinPrediction, protein=ATY65680.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY65765.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY65808.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY65888.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY65896.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY66055.1, CAZyme domains=2-
# resulting protein= -CazymeProteinPrediction, protein=ATY66192.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY66193.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY66259.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY66268.1, CAZyme domains=4-
# resulting protein= -CazymeProteinPrediction, protein=ATY66363.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY66369.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY66426.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY66444.1, CAZyme domains=2-
# resulting protein= -CazymeProteinPrediction, protein=ATY66476.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY66509.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY66529.1, CAZyme domains=2-
# resulting protein= -CazymeProteinPrediction, protein=ATY66542.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY66592.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY66603.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY66615.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY66624.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY66664.1, CAZyme domains=3-
# resulting protein= -CazymeProteinPrediction, protein=ATY66787.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY66848.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY66859.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY66875.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY67094.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY67138.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY67226.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY67280.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY67289.1, CAZyme domains=2-
# resulting protein= -CazymeProteinPrediction, protein=ATY67327.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY67425.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY67467.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY67472.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY63707.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY65793.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY62951.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY61188.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY62721.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY65605.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY67306.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY63087.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY64918.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY59702.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY58696.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY65374.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY65915.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY64049.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY66872.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY66100.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY64941.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY59959.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY66131.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY60866.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY67037.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY61678.1, CAZyme domains=2-
# resulting protein= -CazymeProteinPrediction, protein=ATY58989.1, CAZyme domains=2-
# resulting protein= -CazymeProteinPrediction, protein=ATY60723.1, CAZyme domains=2-
# resulting protein= -CazymeProteinPrediction, protein=ATY59222.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY66389.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY67114.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY64357.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY59304.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY59125.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY64151.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY60075.1, CAZyme domains=1-
# resulting protein= -CazymeProteinPrediction, protein=ATY59281.1, CAZyme domains=1-
#
# number of parsed proteins= 445

# %% [markdown]
# By comparing the progress bar and the `number of parsed proteins` we can see that the method above parses all proteins catalogued in the overview.txt.
#
# Additionally, by looking at the CazymeProteinPrediction instances we can see that the multilpe domains of the proteins are captured. For example, Hotpep predicted the protein ATY58848.1 contained `GH18(42)+CBM12(19)+CBM16(5)+CBM5(17)`, and this produced the output from above: `-CazymeProteinPrediction, protein=ATY58848.1, CAZyme domains=4-`
#
# However, the predicted EC numbers are stored in the 'Hotpep.out' file. It is not guarenteed that the proteins will be listed in same order as they listed in the 'overview.txt' file. Therefore, instead of adding all the parsed proteins from the 'overview.txt' file to the `overview_dict` dictionary, but instead to another dictionary keyed by the protein accession and valued by the corresponding HOTPEPprediction instance.
#
# Then the 'Hotpep.out' file will be parsed to retrieve the predicted EC numbers in each row.

# %% [markdown]
# <a id="hotpep_out"></a>

# %% [markdown]
# ### Parsing the Hotpep.out file
#
# The Hotpep.out file is parsed to retrieve the predicted EC numbers for each protein. Each row contains a unqiue protein. Once the EC numbers are retrieved for a protein the corresponding protein can be found in the `hotpep_proteins` dict, which is keyed by protein accession and valued by the corresponding `HOTPEPprediction` instance. Once the corresponding `HOTPEPprediction` instance is found, the corresponding EC numbers can be added.
#
# Going to be a previous section in the notebook, the 'Gene ID' column the 'Hotpep.out' file contains the protein accession and the column to the furthest right contains the predicted EC numbers.

# %%
with open ("Hotpep.out", "r") as ofh:
    hotpep_file = ofh.read().splitlines()
    
for line in hotpep_file[:20]:
    line = line.split("\t")
    
    protein_accession = line[2]
    ec_numbers = line[-1]
    print(protein_accession, "**", ec_numbers)
# Out:
# Gene ID ** EC number
# ATY65081.1 ** 3.1.1.6:22
# ATY62702.1 ** NA
# ATY63454.1 ** NA
# ATY64953.1 ** NA
# ATY65055.1 ** 3.1.1.74:26
# ATY66875.1 ** 3.5.1.25:14
# ATY64043.1 ** NA
# ATY60133.1 ** NA
# ATY62132.1 ** NA
# ATY63707.1 ** NA
# ATY65793.1 ** NA
# ATY62951.1 ** NA
# ATY61188.1 ** NA
# ATY62721.1 ** NA
# ATY65605.1 ** NA
# ATY58880.1 ** 3.2.1.21:2152, 3.2.1.-:269, 3.2.1.38:49, 3.2.1.23:60, 3.2.1.125:16, 3.2.1.25:39, 3.2.1.182:12, 3.2.1.74:34, 3.2.1.118:33
# ATY66369.1 ** NA
# ATY66363.1 ** NA
# ATY66542.1 ** NA

# %% [markdown]
# Looking at the data above, and referencing back to the early section of the notebook which examined the 'Hotpep.out' file, every listed EC number is immediately followed by a colon and the group number of the EC number in Hotpep, which is not a number we need.
#
# Additionally, if multiple EC numbers are predicted they are separated by commas, making it very easy to separate them by using the `split` method.
#
# However, we need to check if the 'Hotpep.out' file contains a unique protein per line. To do this, lets check how many lines there for the protein with the accession 'ATY58486.1' because in the 'overview.txt' file shows that Hotpep predicted the protein contains 3 CAZyme domains.

# %%
protein_of_interest = "ATY58486.1"
with open ("Hotpep.out", "r") as ofh:
    hotpep_file = ofh.read().splitlines()
    
for line in hotpep_file:
    line = line.split("\t")
    
    protein_accession = line[2]
    ec_numbers = line[-1]
    cazy_fam = line[0]
    if protein_accession == protein_of_interest:
        print(protein_accession, cazy_fam, "**", ec_numbers)
# Out:
# ATY58486.1 GH18 ** 3.2.1.14:15
# ATY58486.1 CBM1 ** NA
# ATY58486.1 CBM19 ** 3.2.1.14:125

# %% [markdown]
# We can see that each CAZyme domain predicted to be present in a protein is presented on a separate line, indicated by the same protein accession and different CAZy family. Therefore, we can use this (by identifying the unqiue CAZy family - CAZy subfamily pairing of a CAZyme domain) to store the predicted EC numbers within their respective `CazymeDomain` instance, for the parent CAZyme.
#
# We need to retrieve the CAZyme domains from the corresponding `CazymeProteinPrediction` instance, and check which of the `CazymeDomain` instances match the current working CAZyme domain from the 'Hotpep.out' file.
#
# Last we also need to check what happens to proteins Hotpep has predicted are not CAZymes, such as "ATY58323.1".

# %%
protein_of_interest = "ATY58323.1"
with open ("Hotpep.out", "r") as ofh:
    hotpep_file = ofh.read().splitlines()
    
for line in hotpep_file:
    line = line.split("\t")
    
    protein_accession = line[2]
    ec_numbers = line[-1]
    cazy_fam = line[0]
    if protein_accession == protein_of_interest:
        print(protein_accession, cazy_fam, "**", ec_numbers)

# %% [markdown]
# We can see that proteins Hotpep has predicted to be non-CAZymes are not included in the 'Hotpep.out' file.
#
# Just before combining all the data and parsing of the Hotpep data, lets design a method to get the EC numbers from the 'Hotpep.out' file. The EC numbers want to be retrieved as a list of strings where each string contains a sinlge EC number becuase this will make it easier to select specific EC numbers if required later.
#
# Furthermore, if no EC numbers are stored the string "NA" is written instead, which will be converted to a true null value. Also, we can adding in quality checking using regular expressions to ensure what is believed to be an EC number is an EC number.

# %%
with open ("Hotpep.out", "r") as ofh:
    hotpep_file = ofh.read().splitlines()
    
for line in hotpep_file:
    line = line.split("\t")
    
    protein_accession = line[2]
    
    # retrieve the EC numbers as a list
    ec_numbers = line[-1]
    ec_numbers = ec_numbers.split(",")
    # strip any remaining white space becuase the separating comma
    # is sometimes followed by a space
    index = 0
    for index in range(len(ec_numbers)):
        ec_numbers[index] = ec_numbers[index].strip()
        ec_numbers[index] = ec_numbers[index].split(":")[0]
        if ec_numbers[index] == "NA":
            ec_numbers[index] = np.nan
    
    print(protein_accession, cazy_fam, ec_numbers)
# Out:
# Gene ID CBM67 ['EC number']
# ATY65081.1 CBM67 ['3.1.1.6']
# ATY62702.1 CBM67 [nan]
# ATY63454.1 CBM67 [nan]
# ATY64953.1 CBM67 [nan]
# ATY65055.1 CBM67 ['3.1.1.74']
# ATY66875.1 CBM67 ['3.5.1.25']
# ATY64043.1 CBM67 [nan]
# ATY60133.1 CBM67 [nan]
# ATY62132.1 CBM67 [nan]
# ATY63707.1 CBM67 [nan]
# ATY65793.1 CBM67 [nan]
# ATY62951.1 CBM67 [nan]
# ATY61188.1 CBM67 [nan]
# ATY62721.1 CBM67 [nan]
# ATY65605.1 CBM67 [nan]
# ATY58880.1 CBM67 ['3.2.1.21', '3.2.1.-', '3.2.1.38', '3.2.1.23', '3.2.1.125', '3.2.1.25', '3.2.1.182', '3.2.1.74', '3.2.1.118']
# ATY66369.1 CBM67 [nan]
# ATY66363.1 CBM67 [nan]
# ATY66542.1 CBM67 [nan]
# ATY65191.1 CBM67 [nan]
# ATY62175.1 CBM67 ['3.2.1.20', '2.4.1.-', '3.2.1.28', '3.2.1.10', '3.2.1.-', '3.2.1.133']
# ATY59031.1 CBM67 ['3.2.1.1', '3.2.1.13.2.1']
# ATY61965.1 CBM67 ['3.2.1.1']
# ATY67289.1 CBM67 ['2.4.1.18']
# ATY62092.1 CBM67 ['3.2.1.-']
# ATY61276.1 CBM67 ['2.4.1.25', '3.2.1.33']
# ATY60620.1 CBM67 [nan]
# ATY62564.1 CBM67 ['3.2.1.3']
# ATY61850.1 CBM67 [nan]
# ATY60381.1 CBM67 [nan]
# ATY62739.1 CBM67 [nan]
# ATY58478.1 CBM67 ['2.4.1.-', '2.4.1.-3.2.1']
# ATY60681.1 CBM67 [nan]
# ATY61824.1 CBM67 ['2.4.1.-3.2.1']
# ATY61301.1 CBM67 ['3.2.1.6']
# ATY62684.1 CBM67 ['3.2.1.39']
# ATY61835.1 CBM67 ['3.2.1.39']
# ATY58949.1 CBM67 [nan]
# ATY60986.1 CBM67 ['3.2.1.73', '2.4.1.-', '3.2.1.-', '3.2.1.6', '3.2.1.39']
# ATY65116.1 CBM67 [nan]
# ATY67306.1 CBM67 [nan]
# ATY67280.1 CBM67 ['3.2.1.-']
# ATY63087.1 CBM67 ['3.2.1.58']
# ATY64843.1 CBM67 [nan]
# ATY67226.1 CBM67 ['3.2.1.14']
# ATY63066.1 CBM67 ['3.2.1.14', '3.2.1.17', '3.2.1.-']
# ATY66268.1 CBM67 ['3.2.1.14']
# ATY58848.1 CBM67 ['3.2.1.14']
# ATY61713.1 CBM67 ['3.2.1.14', '3.2.1.17']
# ATY65637.1 CBM67 ['3.2.1.14']
# ATY66444.1 CBM67 ['3.2.1.14']
# ATY64693.1 CBM67 ['3.2.1.14']
# ATY61069.1 CBM67 ['3.2.1.14']
# ATY59023.1 CBM67 ['3.2.1.14']
# ATY59093.1 CBM67 [nan]
# ATY63573.1 CBM67 [nan]
# ATY61215.1 CBM67 ['3.2.1.14']
# ATY58486.1 CBM67 ['3.2.1.14']
# ATY61718.1 CBM67 ['3.2.1.14']
# ATY61851.1 CBM67 ['3.2.1.14']
# ATY65223.1 CBM67 ['3.2.1.14']
# ATY59188.1 CBM67 ['3.2.1.14']
# ATY66664.1 CBM67 ['3.2.1.23']
# ATY60591.1 CBM67 ['3.2.1.23']
# ATY61914.1 CBM67 [nan]
# ATY66787.1 CBM67 ['3.2.1.25']
# ATY64517.1 CBM67 [nan]
# ATY64671.1 CBM67 ['3.2.1.165']
# ATY62385.1 CBM67 ['3.2.1.52']
# ATY67094.1 CBM67 ['3.2.1.52']
# ATY60851.1 CBM67 [nan]
# ATY65680.1 CBM67 [nan]
# ATY64918.1 CBM67 ['3.2.1.22', '3.2.1.49']
# ATY58705.1 CBM67 [nan]
# ATY62277.1 CBM67 ['3.2.1.52', '3.2.1.-']
# ATY62465.1 CBM67 ['3.2.1.21', '3.2.1.58', '3.2.1.-', '3.2.1.37']
# ATY63588.1 CBM67 ['3.2.1.21', '3.2.1.58', '3.2.1.-', '3.2.1.37']
# ATY66055.1 CBM67 ['3.2.1.21', '3.2.1.58', '3.2.1.-', '3.2.1.37']
# ATY61140.1 CBM67 ['3.2.1.21', '3.2.1.58', '3.2.1.-', '3.2.1.37']
# ATY62757.1 CBM67 [nan]
# ATY64479.1 CBM67 ['3.2.1.21']
# ATY63305.1 CBM67 [nan]
# ATY60491.1 CBM67 [nan]
# ATY61576.1 CBM67 ['3.2.1.20', '3.2.1.177', '3.2.1.84', '3.2.1.10', '3.2.1.48']
# ATY64047.1 CBM67 [nan]
# ATY66193.1 CBM67 ['2.4.1.-', '3.2.1.80', '3.2.1.26']
# ATY64919.1 CBM67 ['3.2.1.23', '3.2.1.-', '3.2.1.38']
# ATY63319.1 CBM67 ['3.2.1.23', '2.4.1.-3.2.1']
# ATY67425.1 CBM67 [nan]
# ATY59702.1 CBM67 [nan]
# ATY63688.1 CBM67 ['3.2.1.28']
# ATY58579.1 CBM67 ['3.2.1.24']
# ATY59890.1 CBM67 ['3.2.1.146']
# ATY64924.1 CBM67 ['3.2.1.113']
# ATY65106.1 CBM67 ['3.2.1.113']
# ATY60662.1 CBM67 ['3.2.1.113']
# ATY62020.1 CBM67 ['3.2.1.113']
# ATY59985.1 CBM67 ['3.2.1.113']
# ATY62742.1 CBM67 ['3.2.1.113']
# ATY66476.1 CBM67 ['3.2.1.58']
# ATY64700.1 CBM67 [nan]
# ATY58494.1 CBM67 [nan]
# ATY62125.1 CBM67 ['3.2.1.4']
# ATY62039.1 CBM67 [nan]
# ATY62578.1 CBM67 ['3.2.1.75']
# ATY59698.1 CBM67 ['3.2.1.37', '3.2.1.55']
# ATY60133.1 CBM67 ['3.2.1.58']
# ATY64150.1 CBM67 ['3.2.1.58']
# ATY64695.1 CBM67 ['3.2.1.58']
# ATY64012.1 CBM67 ['3.2.1.58']
# ATY58512.1 CBM67 ['3.2.1.39']
# ATY63228.1 CBM67 ['3.2.1.-', '3.2.1.106']
# ATY58531.1 CBM67 ['3.2.1.39']
# ATY62933.1 CBM67 ['3.2.1.39']
# ATY66529.1 CBM67 ['3.2.1.28']
# ATY65808.1 CBM67 ['2.4.1.-']
# ATY61893.1 CBM67 ['2.4.1.-']
# ATY64248.1 CBM67 ['2.4.1.-']
# ATY59194.1 CBM67 ['2.4.1.-']
# ATY64179.1 CBM67 [nan]
# ATY58674.1 CBM67 ['3.2.1.132']
# ATY66426.1 CBM67 ['3.2.1.132']
# ATY60408.1 CBM67 [nan]
# ATY65455.1 CBM67 [nan]
# ATY58571.1 CBM67 [nan]
# ATY65449.1 CBM67 [nan]
# ATY65556.1 CBM67 [nan]
# ATY60733.1 CBM67 [nan]
# ATY60629.1 CBM67 [nan]
# ATY64503.1 CBM67 [nan]
# ATY62132.1 CBM67 [nan]
# ATY63601.1 CBM67 ['3.2.1.31', '3.2.1.-3.2.1']
# ATY59065.1 CBM67 ['3.2.1.39']
# ATY60726.1 CBM67 ['3.2.1.52']
# ATY62740.1 CBM67 [nan]
# ATY61147.1 CBM67 [nan]
# ATY64088.1 CBM67 [nan]
# ATY66848.1 CBM67 [nan]
# ATY60330.1 CBM67 [nan]
# ATY63987.1 CBM67 [nan]
# ATY64570.1 CBM67 [nan]
# ATY58696.1 CBM67 [nan]
# ATY59688.1 CBM67 ['1.10.3.2']
# ATY60613.1 CBM67 ['1.10.3.2']
# ATY65020.1 CBM67 [nan]
# ATY60162.1 CBM67 [nan]
# ATY65374.1 CBM67 [nan]
# ATY65915.1 CBM67 [nan]
# ATY65896.1 CBM67 [nan]
# ATY64049.1 CBM67 ['1.10.3.2']
# ATY66872.1 CBM67 [nan]
# ATY60772.1 CBM67 ['1.14.99.53']
# ATY60186.1 CBM67 ['1.14.99.53']
# ATY58330.1 CBM67 [nan]
# ATY63528.1 CBM67 [nan]
# ATY62143.1 CBM67 [nan]
# ATY59363.1 CBM67 [nan]
# ATY58475.1 CBM67 [nan]
# ATY61694.1 CBM67 [nan]
# ATY64015.1 CBM67 [nan]
# ATY64478.1 CBM67 [nan]
# ATY58902.1 CBM67 [nan]
# ATY67472.1 CBM67 [nan]
# ATY58895.1 CBM67 [nan]
# ATY62798.1 CBM67 [nan]
# ATY67138.1 CBM67 [nan]
# ATY62233.1 CBM67 [nan]
# ATY60261.1 CBM67 [nan]
# ATY58396.1 CBM67 ['1.6.5.6']
# ATY64976.1 CBM67 [nan]
# ATY62856.1 CBM67 [nan]
# ATY65765.1 CBM67 [nan]
# ATY62685.1 CBM67 [nan]
# ATY61836.1 CBM67 [nan]
# ATY62412.1 CBM67 [nan]
# ATY59691.1 CBM67 [nan]
# ATY61865.1 CBM67 ['2.4.1.131']
# ATY59250.1 CBM67 ['2.4.1.131']
# ATY62981.1 CBM67 ['2.4.1.131']
# ATY64233.1 CBM67 [nan]
# ATY60094.1 CBM67 [nan]
# ATY63636.1 CBM67 [nan]
# ATY65626.1 CBM67 ['2.4.1.16']
# ATY60416.1 CBM67 ['2.4.1.16']
# ATY66192.1 CBM67 ['2.4.1.16']
# ATY66259.1 CBM67 ['2.4.1.83']
# ATY61741.1 CBM67 ['2.4.1.16']
# ATY60044.1 CBM67 ['2.4.1.16']
# ATY60878.1 CBM67 ['2.4.1.16']
# ATY61753.1 CBM67 ['2.4.1.15']
# ATY64802.1 CBM67 ['3.1.3.12']
# ATY62614.1 CBM67 ['2.4.1.15']
# ATY59638.1 CBM67 ['2.4.1.80']
# ATY60246.1 CBM67 ['2.4.1.-']
# ATY62109.1 CBM67 ['2.4.1.-']
# ATY62235.1 CBM67 [nan]
# ATY61957.1 CBM67 [nan]
# ATY64752.1 CBM67 ['2.4.1.-']
# ATY66624.1 CBM67 [nan]
# ATY66603.1 CBM67 ['2.4.1.11']
# ATY66100.1 CBM67 [nan]
# ATY64941.1 CBM67 [nan]
# ATY59959.1 CBM67 [nan]
# ATY66131.1 CBM67 [nan]
# ATY60866.1 CBM67 [nan]
# ATY67327.1 CBM67 ['2.4.1.-']
# ATY64461.1 CBM67 ['2.4.1.-']
# ATY64005.1 CBM67 [nan]
# ATY60976.1 CBM67 [nan]
# ATY63982.1 CBM67 ['2.4.1.1']
# ATY61989.1 CBM67 ['2.4.1.109']
# ATY62147.1 CBM67 ['2.4.1.109']
# ATY63360.1 CBM67 ['2.4.1.109']
# ATY60146.1 CBM67 ['2.4.1.131']
# ATY60312.1 CBM67 ['2.4.1.257', '2.4.1.132']
# ATY59714.1 CBM67 ['2.4.1.198']
# ATY67037.1 CBM67 [nan]
# ATY64850.1 CBM67 ['2.4.1.34']
# ATY62242.1 CBM67 ['2.4.1.-']
# ATY63255.1 CBM67 ['2.4.1.267']
# ATY64416.1 CBM67 ['2.4.1.265', '2.4.1.-2.4.1']
# ATY62551.1 CBM67 ['2.4.1.258']
# ATY61863.1 CBM67 ['2.4.1.256']
# ATY65484.1 CBM67 [nan]
# ATY66509.1 CBM67 [nan]
# ATY61117.1 CBM67 [nan]
# ATY58803.1 CBM67 ['2.4.99.18']
# ATY61355.1 CBM67 ['2.4.1.-']
# ATY63210.1 CBM67 [nan]
# ATY63227.1 CBM67 [nan]
# ATY65579.1 CBM67 [nan]
# ATY66859.1 CBM67 ['2.4.1.186']
# ATY66592.1 CBM67 [nan]
# ATY65888.1 CBM67 [nan]
# ATY67467.1 CBM67 [nan]
# ATY63344.1 CBM67 [nan]
# ATY64186.1 CBM67 [nan]
# ATY66615.1 CBM67 [nan]
# ATY59185.1 CBM67 [nan]
# ATY58486.1 CBM67 [nan]
# ATY61215.1 CBM67 ['3.2.1.14']
# ATY63588.1 CBM67 ['3.2.1.21']
# ATY64479.1 CBM67 ['3.2.1.21']
# ATY66055.1 CBM67 ['3.2.1.21']
# ATY62465.1 CBM67 ['3.2.1.21']
# ATY61678.1 CBM67 ['3.2.1.4', '3.2.1.78', '3.2.1.43.2.1', '3.2.1.74', '3.2.1.91', '3.2.1.8']
# ATY58989.1 CBM67 ['3.2.1.4', '3.2.1.78', '3.2.1.43.2.1', '3.2.1.74', '3.2.1.91', '3.2.1.8']
# ATY63412.1 CBM67 ['3.2.1.4', '3.2.1.78', '3.2.1.43.2.1', '3.2.1.74', '3.2.1.91', '3.2.1.8']
# ATY60723.1 CBM67 [nan]
# ATY66268.1 CBM67 ['3.2.1.14', '3.2.1.-']
# ATY63066.1 CBM67 ['3.2.1.14']
# ATY58848.1 CBM67 [nan]
# ATY60723.1 CBM67 ['3.2.1.39', '3.2.1.63.2.1']
# ATY59698.1 CBM67 [nan]
# ATY60620.1 CBM67 [nan]
# ATY59222.1 CBM67 [nan]
# ATY58848.1 CBM67 [nan]
# ATY66268.1 CBM67 [nan]
# ATY61718.1 CBM67 ['3.2.1.14']
# ATY65223.1 CBM67 ['3.2.1.14']
# ATY61851.1 CBM67 ['3.2.1.14']
# ATY59188.1 CBM67 ['3.2.1.14']
# ATY66444.1 CBM67 ['3.2.1.14']
# ATY65637.1 CBM67 ['3.2.1.14']
# ATY64693.1 CBM67 ['3.2.1.14']
# ATY61069.1 CBM67 ['3.2.1.14']
# ATY59023.1 CBM67 ['3.2.1.14']
# ATY63454.1 CBM67 [nan]
# ATY64953.1 CBM67 [nan]
# ATY61824.1 CBM67 ['2.4.1.-3.2.1']
# ATY60504.1 CBM67 ['3.2.1.-']
# ATY59093.1 CBM67 ['3.2.1.-']
# ATY62856.1 CBM67 [nan]
# ATY64976.1 CBM67 [nan]
# ATY66389.1 CBM67 [nan]
# ATY58486.1 CBM67 ['3.2.1.14']
# ATY61215.1 CBM67 ['3.2.1.14']
# ATY63066.1 CBM67 ['3.2.1.14', '3.2.1.-']
# ATY64693.1 CBM67 ['3.2.1.14', '3.2.1.-']
# ATY58989.1 CBM67 ['3.2.1.4']
# ATY63412.1 CBM67 ['3.2.1.4']
# ATY61678.1 CBM67 ['3.2.1.4']
# ATY62564.1 CBM67 ['3.2.1.3']
# ATY59031.1 CBM67 ['3.2.1.1']
# ATY61753.1 CBM67 [nan]
# ATY62614.1 CBM67 [nan]
# ATY64996.1 CBM67 [nan]
# ATY66529.1 CBM67 [nan]
# ATY62684.1 CBM67 ['3.2.1.63.2.1', '3.2.1.6', '3.2.1.73', '3.2.1.39', '3.2.1.-']
# ATY61835.1 CBM67 ['3.2.1.63.2.1', '3.2.1.6', '3.2.1.73', '3.2.1.39', '3.2.1.-']
# ATY59698.1 CBM67 ['3.2.1.37', '3.2.1.55']
# ATY64517.1 CBM67 ['3.2.1.146']
# ATY61893.1 CBM67 [nan]
# ATY64248.1 CBM67 [nan]
# ATY67289.1 CBM67 ['2.4.1.18']
# ATY66268.1 CBM67 ['3.2.1.14', '1.14.99.53']
# ATY59093.1 CBM67 ['3.2.1.14', '1.14.99.53']
# ATY58848.1 CBM67 ['3.2.1.14']
# ATY67114.1 CBM67 [nan]
# ATY64357.1 CBM67 [nan]
# ATY63412.1 CBM67 [nan]
# ATY66664.1 CBM67 [nan]
# ATY60591.1 CBM67 [nan]
# ATY62684.1 CBM67 ['3.2.1.63.2.1', '3.2.1.6', '3.2.1.73', '3.2.1.39']
# ATY61835.1 CBM67 ['3.2.1.63.2.1', '3.2.1.6', '3.2.1.73', '3.2.1.39']
# ATY59304.1 CBM67 [nan]
# ATY59125.1 CBM67 [nan]
# ATY64151.1 CBM67 [nan]
# ATY60075.1 CBM67 [nan]
# ATY59281.1 CBM67 [nan]
# ATY62757.1 CBM67 ['3.2.1.74', '3.2.1.120']
# ATY59065.1 CBM67 ['3.2.1.39']
# ATY61835.1 CBM67 [nan]
# ATY62684.1 CBM67 [nan]
# ATY58531.1 CBM67 [nan]
# ATY62933.1 CBM67 [nan]
# ATY59890.1 CBM67 [nan]
# ATY66664.1 CBM67 [nan]
# ATY60591.1 CBM67 [nan]
# ATY64517.1 CBM67 [nan]

# %% [markdown]
# Therefore, first the 'overview.txt' file must be parsed and then the 'Hotpep.out' file. The following functions are invoked before adding the proteins to the overview_dict.

# %%
def parse_overview():
    # Check how text is separated in overview.txt
    with open ("overview.txt", "r") as ofh:
        overview_file = ofh.read().splitlines()

    # create an empty dictionary store all dbCAN, HMMER, Hotpep and DIAMOND prediction data
    # {protein_accession: {prediciton_tool: CazymeProteinPrediction}}
    overview_dict = {}
    
    hotpep_overview_dict = {}

    for line in tqdm(overview_file[1:], desc="Parsing overview.txt"):  # skip the first line becuase this is the 'column' titles
        line = line.split("\t")

        # retrieve and separate the Hotpep CAZyme domains
        hotpep_predictions = line[2].split("+")

        protein_accession = line[0]

        # check if the protein was classified as a non-CAZyme
        if hotpep_predictions[0] == "-":
            cazyme_classification = 0

            try:
                overview_dict[protein_accession]

                try:
                    overview_dict[protein_accession]["Hotpep"]

                    print(f"WARNING -- HOTPEP PREDICTION ALREADY PROVIDED FOR {protein_accession}")

                except KeyError:  # raised if Hotpep prediction not yet catalogued for the protein
                    overview_dict[protein_accession]["Hotpep"] = CazymeProteinPrediction(
                        "Hotpep",
                        protein_accesion,
                        cazyme_classification,
                    )

            except KeyError:  # raised if protein is not yet catalogued
                overview_dict[protein_accession] = {
                    "Hotpep": CazymeProteinPrediction(
                        "Hotpep",
                        protein_accession,
                        cazyme_classification,
                    )
                }

            continue  # go to next protein

        # create CazymeProteinPrediction instance to represent the prediction for the current working protein
        cazyme_classification = 1
        parent_cazyme = CazymeProteinPrediction("Hotpep", protein_accession, cazyme_classification)

        cazyme_domains = []

        # parse each of the predicted CAZyme domains
        for predicted_domain in hotpep_predictions:

            # remove k-mer group number
            predicted_domain = predicted_domain.split("(")[0]

            # check if CAZy subfamily is predicted
            if predicted_domain.find("_") != -1:  # found CAZy subfamily
                cazy_family = predicted_domain[:predicted_domain.find("_")]
                cazy_subfamily = predicted_domain

            else:  # found CAZy family
                cazy_family = predicted_domain
                cazy_subfamily = np.nan

            # create DIAMONDCazymeDomain
            domain = CazymeDomain(
                prediction_tool="Hotpep",
                protein_accession="protein_accession",
                cazy_family="cazy_family",
                cazy_subfamily="cazy_subfamily",
            )

            cazyme_domains.append(domain)

        # add domains to the protein
        parent_cazyme.cazyme_domains = cazyme_domains

        # add the protein to the dictionary of all parsed proteins
        try:
            hotpep_overview_dict[protein_accession]

            print(f"WARNING -- HOTPEP PREDICTION ALREADY PROVIDED FOR {protein_accession}")

        except KeyError:  # raised if not protein yet catalogued
            hotpep_overview_dict[protein_accession] = parent_cazyme

    return overview_dict, hotpep_overview_dict

overview_dict, hotpep_overview_dict = parse_overview()            
print("non-cazymes=", len(list(overview_dict.values())))
print("predicted cazymes=", len(list(hotpep_overview_dict.values())))
print("total=", (len(list(overview_dict.values())) + len(list(hotpep_overview_dict.values()))))
# Out:
# HBox(children=(HTML(value='Parsing overview.txt'), FloatProgress(value=0.0, max=445.0), HTML(value='')))
# non-cazymes= 193
# predicted cazymes= 252
# total= 445

# %%
def parse_hotpep_file(hotpep_overview_dict):
    with open ("Hotpep.out", "r") as ofh:
        hotpep_file = ofh.read().splitlines()

    for line in hotpep_file[1:]:  # skip the first line, which contains titles
        line = line.split("\t")

        protein_accession = line[2].strip()

        # retrieve the EC numbers as a list
        ec_numbers = line[-1]
        ec_numbers = ec_numbers.split(",")
        # strip any remaining white space becuase the separating comma
        # is sometimes followed by a space
        index = 0
        for index in range(len(ec_numbers)):
            ec_numbers[index] = ec_numbers[index].strip()
            ec_numbers[index] = ec_numbers[index].split(":")[0]
            if ec_numbers[index] == "NA":
                ec_numbers[index] = np.nan
        
        # get CAZy family and subfamily of the current working domain
        cazy_family = line[0]
        if cazy_family.find("_") != -1:
            cazy_subfamily = cazy_family
            cazy_family = cazy_family[:cazy_family.find("_")]
        else:
            cazy_subfamily = np.nan

        domain_identifer = [cazy_family, cazy_subfamily]  # used to find the correct domain

        # get the list of CAZyme domains of the parent protein
        parent_protein = hotpep_overview_dict[protein_accession]
        parent_domains = parent_protein.cazyme_domains
        
        for domain in parent_domains:
            if domain_identifer == [domain.cazy_family, domain.cazy_subfamily]:
                domain.ec_numbers = ec_numbers

parse_hotpep_file(hotpep_overview_dict)
"done"
# Out:
# 'done'

# %% [markdown]
# Now we can combine our method of parsing the 'overview.txt' file, and the 'Hotpep.out' to populate the CazymeDomain instances with EC numbers. Additionally, to make the code more human-readable, we can break up the tasks (retrieving EC numbers, parsing different files, etc.) into separate functions.

# %%
def parse_overview():
    # Check how text is separated in overview.txt
    with open ("overview.txt", "r") as ofh:
        overview_file = ofh.read().splitlines()

    # create an empty dictionary store all dbCAN, HMMER, Hotpep and DIAMOND prediction data
    # {protein_accession: {prediciton_tool: CazymeProteinPrediction}}
    overview_dict = {}
    
    hotpep_overview_dict = {}

    for line in tqdm(overview_file[1:], desc="Parsing overview.txt"):  # skip the first line becuase this is the 'column' titles
        line = line.split("\t")

        # retrieve and separate the Hotpep CAZyme domains
        hotpep_predictions = line[2].split("+")

        protein_accession = line[0]

        # check if the protein was classified as a non-CAZyme
        if hotpep_predictions[0] == "-":
            cazyme_classification = 0

            try:
                overview_dict[protein_accession]

                try:
                    overview_dict[protein_accession]["Hotpep"]

                    print(f"WARNING -- HOTPEP PREDICTION ALREADY PROVIDED FOR {protein_accession}")

                except KeyError:  # raised if Hotpep prediction not yet catalogued for the protein
                    overview_dict[protein_accession]["Hotpep"] = CazymeProteinPrediction(
                        "Hotpep",
                        protein_accesion,
                        cazyme_classification,
                    )

            except KeyError:  # raised if protein is not yet catalogued
                overview_dict[protein_accession] = {
                    "Hotpep": CazymeProteinPrediction(
                        "Hotpep",
                        protein_accession,
                        cazyme_classification,
                    )
                }

            continue  # go to next protein

        # create CazymeProteinPrediction instance to represent the prediction for the current working protein
        cazyme_classification = 1
        parent_cazyme = CazymeProteinPrediction("Hotpep", protein_accession, cazyme_classification)
        
        cazyme_domains = get_cazyme_domains(hotpep_predictions, protein_accession)  # list of CazymeDomain instances

        # add domains to the protein
        parent_cazyme.cazyme_domains = cazyme_domains

        # add the protein to the dictionary of all parsed proteins
        try:
            hotpep_overview_dict[protein_accession]

            print(f"WARNING -- HOTPEP PREDICTION ALREADY PROVIDED FOR {protein_accession}")

        except KeyError:  # raised if not protein yet catalogued
            hotpep_overview_dict[protein_accession] = parent_cazyme
        
    # populate predicted CAZyme domains with their EC number predictions
    hotpep_overview_dict = get_ec_numbers(hotpep_overview_dict)
    
    print("non-cazymes=", len(list(overview_dict.values())))
    print("predicted cazymes=", len(list(hotpep_overview_dict.values())))

    # add CAZymes to the overview_dict
    for protein_accession in hotpep_overview_dict:
        try:
            overview_dict[protein_accession]

            try:
                overview_dict[protein_accession]["Hotpep"]

                print(f"WARNING -- HOTPEP PREDICTION ALREADY PROVIDED FOR {protein_accession}")

            except KeyError:  # raised if Hotpep prediction not yet catalogued for the protein
                overview_dict[protein_accession]["Hotpep"] = hotpep_overview_dict[protein_accession]

        except KeyError:  # raised if protein is not yet catalogued
            overview_dict[protein_accession] = {"Hotpep": hotpep_overview_dict[protein_accession]}
    
    return list(overview_dict.values())

def get_cazyme_domains(hotpep_predictions, protein_accession):
    """Retrieve CAZyme domains predicted by Hotpep"""
    cazyme_domains = []
    # parse each of the predicted CAZyme domains
    for predicted_domain in hotpep_predictions:

        # remove k-mer group number
        predicted_domain = predicted_domain.split("(")[0]

        # check if CAZy subfamily is predicted
        if predicted_domain.find("_") != -1:  # found CAZy subfamily
            cazy_family = predicted_domain[:predicted_domain.find("_")]
            cazy_subfamily = predicted_domain

        else:  # found CAZy family
            cazy_family = predicted_domain
            cazy_subfamily = np.nan

        # create DIAMONDCazymeDomain
        domain = CazymeDomain(
            prediction_tool="Hotpep",
            protein_accession="protein_accession",
            cazy_family="cazy_family",
            cazy_subfamily="cazy_subfamily",
        )

        cazyme_domains.append(domain)
    
    return cazyme_domains


def get_ec_numbers(hotpep_overview_dict):
    """Retrieve EC numbers for each CAZyme domain from the Hotpep.out file"""
    with open ("Hotpep.out", "r") as ofh:
        hotpep_file = ofh.read().splitlines()

    for line in hotpep_file[1:]:  # skip the first line, which contains titles
        line = line.split("\t")

        protein_accession = line[2].strip()

        # retrieve the EC numbers as a list
        ec_numbers = line[-1]
        ec_numbers = ec_numbers.split(",")
        # strip any remaining white space becuase the separating comma
        # is sometimes followed by a space
        index = 0
        for index in range(len(ec_numbers)):
            ec_numbers[index] = ec_numbers[index].strip()
            ec_numbers[index] = ec_numbers[index].split(":")[0]
            if ec_numbers[index] == "NA":
                ec_numbers[index] = np.nan
        
        # get CAZy family and subfamily of the current working domain
        cazy_family = line[0]
        if cazy_family.find("_") != -1:
            cazy_subfamily = cazy_family
            cazy_family = cazy_family[:cazy_family.find("_")]
        else:
            cazy_subfamily = np.nan

        domain_identifer = [cazy_family, cazy_subfamily]  # used to find the correct domain

        # get the list of CAZyme domains of the parent protein
        parent_protein = hotpep_overview_dict[protein_accession]
        parent_domains = parent_protein.cazyme_domains
        
        for domain in parent_domains:
            if domain_identifer == [domain.cazy_family, domain.cazy_subfamily]:
                domain.ec_numbers = ec_numbers

    return hotpep_overview_dict

all_proteins = parse_overview()
print("done.", len(all_proteins))

for p in all_proteins:
    print(p["Hotpep"])
# Out:
# HBox(children=(HTML(value='Parsing overview.txt'), FloatProgress(value=0.0, max=445.0), HTML(value='')))
# non-cazymes= 193
# predicted cazymes= 252
# done. 445
# -CazymeProteinPrediction, protein=ATY58323.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY58395.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY58528.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY58532.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY58636.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY58637.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY58653.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY58687.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY58910.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY58915.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY58965.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY59202.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY59524.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY59596.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY59663.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY59671.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY59673.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY59728.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY59756.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY59775.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY59781.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY59860.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY59904.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY59918.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY59933.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY59950.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY60072.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY60187.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY60251.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY60367.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY60372.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY60550.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY60555.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY60734.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY60853.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY60943.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY61013.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY61023.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY61046.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY61152.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY61280.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY61441.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY61486.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY61595.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY61630.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY61788.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY61822.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY61890.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY61926.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY62050.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY62087.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY62231.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY62278.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY62287.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY62309.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY62338.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY62433.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY62592.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY62660.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY62663.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY62900.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY63039.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY63199.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY63301.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY63375.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY63468.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY63517.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY63703.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY63705.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY63786.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY63856.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY63886.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY63993.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY63999.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY64050.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY64132.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY64187.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY64188.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY64353.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY64437.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY64579.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY64630.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY64774.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY64989.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY65010.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY65185.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY65188.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY65205.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY65544.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY65604.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY65665.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY65674.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY65728.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY65886.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY66198.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY66491.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY66531.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY66551.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY66850.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY66876.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY66975.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67020.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67122.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67182.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67196.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67309.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67358.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67468.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67205.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67423.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67158.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67142.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY66871.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY66532.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY66650.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY67063.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY66815.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY66513.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY66936.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY66588.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY66605.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY65351.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY66370.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY66292.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY65856.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY65614.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY65640.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY65715.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY65800.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY66201.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY59704.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY58302.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY59753.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY59367.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY58953.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY58554.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY59000.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY58522.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY59100.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY58615.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY58749.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY64072.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY65221.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY65222.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY64270.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY63768.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY65096.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY65135.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY64613.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY63956.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY64438.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY63857.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY64414.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY64183.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY64808.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY60156.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY61008.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY61113.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY60691.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY61197.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY60299.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY60767.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY59795.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY60923.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY60283.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY60286.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY61131.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY60572.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY62873.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY61476.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY63559.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY61542.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY62188.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY62193.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY62194.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY63571.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY62227.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY62896.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY63166.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY62297.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY61491.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY62667.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY62782.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY62784.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY63618.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY63554.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY63408.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY63733.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY61789.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY61853.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY63072.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY61716.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# -CazymeProteinPrediction, protein=ATY58330.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY58396.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY58475.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY58478.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY58486.1, CAZyme domains=3-
# -CazymeProteinPrediction, protein=ATY58494.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY58512.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY58531.1, CAZyme domains=2-
# -CazymeProteinPrediction, protein=ATY58571.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY58579.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY58674.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY58705.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY58803.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY58848.1, CAZyme domains=4-
# -CazymeProteinPrediction, protein=ATY58880.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY58895.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY58902.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY58949.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY59023.1, CAZyme domains=2-
# -CazymeProteinPrediction, protein=ATY59031.1, CAZyme domains=2-
# -CazymeProteinPrediction, protein=ATY59065.1, CAZyme domains=2-
# -CazymeProteinPrediction, protein=ATY59093.1, CAZyme domains=3-
# -CazymeProteinPrediction, protein=ATY59185.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY59188.1, CAZyme domains=2-
# -CazymeProteinPrediction, protein=ATY59194.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY59250.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY59363.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY59638.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY59688.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY59691.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY59698.1, CAZyme domains=3-
# -CazymeProteinPrediction, protein=ATY59714.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY59890.1, CAZyme domains=2-
# -CazymeProteinPrediction, protein=ATY59985.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60044.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60094.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60133.1, CAZyme domains=2-
# -CazymeProteinPrediction, protein=ATY60146.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60162.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60186.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60246.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60261.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60312.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60330.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60381.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60408.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60416.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60491.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60504.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60591.1, CAZyme domains=3-
# -CazymeProteinPrediction, protein=ATY60613.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60620.1, CAZyme domains=2-
# -CazymeProteinPrediction, protein=ATY60629.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60662.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60681.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60726.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60733.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60772.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60851.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60878.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60976.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60986.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61069.1, CAZyme domains=2-
# -CazymeProteinPrediction, protein=ATY61117.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61140.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61147.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61215.1, CAZyme domains=3-
# -CazymeProteinPrediction, protein=ATY61276.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61301.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61355.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61576.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61694.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61713.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61718.1, CAZyme domains=2-
# -CazymeProteinPrediction, protein=ATY61741.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61753.1, CAZyme domains=2-
# -CazymeProteinPrediction, protein=ATY61824.1, CAZyme domains=2-
# -CazymeProteinPrediction, protein=ATY61835.1, CAZyme domains=4-
# -CazymeProteinPrediction, protein=ATY61836.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61850.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61851.1, CAZyme domains=2-
# -CazymeProteinPrediction, protein=ATY61863.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61865.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61893.1, CAZyme domains=2-
# -CazymeProteinPrediction, protein=ATY61914.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61957.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61965.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61989.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62020.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62039.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62092.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62109.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62125.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62132.1, CAZyme domains=2-
# -CazymeProteinPrediction, protein=ATY62143.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62147.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62175.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62233.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62235.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62242.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62277.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62385.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62412.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62465.1, CAZyme domains=2-
# -CazymeProteinPrediction, protein=ATY62551.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62564.1, CAZyme domains=2-
# -CazymeProteinPrediction, protein=ATY62578.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62614.1, CAZyme domains=2-
# -CazymeProteinPrediction, protein=ATY62684.1, CAZyme domains=4-
# -CazymeProteinPrediction, protein=ATY62685.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62702.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62739.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62740.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62742.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62757.1, CAZyme domains=2-
# -CazymeProteinPrediction, protein=ATY62798.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62856.1, CAZyme domains=2-
# -CazymeProteinPrediction, protein=ATY62933.1, CAZyme domains=2-
# -CazymeProteinPrediction, protein=ATY62981.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63066.1, CAZyme domains=3-
# -CazymeProteinPrediction, protein=ATY63210.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63227.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63228.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63255.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63305.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63319.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63344.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63360.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63412.1, CAZyme domains=3-
# -CazymeProteinPrediction, protein=ATY63454.1, CAZyme domains=2-
# -CazymeProteinPrediction, protein=ATY63528.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63573.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63588.1, CAZyme domains=2-
# -CazymeProteinPrediction, protein=ATY63601.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63636.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63688.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63982.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63987.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64005.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64012.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64015.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64043.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64047.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64088.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64150.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64179.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64186.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64233.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64248.1, CAZyme domains=2-
# -CazymeProteinPrediction, protein=ATY64416.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64461.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64478.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64479.1, CAZyme domains=2-
# -CazymeProteinPrediction, protein=ATY64503.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64517.1, CAZyme domains=3-
# -CazymeProteinPrediction, protein=ATY64570.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64671.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64693.1, CAZyme domains=3-
# -CazymeProteinPrediction, protein=ATY64695.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64700.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64752.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64802.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64843.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64850.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64919.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64924.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64953.1, CAZyme domains=2-
# -CazymeProteinPrediction, protein=ATY64976.1, CAZyme domains=2-
# -CazymeProteinPrediction, protein=ATY64996.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65020.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65055.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65081.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65106.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65116.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65191.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65223.1, CAZyme domains=2-
# -CazymeProteinPrediction, protein=ATY65449.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65455.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65484.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65556.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65579.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65626.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65637.1, CAZyme domains=2-
# -CazymeProteinPrediction, protein=ATY65680.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65765.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65808.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65888.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65896.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66055.1, CAZyme domains=2-
# -CazymeProteinPrediction, protein=ATY66192.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66193.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66259.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66268.1, CAZyme domains=4-
# -CazymeProteinPrediction, protein=ATY66363.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66369.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66426.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66444.1, CAZyme domains=2-
# -CazymeProteinPrediction, protein=ATY66476.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66509.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66529.1, CAZyme domains=2-
# -CazymeProteinPrediction, protein=ATY66542.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66592.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66603.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66615.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66624.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66664.1, CAZyme domains=3-
# -CazymeProteinPrediction, protein=ATY66787.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66848.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66859.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66875.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY67094.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY67138.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY67226.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY67280.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY67289.1, CAZyme domains=2-
# -CazymeProteinPrediction, protein=ATY67327.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY67425.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY67467.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY67472.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63707.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65793.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62951.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61188.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY62721.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65605.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY67306.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY63087.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64918.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY59702.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY58696.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65374.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY65915.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64049.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66872.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66100.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64941.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY59959.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66131.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60866.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY67037.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY61678.1, CAZyme domains=2-
# -CazymeProteinPrediction, protein=ATY58989.1, CAZyme domains=2-
# -CazymeProteinPrediction, protein=ATY60723.1, CAZyme domains=2-
# -CazymeProteinPrediction, protein=ATY59222.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY66389.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY67114.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64357.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY59304.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY59125.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY64151.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY60075.1, CAZyme domains=1-
# -CazymeProteinPrediction, protein=ATY59281.1, CAZyme domains=1-

# %% [markdown]
# We can see from printing out the analysis that all proteins were parsed from the overview.txt and Hotpep.out files. Additionally, from printing out the proteins in the returned list of items, we can see we still maintain storing the CAZyme domains within their respective parent CAZyme (`CazymeProteinPrediciton` instance)

# %% [markdown]
# <a id="diamond"></a>

# %% [markdown]
# ## DIAMOND
#
# The data from **DIAMOND** includes:
# - The protein accession
# - CAZy family of each domain
# - CAZy subfamily of each domain (if not in a subfamily, the subfamily is listed as a null value)

# %% [markdown]
# <a id="over_diamond"></a>

# %% [markdown]
# ### Parsing DIAMOND data from overview.txt
#
# The last tool to whose output is listed in the overview.txt file is DIAMOND. The data we want to retrieve from DIAMOND is the classification of proteins as CAZymes and non-CAZymes, and the predict CAZy families and subfamilies of each of the CAZyme domains in each protein.
#
# Each CAZyme domain in a protein is identified by predicting a different CAZy (sub)family). For example, predicting the CAZy (sub)families GH3_1 and CBM2 in a protein indicates the protein has two CAZyme domains, one belonging to the CAZy family GH3, subfamily GH3_1 and the other domain belongs to the CAZy family CBM2.
#
# First lets look at the structure of the data in the DIAMOND column of the overview.txt file.

# %%
# Check how text is separated in overview.txt
with open ("overview.txt", "r") as ofh:
    overview_file = ofh.read().splitlines()

for line in overview_file[1:]:  # skip the first line becuase this is the 'column' titles
    line = line.split("\t")
    diamond = line[3]
    print(line[0], diamond)
# Out:
# ATY58323.1 CE5
# ATY58330.1 AA11
# ATY58395.1 -
# ATY58396.1 -
# ATY58475.1 AA3
# ATY58478.1 GH16
# ATY58486.1 CBM1+GH18
# ATY58494.1 GH5_24
# ATY58512.1 GH55
# ATY58528.1 GH16
# ATY58531.1 GH64
# ATY58532.1 CE5
# ATY58571.1 GH76
# ATY58579.1 GH38
# ATY58636.1 GT2
# ATY58637.1 GH12
# ATY58653.1 -
# ATY58674.1 GH75
# ATY58687.1 -
# ATY58705.1 GH29
# ATY58803.1 GT66
# ATY58848.1 GH18
# ATY58880.1 GH1
# ATY58895.1 AA3_1
# ATY58902.1 AA3_3
# ATY58910.1 -
# ATY58915.1 -
# ATY58949.1 GH16
# ATY58965.1 CE5
# ATY59023.1 CBM18+GH18
# ATY59031.1 GH13_5
# ATY59065.1 GH81
# ATY59093.1 GH18
# ATY59185.1 GT90
# ATY59188.1 CBM18+CBM50+CBM66+GH18
# ATY59194.1 GH72
# ATY59202.1 GT90
# ATY59250.1 GT15
# ATY59363.1 AA12
# ATY59524.1 -
# ATY59596.1 -
# ATY59638.1 GT21
# ATY59663.1 -
# ATY59671.1 CE4
# ATY59673.1 -
# ATY59688.1 AA1_2
# ATY59691.1 GT1
# ATY59698.1 CBM42+GH54
# ATY59714.1 GT4
# ATY59728.1 -
# ATY59756.1 -
# ATY59775.1 -
# ATY59781.1 GT1
# ATY59860.1 AA3_1
# ATY59890.1 CBM66+GH43_34
# ATY59904.1 AA3_2
# ATY59918.1 -
# ATY59933.1 GT2
# ATY59950.1 GH128
# ATY59985.1 GH47
# ATY60044.1 GT2
# ATY60072.1 GH16
# ATY60094.1 GT17
# ATY60133.1 GH55
# ATY60146.1 GT4
# ATY60162.1 AA1_3
# ATY60186.1 AA11
# ATY60187.1 -
# ATY60246.1 GT22
# ATY60251.1 GH16
# ATY60261.1 AA5_1
# ATY60312.1 GT4
# ATY60330.1 GH92
# ATY60367.1 CBM50
# ATY60372.1 GH16
# ATY60381.1 GH152
# ATY60408.1 GH76
# ATY60416.1 GT2
# ATY60491.1 GH31
# ATY60504.1 GH18
# ATY60550.1 GH55
# ATY60555.1 PL35
# ATY60591.1 GH2
# ATY60613.1 AA1
# ATY60620.1 CBM13+GH142
# ATY60629.1 GH76
# ATY60662.1 GH47
# ATY60681.1 GH16
# ATY60726.1 GH84
# ATY60733.1 GH76
# ATY60734.1 -
# ATY60772.1 AA11
# ATY60851.1 GH20
# ATY60853.1 GH135
# ATY60878.1 GT2
# ATY60943.1 -
# ATY60976.1 GT34
# ATY60986.1 GH16
# ATY61013.1 -
# ATY61023.1 -
# ATY61046.1 -
# ATY61069.1 CBM18+GH18
# ATY61117.1 GT64
# ATY61140.1 GH3
# ATY61147.1 GH89
# ATY61152.1 CE1
# ATY61215.1 CBM1+GH18
# ATY61276.1 GH13_25+GH133
# ATY61280.1 AA7
# ATY61301.1 GH16
# ATY61355.1 GT69
# ATY61441.1 PL20
# ATY61486.1 -
# ATY61576.1 GH31
# ATY61595.1 GT2
# ATY61630.1 GH79
# ATY61694.1 AA3_2
# ATY61713.1 GH18
# ATY61718.1 CBM18+GH18
# ATY61741.1 GT2
# ATY61753.1 GT20
# ATY61788.1 GH16
# ATY61822.1 -
# ATY61824.1 CBM18+GH16
# ATY61835.1 GH16
# ATY61836.1 GT0
# ATY61850.1 GH15
# ATY61851.1 CBM50+GH18
# ATY61863.1 GT59
# ATY61865.1 GT15
# ATY61890.1 GH18
# ATY61893.1 CBM43+GH72
# ATY61914.1 GH2
# ATY61926.1 GH16
# ATY61957.1 GT22
# ATY61965.1 GH13_40
# ATY61989.1 GT39
# ATY62020.1 GH47
# ATY62039.1 GH5_11
# ATY62050.1 -
# ATY62087.1 GT32
# ATY62092.1 GH132
# ATY62109.1 GT22
# ATY62125.1 GH5_5
# ATY62132.1 GH0
# ATY62143.1 AA12
# ATY62147.1 GT39
# ATY62175.1 GH13_40
# ATY62231.1 -
# ATY62233.1 AA3_2
# ATY62235.1 GT22
# ATY62242.1 GT50
# ATY62277.1 GH3
# ATY62278.1 GT25
# ATY62287.1 -
# ATY62309.1 -
# ATY62338.1 GH136
# ATY62385.1 GH20
# ATY62412.1 GT1
# ATY62433.1 -
# ATY62465.1 GH3
# ATY62551.1 GT58
# ATY62564.1 CBM20+GH15
# ATY62578.1 GH5_15
# ATY62592.1 -
# ATY62614.1 GT20
# ATY62660.1 -
# ATY62663.1 GT2
# ATY62684.1 GH16
# ATY62685.1 GT0
# ATY62702.1 CE3
# ATY62739.1 GH154
# ATY62740.1 GH88
# ATY62742.1 GH47
# ATY62757.1 GH3
# ATY62798.1 AA3_2
# ATY62856.1 AA9+CBM18
# ATY62900.1 -
# ATY62933.1 GH64
# ATY62981.1 GT15
# ATY63039.1 GH16
# ATY63066.1 GH18
# ATY63199.1 -
# ATY63210.1 GT69
# ATY63227.1 GT71
# ATY63228.1 GH63
# ATY63255.1 GT57
# ATY63301.1 -
# ATY63305.1 GH3
# ATY63319.1 GH35
# ATY63344.1 GT90
# ATY63360.1 GT39
# ATY63375.1 -
# ATY63412.1 GH16
# ATY63454.1 CBM18+CE4
# ATY63468.1 GH18
# ATY63517.1 -
# ATY63528.1 AA11
# ATY63573.1 GH18
# ATY63588.1 GH3
# ATY63601.1 GH79
# ATY63636.1 GT17
# ATY63688.1 GH37
# ATY63703.1 GT1
# ATY63705.1 GT1
# ATY63786.1 -
# ATY63856.1 GH55
# ATY63886.1 -
# ATY63982.1 GT35
# ATY63987.1 GH92
# ATY63993.1 GT1
# ATY63999.1 GH128
# ATY64005.1 GT34
# ATY64012.1 GH55
# ATY64015.1 AA3_2
# ATY64043.1 GH0
# ATY64047.1 GH31
# ATY64050.1 -
# ATY64088.1 GH89
# ATY64132.1 -
# ATY64150.1 GH55
# ATY64179.1 GH72
# ATY64186.1 GT90
# ATY64187.1 GH16
# ATY64188.1 GT69
# ATY64233.1 GT17
# ATY64248.1 CBM43+GH72
# ATY64353.1 PL8_4
# ATY64416.1 GT57
# ATY64437.1 GT4
# ATY64461.1 GT33
# ATY64478.1 AA3_2
# ATY64479.1 GH3
# ATY64503.1 GH76
# ATY64517.1 GH2
# ATY64570.1 GH92
# ATY64579.1 -
# ATY64630.1 -
# ATY64671.1 GH2
# ATY64693.1 CBM18+GH18
# ATY64695.1 CBM50+GH55
# ATY64700.1 GH5_12
# ATY64752.1 GT24
# ATY64774.1 GH18
# ATY64802.1 GT20
# ATY64843.1 GH17
# ATY64850.1 GT48
# ATY64919.1 GH35
# ATY64924.1 GH47
# ATY64953.1 CBM18+CE4
# ATY64976.1 AA7
# ATY64989.1 -
# ATY64996.1 CBM21
# ATY65010.1 GT2
# ATY65020.1 AA1_3
# ATY65055.1 CE5
# ATY65081.1 CE16
# ATY65106.1 GH47
# ATY65116.1 GH17
# ATY65185.1 GH16
# ATY65188.1 -
# ATY65191.1 GH128
# ATY65205.1 GH79
# ATY65223.1 CBM18+CBM50+GH18
# ATY65449.1 GH76
# ATY65455.1 GH76
# ATY65484.1 GT62
# ATY65544.1 GH28
# ATY65556.1 GH76
# ATY65579.1 GT76
# ATY65604.1 GH128
# ATY65626.1 GT2
# ATY65637.1 CBM18+GH18
# ATY65665.1 CE5
# ATY65674.1 -
# ATY65680.1 -
# ATY65728.1 -
# ATY65765.1 PL7_4
# ATY65808.1 GH72
# ATY65886.1 -
# ATY65888.1 GT90
# ATY65896.1 AA1
# ATY66055.1 GH3
# ATY66192.1 GT2
# ATY66193.1 GH32
# ATY66198.1 -
# ATY66259.1 GT2
# ATY66268.1 GH18
# ATY66363.1 GH125
# ATY66369.1 GH114
# ATY66426.1 GH75
# ATY66444.1 CBM18+GH18
# ATY66476.1 GH5_9
# ATY66491.1 GH16
# ATY66509.1 GT62
# ATY66529.1 CBM32+GH65
# ATY66531.1 -
# ATY66542.1 GH125
# ATY66551.1 -
# ATY66592.1 GT8
# ATY66603.1 GT3
# ATY66615.1 GT90
# ATY66624.1 GT25
# ATY66664.1 GH2
# ATY66787.1 GH2
# ATY66848.1 GH92
# ATY66850.1 -
# ATY66859.1 GT8
# ATY66875.1 CE9
# ATY66876.1 GH3
# ATY66975.1 -
# ATY67020.1 GH5_27
# ATY67094.1 GH20
# ATY67122.1 -
# ATY67138.1 AA3_2
# ATY67182.1 GH114
# ATY67196.1 GH18
# ATY67226.1 GH18
# ATY67280.1 GH17
# ATY67289.1 CBM48+GH13_8
# ATY67309.1 GT20
# ATY67327.1 GT32
# ATY67358.1 -
# ATY67425.1 GH36
# ATY67467.1 GT90
# ATY67468.1 GH29
# ATY67472.1 AA3_2
# ATY63707.1 GH0
# ATY65793.1 GH0
# ATY62951.1 GH0
# ATY61188.1 GH0
# ATY62721.1 GH0
# ATY65605.1 GH0
# ATY67306.1 GH17
# ATY63087.1 GH17
# ATY64918.1 CBM13+GH27
# ATY59702.1 GH36
# ATY58696.1 -
# ATY65374.1 AA1
# ATY65915.1 AA1
# ATY64049.1 AA1
# ATY66872.1 AA1
# ATY66100.1 GT31
# ATY64941.1 GT31
# ATY59959.1 GT31
# ATY66131.1 GT31
# ATY60866.1 GT31
# ATY67037.1 GT41
# ATY61678.1 GH18
# ATY58989.1 -
# ATY60723.1 -
# ATY59222.1 -
# ATY66389.1 -
# ATY67114.1 -
# ATY64357.1 -
# ATY59304.1 -
# ATY59125.1 -
# ATY64151.1 -
# ATY60075.1 -
# ATY59281.1 -
# ATY67205.1 CBM20+GH15
# ATY67423.1 GH6
# ATY67158.1 CBM50
# ATY67142.1 GH93
# ATY66871.1 GT2
# ATY66532.1 AA1
# ATY66650.1 GH18
# ATY67063.1 GH47
# ATY66815.1 GH37
# ATY66513.1 GH0
# ATY66936.1 GT2
# ATY66588.1 CBM50
# ATY66605.1 GH36
# ATY65351.1 GH0
# ATY66370.1 CBM48
# ATY66292.1 CE8
# ATY65856.1 GH72
# ATY65614.1 GH76
# ATY65640.1 CBM50
# ATY65715.1 GT95
# ATY65800.1 CBM13
# ATY66201.1 GH132
# ATY59704.1 CBM50
# ATY58302.1 GH43_29
# ATY59753.1 CE1
# ATY59367.1 GH19
# ATY58953.1 GH18
# ATY58554.1 GH6
# ATY59000.1 CE4
# ATY58522.1 GH78+GH79
# ATY59100.1 GH18
# ATY58615.1 GT4
# ATY58749.1 CBM50
# ATY64072.1 GH20
# ATY65221.1 GT7
# ATY65222.1 CBM50
# ATY64270.1 GT31
# ATY63768.1 GH1+GH95
# ATY65096.1 GH71
# ATY65135.1 CBM48+GH13_8
# ATY64613.1 GT32
# ATY63956.1 GT15
# ATY64438.1 CBM48+GH13_8
# ATY63857.1 GH2
# ATY64414.1 GT57
# ATY64183.1 CBM48+GH13_8
# ATY64808.1 CBM50
# ATY60156.1 GH16
# ATY61008.1 GT2
# ATY61113.1 GT31
# ATY60691.1 AA1
# ATY61197.1 GH23
# ATY60299.1 GH71
# ATY60767.1 CBM50
# ATY59795.1 CBM18+CBM50+GH18
# ATY60923.1 GT22
# ATY60283.1 GT2
# ATY60286.1 GH78+GH79
# ATY61131.1 GT0
# ATY60572.1 GT1
# ATY62873.1 GH0
# ATY61476.1 GT22
# ATY63559.1 CE8
# ATY61542.1 GH18
# ATY62188.1 GH20
# ATY62193.1 CBM50
# ATY62194.1 CBM43
# ATY63571.1 GH43_21
# ATY62227.1 CBM66+GH43_34
# ATY62896.1 CBM13+GT27
# ATY63166.1 CBM50
# ATY62297.1 GT30
# ATY61491.1 GT0
# ATY62667.1 GT7
# ATY62782.1 CBM48+GH13_8
# ATY62784.1 GT0
# ATY63618.1 GT0
# ATY63554.1 GH18
# ATY63408.1 GH18
# ATY63733.1 CBM50
# ATY61789.1 CBM48+GH13_8
# ATY61853.1 CBM50
# ATY63072.1 GT1
# ATY61716.1 CBM50
# ATY62977.1 GT1

# %% [markdown]
# Like HMMER and Hotpep, if DIAMOND predicts a protein is not a CAZyme, only a dash is provided.
#
# If multiple CAZyme domains are predicted, each domain is separated by '+'.
#
# However, if a CAZy subfamily is predicted only the CAZy subfamily is predicted, and not the CAZy family. The evaluation by `pyrewton` of the performance of CAZyme prediction needs the CAZy family and not the subfamily. Therefore, a check is included to see if a CAZy subfamily is provided. If it is the parent CAZy family and subfamily wil be retrieved.
#
# Each CAZyme domain is represented by a unique DIAMONDCazymeDomain instance, including the CAZy family and subfamily (a null value if not given), which will then be stored as members in the parent DIAMONDprediction instance that represents a single protein.

# %%
# Check how text is separated in overview.txt
with open ("overview.txt", "r") as ofh:
    overview_file = ofh.read().splitlines()

# create an empty dictionary store all dbCAN, HMMER, Hotpep and DIAMOND prediction data
# {protein_accession: {prediciton_tool: CazymeProteinPrediction}}
overview_dict = {}

for line in tqdm(overview_file[1:], desc="Parsing overview.txt"):  # skip the first line becuase this is the 'column' titles
    line = line.split("\t")
    
    # retrieve and separate the DIAMOND CAZyme domains
    diamond_predictions = line[3].split("+")

    protein_accession = line[0]
    
    # check if the protein was classified as a non-CAZyme
    if diamond_predictions[0] == "-":
        cazyme_classification = 0
        
        try:
            overview_dict[protein_accession]
            
            try:
                overview_dict[protein_accession]["DIAMOND"]
                
                print(f"WARNING -- DIAMOND PREDICTION ALREADY PROVIDED FOR {protein_accession}")
            
            except KeyError:  # raised if DIAMOND prediction not yet catalogued for the protein
                overview_dict[protein_accession]["DIAMOND"] = CazymeProteinPrediction(
                    "DIAMOND",
                    protein_accession,
                    cazyme_classification,
                )
        
        except KeyError:  # raised if protein is not yet catalogued
            overview_dict[protein_accession] = {
                "DIAMOND": CazymeProteinPrediction(
                    "DIAMOND",
                    protein_accession,
                    cazyme_classification,
                )
            }
        
        continue  # go to next protein
    
    # create DIAMONDprediction instance to represent the prediction for the current working protein
    cazyme_classification = 1
    parent_cazyme = CazymeProteinPrediction("DIAMOND", protein_accession, cazyme_classification)
    
    cazyme_domains = []

    # parse each of the predicted CAZyme domains
    for predicted_domain in diamond_predictions:
        print("predicted domain=", predicted_domain)
        
        # check if CAZy subfamily is predicted
        if predicted_domain.find("_") != -1:  # found CAZy subfamily
            cazy_family = predicted_domain[:predicted_domain.find("_")]
            cazy_subfamily = predicted_domain
        
        else:  # found CAZy family
            cazy_family = predicted_domain
            cazy_subfamily = np.nan
        
        domain = CazymeDomain(protein_accession, cazy_family, cazy_subfamily)

        cazyme_domains.append(domain)
    
    # add domains to the protein
    parent_cazyme.cazyme_domains = cazyme_domains
    
    # add the protein to the dictionary of all parsed proteins
    try:
        overview_dict[protein_accession]
        
        try:
            overview_dict[protein_accession]["DIAMOND"]
            
            print(f"WARNING -- DIAMOND PREDICTION ALREADY PROVIDED FOR {protein_accession}")
        
        except KeyError:  # raised it not HMMER prediction catagloued yet
            overview_dict[protein_accession]["DIAMOND"] = parent_cazyme
    
    except KeyError:  # raised if not protein yet catalogued
        overview_dict[protein_accession] = {"DIAMOND": parent_cazyme}
        
    print("resulting protein=", parent_cazyme)

print("number of parsed proteins=", len(list(overview_dict.values())))
# Out:
# HBox(children=(HTML(value='Parsing overview.txt'), FloatProgress(value=0.0, max=445.0), HTML(value='')))
# predicted domain= CE5
# resulting protein= -CazymeProteinPrediction, protein=ATY58323.1, CAZyme domains=1-
# predicted domain= AA11
# resulting protein= -CazymeProteinPrediction, protein=ATY58330.1, CAZyme domains=1-
# predicted domain= AA3
# resulting protein= -CazymeProteinPrediction, protein=ATY58475.1, CAZyme domains=1-
# predicted domain= GH16
# resulting protein= -CazymeProteinPrediction, protein=ATY58478.1, CAZyme domains=1-
# predicted domain= CBM1
# predicted domain= GH18
# resulting protein= -CazymeProteinPrediction, protein=ATY58486.1, CAZyme domains=2-
# predicted domain= GH5_24
# resulting protein= -CazymeProteinPrediction, protein=ATY58494.1, CAZyme domains=1-
# predicted domain= GH55
# resulting protein= -CazymeProteinPrediction, protein=ATY58512.1, CAZyme domains=1-
# predicted domain= GH16
# resulting protein= -CazymeProteinPrediction, protein=ATY58528.1, CAZyme domains=1-
# predicted domain= GH64
# resulting protein= -CazymeProteinPrediction, protein=ATY58531.1, CAZyme domains=1-
# predicted domain= CE5
# resulting protein= -CazymeProteinPrediction, protein=ATY58532.1, CAZyme domains=1-
# predicted domain= GH76
# resulting protein= -CazymeProteinPrediction, protein=ATY58571.1, CAZyme domains=1-
# predicted domain= GH38
# resulting protein= -CazymeProteinPrediction, protein=ATY58579.1, CAZyme domains=1-
# predicted domain= GT2
# resulting protein= -CazymeProteinPrediction, protein=ATY58636.1, CAZyme domains=1-
# predicted domain= GH12
# resulting protein= -CazymeProteinPrediction, protein=ATY58637.1, CAZyme domains=1-
# predicted domain= GH75
# resulting protein= -CazymeProteinPrediction, protein=ATY58674.1, CAZyme domains=1-
# predicted domain= GH29
# resulting protein= -CazymeProteinPrediction, protein=ATY58705.1, CAZyme domains=1-
# predicted domain= GT66
# resulting protein= -CazymeProteinPrediction, protein=ATY58803.1, CAZyme domains=1-
# predicted domain= GH18
# resulting protein= -CazymeProteinPrediction, protein=ATY58848.1, CAZyme domains=1-
# predicted domain= GH1
# resulting protein= -CazymeProteinPrediction, protein=ATY58880.1, CAZyme domains=1-
# predicted domain= AA3_1
# resulting protein= -CazymeProteinPrediction, protein=ATY58895.1, CAZyme domains=1-
# predicted domain= AA3_3
# resulting protein= -CazymeProteinPrediction, protein=ATY58902.1, CAZyme domains=1-
# predicted domain= GH16
# resulting protein= -CazymeProteinPrediction, protein=ATY58949.1, CAZyme domains=1-
# predicted domain= CE5
# resulting protein= -CazymeProteinPrediction, protein=ATY58965.1, CAZyme domains=1-
# predicted domain= CBM18
# predicted domain= GH18
# resulting protein= -CazymeProteinPrediction, protein=ATY59023.1, CAZyme domains=2-
# predicted domain= GH13_5
# resulting protein= -CazymeProteinPrediction, protein=ATY59031.1, CAZyme domains=1-
# predicted domain= GH81
# resulting protein= -CazymeProteinPrediction, protein=ATY59065.1, CAZyme domains=1-
# predicted domain= GH18
# resulting protein= -CazymeProteinPrediction, protein=ATY59093.1, CAZyme domains=1-
# predicted domain= GT90
# resulting protein= -CazymeProteinPrediction, protein=ATY59185.1, CAZyme domains=1-
# predicted domain= CBM18
# predicted domain= CBM50
# predicted domain= CBM66
# predicted domain= GH18
# resulting protein= -CazymeProteinPrediction, protein=ATY59188.1, CAZyme domains=4-
# predicted domain= GH72
# resulting protein= -CazymeProteinPrediction, protein=ATY59194.1, CAZyme domains=1-
# predicted domain= GT90
# resulting protein= -CazymeProteinPrediction, protein=ATY59202.1, CAZyme domains=1-
# predicted domain= GT15
# resulting protein= -CazymeProteinPrediction, protein=ATY59250.1, CAZyme domains=1-
# predicted domain= AA12
# resulting protein= -CazymeProteinPrediction, protein=ATY59363.1, CAZyme domains=1-
# predicted domain= GT21
# resulting protein= -CazymeProteinPrediction, protein=ATY59638.1, CAZyme domains=1-
# predicted domain= CE4
# resulting protein= -CazymeProteinPrediction, protein=ATY59671.1, CAZyme domains=1-
# predicted domain= AA1_2
# resulting protein= -CazymeProteinPrediction, protein=ATY59688.1, CAZyme domains=1-
# predicted domain= GT1
# resulting protein= -CazymeProteinPrediction, protein=ATY59691.1, CAZyme domains=1-
# predicted domain= CBM42
# predicted domain= GH54
# resulting protein= -CazymeProteinPrediction, protein=ATY59698.1, CAZyme domains=2-
# predicted domain= GT4
# resulting protein= -CazymeProteinPrediction, protein=ATY59714.1, CAZyme domains=1-
# predicted domain= GT1
# resulting protein= -CazymeProteinPrediction, protein=ATY59781.1, CAZyme domains=1-
# predicted domain= AA3_1
# resulting protein= -CazymeProteinPrediction, protein=ATY59860.1, CAZyme domains=1-
# predicted domain= CBM66
# predicted domain= GH43_34
# resulting protein= -CazymeProteinPrediction, protein=ATY59890.1, CAZyme domains=2-
# predicted domain= AA3_2
# resulting protein= -CazymeProteinPrediction, protein=ATY59904.1, CAZyme domains=1-
# predicted domain= GT2
# resulting protein= -CazymeProteinPrediction, protein=ATY59933.1, CAZyme domains=1-
# predicted domain= GH128
# resulting protein= -CazymeProteinPrediction, protein=ATY59950.1, CAZyme domains=1-
# predicted domain= GH47
# resulting protein= -CazymeProteinPrediction, protein=ATY59985.1, CAZyme domains=1-
# predicted domain= GT2
# resulting protein= -CazymeProteinPrediction, protein=ATY60044.1, CAZyme domains=1-
# predicted domain= GH16
# resulting protein= -CazymeProteinPrediction, protein=ATY60072.1, CAZyme domains=1-
# predicted domain= GT17
# resulting protein= -CazymeProteinPrediction, protein=ATY60094.1, CAZyme domains=1-
# predicted domain= GH55
# resulting protein= -CazymeProteinPrediction, protein=ATY60133.1, CAZyme domains=1-
# predicted domain= GT4
# resulting protein= -CazymeProteinPrediction, protein=ATY60146.1, CAZyme domains=1-
# predicted domain= AA1_3
# resulting protein= -CazymeProteinPrediction, protein=ATY60162.1, CAZyme domains=1-
# predicted domain= AA11
# resulting protein= -CazymeProteinPrediction, protein=ATY60186.1, CAZyme domains=1-
# predicted domain= GT22
# resulting protein= -CazymeProteinPrediction, protein=ATY60246.1, CAZyme domains=1-
# predicted domain= GH16
# resulting protein= -CazymeProteinPrediction, protein=ATY60251.1, CAZyme domains=1-
# predicted domain= AA5_1
# resulting protein= -CazymeProteinPrediction, protein=ATY60261.1, CAZyme domains=1-
# predicted domain= GT4
# resulting protein= -CazymeProteinPrediction, protein=ATY60312.1, CAZyme domains=1-
# predicted domain= GH92
# resulting protein= -CazymeProteinPrediction, protein=ATY60330.1, CAZyme domains=1-
# predicted domain= CBM50
# resulting protein= -CazymeProteinPrediction, protein=ATY60367.1, CAZyme domains=1-
# predicted domain= GH16
# resulting protein= -CazymeProteinPrediction, protein=ATY60372.1, CAZyme domains=1-
# predicted domain= GH152
# resulting protein= -CazymeProteinPrediction, protein=ATY60381.1, CAZyme domains=1-
# predicted domain= GH76
# resulting protein= -CazymeProteinPrediction, protein=ATY60408.1, CAZyme domains=1-
# predicted domain= GT2
# resulting protein= -CazymeProteinPrediction, protein=ATY60416.1, CAZyme domains=1-
# predicted domain= GH31
# resulting protein= -CazymeProteinPrediction, protein=ATY60491.1, CAZyme domains=1-
# predicted domain= GH18
# resulting protein= -CazymeProteinPrediction, protein=ATY60504.1, CAZyme domains=1-
# predicted domain= GH55
# resulting protein= -CazymeProteinPrediction, protein=ATY60550.1, CAZyme domains=1-
# predicted domain= PL35
# resulting protein= -CazymeProteinPrediction, protein=ATY60555.1, CAZyme domains=1-
# predicted domain= GH2
# resulting protein= -CazymeProteinPrediction, protein=ATY60591.1, CAZyme domains=1-
# predicted domain= AA1
# resulting protein= -CazymeProteinPrediction, protein=ATY60613.1, CAZyme domains=1-
# predicted domain= CBM13
# predicted domain= GH142
# resulting protein= -CazymeProteinPrediction, protein=ATY60620.1, CAZyme domains=2-
# predicted domain= GH76
# resulting protein= -CazymeProteinPrediction, protein=ATY60629.1, CAZyme domains=1-
# predicted domain= GH47
# resulting protein= -CazymeProteinPrediction, protein=ATY60662.1, CAZyme domains=1-
# predicted domain= GH16
# resulting protein= -CazymeProteinPrediction, protein=ATY60681.1, CAZyme domains=1-
# predicted domain= GH84
# resulting protein= -CazymeProteinPrediction, protein=ATY60726.1, CAZyme domains=1-
# predicted domain= GH76
# resulting protein= -CazymeProteinPrediction, protein=ATY60733.1, CAZyme domains=1-
# predicted domain= AA11
# resulting protein= -CazymeProteinPrediction, protein=ATY60772.1, CAZyme domains=1-
# predicted domain= GH20
# resulting protein= -CazymeProteinPrediction, protein=ATY60851.1, CAZyme domains=1-
# predicted domain= GH135
# resulting protein= -CazymeProteinPrediction, protein=ATY60853.1, CAZyme domains=1-
# predicted domain= GT2
# resulting protein= -CazymeProteinPrediction, protein=ATY60878.1, CAZyme domains=1-
# predicted domain= GT34
# resulting protein= -CazymeProteinPrediction, protein=ATY60976.1, CAZyme domains=1-
# predicted domain= GH16
# resulting protein= -CazymeProteinPrediction, protein=ATY60986.1, CAZyme domains=1-
# predicted domain= CBM18
# predicted domain= GH18
# resulting protein= -CazymeProteinPrediction, protein=ATY61069.1, CAZyme domains=2-
# predicted domain= GT64
# resulting protein= -CazymeProteinPrediction, protein=ATY61117.1, CAZyme domains=1-
# predicted domain= GH3
# resulting protein= -CazymeProteinPrediction, protein=ATY61140.1, CAZyme domains=1-
# predicted domain= GH89
# resulting protein= -CazymeProteinPrediction, protein=ATY61147.1, CAZyme domains=1-
# predicted domain= CE1
# resulting protein= -CazymeProteinPrediction, protein=ATY61152.1, CAZyme domains=1-
# predicted domain= CBM1
# predicted domain= GH18
# resulting protein= -CazymeProteinPrediction, protein=ATY61215.1, CAZyme domains=2-
# predicted domain= GH13_25
# predicted domain= GH133
# resulting protein= -CazymeProteinPrediction, protein=ATY61276.1, CAZyme domains=2-
# predicted domain= AA7
# resulting protein= -CazymeProteinPrediction, protein=ATY61280.1, CAZyme domains=1-
# predicted domain= GH16
# resulting protein= -CazymeProteinPrediction, protein=ATY61301.1, CAZyme domains=1-
# predicted domain= GT69
# resulting protein= -CazymeProteinPrediction, protein=ATY61355.1, CAZyme domains=1-
# predicted domain= PL20
# resulting protein= -CazymeProteinPrediction, protein=ATY61441.1, CAZyme domains=1-
# predicted domain= GH31
# resulting protein= -CazymeProteinPrediction, protein=ATY61576.1, CAZyme domains=1-
# predicted domain= GT2
# resulting protein= -CazymeProteinPrediction, protein=ATY61595.1, CAZyme domains=1-
# predicted domain= GH79
# resulting protein= -CazymeProteinPrediction, protein=ATY61630.1, CAZyme domains=1-
# predicted domain= AA3_2
# resulting protein= -CazymeProteinPrediction, protein=ATY61694.1, CAZyme domains=1-
# predicted domain= GH18
# resulting protein= -CazymeProteinPrediction, protein=ATY61713.1, CAZyme domains=1-
# predicted domain= CBM18
# predicted domain= GH18
# resulting protein= -CazymeProteinPrediction, protein=ATY61718.1, CAZyme domains=2-
# predicted domain= GT2
# resulting protein= -CazymeProteinPrediction, protein=ATY61741.1, CAZyme domains=1-
# predicted domain= GT20
# resulting protein= -CazymeProteinPrediction, protein=ATY61753.1, CAZyme domains=1-
# predicted domain= GH16
# resulting protein= -CazymeProteinPrediction, protein=ATY61788.1, CAZyme domains=1-
# predicted domain= CBM18
# predicted domain= GH16
# resulting protein= -CazymeProteinPrediction, protein=ATY61824.1, CAZyme domains=2-
# predicted domain= GH16
# resulting protein= -CazymeProteinPrediction, protein=ATY61835.1, CAZyme domains=1-
# predicted domain= GT0
# resulting protein= -CazymeProteinPrediction, protein=ATY61836.1, CAZyme domains=1-
# predicted domain= GH15
# resulting protein= -CazymeProteinPrediction, protein=ATY61850.1, CAZyme domains=1-
# predicted domain= CBM50
# predicted domain= GH18
# resulting protein= -CazymeProteinPrediction, protein=ATY61851.1, CAZyme domains=2-
# predicted domain= GT59
# resulting protein= -CazymeProteinPrediction, protein=ATY61863.1, CAZyme domains=1-
# predicted domain= GT15
# resulting protein= -CazymeProteinPrediction, protein=ATY61865.1, CAZyme domains=1-
# predicted domain= GH18
# resulting protein= -CazymeProteinPrediction, protein=ATY61890.1, CAZyme domains=1-
# predicted domain= CBM43
# predicted domain= GH72
# resulting protein= -CazymeProteinPrediction, protein=ATY61893.1, CAZyme domains=2-
# predicted domain= GH2
# resulting protein= -CazymeProteinPrediction, protein=ATY61914.1, CAZyme domains=1-
# predicted domain= GH16
# resulting protein= -CazymeProteinPrediction, protein=ATY61926.1, CAZyme domains=1-
# predicted domain= GT22
# resulting protein= -CazymeProteinPrediction, protein=ATY61957.1, CAZyme domains=1-
# predicted domain= GH13_40
# resulting protein= -CazymeProteinPrediction, protein=ATY61965.1, CAZyme domains=1-
# predicted domain= GT39
# resulting protein= -CazymeProteinPrediction, protein=ATY61989.1, CAZyme domains=1-
# predicted domain= GH47
# resulting protein= -CazymeProteinPrediction, protein=ATY62020.1, CAZyme domains=1-
# predicted domain= GH5_11
# resulting protein= -CazymeProteinPrediction, protein=ATY62039.1, CAZyme domains=1-
# predicted domain= GT32
# resulting protein= -CazymeProteinPrediction, protein=ATY62087.1, CAZyme domains=1-
# predicted domain= GH132
# resulting protein= -CazymeProteinPrediction, protein=ATY62092.1, CAZyme domains=1-
# predicted domain= GT22
# resulting protein= -CazymeProteinPrediction, protein=ATY62109.1, CAZyme domains=1-
# predicted domain= GH5_5
# resulting protein= -CazymeProteinPrediction, protein=ATY62125.1, CAZyme domains=1-
# predicted domain= GH0
# resulting protein= -CazymeProteinPrediction, protein=ATY62132.1, CAZyme domains=1-
# predicted domain= AA12
# resulting protein= -CazymeProteinPrediction, protein=ATY62143.1, CAZyme domains=1-
# predicted domain= GT39
# resulting protein= -CazymeProteinPrediction, protein=ATY62147.1, CAZyme domains=1-
# predicted domain= GH13_40
# resulting protein= -CazymeProteinPrediction, protein=ATY62175.1, CAZyme domains=1-
# predicted domain= AA3_2
# resulting protein= -CazymeProteinPrediction, protein=ATY62233.1, CAZyme domains=1-
# predicted domain= GT22
# resulting protein= -CazymeProteinPrediction, protein=ATY62235.1, CAZyme domains=1-
# predicted domain= GT50
# resulting protein= -CazymeProteinPrediction, protein=ATY62242.1, CAZyme domains=1-
# predicted domain= GH3
# resulting protein= -CazymeProteinPrediction, protein=ATY62277.1, CAZyme domains=1-
# predicted domain= GT25
# resulting protein= -CazymeProteinPrediction, protein=ATY62278.1, CAZyme domains=1-
# predicted domain= GH136
# resulting protein= -CazymeProteinPrediction, protein=ATY62338.1, CAZyme domains=1-
# predicted domain= GH20
# resulting protein= -CazymeProteinPrediction, protein=ATY62385.1, CAZyme domains=1-
# predicted domain= GT1
# resulting protein= -CazymeProteinPrediction, protein=ATY62412.1, CAZyme domains=1-
# predicted domain= GH3
# resulting protein= -CazymeProteinPrediction, protein=ATY62465.1, CAZyme domains=1-
# predicted domain= GT58
# resulting protein= -CazymeProteinPrediction, protein=ATY62551.1, CAZyme domains=1-
# predicted domain= CBM20
# predicted domain= GH15
# resulting protein= -CazymeProteinPrediction, protein=ATY62564.1, CAZyme domains=2-
# predicted domain= GH5_15
# resulting protein= -CazymeProteinPrediction, protein=ATY62578.1, CAZyme domains=1-
# predicted domain= GT20
# resulting protein= -CazymeProteinPrediction, protein=ATY62614.1, CAZyme domains=1-
# predicted domain= GT2
# resulting protein= -CazymeProteinPrediction, protein=ATY62663.1, CAZyme domains=1-
# predicted domain= GH16
# resulting protein= -CazymeProteinPrediction, protein=ATY62684.1, CAZyme domains=1-
# predicted domain= GT0
# resulting protein= -CazymeProteinPrediction, protein=ATY62685.1, CAZyme domains=1-
# predicted domain= CE3
# resulting protein= -CazymeProteinPrediction, protein=ATY62702.1, CAZyme domains=1-
# predicted domain= GH154
# resulting protein= -CazymeProteinPrediction, protein=ATY62739.1, CAZyme domains=1-
# predicted domain= GH88
# resulting protein= -CazymeProteinPrediction, protein=ATY62740.1, CAZyme domains=1-
# predicted domain= GH47
# resulting protein= -CazymeProteinPrediction, protein=ATY62742.1, CAZyme domains=1-
# predicted domain= GH3
# resulting protein= -CazymeProteinPrediction, protein=ATY62757.1, CAZyme domains=1-
# predicted domain= AA3_2
# resulting protein= -CazymeProteinPrediction, protein=ATY62798.1, CAZyme domains=1-
# predicted domain= AA9
# predicted domain= CBM18
# resulting protein= -CazymeProteinPrediction, protein=ATY62856.1, CAZyme domains=2-
# predicted domain= GH64
# resulting protein= -CazymeProteinPrediction, protein=ATY62933.1, CAZyme domains=1-
# predicted domain= GT15
# resulting protein= -CazymeProteinPrediction, protein=ATY62981.1, CAZyme domains=1-
# predicted domain= GH16
# resulting protein= -CazymeProteinPrediction, protein=ATY63039.1, CAZyme domains=1-
# predicted domain= GH18
# resulting protein= -CazymeProteinPrediction, protein=ATY63066.1, CAZyme domains=1-
# predicted domain= GT69
# resulting protein= -CazymeProteinPrediction, protein=ATY63210.1, CAZyme domains=1-
# predicted domain= GT71
# resulting protein= -CazymeProteinPrediction, protein=ATY63227.1, CAZyme domains=1-
# predicted domain= GH63
# resulting protein= -CazymeProteinPrediction, protein=ATY63228.1, CAZyme domains=1-
# predicted domain= GT57
# resulting protein= -CazymeProteinPrediction, protein=ATY63255.1, CAZyme domains=1-
# predicted domain= GH3
# resulting protein= -CazymeProteinPrediction, protein=ATY63305.1, CAZyme domains=1-
# predicted domain= GH35
# resulting protein= -CazymeProteinPrediction, protein=ATY63319.1, CAZyme domains=1-
# predicted domain= GT90
# resulting protein= -CazymeProteinPrediction, protein=ATY63344.1, CAZyme domains=1-
# predicted domain= GT39
# resulting protein= -CazymeProteinPrediction, protein=ATY63360.1, CAZyme domains=1-
# predicted domain= GH16
# resulting protein= -CazymeProteinPrediction, protein=ATY63412.1, CAZyme domains=1-
# predicted domain= CBM18
# predicted domain= CE4
# resulting protein= -CazymeProteinPrediction, protein=ATY63454.1, CAZyme domains=2-
# predicted domain= GH18
# resulting protein= -CazymeProteinPrediction, protein=ATY63468.1, CAZyme domains=1-
# predicted domain= AA11
# resulting protein= -CazymeProteinPrediction, protein=ATY63528.1, CAZyme domains=1-
# predicted domain= GH18
# resulting protein= -CazymeProteinPrediction, protein=ATY63573.1, CAZyme domains=1-
# predicted domain= GH3
# resulting protein= -CazymeProteinPrediction, protein=ATY63588.1, CAZyme domains=1-
# predicted domain= GH79
# resulting protein= -CazymeProteinPrediction, protein=ATY63601.1, CAZyme domains=1-
# predicted domain= GT17
# resulting protein= -CazymeProteinPrediction, protein=ATY63636.1, CAZyme domains=1-
# predicted domain= GH37
# resulting protein= -CazymeProteinPrediction, protein=ATY63688.1, CAZyme domains=1-
# predicted domain= GT1
# resulting protein= -CazymeProteinPrediction, protein=ATY63703.1, CAZyme domains=1-
# predicted domain= GT1
# resulting protein= -CazymeProteinPrediction, protein=ATY63705.1, CAZyme domains=1-
# predicted domain= GH55
# resulting protein= -CazymeProteinPrediction, protein=ATY63856.1, CAZyme domains=1-
# predicted domain= GT35
# resulting protein= -CazymeProteinPrediction, protein=ATY63982.1, CAZyme domains=1-
# predicted domain= GH92
# resulting protein= -CazymeProteinPrediction, protein=ATY63987.1, CAZyme domains=1-
# predicted domain= GT1
# resulting protein= -CazymeProteinPrediction, protein=ATY63993.1, CAZyme domains=1-
# predicted domain= GH128
# resulting protein= -CazymeProteinPrediction, protein=ATY63999.1, CAZyme domains=1-
# predicted domain= GT34
# resulting protein= -CazymeProteinPrediction, protein=ATY64005.1, CAZyme domains=1-
# predicted domain= GH55
# resulting protein= -CazymeProteinPrediction, protein=ATY64012.1, CAZyme domains=1-
# predicted domain= AA3_2
# resulting protein= -CazymeProteinPrediction, protein=ATY64015.1, CAZyme domains=1-
# predicted domain= GH0
# resulting protein= -CazymeProteinPrediction, protein=ATY64043.1, CAZyme domains=1-
# predicted domain= GH31
# resulting protein= -CazymeProteinPrediction, protein=ATY64047.1, CAZyme domains=1-
# predicted domain= GH89
# resulting protein= -CazymeProteinPrediction, protein=ATY64088.1, CAZyme domains=1-
# predicted domain= GH55
# resulting protein= -CazymeProteinPrediction, protein=ATY64150.1, CAZyme domains=1-
# predicted domain= GH72
# resulting protein= -CazymeProteinPrediction, protein=ATY64179.1, CAZyme domains=1-
# predicted domain= GT90
# resulting protein= -CazymeProteinPrediction, protein=ATY64186.1, CAZyme domains=1-
# predicted domain= GH16
# resulting protein= -CazymeProteinPrediction, protein=ATY64187.1, CAZyme domains=1-
# predicted domain= GT69
# resulting protein= -CazymeProteinPrediction, protein=ATY64188.1, CAZyme domains=1-
# predicted domain= GT17
# resulting protein= -CazymeProteinPrediction, protein=ATY64233.1, CAZyme domains=1-
# predicted domain= CBM43
# predicted domain= GH72
# resulting protein= -CazymeProteinPrediction, protein=ATY64248.1, CAZyme domains=2-
# predicted domain= PL8_4
# resulting protein= -CazymeProteinPrediction, protein=ATY64353.1, CAZyme domains=1-
# predicted domain= GT57
# resulting protein= -CazymeProteinPrediction, protein=ATY64416.1, CAZyme domains=1-
# predicted domain= GT4
# resulting protein= -CazymeProteinPrediction, protein=ATY64437.1, CAZyme domains=1-
# predicted domain= GT33
# resulting protein= -CazymeProteinPrediction, protein=ATY64461.1, CAZyme domains=1-
# predicted domain= AA3_2
# resulting protein= -CazymeProteinPrediction, protein=ATY64478.1, CAZyme domains=1-
# predicted domain= GH3
# resulting protein= -CazymeProteinPrediction, protein=ATY64479.1, CAZyme domains=1-
# predicted domain= GH76
# resulting protein= -CazymeProteinPrediction, protein=ATY64503.1, CAZyme domains=1-
# predicted domain= GH2
# resulting protein= -CazymeProteinPrediction, protein=ATY64517.1, CAZyme domains=1-
# predicted domain= GH92
# resulting protein= -CazymeProteinPrediction, protein=ATY64570.1, CAZyme domains=1-
# predicted domain= GH2
# resulting protein= -CazymeProteinPrediction, protein=ATY64671.1, CAZyme domains=1-
# predicted domain= CBM18
# predicted domain= GH18
# resulting protein= -CazymeProteinPrediction, protein=ATY64693.1, CAZyme domains=2-
# predicted domain= CBM50
# predicted domain= GH55
# resulting protein= -CazymeProteinPrediction, protein=ATY64695.1, CAZyme domains=2-
# predicted domain= GH5_12
# resulting protein= -CazymeProteinPrediction, protein=ATY64700.1, CAZyme domains=1-
# predicted domain= GT24
# resulting protein= -CazymeProteinPrediction, protein=ATY64752.1, CAZyme domains=1-
# predicted domain= GH18
# resulting protein= -CazymeProteinPrediction, protein=ATY64774.1, CAZyme domains=1-
# predicted domain= GT20
# resulting protein= -CazymeProteinPrediction, protein=ATY64802.1, CAZyme domains=1-
# predicted domain= GH17
# resulting protein= -CazymeProteinPrediction, protein=ATY64843.1, CAZyme domains=1-
# predicted domain= GT48
# resulting protein= -CazymeProteinPrediction, protein=ATY64850.1, CAZyme domains=1-
# predicted domain= GH35
# resulting protein= -CazymeProteinPrediction, protein=ATY64919.1, CAZyme domains=1-
# predicted domain= GH47
# resulting protein= -CazymeProteinPrediction, protein=ATY64924.1, CAZyme domains=1-
# predicted domain= CBM18
# predicted domain= CE4
# resulting protein= -CazymeProteinPrediction, protein=ATY64953.1, CAZyme domains=2-
# predicted domain= AA7
# resulting protein= -CazymeProteinPrediction, protein=ATY64976.1, CAZyme domains=1-
# predicted domain= CBM21
# resulting protein= -CazymeProteinPrediction, protein=ATY64996.1, CAZyme domains=1-
# predicted domain= GT2
# resulting protein= -CazymeProteinPrediction, protein=ATY65010.1, CAZyme domains=1-
# predicted domain= AA1_3
# resulting protein= -CazymeProteinPrediction, protein=ATY65020.1, CAZyme domains=1-
# predicted domain= CE5
# resulting protein= -CazymeProteinPrediction, protein=ATY65055.1, CAZyme domains=1-
# predicted domain= CE16
# resulting protein= -CazymeProteinPrediction, protein=ATY65081.1, CAZyme domains=1-
# predicted domain= GH47
# resulting protein= -CazymeProteinPrediction, protein=ATY65106.1, CAZyme domains=1-
# predicted domain= GH17
# resulting protein= -CazymeProteinPrediction, protein=ATY65116.1, CAZyme domains=1-
# predicted domain= GH16
# resulting protein= -CazymeProteinPrediction, protein=ATY65185.1, CAZyme domains=1-
# predicted domain= GH128
# resulting protein= -CazymeProteinPrediction, protein=ATY65191.1, CAZyme domains=1-
# predicted domain= GH79
# resulting protein= -CazymeProteinPrediction, protein=ATY65205.1, CAZyme domains=1-
# predicted domain= CBM18
# predicted domain= CBM50
# predicted domain= GH18
# resulting protein= -CazymeProteinPrediction, protein=ATY65223.1, CAZyme domains=3-
# predicted domain= GH76
# resulting protein= -CazymeProteinPrediction, protein=ATY65449.1, CAZyme domains=1-
# predicted domain= GH76
# resulting protein= -CazymeProteinPrediction, protein=ATY65455.1, CAZyme domains=1-
# predicted domain= GT62
# resulting protein= -CazymeProteinPrediction, protein=ATY65484.1, CAZyme domains=1-
# predicted domain= GH28
# resulting protein= -CazymeProteinPrediction, protein=ATY65544.1, CAZyme domains=1-
# predicted domain= GH76
# resulting protein= -CazymeProteinPrediction, protein=ATY65556.1, CAZyme domains=1-
# predicted domain= GT76
# resulting protein= -CazymeProteinPrediction, protein=ATY65579.1, CAZyme domains=1-
# predicted domain= GH128
# resulting protein= -CazymeProteinPrediction, protein=ATY65604.1, CAZyme domains=1-
# predicted domain= GT2
# resulting protein= -CazymeProteinPrediction, protein=ATY65626.1, CAZyme domains=1-
# predicted domain= CBM18
# predicted domain= GH18
# resulting protein= -CazymeProteinPrediction, protein=ATY65637.1, CAZyme domains=2-
# predicted domain= CE5
# resulting protein= -CazymeProteinPrediction, protein=ATY65665.1, CAZyme domains=1-
# predicted domain= PL7_4
# resulting protein= -CazymeProteinPrediction, protein=ATY65765.1, CAZyme domains=1-
# predicted domain= GH72
# resulting protein= -CazymeProteinPrediction, protein=ATY65808.1, CAZyme domains=1-
# predicted domain= GT90
# resulting protein= -CazymeProteinPrediction, protein=ATY65888.1, CAZyme domains=1-
# predicted domain= AA1
# resulting protein= -CazymeProteinPrediction, protein=ATY65896.1, CAZyme domains=1-
# predicted domain= GH3
# resulting protein= -CazymeProteinPrediction, protein=ATY66055.1, CAZyme domains=1-
# predicted domain= GT2
# resulting protein= -CazymeProteinPrediction, protein=ATY66192.1, CAZyme domains=1-
# predicted domain= GH32
# resulting protein= -CazymeProteinPrediction, protein=ATY66193.1, CAZyme domains=1-
# predicted domain= GT2
# resulting protein= -CazymeProteinPrediction, protein=ATY66259.1, CAZyme domains=1-
# predicted domain= GH18
# resulting protein= -CazymeProteinPrediction, protein=ATY66268.1, CAZyme domains=1-
# predicted domain= GH125
# resulting protein= -CazymeProteinPrediction, protein=ATY66363.1, CAZyme domains=1-
# predicted domain= GH114
# resulting protein= -CazymeProteinPrediction, protein=ATY66369.1, CAZyme domains=1-
# predicted domain= GH75
# resulting protein= -CazymeProteinPrediction, protein=ATY66426.1, CAZyme domains=1-
# predicted domain= CBM18
# predicted domain= GH18
# resulting protein= -CazymeProteinPrediction, protein=ATY66444.1, CAZyme domains=2-
# predicted domain= GH5_9
# resulting protein= -CazymeProteinPrediction, protein=ATY66476.1, CAZyme domains=1-
# predicted domain= GH16
# resulting protein= -CazymeProteinPrediction, protein=ATY66491.1, CAZyme domains=1-
# predicted domain= GT62
# resulting protein= -CazymeProteinPrediction, protein=ATY66509.1, CAZyme domains=1-
# predicted domain= CBM32
# predicted domain= GH65
# resulting protein= -CazymeProteinPrediction, protein=ATY66529.1, CAZyme domains=2-
# predicted domain= GH125
# resulting protein= -CazymeProteinPrediction, protein=ATY66542.1, CAZyme domains=1-
# predicted domain= GT8
# resulting protein= -CazymeProteinPrediction, protein=ATY66592.1, CAZyme domains=1-
# predicted domain= GT3
# resulting protein= -CazymeProteinPrediction, protein=ATY66603.1, CAZyme domains=1-
# predicted domain= GT90
# resulting protein= -CazymeProteinPrediction, protein=ATY66615.1, CAZyme domains=1-
# predicted domain= GT25
# resulting protein= -CazymeProteinPrediction, protein=ATY66624.1, CAZyme domains=1-
# predicted domain= GH2
# resulting protein= -CazymeProteinPrediction, protein=ATY66664.1, CAZyme domains=1-
# predicted domain= GH2
# resulting protein= -CazymeProteinPrediction, protein=ATY66787.1, CAZyme domains=1-
# predicted domain= GH92
# resulting protein= -CazymeProteinPrediction, protein=ATY66848.1, CAZyme domains=1-
# predicted domain= GT8
# resulting protein= -CazymeProteinPrediction, protein=ATY66859.1, CAZyme domains=1-
# predicted domain= CE9
# resulting protein= -CazymeProteinPrediction, protein=ATY66875.1, CAZyme domains=1-
# predicted domain= GH3
# resulting protein= -CazymeProteinPrediction, protein=ATY66876.1, CAZyme domains=1-
# predicted domain= GH5_27
# resulting protein= -CazymeProteinPrediction, protein=ATY67020.1, CAZyme domains=1-
# predicted domain= GH20
# resulting protein= -CazymeProteinPrediction, protein=ATY67094.1, CAZyme domains=1-
# predicted domain= AA3_2
# resulting protein= -CazymeProteinPrediction, protein=ATY67138.1, CAZyme domains=1-
# predicted domain= GH114
# resulting protein= -CazymeProteinPrediction, protein=ATY67182.1, CAZyme domains=1-
# predicted domain= GH18
# resulting protein= -CazymeProteinPrediction, protein=ATY67196.1, CAZyme domains=1-
# predicted domain= GH18
# resulting protein= -CazymeProteinPrediction, protein=ATY67226.1, CAZyme domains=1-
# predicted domain= GH17
# resulting protein= -CazymeProteinPrediction, protein=ATY67280.1, CAZyme domains=1-
# predicted domain= CBM48
# predicted domain= GH13_8
# resulting protein= -CazymeProteinPrediction, protein=ATY67289.1, CAZyme domains=2-
# predicted domain= GT20
# resulting protein= -CazymeProteinPrediction, protein=ATY67309.1, CAZyme domains=1-
# predicted domain= GT32
# resulting protein= -CazymeProteinPrediction, protein=ATY67327.1, CAZyme domains=1-
# predicted domain= GH36
# resulting protein= -CazymeProteinPrediction, protein=ATY67425.1, CAZyme domains=1-
# predicted domain= GT90
# resulting protein= -CazymeProteinPrediction, protein=ATY67467.1, CAZyme domains=1-
# predicted domain= GH29
# resulting protein= -CazymeProteinPrediction, protein=ATY67468.1, CAZyme domains=1-
# predicted domain= AA3_2
# resulting protein= -CazymeProteinPrediction, protein=ATY67472.1, CAZyme domains=1-
# predicted domain= GH0
# resulting protein= -CazymeProteinPrediction, protein=ATY63707.1, CAZyme domains=1-
# predicted domain= GH0
# resulting protein= -CazymeProteinPrediction, protein=ATY65793.1, CAZyme domains=1-
# predicted domain= GH0
# resulting protein= -CazymeProteinPrediction, protein=ATY62951.1, CAZyme domains=1-
# predicted domain= GH0
# resulting protein= -CazymeProteinPrediction, protein=ATY61188.1, CAZyme domains=1-
# predicted domain= GH0
# resulting protein= -CazymeProteinPrediction, protein=ATY62721.1, CAZyme domains=1-
# predicted domain= GH0
# resulting protein= -CazymeProteinPrediction, protein=ATY65605.1, CAZyme domains=1-
# predicted domain= GH17
# resulting protein= -CazymeProteinPrediction, protein=ATY67306.1, CAZyme domains=1-
# predicted domain= GH17
# resulting protein= -CazymeProteinPrediction, protein=ATY63087.1, CAZyme domains=1-
# predicted domain= CBM13
# predicted domain= GH27
# resulting protein= -CazymeProteinPrediction, protein=ATY64918.1, CAZyme domains=2-
# predicted domain= GH36
# resulting protein= -CazymeProteinPrediction, protein=ATY59702.1, CAZyme domains=1-
# predicted domain= AA1
# resulting protein= -CazymeProteinPrediction, protein=ATY65374.1, CAZyme domains=1-
# predicted domain= AA1
# resulting protein= -CazymeProteinPrediction, protein=ATY65915.1, CAZyme domains=1-
# predicted domain= AA1
# resulting protein= -CazymeProteinPrediction, protein=ATY64049.1, CAZyme domains=1-
# predicted domain= AA1
# resulting protein= -CazymeProteinPrediction, protein=ATY66872.1, CAZyme domains=1-
# predicted domain= GT31
# resulting protein= -CazymeProteinPrediction, protein=ATY66100.1, CAZyme domains=1-
# predicted domain= GT31
# resulting protein= -CazymeProteinPrediction, protein=ATY64941.1, CAZyme domains=1-
# predicted domain= GT31
# resulting protein= -CazymeProteinPrediction, protein=ATY59959.1, CAZyme domains=1-
# predicted domain= GT31
# resulting protein= -CazymeProteinPrediction, protein=ATY66131.1, CAZyme domains=1-
# predicted domain= GT31
# resulting protein= -CazymeProteinPrediction, protein=ATY60866.1, CAZyme domains=1-
# predicted domain= GT41
# resulting protein= -CazymeProteinPrediction, protein=ATY67037.1, CAZyme domains=1-
# predicted domain= GH18
# resulting protein= -CazymeProteinPrediction, protein=ATY61678.1, CAZyme domains=1-
# predicted domain= CBM20
# predicted domain= GH15
# resulting protein= -CazymeProteinPrediction, protein=ATY67205.1, CAZyme domains=2-
# predicted domain= GH6
# resulting protein= -CazymeProteinPrediction, protein=ATY67423.1, CAZyme domains=1-
# predicted domain= CBM50
# resulting protein= -CazymeProteinPrediction, protein=ATY67158.1, CAZyme domains=1-
# predicted domain= GH93
# resulting protein= -CazymeProteinPrediction, protein=ATY67142.1, CAZyme domains=1-
# predicted domain= GT2
# resulting protein= -CazymeProteinPrediction, protein=ATY66871.1, CAZyme domains=1-
# predicted domain= AA1
# resulting protein= -CazymeProteinPrediction, protein=ATY66532.1, CAZyme domains=1-
# predicted domain= GH18
# resulting protein= -CazymeProteinPrediction, protein=ATY66650.1, CAZyme domains=1-
# predicted domain= GH47
# resulting protein= -CazymeProteinPrediction, protein=ATY67063.1, CAZyme domains=1-
# predicted domain= GH37
# resulting protein= -CazymeProteinPrediction, protein=ATY66815.1, CAZyme domains=1-
# predicted domain= GH0
# resulting protein= -CazymeProteinPrediction, protein=ATY66513.1, CAZyme domains=1-
# predicted domain= GT2
# resulting protein= -CazymeProteinPrediction, protein=ATY66936.1, CAZyme domains=1-
# predicted domain= CBM50
# resulting protein= -CazymeProteinPrediction, protein=ATY66588.1, CAZyme domains=1-
# predicted domain= GH36
# resulting protein= -CazymeProteinPrediction, protein=ATY66605.1, CAZyme domains=1-
# predicted domain= GH0
# resulting protein= -CazymeProteinPrediction, protein=ATY65351.1, CAZyme domains=1-
# predicted domain= CBM48
# resulting protein= -CazymeProteinPrediction, protein=ATY66370.1, CAZyme domains=1-
# predicted domain= CE8
# resulting protein= -CazymeProteinPrediction, protein=ATY66292.1, CAZyme domains=1-
# predicted domain= GH72
# resulting protein= -CazymeProteinPrediction, protein=ATY65856.1, CAZyme domains=1-
# predicted domain= GH76
# resulting protein= -CazymeProteinPrediction, protein=ATY65614.1, CAZyme domains=1-
# predicted domain= CBM50
# resulting protein= -CazymeProteinPrediction, protein=ATY65640.1, CAZyme domains=1-
# predicted domain= GT95
# resulting protein= -CazymeProteinPrediction, protein=ATY65715.1, CAZyme domains=1-
# predicted domain= CBM13
# resulting protein= -CazymeProteinPrediction, protein=ATY65800.1, CAZyme domains=1-
# predicted domain= GH132
# resulting protein= -CazymeProteinPrediction, protein=ATY66201.1, CAZyme domains=1-
# predicted domain= CBM50
# resulting protein= -CazymeProteinPrediction, protein=ATY59704.1, CAZyme domains=1-
# predicted domain= GH43_29
# resulting protein= -CazymeProteinPrediction, protein=ATY58302.1, CAZyme domains=1-
# predicted domain= CE1
# resulting protein= -CazymeProteinPrediction, protein=ATY59753.1, CAZyme domains=1-
# predicted domain= GH19
# resulting protein= -CazymeProteinPrediction, protein=ATY59367.1, CAZyme domains=1-
# predicted domain= GH18
# resulting protein= -CazymeProteinPrediction, protein=ATY58953.1, CAZyme domains=1-
# predicted domain= GH6
# resulting protein= -CazymeProteinPrediction, protein=ATY58554.1, CAZyme domains=1-
# predicted domain= CE4
# resulting protein= -CazymeProteinPrediction, protein=ATY59000.1, CAZyme domains=1-
# predicted domain= GH78
# predicted domain= GH79
# resulting protein= -CazymeProteinPrediction, protein=ATY58522.1, CAZyme domains=2-
# predicted domain= GH18
# resulting protein= -CazymeProteinPrediction, protein=ATY59100.1, CAZyme domains=1-
# predicted domain= GT4
# resulting protein= -CazymeProteinPrediction, protein=ATY58615.1, CAZyme domains=1-
# predicted domain= CBM50
# resulting protein= -CazymeProteinPrediction, protein=ATY58749.1, CAZyme domains=1-
# predicted domain= GH20
# resulting protein= -CazymeProteinPrediction, protein=ATY64072.1, CAZyme domains=1-
# predicted domain= GT7
# resulting protein= -CazymeProteinPrediction, protein=ATY65221.1, CAZyme domains=1-
# predicted domain= CBM50
# resulting protein= -CazymeProteinPrediction, protein=ATY65222.1, CAZyme domains=1-
# predicted domain= GT31
# resulting protein= -CazymeProteinPrediction, protein=ATY64270.1, CAZyme domains=1-
# predicted domain= GH1
# predicted domain= GH95
# resulting protein= -CazymeProteinPrediction, protein=ATY63768.1, CAZyme domains=2-
# predicted domain= GH71
# resulting protein= -CazymeProteinPrediction, protein=ATY65096.1, CAZyme domains=1-
# predicted domain= CBM48
# predicted domain= GH13_8
# resulting protein= -CazymeProteinPrediction, protein=ATY65135.1, CAZyme domains=2-
# predicted domain= GT32
# resulting protein= -CazymeProteinPrediction, protein=ATY64613.1, CAZyme domains=1-
# predicted domain= GT15
# resulting protein= -CazymeProteinPrediction, protein=ATY63956.1, CAZyme domains=1-
# predicted domain= CBM48
# predicted domain= GH13_8
# resulting protein= -CazymeProteinPrediction, protein=ATY64438.1, CAZyme domains=2-
# predicted domain= GH2
# resulting protein= -CazymeProteinPrediction, protein=ATY63857.1, CAZyme domains=1-
# predicted domain= GT57
# resulting protein= -CazymeProteinPrediction, protein=ATY64414.1, CAZyme domains=1-
# predicted domain= CBM48
# predicted domain= GH13_8
# resulting protein= -CazymeProteinPrediction, protein=ATY64183.1, CAZyme domains=2-
# predicted domain= CBM50
# resulting protein= -CazymeProteinPrediction, protein=ATY64808.1, CAZyme domains=1-
# predicted domain= GH16
# resulting protein= -CazymeProteinPrediction, protein=ATY60156.1, CAZyme domains=1-
# predicted domain= GT2
# resulting protein= -CazymeProteinPrediction, protein=ATY61008.1, CAZyme domains=1-
# predicted domain= GT31
# resulting protein= -CazymeProteinPrediction, protein=ATY61113.1, CAZyme domains=1-
# predicted domain= AA1
# resulting protein= -CazymeProteinPrediction, protein=ATY60691.1, CAZyme domains=1-
# predicted domain= GH23
# resulting protein= -CazymeProteinPrediction, protein=ATY61197.1, CAZyme domains=1-
# predicted domain= GH71
# resulting protein= -CazymeProteinPrediction, protein=ATY60299.1, CAZyme domains=1-
# predicted domain= CBM50
# resulting protein= -CazymeProteinPrediction, protein=ATY60767.1, CAZyme domains=1-
# predicted domain= CBM18
# predicted domain= CBM50
# predicted domain= GH18
# resulting protein= -CazymeProteinPrediction, protein=ATY59795.1, CAZyme domains=3-
# predicted domain= GT22
# resulting protein= -CazymeProteinPrediction, protein=ATY60923.1, CAZyme domains=1-
# predicted domain= GT2
# resulting protein= -CazymeProteinPrediction, protein=ATY60283.1, CAZyme domains=1-
# predicted domain= GH78
# predicted domain= GH79
# resulting protein= -CazymeProteinPrediction, protein=ATY60286.1, CAZyme domains=2-
# predicted domain= GT0
# resulting protein= -CazymeProteinPrediction, protein=ATY61131.1, CAZyme domains=1-
# predicted domain= GT1
# resulting protein= -CazymeProteinPrediction, protein=ATY60572.1, CAZyme domains=1-
# predicted domain= GH0
# resulting protein= -CazymeProteinPrediction, protein=ATY62873.1, CAZyme domains=1-
# predicted domain= GT22
# resulting protein= -CazymeProteinPrediction, protein=ATY61476.1, CAZyme domains=1-
# predicted domain= CE8
# resulting protein= -CazymeProteinPrediction, protein=ATY63559.1, CAZyme domains=1-
# predicted domain= GH18
# resulting protein= -CazymeProteinPrediction, protein=ATY61542.1, CAZyme domains=1-
# predicted domain= GH20
# resulting protein= -CazymeProteinPrediction, protein=ATY62188.1, CAZyme domains=1-
# predicted domain= CBM50
# resulting protein= -CazymeProteinPrediction, protein=ATY62193.1, CAZyme domains=1-
# predicted domain= CBM43
# resulting protein= -CazymeProteinPrediction, protein=ATY62194.1, CAZyme domains=1-
# predicted domain= GH43_21
# resulting protein= -CazymeProteinPrediction, protein=ATY63571.1, CAZyme domains=1-
# predicted domain= CBM66
# predicted domain= GH43_34
# resulting protein= -CazymeProteinPrediction, protein=ATY62227.1, CAZyme domains=2-
# predicted domain= CBM13
# predicted domain= GT27
# resulting protein= -CazymeProteinPrediction, protein=ATY62896.1, CAZyme domains=2-
# predicted domain= CBM50
# resulting protein= -CazymeProteinPrediction, protein=ATY63166.1, CAZyme domains=1-
# predicted domain= GT30
# resulting protein= -CazymeProteinPrediction, protein=ATY62297.1, CAZyme domains=1-
# predicted domain= GT0
# resulting protein= -CazymeProteinPrediction, protein=ATY61491.1, CAZyme domains=1-
# predicted domain= GT7
# resulting protein= -CazymeProteinPrediction, protein=ATY62667.1, CAZyme domains=1-
# predicted domain= CBM48
# predicted domain= GH13_8
# resulting protein= -CazymeProteinPrediction, protein=ATY62782.1, CAZyme domains=2-
# predicted domain= GT0
# resulting protein= -CazymeProteinPrediction, protein=ATY62784.1, CAZyme domains=1-
# predicted domain= GT0
# resulting protein= -CazymeProteinPrediction, protein=ATY63618.1, CAZyme domains=1-
# predicted domain= GH18
# resulting protein= -CazymeProteinPrediction, protein=ATY63554.1, CAZyme domains=1-
# predicted domain= GH18
# resulting protein= -CazymeProteinPrediction, protein=ATY63408.1, CAZyme domains=1-
# predicted domain= CBM50
# resulting protein= -CazymeProteinPrediction, protein=ATY63733.1, CAZyme domains=1-
# predicted domain= CBM48
# predicted domain= GH13_8
# resulting protein= -CazymeProteinPrediction, protein=ATY61789.1, CAZyme domains=2-
# predicted domain= CBM50
# resulting protein= -CazymeProteinPrediction, protein=ATY61853.1, CAZyme domains=1-
# predicted domain= GT1
# resulting protein= -CazymeProteinPrediction, protein=ATY63072.1, CAZyme domains=1-
# predicted domain= CBM50
# resulting protein= -CazymeProteinPrediction, protein=ATY61716.1, CAZyme domains=1-
# predicted domain= GT1
# resulting protein= -CazymeProteinPrediction, protein=ATY62977.1, CAZyme domains=1-
#
# number of parsed proteins= 445

# %% [markdown]
# By comparing the progress bar and the number of parsed proteins we can see that the method above parses all proteins catalogued in the overview.txt.
#
# Additionally, by looking at the `CazymeProteinPrediction` instances we can see that the multilpe domains of the proteins are captured, and stored within their respecetive parent cazyme represented by a `CazymeProteinPrediction` instance.
#
# To improve the robustness of the method, 'quality' checks can be included to make sure a CAZy (sub)family is being retrieved. This is retrieved by using regular expressions to check the format of the retrieved data.

# %%
# Check how text is separated in overview.txt
with open ("overview.txt", "r") as ofh:
    overview_file = ofh.read().splitlines()

# create an empty dictionary store all dbCAN, HMMER, Hotpep and DIAMOND prediction data
# {protein_accession: {prediciton_tool: CazymeProteinPrediction}}
overview_dict = {}

for line in tqdm(overview_file[1:], desc="Parsing overview.txt"):  # skip the first line becuase this is the 'column' titles
    line = line.split("\t")
    
    # retrieve and separate the DIAMOND CAZyme domains
    diamond_predictions = line[3].split("+")

    protein_accession = line[0]
    
    # check if the protein was classified as a non-CAZyme
    if diamond_predictions[0] == "-":
        cazyme_classification = 0
        
        try:
            overview_dict[protein_accession]
            
            try:
                overview_dict[protein_accession]["DIAMOND"]
                
                print(f"WARNING -- DIAMOND PREDICTION ALREADY PROVIDED FOR {protein_accession}")
            
            except KeyError:  # raised if DIAMOND prediction not yet catalogued for the protein
                overview_dict[protein_accession]["DIAMOND"] = CazymeProteinPrediction(
                    "DIAMOND",
                    protein_accession,
                    cazyme_classification,
                )
        
        except KeyError:  # raised if protein is not yet catalogued
            overview_dict[protein_accession] = {
                "DIAMOND": CazymeProteinPrediction(
                    "DIAMOND",
                    protein_accession,
                    cazyme_classification,
                )
            }
        
        continue  # go to next protein
    
    # create DIAMONDprediction instance to represent the prediction for the current working protein
    cazyme_classification = 1
    parent_cazyme = CazymeProteinPrediction("DIAMOND", protein_accession, cazyme_classification)
    
    cazyme_domains = []

    # parse each of the predicted CAZyme domains
    for predicted_domain in diamond_predictions:
        print("predicted domain=", predicted_domain)
        
        # check if CAZy subfamily is predicted
        try:
            re.match(r"\D{2,3}\d+?_\d+", predicted_domain).group()
            
            cazy_family = predicted_domain[:predicted_domain.find("_")]
            cazy_subfamily = predicted_domain
        
        except AttributeError:  # raised if predicted_domain is not a CAZy subfamily
            try:
                re.match(r"\D{2,3}\d+", predicted_domain).group()
                
                cazy_family = predicted_domain
                cazy_subfamily = np.nan
            
            except AttributeError:  # raised it no a CAZy family
                print(
                    f"WARNING -- UNEXPECTED DATA FORMAT {predicted_domain}\n"
                    f"Expected cazy family or subfamily but this is neither, not adding as a CAZyme domain to {protein_accession}"
                )
                continue
        
        domain = CazymeDomain(protein_accession, cazy_family, cazy_subfamily)

        cazyme_domains.append(domain)
    
    # add domains to the protein
    parent_cazyme.cazyme_domains = cazyme_domains
    
    # add the protein to the dictionary of all parsed proteins
    try:
        overview_dict[protein_accession]
        
        try:
            overview_dict[protein_accession]["DIAMOND"]
            
            print(f"WARNING -- DIAMOND PREDICTION ALREADY PROVIDED FOR {protein_accession}")
        
        except KeyError:  # raised it not HMMER prediction catagloued yet
            overview_dict[protein_accession]["DIAMOND"] = parent_cazyme
    
    except KeyError:  # raised if not protein yet catalogued
        overview_dict[protein_accession] = {"DIAMOND": parent_cazyme}
        
    print("resulting protein=", parent_cazyme)

print("number of parsed proteins=", len(list(overview_dict.values())))
# Out:
# HBox(children=(HTML(value='Parsing overview.txt'), FloatProgress(value=0.0, max=445.0), HTML(value='')))
# predicted domain= CE5
# resulting protein= -CazymeProteinPrediction, protein=ATY58323.1, CAZyme domains=1-
# predicted domain= AA11
# resulting protein= -CazymeProteinPrediction, protein=ATY58330.1, CAZyme domains=1-
# predicted domain= AA3
# resulting protein= -CazymeProteinPrediction, protein=ATY58475.1, CAZyme domains=1-
# predicted domain= GH16
# resulting protein= -CazymeProteinPrediction, protein=ATY58478.1, CAZyme domains=1-
# predicted domain= CBM1
# predicted domain= GH18
# resulting protein= -CazymeProteinPrediction, protein=ATY58486.1, CAZyme domains=2-
# predicted domain= GH5_24
# resulting protein= -CazymeProteinPrediction, protein=ATY58494.1, CAZyme domains=1-
# predicted domain= GH55
# resulting protein= -CazymeProteinPrediction, protein=ATY58512.1, CAZyme domains=1-
# predicted domain= GH16
# resulting protein= -CazymeProteinPrediction, protein=ATY58528.1, CAZyme domains=1-
# predicted domain= GH64
# resulting protein= -CazymeProteinPrediction, protein=ATY58531.1, CAZyme domains=1-
# predicted domain= CE5
# resulting protein= -CazymeProteinPrediction, protein=ATY58532.1, CAZyme domains=1-
# predicted domain= GH76
# resulting protein= -CazymeProteinPrediction, protein=ATY58571.1, CAZyme domains=1-
# predicted domain= GH38
# resulting protein= -CazymeProteinPrediction, protein=ATY58579.1, CAZyme domains=1-
# predicted domain= GT2
# resulting protein= -CazymeProteinPrediction, protein=ATY58636.1, CAZyme domains=1-
# predicted domain= GH12
# resulting protein= -CazymeProteinPrediction, protein=ATY58637.1, CAZyme domains=1-
# predicted domain= GH75
# resulting protein= -CazymeProteinPrediction, protein=ATY58674.1, CAZyme domains=1-
# predicted domain= GH29
# resulting protein= -CazymeProteinPrediction, protein=ATY58705.1, CAZyme domains=1-
# predicted domain= GT66
# resulting protein= -CazymeProteinPrediction, protein=ATY58803.1, CAZyme domains=1-
# predicted domain= GH18
# resulting protein= -CazymeProteinPrediction, protein=ATY58848.1, CAZyme domains=1-
# predicted domain= GH1
# resulting protein= -CazymeProteinPrediction, protein=ATY58880.1, CAZyme domains=1-
# predicted domain= AA3_1
# resulting protein= -CazymeProteinPrediction, protein=ATY58895.1, CAZyme domains=1-
# predicted domain= AA3_3
# resulting protein= -CazymeProteinPrediction, protein=ATY58902.1, CAZyme domains=1-
# predicted domain= GH16
# resulting protein= -CazymeProteinPrediction, protein=ATY58949.1, CAZyme domains=1-
# predicted domain= CE5
# resulting protein= -CazymeProteinPrediction, protein=ATY58965.1, CAZyme domains=1-
# predicted domain= CBM18
# predicted domain= GH18
# resulting protein= -CazymeProteinPrediction, protein=ATY59023.1, CAZyme domains=2-
# predicted domain= GH13_5
# resulting protein= -CazymeProteinPrediction, protein=ATY59031.1, CAZyme domains=1-
# predicted domain= GH81
# resulting protein= -CazymeProteinPrediction, protein=ATY59065.1, CAZyme domains=1-
# predicted domain= GH18
# resulting protein= -CazymeProteinPrediction, protein=ATY59093.1, CAZyme domains=1-
# predicted domain= GT90
# resulting protein= -CazymeProteinPrediction, protein=ATY59185.1, CAZyme domains=1-
# predicted domain= CBM18
# predicted domain= CBM50
# predicted domain= CBM66
# predicted domain= GH18
# resulting protein= -CazymeProteinPrediction, protein=ATY59188.1, CAZyme domains=4-
# predicted domain= GH72
# resulting protein= -CazymeProteinPrediction, protein=ATY59194.1, CAZyme domains=1-
# predicted domain= GT90
# resulting protein= -CazymeProteinPrediction, protein=ATY59202.1, CAZyme domains=1-
# predicted domain= GT15
# resulting protein= -CazymeProteinPrediction, protein=ATY59250.1, CAZyme domains=1-
# predicted domain= AA12
# resulting protein= -CazymeProteinPrediction, protein=ATY59363.1, CAZyme domains=1-
# predicted domain= GT21
# resulting protein= -CazymeProteinPrediction, protein=ATY59638.1, CAZyme domains=1-
# predicted domain= CE4
# resulting protein= -CazymeProteinPrediction, protein=ATY59671.1, CAZyme domains=1-
# predicted domain= AA1_2
# resulting protein= -CazymeProteinPrediction, protein=ATY59688.1, CAZyme domains=1-
# predicted domain= GT1
# resulting protein= -CazymeProteinPrediction, protein=ATY59691.1, CAZyme domains=1-
# predicted domain= CBM42
# predicted domain= GH54
# resulting protein= -CazymeProteinPrediction, protein=ATY59698.1, CAZyme domains=2-
# predicted domain= GT4
# resulting protein= -CazymeProteinPrediction, protein=ATY59714.1, CAZyme domains=1-
# predicted domain= GT1
# resulting protein= -CazymeProteinPrediction, protein=ATY59781.1, CAZyme domains=1-
# predicted domain= AA3_1
# resulting protein= -CazymeProteinPrediction, protein=ATY59860.1, CAZyme domains=1-
# predicted domain= CBM66
# predicted domain= GH43_34
# resulting protein= -CazymeProteinPrediction, protein=ATY59890.1, CAZyme domains=2-
# predicted domain= AA3_2
# resulting protein= -CazymeProteinPrediction, protein=ATY59904.1, CAZyme domains=1-
# predicted domain= GT2
# resulting protein= -CazymeProteinPrediction, protein=ATY59933.1, CAZyme domains=1-
# predicted domain= GH128
# resulting protein= -CazymeProteinPrediction, protein=ATY59950.1, CAZyme domains=1-
# predicted domain= GH47
# resulting protein= -CazymeProteinPrediction, protein=ATY59985.1, CAZyme domains=1-
# predicted domain= GT2
# resulting protein= -CazymeProteinPrediction, protein=ATY60044.1, CAZyme domains=1-
# predicted domain= GH16
# resulting protein= -CazymeProteinPrediction, protein=ATY60072.1, CAZyme domains=1-
# predicted domain= GT17
# resulting protein= -CazymeProteinPrediction, protein=ATY60094.1, CAZyme domains=1-
# predicted domain= GH55
# resulting protein= -CazymeProteinPrediction, protein=ATY60133.1, CAZyme domains=1-
# predicted domain= GT4
# resulting protein= -CazymeProteinPrediction, protein=ATY60146.1, CAZyme domains=1-
# predicted domain= AA1_3
# resulting protein= -CazymeProteinPrediction, protein=ATY60162.1, CAZyme domains=1-
# predicted domain= AA11
# resulting protein= -CazymeProteinPrediction, protein=ATY60186.1, CAZyme domains=1-
# predicted domain= GT22
# resulting protein= -CazymeProteinPrediction, protein=ATY60246.1, CAZyme domains=1-
# predicted domain= GH16
# resulting protein= -CazymeProteinPrediction, protein=ATY60251.1, CAZyme domains=1-
# predicted domain= AA5_1
# resulting protein= -CazymeProteinPrediction, protein=ATY60261.1, CAZyme domains=1-
# predicted domain= GT4
# resulting protein= -CazymeProteinPrediction, protein=ATY60312.1, CAZyme domains=1-
# predicted domain= GH92
# resulting protein= -CazymeProteinPrediction, protein=ATY60330.1, CAZyme domains=1-
# predicted domain= CBM50
# resulting protein= -CazymeProteinPrediction, protein=ATY60367.1, CAZyme domains=1-
# predicted domain= GH16
# resulting protein= -CazymeProteinPrediction, protein=ATY60372.1, CAZyme domains=1-
# predicted domain= GH152
# resulting protein= -CazymeProteinPrediction, protein=ATY60381.1, CAZyme domains=1-
# predicted domain= GH76
# resulting protein= -CazymeProteinPrediction, protein=ATY60408.1, CAZyme domains=1-
# predicted domain= GT2
# resulting protein= -CazymeProteinPrediction, protein=ATY60416.1, CAZyme domains=1-
# predicted domain= GH31
# resulting protein= -CazymeProteinPrediction, protein=ATY60491.1, CAZyme domains=1-
# predicted domain= GH18
# resulting protein= -CazymeProteinPrediction, protein=ATY60504.1, CAZyme domains=1-
# predicted domain= GH55
# resulting protein= -CazymeProteinPrediction, protein=ATY60550.1, CAZyme domains=1-
# predicted domain= PL35
# resulting protein= -CazymeProteinPrediction, protein=ATY60555.1, CAZyme domains=1-
# predicted domain= GH2
# resulting protein= -CazymeProteinPrediction, protein=ATY60591.1, CAZyme domains=1-
# predicted domain= AA1
# resulting protein= -CazymeProteinPrediction, protein=ATY60613.1, CAZyme domains=1-
# predicted domain= CBM13
# predicted domain= GH142
# resulting protein= -CazymeProteinPrediction, protein=ATY60620.1, CAZyme domains=2-
# predicted domain= GH76
# resulting protein= -CazymeProteinPrediction, protein=ATY60629.1, CAZyme domains=1-
# predicted domain= GH47
# resulting protein= -CazymeProteinPrediction, protein=ATY60662.1, CAZyme domains=1-
# predicted domain= GH16
# resulting protein= -CazymeProteinPrediction, protein=ATY60681.1, CAZyme domains=1-
# predicted domain= GH84
# resulting protein= -CazymeProteinPrediction, protein=ATY60726.1, CAZyme domains=1-
# predicted domain= GH76
# resulting protein= -CazymeProteinPrediction, protein=ATY60733.1, CAZyme domains=1-
# predicted domain= AA11
# resulting protein= -CazymeProteinPrediction, protein=ATY60772.1, CAZyme domains=1-
# predicted domain= GH20
# resulting protein= -CazymeProteinPrediction, protein=ATY60851.1, CAZyme domains=1-
# predicted domain= GH135
# resulting protein= -CazymeProteinPrediction, protein=ATY60853.1, CAZyme domains=1-
# predicted domain= GT2
# resulting protein= -CazymeProteinPrediction, protein=ATY60878.1, CAZyme domains=1-
# predicted domain= GT34
# resulting protein= -CazymeProteinPrediction, protein=ATY60976.1, CAZyme domains=1-
# predicted domain= GH16
# resulting protein= -CazymeProteinPrediction, protein=ATY60986.1, CAZyme domains=1-
# predicted domain= CBM18
# predicted domain= GH18
# resulting protein= -CazymeProteinPrediction, protein=ATY61069.1, CAZyme domains=2-
# predicted domain= GT64
# resulting protein= -CazymeProteinPrediction, protein=ATY61117.1, CAZyme domains=1-
# predicted domain= GH3
# resulting protein= -CazymeProteinPrediction, protein=ATY61140.1, CAZyme domains=1-
# predicted domain= GH89
# resulting protein= -CazymeProteinPrediction, protein=ATY61147.1, CAZyme domains=1-
# predicted domain= CE1
# resulting protein= -CazymeProteinPrediction, protein=ATY61152.1, CAZyme domains=1-
# predicted domain= CBM1
# predicted domain= GH18
# resulting protein= -CazymeProteinPrediction, protein=ATY61215.1, CAZyme domains=2-
# predicted domain= GH13_25
# predicted domain= GH133
# resulting protein= -CazymeProteinPrediction, protein=ATY61276.1, CAZyme domains=2-
# predicted domain= AA7
# resulting protein= -CazymeProteinPrediction, protein=ATY61280.1, CAZyme domains=1-
# predicted domain= GH16
# resulting protein= -CazymeProteinPrediction, protein=ATY61301.1, CAZyme domains=1-
# predicted domain= GT69
# resulting protein= -CazymeProteinPrediction, protein=ATY61355.1, CAZyme domains=1-
# predicted domain= PL20
# resulting protein= -CazymeProteinPrediction, protein=ATY61441.1, CAZyme domains=1-
# predicted domain= GH31
# resulting protein= -CazymeProteinPrediction, protein=ATY61576.1, CAZyme domains=1-
# predicted domain= GT2
# resulting protein= -CazymeProteinPrediction, protein=ATY61595.1, CAZyme domains=1-
# predicted domain= GH79
# resulting protein= -CazymeProteinPrediction, protein=ATY61630.1, CAZyme domains=1-
# predicted domain= AA3_2
# resulting protein= -CazymeProteinPrediction, protein=ATY61694.1, CAZyme domains=1-
# predicted domain= GH18
# resulting protein= -CazymeProteinPrediction, protein=ATY61713.1, CAZyme domains=1-
# predicted domain= CBM18
# predicted domain= GH18
# resulting protein= -CazymeProteinPrediction, protein=ATY61718.1, CAZyme domains=2-
# predicted domain= GT2
# resulting protein= -CazymeProteinPrediction, protein=ATY61741.1, CAZyme domains=1-
# predicted domain= GT20
# resulting protein= -CazymeProteinPrediction, protein=ATY61753.1, CAZyme domains=1-
# predicted domain= GH16
# resulting protein= -CazymeProteinPrediction, protein=ATY61788.1, CAZyme domains=1-
# predicted domain= CBM18
# predicted domain= GH16
# resulting protein= -CazymeProteinPrediction, protein=ATY61824.1, CAZyme domains=2-
# predicted domain= GH16
# resulting protein= -CazymeProteinPrediction, protein=ATY61835.1, CAZyme domains=1-
# predicted domain= GT0
# resulting protein= -CazymeProteinPrediction, protein=ATY61836.1, CAZyme domains=1-
# predicted domain= GH15
# resulting protein= -CazymeProteinPrediction, protein=ATY61850.1, CAZyme domains=1-
# predicted domain= CBM50
# predicted domain= GH18
# resulting protein= -CazymeProteinPrediction, protein=ATY61851.1, CAZyme domains=2-
# predicted domain= GT59
# resulting protein= -CazymeProteinPrediction, protein=ATY61863.1, CAZyme domains=1-
# predicted domain= GT15
# resulting protein= -CazymeProteinPrediction, protein=ATY61865.1, CAZyme domains=1-
# predicted domain= GH18
# resulting protein= -CazymeProteinPrediction, protein=ATY61890.1, CAZyme domains=1-
# predicted domain= CBM43
# predicted domain= GH72
# resulting protein= -CazymeProteinPrediction, protein=ATY61893.1, CAZyme domains=2-
# predicted domain= GH2
# resulting protein= -CazymeProteinPrediction, protein=ATY61914.1, CAZyme domains=1-
# predicted domain= GH16
# resulting protein= -CazymeProteinPrediction, protein=ATY61926.1, CAZyme domains=1-
# predicted domain= GT22
# resulting protein= -CazymeProteinPrediction, protein=ATY61957.1, CAZyme domains=1-
# predicted domain= GH13_40
# resulting protein= -CazymeProteinPrediction, protein=ATY61965.1, CAZyme domains=1-
# predicted domain= GT39
# resulting protein= -CazymeProteinPrediction, protein=ATY61989.1, CAZyme domains=1-
# predicted domain= GH47
# resulting protein= -CazymeProteinPrediction, protein=ATY62020.1, CAZyme domains=1-
# predicted domain= GH5_11
# resulting protein= -CazymeProteinPrediction, protein=ATY62039.1, CAZyme domains=1-
# predicted domain= GT32
# resulting protein= -CazymeProteinPrediction, protein=ATY62087.1, CAZyme domains=1-
# predicted domain= GH132
# resulting protein= -CazymeProteinPrediction, protein=ATY62092.1, CAZyme domains=1-
# predicted domain= GT22
# resulting protein= -CazymeProteinPrediction, protein=ATY62109.1, CAZyme domains=1-
# predicted domain= GH5_5
# resulting protein= -CazymeProteinPrediction, protein=ATY62125.1, CAZyme domains=1-
# predicted domain= GH0
# resulting protein= -CazymeProteinPrediction, protein=ATY62132.1, CAZyme domains=1-
# predicted domain= AA12
# resulting protein= -CazymeProteinPrediction, protein=ATY62143.1, CAZyme domains=1-
# predicted domain= GT39
# resulting protein= -CazymeProteinPrediction, protein=ATY62147.1, CAZyme domains=1-
# predicted domain= GH13_40
# resulting protein= -CazymeProteinPrediction, protein=ATY62175.1, CAZyme domains=1-
# predicted domain= AA3_2
# resulting protein= -CazymeProteinPrediction, protein=ATY62233.1, CAZyme domains=1-
# predicted domain= GT22
# resulting protein= -CazymeProteinPrediction, protein=ATY62235.1, CAZyme domains=1-
# predicted domain= GT50
# resulting protein= -CazymeProteinPrediction, protein=ATY62242.1, CAZyme domains=1-
# predicted domain= GH3
# resulting protein= -CazymeProteinPrediction, protein=ATY62277.1, CAZyme domains=1-
# predicted domain= GT25
# resulting protein= -CazymeProteinPrediction, protein=ATY62278.1, CAZyme domains=1-
# predicted domain= GH136
# resulting protein= -CazymeProteinPrediction, protein=ATY62338.1, CAZyme domains=1-
# predicted domain= GH20
# resulting protein= -CazymeProteinPrediction, protein=ATY62385.1, CAZyme domains=1-
# predicted domain= GT1
# resulting protein= -CazymeProteinPrediction, protein=ATY62412.1, CAZyme domains=1-
# predicted domain= GH3
# resulting protein= -CazymeProteinPrediction, protein=ATY62465.1, CAZyme domains=1-
# predicted domain= GT58
# resulting protein= -CazymeProteinPrediction, protein=ATY62551.1, CAZyme domains=1-
# predicted domain= CBM20
# predicted domain= GH15
# resulting protein= -CazymeProteinPrediction, protein=ATY62564.1, CAZyme domains=2-
# predicted domain= GH5_15
# resulting protein= -CazymeProteinPrediction, protein=ATY62578.1, CAZyme domains=1-
# predicted domain= GT20
# resulting protein= -CazymeProteinPrediction, protein=ATY62614.1, CAZyme domains=1-
# predicted domain= GT2
# resulting protein= -CazymeProteinPrediction, protein=ATY62663.1, CAZyme domains=1-
# predicted domain= GH16
# resulting protein= -CazymeProteinPrediction, protein=ATY62684.1, CAZyme domains=1-
# predicted domain= GT0
# resulting protein= -CazymeProteinPrediction, protein=ATY62685.1, CAZyme domains=1-
# predicted domain= CE3
# resulting protein= -CazymeProteinPrediction, protein=ATY62702.1, CAZyme domains=1-
# predicted domain= GH154
# resulting protein= -CazymeProteinPrediction, protein=ATY62739.1, CAZyme domains=1-
# predicted domain= GH88
# resulting protein= -CazymeProteinPrediction, protein=ATY62740.1, CAZyme domains=1-
# predicted domain= GH47
# resulting protein= -CazymeProteinPrediction, protein=ATY62742.1, CAZyme domains=1-
# predicted domain= GH3
# resulting protein= -CazymeProteinPrediction, protein=ATY62757.1, CAZyme domains=1-
# predicted domain= AA3_2
# resulting protein= -CazymeProteinPrediction, protein=ATY62798.1, CAZyme domains=1-
# predicted domain= AA9
# predicted domain= CBM18
# resulting protein= -CazymeProteinPrediction, protein=ATY62856.1, CAZyme domains=2-
# predicted domain= GH64
# resulting protein= -CazymeProteinPrediction, protein=ATY62933.1, CAZyme domains=1-
# predicted domain= GT15
# resulting protein= -CazymeProteinPrediction, protein=ATY62981.1, CAZyme domains=1-
# predicted domain= GH16
# resulting protein= -CazymeProteinPrediction, protein=ATY63039.1, CAZyme domains=1-
# predicted domain= GH18
# resulting protein= -CazymeProteinPrediction, protein=ATY63066.1, CAZyme domains=1-
# predicted domain= GT69
# resulting protein= -CazymeProteinPrediction, protein=ATY63210.1, CAZyme domains=1-
# predicted domain= GT71
# resulting protein= -CazymeProteinPrediction, protein=ATY63227.1, CAZyme domains=1-
# predicted domain= GH63
# resulting protein= -CazymeProteinPrediction, protein=ATY63228.1, CAZyme domains=1-
# predicted domain= GT57
# resulting protein= -CazymeProteinPrediction, protein=ATY63255.1, CAZyme domains=1-
# predicted domain= GH3
# resulting protein= -CazymeProteinPrediction, protein=ATY63305.1, CAZyme domains=1-
# predicted domain= GH35
# resulting protein= -CazymeProteinPrediction, protein=ATY63319.1, CAZyme domains=1-
# predicted domain= GT90
# resulting protein= -CazymeProteinPrediction, protein=ATY63344.1, CAZyme domains=1-
# predicted domain= GT39
# resulting protein= -CazymeProteinPrediction, protein=ATY63360.1, CAZyme domains=1-
# predicted domain= GH16
# resulting protein= -CazymeProteinPrediction, protein=ATY63412.1, CAZyme domains=1-
# predicted domain= CBM18
# predicted domain= CE4
# resulting protein= -CazymeProteinPrediction, protein=ATY63454.1, CAZyme domains=2-
# predicted domain= GH18
# resulting protein= -CazymeProteinPrediction, protein=ATY63468.1, CAZyme domains=1-
# predicted domain= AA11
# resulting protein= -CazymeProteinPrediction, protein=ATY63528.1, CAZyme domains=1-
# predicted domain= GH18
# resulting protein= -CazymeProteinPrediction, protein=ATY63573.1, CAZyme domains=1-
# predicted domain= GH3
# resulting protein= -CazymeProteinPrediction, protein=ATY63588.1, CAZyme domains=1-
# predicted domain= GH79
# resulting protein= -CazymeProteinPrediction, protein=ATY63601.1, CAZyme domains=1-
# predicted domain= GT17
# resulting protein= -CazymeProteinPrediction, protein=ATY63636.1, CAZyme domains=1-
# predicted domain= GH37
# resulting protein= -CazymeProteinPrediction, protein=ATY63688.1, CAZyme domains=1-
# predicted domain= GT1
# resulting protein= -CazymeProteinPrediction, protein=ATY63703.1, CAZyme domains=1-
# predicted domain= GT1
# resulting protein= -CazymeProteinPrediction, protein=ATY63705.1, CAZyme domains=1-
# predicted domain= GH55
# resulting protein= -CazymeProteinPrediction, protein=ATY63856.1, CAZyme domains=1-
# predicted domain= GT35
# resulting protein= -CazymeProteinPrediction, protein=ATY63982.1, CAZyme domains=1-
# predicted domain= GH92
# resulting protein= -CazymeProteinPrediction, protein=ATY63987.1, CAZyme domains=1-
# predicted domain= GT1
# resulting protein= -CazymeProteinPrediction, protein=ATY63993.1, CAZyme domains=1-
# predicted domain= GH128
# resulting protein= -CazymeProteinPrediction, protein=ATY63999.1, CAZyme domains=1-
# predicted domain= GT34
# resulting protein= -CazymeProteinPrediction, protein=ATY64005.1, CAZyme domains=1-
# predicted domain= GH55
# resulting protein= -CazymeProteinPrediction, protein=ATY64012.1, CAZyme domains=1-
# predicted domain= AA3_2
# resulting protein= -CazymeProteinPrediction, protein=ATY64015.1, CAZyme domains=1-
# predicted domain= GH0
# resulting protein= -CazymeProteinPrediction, protein=ATY64043.1, CAZyme domains=1-
# predicted domain= GH31
# resulting protein= -CazymeProteinPrediction, protein=ATY64047.1, CAZyme domains=1-
# predicted domain= GH89
# resulting protein= -CazymeProteinPrediction, protein=ATY64088.1, CAZyme domains=1-
# predicted domain= GH55
# resulting protein= -CazymeProteinPrediction, protein=ATY64150.1, CAZyme domains=1-
# predicted domain= GH72
# resulting protein= -CazymeProteinPrediction, protein=ATY64179.1, CAZyme domains=1-
# predicted domain= GT90
# resulting protein= -CazymeProteinPrediction, protein=ATY64186.1, CAZyme domains=1-
# predicted domain= GH16
# resulting protein= -CazymeProteinPrediction, protein=ATY64187.1, CAZyme domains=1-
# predicted domain= GT69
# resulting protein= -CazymeProteinPrediction, protein=ATY64188.1, CAZyme domains=1-
# predicted domain= GT17
# resulting protein= -CazymeProteinPrediction, protein=ATY64233.1, CAZyme domains=1-
# predicted domain= CBM43
# predicted domain= GH72
# resulting protein= -CazymeProteinPrediction, protein=ATY64248.1, CAZyme domains=2-
# predicted domain= PL8_4
# resulting protein= -CazymeProteinPrediction, protein=ATY64353.1, CAZyme domains=1-
# predicted domain= GT57
# resulting protein= -CazymeProteinPrediction, protein=ATY64416.1, CAZyme domains=1-
# predicted domain= GT4
# resulting protein= -CazymeProteinPrediction, protein=ATY64437.1, CAZyme domains=1-
# predicted domain= GT33
# resulting protein= -CazymeProteinPrediction, protein=ATY64461.1, CAZyme domains=1-
# predicted domain= AA3_2
# resulting protein= -CazymeProteinPrediction, protein=ATY64478.1, CAZyme domains=1-
# predicted domain= GH3
# resulting protein= -CazymeProteinPrediction, protein=ATY64479.1, CAZyme domains=1-
# predicted domain= GH76
# resulting protein= -CazymeProteinPrediction, protein=ATY64503.1, CAZyme domains=1-
# predicted domain= GH2
# resulting protein= -CazymeProteinPrediction, protein=ATY64517.1, CAZyme domains=1-
# predicted domain= GH92
# resulting protein= -CazymeProteinPrediction, protein=ATY64570.1, CAZyme domains=1-
# predicted domain= GH2
# resulting protein= -CazymeProteinPrediction, protein=ATY64671.1, CAZyme domains=1-
# predicted domain= CBM18
# predicted domain= GH18
# resulting protein= -CazymeProteinPrediction, protein=ATY64693.1, CAZyme domains=2-
# predicted domain= CBM50
# predicted domain= GH55
# resulting protein= -CazymeProteinPrediction, protein=ATY64695.1, CAZyme domains=2-
# predicted domain= GH5_12
# resulting protein= -CazymeProteinPrediction, protein=ATY64700.1, CAZyme domains=1-
# predicted domain= GT24
# resulting protein= -CazymeProteinPrediction, protein=ATY64752.1, CAZyme domains=1-
# predicted domain= GH18
# resulting protein= -CazymeProteinPrediction, protein=ATY64774.1, CAZyme domains=1-
# predicted domain= GT20
# resulting protein= -CazymeProteinPrediction, protein=ATY64802.1, CAZyme domains=1-
# predicted domain= GH17
# resulting protein= -CazymeProteinPrediction, protein=ATY64843.1, CAZyme domains=1-
# predicted domain= GT48
# resulting protein= -CazymeProteinPrediction, protein=ATY64850.1, CAZyme domains=1-
# predicted domain= GH35
# resulting protein= -CazymeProteinPrediction, protein=ATY64919.1, CAZyme domains=1-
# predicted domain= GH47
# resulting protein= -CazymeProteinPrediction, protein=ATY64924.1, CAZyme domains=1-
# predicted domain= CBM18
# predicted domain= CE4
# resulting protein= -CazymeProteinPrediction, protein=ATY64953.1, CAZyme domains=2-
# predicted domain= AA7
# resulting protein= -CazymeProteinPrediction, protein=ATY64976.1, CAZyme domains=1-
# predicted domain= CBM21
# resulting protein= -CazymeProteinPrediction, protein=ATY64996.1, CAZyme domains=1-
# predicted domain= GT2
# resulting protein= -CazymeProteinPrediction, protein=ATY65010.1, CAZyme domains=1-
# predicted domain= AA1_3
# resulting protein= -CazymeProteinPrediction, protein=ATY65020.1, CAZyme domains=1-
# predicted domain= CE5
# resulting protein= -CazymeProteinPrediction, protein=ATY65055.1, CAZyme domains=1-
# predicted domain= CE16
# resulting protein= -CazymeProteinPrediction, protein=ATY65081.1, CAZyme domains=1-
# predicted domain= GH47
# resulting protein= -CazymeProteinPrediction, protein=ATY65106.1, CAZyme domains=1-
# predicted domain= GH17
# resulting protein= -CazymeProteinPrediction, protein=ATY65116.1, CAZyme domains=1-
# predicted domain= GH16
# resulting protein= -CazymeProteinPrediction, protein=ATY65185.1, CAZyme domains=1-
# predicted domain= GH128
# resulting protein= -CazymeProteinPrediction, protein=ATY65191.1, CAZyme domains=1-
# predicted domain= GH79
# resulting protein= -CazymeProteinPrediction, protein=ATY65205.1, CAZyme domains=1-
# predicted domain= CBM18
# predicted domain= CBM50
# predicted domain= GH18
# resulting protein= -CazymeProteinPrediction, protein=ATY65223.1, CAZyme domains=3-
# predicted domain= GH76
# resulting protein= -CazymeProteinPrediction, protein=ATY65449.1, CAZyme domains=1-
# predicted domain= GH76
# resulting protein= -CazymeProteinPrediction, protein=ATY65455.1, CAZyme domains=1-
# predicted domain= GT62
# resulting protein= -CazymeProteinPrediction, protein=ATY65484.1, CAZyme domains=1-
# predicted domain= GH28
# resulting protein= -CazymeProteinPrediction, protein=ATY65544.1, CAZyme domains=1-
# predicted domain= GH76
# resulting protein= -CazymeProteinPrediction, protein=ATY65556.1, CAZyme domains=1-
# predicted domain= GT76
# resulting protein= -CazymeProteinPrediction, protein=ATY65579.1, CAZyme domains=1-
# predicted domain= GH128
# resulting protein= -CazymeProteinPrediction, protein=ATY65604.1, CAZyme domains=1-
# predicted domain= GT2
# resulting protein= -CazymeProteinPrediction, protein=ATY65626.1, CAZyme domains=1-
# predicted domain= CBM18
# predicted domain= GH18
# resulting protein= -CazymeProteinPrediction, protein=ATY65637.1, CAZyme domains=2-
# predicted domain= CE5
# resulting protein= -CazymeProteinPrediction, protein=ATY65665.1, CAZyme domains=1-
# predicted domain= PL7_4
# resulting protein= -CazymeProteinPrediction, protein=ATY65765.1, CAZyme domains=1-
# predicted domain= GH72
# resulting protein= -CazymeProteinPrediction, protein=ATY65808.1, CAZyme domains=1-
# predicted domain= GT90
# resulting protein= -CazymeProteinPrediction, protein=ATY65888.1, CAZyme domains=1-
# predicted domain= AA1
# resulting protein= -CazymeProteinPrediction, protein=ATY65896.1, CAZyme domains=1-
# predicted domain= GH3
# resulting protein= -CazymeProteinPrediction, protein=ATY66055.1, CAZyme domains=1-
# predicted domain= GT2
# resulting protein= -CazymeProteinPrediction, protein=ATY66192.1, CAZyme domains=1-
# predicted domain= GH32
# resulting protein= -CazymeProteinPrediction, protein=ATY66193.1, CAZyme domains=1-
# predicted domain= GT2
# resulting protein= -CazymeProteinPrediction, protein=ATY66259.1, CAZyme domains=1-
# predicted domain= GH18
# resulting protein= -CazymeProteinPrediction, protein=ATY66268.1, CAZyme domains=1-
# predicted domain= GH125
# resulting protein= -CazymeProteinPrediction, protein=ATY66363.1, CAZyme domains=1-
# predicted domain= GH114
# resulting protein= -CazymeProteinPrediction, protein=ATY66369.1, CAZyme domains=1-
# predicted domain= GH75
# resulting protein= -CazymeProteinPrediction, protein=ATY66426.1, CAZyme domains=1-
# predicted domain= CBM18
# predicted domain= GH18
# resulting protein= -CazymeProteinPrediction, protein=ATY66444.1, CAZyme domains=2-
# predicted domain= GH5_9
# resulting protein= -CazymeProteinPrediction, protein=ATY66476.1, CAZyme domains=1-
# predicted domain= GH16
# resulting protein= -CazymeProteinPrediction, protein=ATY66491.1, CAZyme domains=1-
# predicted domain= GT62
# resulting protein= -CazymeProteinPrediction, protein=ATY66509.1, CAZyme domains=1-
# predicted domain= CBM32
# predicted domain= GH65
# resulting protein= -CazymeProteinPrediction, protein=ATY66529.1, CAZyme domains=2-
# predicted domain= GH125
# resulting protein= -CazymeProteinPrediction, protein=ATY66542.1, CAZyme domains=1-
# predicted domain= GT8
# resulting protein= -CazymeProteinPrediction, protein=ATY66592.1, CAZyme domains=1-
# predicted domain= GT3
# resulting protein= -CazymeProteinPrediction, protein=ATY66603.1, CAZyme domains=1-
# predicted domain= GT90
# resulting protein= -CazymeProteinPrediction, protein=ATY66615.1, CAZyme domains=1-
# predicted domain= GT25
# resulting protein= -CazymeProteinPrediction, protein=ATY66624.1, CAZyme domains=1-
# predicted domain= GH2
# resulting protein= -CazymeProteinPrediction, protein=ATY66664.1, CAZyme domains=1-
# predicted domain= GH2
# resulting protein= -CazymeProteinPrediction, protein=ATY66787.1, CAZyme domains=1-
# predicted domain= GH92
# resulting protein= -CazymeProteinPrediction, protein=ATY66848.1, CAZyme domains=1-
# predicted domain= GT8
# resulting protein= -CazymeProteinPrediction, protein=ATY66859.1, CAZyme domains=1-
# predicted domain= CE9
# resulting protein= -CazymeProteinPrediction, protein=ATY66875.1, CAZyme domains=1-
# predicted domain= GH3
# resulting protein= -CazymeProteinPrediction, protein=ATY66876.1, CAZyme domains=1-
# predicted domain= GH5_27
# resulting protein= -CazymeProteinPrediction, protein=ATY67020.1, CAZyme domains=1-
# predicted domain= GH20
# resulting protein= -CazymeProteinPrediction, protein=ATY67094.1, CAZyme domains=1-
# predicted domain= AA3_2
# resulting protein= -CazymeProteinPrediction, protein=ATY67138.1, CAZyme domains=1-
# predicted domain= GH114
# resulting protein= -CazymeProteinPrediction, protein=ATY67182.1, CAZyme domains=1-
# predicted domain= GH18
# resulting protein= -CazymeProteinPrediction, protein=ATY67196.1, CAZyme domains=1-
# predicted domain= GH18
# resulting protein= -CazymeProteinPrediction, protein=ATY67226.1, CAZyme domains=1-
# predicted domain= GH17
# resulting protein= -CazymeProteinPrediction, protein=ATY67280.1, CAZyme domains=1-
# predicted domain= CBM48
# predicted domain= GH13_8
# resulting protein= -CazymeProteinPrediction, protein=ATY67289.1, CAZyme domains=2-
# predicted domain= GT20
# resulting protein= -CazymeProteinPrediction, protein=ATY67309.1, CAZyme domains=1-
# predicted domain= GT32
# resulting protein= -CazymeProteinPrediction, protein=ATY67327.1, CAZyme domains=1-
# predicted domain= GH36
# resulting protein= -CazymeProteinPrediction, protein=ATY67425.1, CAZyme domains=1-
# predicted domain= GT90
# resulting protein= -CazymeProteinPrediction, protein=ATY67467.1, CAZyme domains=1-
# predicted domain= GH29
# resulting protein= -CazymeProteinPrediction, protein=ATY67468.1, CAZyme domains=1-
# predicted domain= AA3_2
# resulting protein= -CazymeProteinPrediction, protein=ATY67472.1, CAZyme domains=1-
# predicted domain= GH0
# resulting protein= -CazymeProteinPrediction, protein=ATY63707.1, CAZyme domains=1-
# predicted domain= GH0
# resulting protein= -CazymeProteinPrediction, protein=ATY65793.1, CAZyme domains=1-
# predicted domain= GH0
# resulting protein= -CazymeProteinPrediction, protein=ATY62951.1, CAZyme domains=1-
# predicted domain= GH0
# resulting protein= -CazymeProteinPrediction, protein=ATY61188.1, CAZyme domains=1-
# predicted domain= GH0
# resulting protein= -CazymeProteinPrediction, protein=ATY62721.1, CAZyme domains=1-
# predicted domain= GH0
# resulting protein= -CazymeProteinPrediction, protein=ATY65605.1, CAZyme domains=1-
# predicted domain= GH17
# resulting protein= -CazymeProteinPrediction, protein=ATY67306.1, CAZyme domains=1-
# predicted domain= GH17
# resulting protein= -CazymeProteinPrediction, protein=ATY63087.1, CAZyme domains=1-
# predicted domain= CBM13
# predicted domain= GH27
# resulting protein= -CazymeProteinPrediction, protein=ATY64918.1, CAZyme domains=2-
# predicted domain= GH36
# resulting protein= -CazymeProteinPrediction, protein=ATY59702.1, CAZyme domains=1-
# predicted domain= AA1
# resulting protein= -CazymeProteinPrediction, protein=ATY65374.1, CAZyme domains=1-
# predicted domain= AA1
# resulting protein= -CazymeProteinPrediction, protein=ATY65915.1, CAZyme domains=1-
# predicted domain= AA1
# resulting protein= -CazymeProteinPrediction, protein=ATY64049.1, CAZyme domains=1-
# predicted domain= AA1
# resulting protein= -CazymeProteinPrediction, protein=ATY66872.1, CAZyme domains=1-
# predicted domain= GT31
# resulting protein= -CazymeProteinPrediction, protein=ATY66100.1, CAZyme domains=1-
# predicted domain= GT31
# resulting protein= -CazymeProteinPrediction, protein=ATY64941.1, CAZyme domains=1-
# predicted domain= GT31
# resulting protein= -CazymeProteinPrediction, protein=ATY59959.1, CAZyme domains=1-
# predicted domain= GT31
# resulting protein= -CazymeProteinPrediction, protein=ATY66131.1, CAZyme domains=1-
# predicted domain= GT31
# resulting protein= -CazymeProteinPrediction, protein=ATY60866.1, CAZyme domains=1-
# predicted domain= GT41
# resulting protein= -CazymeProteinPrediction, protein=ATY67037.1, CAZyme domains=1-
# predicted domain= GH18
# resulting protein= -CazymeProteinPrediction, protein=ATY61678.1, CAZyme domains=1-
# predicted domain= CBM20
# predicted domain= GH15
# resulting protein= -CazymeProteinPrediction, protein=ATY67205.1, CAZyme domains=2-
# predicted domain= GH6
# resulting protein= -CazymeProteinPrediction, protein=ATY67423.1, CAZyme domains=1-
# predicted domain= CBM50
# resulting protein= -CazymeProteinPrediction, protein=ATY67158.1, CAZyme domains=1-
# predicted domain= GH93
# resulting protein= -CazymeProteinPrediction, protein=ATY67142.1, CAZyme domains=1-
# predicted domain= GT2
# resulting protein= -CazymeProteinPrediction, protein=ATY66871.1, CAZyme domains=1-
# predicted domain= AA1
# resulting protein= -CazymeProteinPrediction, protein=ATY66532.1, CAZyme domains=1-
# predicted domain= GH18
# resulting protein= -CazymeProteinPrediction, protein=ATY66650.1, CAZyme domains=1-
# predicted domain= GH47
# resulting protein= -CazymeProteinPrediction, protein=ATY67063.1, CAZyme domains=1-
# predicted domain= GH37
# resulting protein= -CazymeProteinPrediction, protein=ATY66815.1, CAZyme domains=1-
# predicted domain= GH0
# resulting protein= -CazymeProteinPrediction, protein=ATY66513.1, CAZyme domains=1-
# predicted domain= GT2
# resulting protein= -CazymeProteinPrediction, protein=ATY66936.1, CAZyme domains=1-
# predicted domain= CBM50
# resulting protein= -CazymeProteinPrediction, protein=ATY66588.1, CAZyme domains=1-
# predicted domain= GH36
# resulting protein= -CazymeProteinPrediction, protein=ATY66605.1, CAZyme domains=1-
# predicted domain= GH0
# resulting protein= -CazymeProteinPrediction, protein=ATY65351.1, CAZyme domains=1-
# predicted domain= CBM48
# resulting protein= -CazymeProteinPrediction, protein=ATY66370.1, CAZyme domains=1-
# predicted domain= CE8
# resulting protein= -CazymeProteinPrediction, protein=ATY66292.1, CAZyme domains=1-
# predicted domain= GH72
# resulting protein= -CazymeProteinPrediction, protein=ATY65856.1, CAZyme domains=1-
# predicted domain= GH76
# resulting protein= -CazymeProteinPrediction, protein=ATY65614.1, CAZyme domains=1-
# predicted domain= CBM50
# resulting protein= -CazymeProteinPrediction, protein=ATY65640.1, CAZyme domains=1-
# predicted domain= GT95
# resulting protein= -CazymeProteinPrediction, protein=ATY65715.1, CAZyme domains=1-
# predicted domain= CBM13
# resulting protein= -CazymeProteinPrediction, protein=ATY65800.1, CAZyme domains=1-
# predicted domain= GH132
# resulting protein= -CazymeProteinPrediction, protein=ATY66201.1, CAZyme domains=1-
# predicted domain= CBM50
# resulting protein= -CazymeProteinPrediction, protein=ATY59704.1, CAZyme domains=1-
# predicted domain= GH43_29
# resulting protein= -CazymeProteinPrediction, protein=ATY58302.1, CAZyme domains=1-
# predicted domain= CE1
# resulting protein= -CazymeProteinPrediction, protein=ATY59753.1, CAZyme domains=1-
# predicted domain= GH19
# resulting protein= -CazymeProteinPrediction, protein=ATY59367.1, CAZyme domains=1-
# predicted domain= GH18
# resulting protein= -CazymeProteinPrediction, protein=ATY58953.1, CAZyme domains=1-
# predicted domain= GH6
# resulting protein= -CazymeProteinPrediction, protein=ATY58554.1, CAZyme domains=1-
# predicted domain= CE4
# resulting protein= -CazymeProteinPrediction, protein=ATY59000.1, CAZyme domains=1-
# predicted domain= GH78
# predicted domain= GH79
# resulting protein= -CazymeProteinPrediction, protein=ATY58522.1, CAZyme domains=2-
# predicted domain= GH18
# resulting protein= -CazymeProteinPrediction, protein=ATY59100.1, CAZyme domains=1-
# predicted domain= GT4
# resulting protein= -CazymeProteinPrediction, protein=ATY58615.1, CAZyme domains=1-
# predicted domain= CBM50
# resulting protein= -CazymeProteinPrediction, protein=ATY58749.1, CAZyme domains=1-
# predicted domain= GH20
# resulting protein= -CazymeProteinPrediction, protein=ATY64072.1, CAZyme domains=1-
# predicted domain= GT7
# resulting protein= -CazymeProteinPrediction, protein=ATY65221.1, CAZyme domains=1-
# predicted domain= CBM50
# resulting protein= -CazymeProteinPrediction, protein=ATY65222.1, CAZyme domains=1-
# predicted domain= GT31
# resulting protein= -CazymeProteinPrediction, protein=ATY64270.1, CAZyme domains=1-
# predicted domain= GH1
# predicted domain= GH95
# resulting protein= -CazymeProteinPrediction, protein=ATY63768.1, CAZyme domains=2-
# predicted domain= GH71
# resulting protein= -CazymeProteinPrediction, protein=ATY65096.1, CAZyme domains=1-
# predicted domain= CBM48
# predicted domain= GH13_8
# resulting protein= -CazymeProteinPrediction, protein=ATY65135.1, CAZyme domains=2-
# predicted domain= GT32
# resulting protein= -CazymeProteinPrediction, protein=ATY64613.1, CAZyme domains=1-
# predicted domain= GT15
# resulting protein= -CazymeProteinPrediction, protein=ATY63956.1, CAZyme domains=1-
# predicted domain= CBM48
# predicted domain= GH13_8
# resulting protein= -CazymeProteinPrediction, protein=ATY64438.1, CAZyme domains=2-
# predicted domain= GH2
# resulting protein= -CazymeProteinPrediction, protein=ATY63857.1, CAZyme domains=1-
# predicted domain= GT57
# resulting protein= -CazymeProteinPrediction, protein=ATY64414.1, CAZyme domains=1-
# predicted domain= CBM48
# predicted domain= GH13_8
# resulting protein= -CazymeProteinPrediction, protein=ATY64183.1, CAZyme domains=2-
# predicted domain= CBM50
# resulting protein= -CazymeProteinPrediction, protein=ATY64808.1, CAZyme domains=1-
# predicted domain= GH16
# resulting protein= -CazymeProteinPrediction, protein=ATY60156.1, CAZyme domains=1-
# predicted domain= GT2
# resulting protein= -CazymeProteinPrediction, protein=ATY61008.1, CAZyme domains=1-
# predicted domain= GT31
# resulting protein= -CazymeProteinPrediction, protein=ATY61113.1, CAZyme domains=1-
# predicted domain= AA1
# resulting protein= -CazymeProteinPrediction, protein=ATY60691.1, CAZyme domains=1-
# predicted domain= GH23
# resulting protein= -CazymeProteinPrediction, protein=ATY61197.1, CAZyme domains=1-
# predicted domain= GH71
# resulting protein= -CazymeProteinPrediction, protein=ATY60299.1, CAZyme domains=1-
# predicted domain= CBM50
# resulting protein= -CazymeProteinPrediction, protein=ATY60767.1, CAZyme domains=1-
# predicted domain= CBM18
# predicted domain= CBM50
# predicted domain= GH18
# resulting protein= -CazymeProteinPrediction, protein=ATY59795.1, CAZyme domains=3-
# predicted domain= GT22
# resulting protein= -CazymeProteinPrediction, protein=ATY60923.1, CAZyme domains=1-
# predicted domain= GT2
# resulting protein= -CazymeProteinPrediction, protein=ATY60283.1, CAZyme domains=1-
# predicted domain= GH78
# predicted domain= GH79
# resulting protein= -CazymeProteinPrediction, protein=ATY60286.1, CAZyme domains=2-
# predicted domain= GT0
# resulting protein= -CazymeProteinPrediction, protein=ATY61131.1, CAZyme domains=1-
# predicted domain= GT1
# resulting protein= -CazymeProteinPrediction, protein=ATY60572.1, CAZyme domains=1-
# predicted domain= GH0
# resulting protein= -CazymeProteinPrediction, protein=ATY62873.1, CAZyme domains=1-
# predicted domain= GT22
# resulting protein= -CazymeProteinPrediction, protein=ATY61476.1, CAZyme domains=1-
# predicted domain= CE8
# resulting protein= -CazymeProteinPrediction, protein=ATY63559.1, CAZyme domains=1-
# predicted domain= GH18
# resulting protein= -CazymeProteinPrediction, protein=ATY61542.1, CAZyme domains=1-
# predicted domain= GH20
# resulting protein= -CazymeProteinPrediction, protein=ATY62188.1, CAZyme domains=1-
# predicted domain= CBM50
# resulting protein= -CazymeProteinPrediction, protein=ATY62193.1, CAZyme domains=1-
# predicted domain= CBM43
# resulting protein= -CazymeProteinPrediction, protein=ATY62194.1, CAZyme domains=1-
# predicted domain= GH43_21
# resulting protein= -CazymeProteinPrediction, protein=ATY63571.1, CAZyme domains=1-
# predicted domain= CBM66
# predicted domain= GH43_34
# resulting protein= -CazymeProteinPrediction, protein=ATY62227.1, CAZyme domains=2-
# predicted domain= CBM13
# predicted domain= GT27
# resulting protein= -CazymeProteinPrediction, protein=ATY62896.1, CAZyme domains=2-
# predicted domain= CBM50
# resulting protein= -CazymeProteinPrediction, protein=ATY63166.1, CAZyme domains=1-
# predicted domain= GT30
# resulting protein= -CazymeProteinPrediction, protein=ATY62297.1, CAZyme domains=1-
# predicted domain= GT0
# resulting protein= -CazymeProteinPrediction, protein=ATY61491.1, CAZyme domains=1-
# predicted domain= GT7
# resulting protein= -CazymeProteinPrediction, protein=ATY62667.1, CAZyme domains=1-
# predicted domain= CBM48
# predicted domain= GH13_8
# resulting protein= -CazymeProteinPrediction, protein=ATY62782.1, CAZyme domains=2-
# predicted domain= GT0
# resulting protein= -CazymeProteinPrediction, protein=ATY62784.1, CAZyme domains=1-
# predicted domain= GT0
# resulting protein= -CazymeProteinPrediction, protein=ATY63618.1, CAZyme domains=1-
# predicted domain= GH18
# resulting protein= -CazymeProteinPrediction, protein=ATY63554.1, CAZyme domains=1-
# predicted domain= GH18
# resulting protein= -CazymeProteinPrediction, protein=ATY63408.1, CAZyme domains=1-
# predicted domain= CBM50
# resulting protein= -CazymeProteinPrediction, protein=ATY63733.1, CAZyme domains=1-
# predicted domain= CBM48
# predicted domain= GH13_8
# resulting protein= -CazymeProteinPrediction, protein=ATY61789.1, CAZyme domains=2-
# predicted domain= CBM50
# resulting protein= -CazymeProteinPrediction, protein=ATY61853.1, CAZyme domains=1-
# predicted domain= GT1
# resulting protein= -CazymeProteinPrediction, protein=ATY63072.1, CAZyme domains=1-
# predicted domain= CBM50
# resulting protein= -CazymeProteinPrediction, protein=ATY61716.1, CAZyme domains=1-
# predicted domain= GT1
# resulting protein= -CazymeProteinPrediction, protein=ATY62977.1, CAZyme domains=1-
#
# number of parsed proteins= 445

# %% [markdown]
# <a id="dbcan"></a>

# %% [markdown]
# ## dbCAN (consensus result)

# %% [markdown]
# The prediction result for consensus result of HMMER, DIAMOND, and Hotpep, where at least two of the tools agree upon the prediction, as  the practise of the dbCAN developers.
#
# The data from dbCAN includes:
# - The protein accession
# - CAZy family of each domain
# - CAZy subfamily of each domain (if not in a subfamily, the subfamily is listed as a null value)
#
# Rembering back to the investigation of the 'overview.txt' file earlier, each row contains:
# - the data for a unique protein
# - the prediction data from HMMER, Hotpep and DIAMOND
# - the number of tools that predicted the protein was a CAZymes
#
# Therefore, we can need to produce the dbCAN consensus result of the data in each row of the 'overview.txt' file to get the consensus dbCAN result for each protein.
#
# A consesnsus result is a result that the majoirty of tools agree upon, therefore, we can quickly filter for proteins with the consensus result that the protein is not a CAZyme by checking if the value of '#ofTools' is 1. If the value is 2 or 3, then we can check for a consensus results.
#
# Therefore, we we need to do is parse each line of the 'overview.txt' file one, and retrieve the HMMER, Hotpep, DIAMOND and dbCAN prediction, instead of how it has been layed out so far in this notebook (where the 'overview.txt' file is parsed each for HMMER, Hotpep and DIAMOND).
#
# The first task is to combine the wrok conducted so far in this notebook to createa series of function, which retrieve for each line in the 'overview.txt' file the HMMER, Hotpep and DIAMOND prediciton.

# %% [markdown]
# <a id="retrieve_hmmer_hotpep_diamond"></a>

# %% [markdown]
# ### Retrieving the HMMER, Hotpep and DIAMOND data for each line in the overview.txt file
#
# Below are a set of functions to parse each line of the overview.txt file, instead of having to parse the file for each CAZyme prediction tool (HMMER, Hotpep and DIAMOND).

# %%
def parse_dbcan_output(overview_path, hotpep_file):
    """Parse the data in the 'overview.txt' files from dbCAN.
    
    The 'overview.txt' file contains the CAZyme predicion data from
    HMMER, Hotpep and DIAMOND. A dbCAN consensus result is retrieved
    by finding predictions that at least to of the prediction tools
    agree upon.
    
    Each protein from the input FASTA file containing all query protein
    sequences parsed by dbCAN is represented by a CazymeProteinprediction
    instance. Each predicted CAZyme domains in each predicted CAZyme is
    represented by a CazymeDomain instance, which are sotred within their
    parent CAZyme's CazymeProteinPrediction instance. A CazymeProteinPrediction
    instance is created for each protein in the inpu FASTA file parsed
    by dbCAN and for each CAZyme prediction tool: dbCAN, HMMER, Hotpep and
    DIAMOND.
    
    :param overview_path: Path, path to dbCAN output overview.txt file
    :param hotpep_file: Path, path to Hotpep.out file
    
    Return 4 lists, each containing the CazymeProteinPrediction instances for
    HMMER, Hotpep, DIAMOND and dbCAN.
    """
    # open the overview.txt file
    with open(overview_path, "r") as ofh:
        overview_file = ofh.read().splitlines()
    
    # create an empty dictionary to store the CazymeProteinPrediction instances
    # {protein_accesion: CazymeProteinPrediction_instance}
    overview_dict = {}

    # skip the the first line in the file, becuase it contains the 'column' headings
    for line in tqdm(overview_file[1:], desc="Parsing overview.txt"):
        # separate the line content
        line = line.split("\t")
        
        protein_accession = line[0]
        
        # create a CazymeProteinPrediction instance each for HMMER, Hotpep and DIAMOND
        hmmer_prediction = get_hmmer_prediction(line[1], protein_accession)
        hotpep_prediction = get_hotpep_prediction(line[2], protein_accession)
        diamond_prediction = get_diamond_prediction(line[3], protein_accession)
        
        # get the dbCAN consensus result
        # dbcan_prediction = get_dbcan_consensus(hmmer_prediction, hotpep_prediction, diamond_prediction)
        
        # add the CazymeProteinPrediction instances to the overview_dict
        try:
            overview_dict[protein_accession]
            prediction_outputs = [["HMMER", hmmer_prediction], ["Hotpep", hotpep_prediction], ["DIAMOND", diamond_prediction], ["dbCAN", dbcan_prediction]]
            
            for prediction_tool in prediction_outputs:
                try:
                    overview_dict[protein_accession][prediction_tool[0]]
                    print(
                        f"WARNING -- Protein {protein_accession} already catalogued with {prediction_tool[0]}"
                    )
                except KeyError:  # raised if CazymeProteinPrediciton instance not stored for prediction_tool
                    overview_dict[protein_accession][prediction_tool[0]] = prediction_tool[1]
        
        except KeyError:  # raised if protein has not been added yet
            overview_dict[protein_accession] = {
                "HMMER": hmmer_prediction,
                "Hotpep": hotpep_prediction,
                "DIAMOND": diamond_prediction,
                "dbCAN": "dbcan_prediction",
            }
    
    # get EC numbers predicted by Hotpep
    overview_dict = get_hotpep_ec_numbers(overview_dict, hotpep_file)
    return overview_dict
        

def get_hmmer_prediction(hmmer_data, protein_accession):
    """Retrieve HMMER prediciton data from the dbCAN overview.txt file.
    
    :param hmmer_data: str, output data from HMMER written in the overview.txt file.
    :param protein_accession: str
    
    Return a CazymeProteinPrediction instance.
    """
    # check if the protein was classified as a non-CAZyme
    if hmmer_data == "-":
        cazyme_classification = 0  # non-CAZyme
        protein = CazymeProteinPrediction("HMMER", protein_accession, cazyme_classification)
        return protein
    
    # create a CazymeProteinPrediction instance to represent the CAZyme
    cazyme_classification = 1
    parent_cazyme = CazymeProteinPrediction("HMMER", protein_accession, cazyme_classification)

    # HMMER can predicted multiple CAZyme domaisn for a CAZyme
    # HMMER separates each of the predicted CAZyme domains by additiona symbols
    parent_cazyme.cazyme_domains = get_hmmer_cazyme_domains(hmmer_data.split("+"), protein_accession)
    
    return parent_cazyme

    
def get_hmmer_cazyme_domains(predicted_domains, protein_accession):
    """Retrieve the CAZyme domains predicted by HMMER.
    
    :param predicted_domains: list of strings, each string containing a CAZyme domain prediction
    :param protein_accession: str
    
    Return list of CazymeDomain instances. Each instance represents a unique CAZyme domain.
    """
    cazyme_domains = {}  # {"cazyfam-cazysubfam": CazymeDomain_instance}

    for domain in predicted_domains:
        # separate the predicted CAZy family from the domain range
        domain = domain.split("(")
        
        # get the predicted CAZy family(subfamily)
        domain_name = domain[0]  # CAZy (sub)family
        cazy_family, cazy_subfamily = get_hmmer_cazy_family(domain_name)
        
        if cazy_family is None:  # unexpected data format found by get_hmmer_cazy_family()
            continue
        
        # get the predicted amino acid domain range
        domain_range = domain[1][:-1]  # drop the terminal ")"
        # check it matches the expected format and thus is the predicted domain range
        try:
            re.match(r"\d+?-\d+", domain_range).group()
        except AttributeError:  # raised if not correct format
            print(
                f"WARNING -- UNKNOWN DATA TYPE OF {domain_range} FOR {protein_accession}\n"
                f"Not adding domain range for the domain {cazy_family}-{cazy_subfamily}"
            )
            domain_range = np.nan

        # create identifier for the CAZyme domain to check if it has already been catalogued
        domain_identifier = f"{cazy_family}-{cazy_subfamily}"
    
        # check if the CAZyme domain has already been cataglouged
        try:
            existing_domain = cazyme_domains[domain_identifier]

            # CAZyme domain already catalogued, check if the retrieved domain range is the same
            if domain_range not in existing_domain.domain_range:
                # append the new domain_range
                existing_domain.domain_range.append(domain_range)
                print("multiple domain ranges=", existing_domain, existing_domain.domain_range, protein_accession)

        except KeyError:  # raised if the CAZyme domain has not yet been catalogued
            cazyme_domains[domain_identifier] = CazymeDomain(
                prediction_tool="HMMER",
                protein_accession=protein_accession,
                cazy_family=cazy_family,
                cazy_subfamily=cazy_subfamily,
                domain_range=[domain_range],
            )

    return list(cazyme_domains.values())


def get_hmmer_cazy_family(domain_name):
    """Retrieve the name of the CAZyme domain, this is the predicted CAZy family and subfamily.
    
    If a subfamily is not predicted, the CAZy subfamily is set as a null value.
    If the data formate does not match the expected format, the CAZy family will
    be set by None, which will be used to not add the current working domain to
    the parent CazymeProteinPrediction instance.
    
    :param domain_name: str, contains the CAZy (sub)family
    
    Return two strings, the CAZy family and the CAZy subfamily.
    """
    # check if unusal CAZy family format or subfamily was given
    if domain_name.find("_") != -1:
        try:
            re.match(r"\D{2,3}\d+?_\D", domain_name).group()  # check unusal CAZy family formating
            cazy_family = domain_name[:domain_name.find("_")]
            cazy_subfamily = np.nan

        except AttributeError:  # raised if not an usual CAZy family format
            try:
                # check if its a CAZy subfamily
                re.match(r"\D{2,3}\d+?_\d+", domain_name).group()
                cazy_family = domain_name[:domain_name.find("_")]
                cazy_subfamily = np.nan

            except AttributeError:  # raised if it doesn't match the expected CAZy subfamily format
                print(
                    f"WARNING -- UNKNOWN DATA TYPE OF {domain_name} FOR {protein_accession}\n"
                    "Not adding as a domain."
                )
                return None, None

    else:
        # potentially have a CAZy family
        try:
            re.match(r"\D{2,3}\d+", domain_name).group()
            cazy_family = domain_name
            cazy_subfamily = np.nan

        except AttributeError:  # raised if doesn't match expected CAZy family
            print(
                f"WARNING -- UNKNOWN DATA TYPE OF {domain_name} FOR {protein_accession}\n"
                "Not adding as a domain."
            )
            return None, None
    
    return cazy_family, cazy_subfamily


def get_hotpep_prediction(hotpep_data, protein_accession):
    """Retrieve Hotpep prediciton data from the dbCAN overview.txt file.
    
    :param hmmer_data: str, output data from Hotpep written in the overview.txt file.
    :param protein_accession: str
    
    Return a CazymeProteinPrediction instance.
    """
    # check if the protein was classified as a non-CAZyme
    if hotpep_data == "-":
        cazyme_classification = 0  # non-CAZyme
        protein = CazymeProteinPrediction("Hotpep", protein_accession, cazyme_classification)
        return protein
    
    # create a CazymeProteinPrediction instance to represent the CAZyme
    cazyme_classification = 1
    parent_cazyme = CazymeProteinPrediction("Hotpep", protein_accession, cazyme_classification)

    # Hotpep can predicted multiple CAZyme domaisn for a CAZyme
    # Hotpep separates each of the predicted CAZyme domains by additiona symbols
    parent_cazyme.cazyme_domains = get_hotpep_cazyme_domains(hotpep_data.split("+"), protein_accession)
    
    return parent_cazyme


def get_hotpep_cazyme_domains(predicted_domains, protein_accession):
    """Retrieve the CAZyme domains predicted by Hotpep.
    
    :param predicted_domains: list of strings, each string containing a CAZyme domain prediction.
    
    Return list of CazymeDomain instances. Each instance represents a unique CAZyme domain.
    """
    cazyme_domains = []
    
    for domain in predicted_domains:
        # remove k-mer group number
        domain = domain.split("(")[0]
        
        # check if a CAZy subfamily was predicted
        if domain.find("_") != -1:  # found a CAZy subfamily
            try:
                # check if its a CAZy subfamily
                re.match(r"\D{2,3}\d+?_\d+", domain).group()
                cazy_family = domain[:domain.find("_")]
                cazy_subfamily = np.nan

            except AttributeError:  # raised if it doesn't match the expected CAZy subfamily format
                print(
                    f"WARNING -- UNKNOWN DATA TYPE OF {domain} FOR {protein_accession}\n"
                    "Not adding as a domain."
                )
                continue
        
        else:  # found a CAZy family
            try:  # check it is a CAZy family
                re.match(r"\D{2,3}\d+", domain).group()
                cazy_family = domain
                cazy_subfamily = np.nan

            except AttributeError:  # raised if doesn't match expected CAZy family
                print(
                    f"WARNING -- UNKNOWN DATA TYPE OF {domain} FOR {protein_accession}\n"
                    "Not adding as a domain."
                )
                continue
        
        domain = CazymeDomain("Hotpep", protein_accession, cazy_family, cazy_subfamily)
        cazyme_domains.append(domain)
    
    return cazyme_domains
        

def get_hotpep_ec_numbers(overview_dict, hotpep_file):
    """Retrieve EC numbers from the Hotpep.out file, and add them to the CAZyme domains.
    
    :param overview_dict: dict, keyed by protein accession, valued by dictionary of 
                            predicion_tool:CazymeDomain
    :param hotpep_file: Path, path to Hotpep.out file
    
    Return overview_dict
    """
    with open (hotpep_file, "r") as fh:
        hotpep_file_data = fh.read().splitlines()
    
    for line in tqdm(hotpep_file_data[1:], desc="Parsing Hotpep.out"):  # skip the first line containing headings
        # separate out the data
        line = line.split("\t")
        
        protein_accession = line[2].strip()
        
        # retrieve the EC numbers
        ec_numbers = line[-1]
        ec_numbers = ec_numbers.split(",")

        # strip any remaining white space becuase the separating comma
        # is sometimes followed by a space
        index = 0
        for index in range(len(ec_numbers)):
            ec_numbers[index] = ec_numbers[index].strip()
            # remove k-mer group number (EC:kmer_group#)
            ec_numbers[index] = ec_numbers[index].split(":")[0]
        
            if ec_numbers[index] == "NA":
                ec_numbers[index] = np.nan
        
        # get CAZy family and subfamily of the current working domain
        cazy_family = line[0]
        if cazy_family.find("_") != -1:
            cazy_subfamily = cazy_family
            cazy_family = cazy_family[:cazy_family.find("_")]
        else:
            cazy_subfamily = np.nan

        domain_identifer = [cazy_family, cazy_subfamily]
        
        parent_cazyme = overview_dict[protein_accession]["Hotpep"]
        parent_domains = parent_cazyme.cazyme_domains
        
        for domain in parent_domains:
            if domain_identifer == [domain.cazy_family, domain.cazy_subfamily]:
                domain.ec_numbers = ec_numbers
        
        parent_cazyme.cazyme_domains = parent_domains
        overview_dict[protein_accession]["Hotpep"] = parent_cazyme
        
    return overview_dict


def get_diamond_prediction(diamond_data, protein_accession):
    """Retrieve DIAMOND prediction data from dbCAN overview.txt file.
    
    :param diamond_data, str, output data from DIAMOND written in the overview.txt
    :param protein_accession, str
    
    Return a CazymeProteinPrediction instance.
    """
    # check if the protein was classified as a non-CAZyme
    if diamond_data == "-":
        cazyme_classification = 0  # non-CAZyme
        protein = CazymeProteinPrediction("DIAMOND", protein_accession, cazyme_classification)
        return protein
    
    # create a CazymeProteinPrediction instance to represent the CAZyme
    cazyme_classification = 1
    parent_cazyme = CazymeProteinPrediction("DIAMOND", protein_accession, cazyme_classification)
    
    # DIAMOND can predict multiple CAZyme domains per CAZyme, each domain is separated by '+'
    parent_cazyme.cazyme_domains = get_diamond_predicted_domains(diamond_data.split("+"), protein_accession)
 
    return parent_cazyme


def get_diamond_predicted_domains(predicted_domains, protein_accession):
    """Retrieve the CAZyme domains predicted by DIAMOND, from the overview.txt file.
    
    :param predicted_domains: list of strings, each string contains a unique CAZyme domain prediction
    :param protein_accession: str
    
    Return list of CazymeDomain instances, one instance per unique CAZyme domain.
    """
    cazyme_domains = []  # store CazymeDomain instances
    
    for predicted_domain in predicted_domains:
        # check if a subfamily was predicted
        try:
            re.match(r"\D{2,3}\d+?_\d+", predicted_domain).group()
            cazy_family = predicted_domain[:predicted_domain.find("_")]
            cazy_subfamily = predicted_domain
        
        except AttributeError:  # raised if predicted_domain is not a CAZy subfamily
            try:
                # check if a CAZy family was predicted
                re.match(r"\D{2,3}\d+", predicted_domain).group()
                cazy_family = predicted_domain
                cazy_subfamily = np.nan
            
            except AttributeError:  # raised if not a CAZy family
                print(
                    f"WARNING -- Unexpected data formate for '{predicted_domain}' for\n"
                    "DIAMOND in the overview.txt file. Not adding domain to the CAZyme."
                )
            continue
        
        new_domain = CazymeDomain("DIAMOND", protein_accession, cazy_family, cazy_subfamily)
        cazyme_domains.append(new_domain)
    
    return cazyme_domains
    
    parent_cazyme.cazyme_domains = cazyme_domains


overview_path = "overview.txt"
hotpep_file = "Hotpep.out"
overview_dict = parse_dbcan_output(overview_path, hotpep_file)
print("protein count =", len(list(overview_dict.keys())))
# Out:
# HBox(children=(HTML(value='Parsing overview.txt'), FloatProgress(value=0.0, max=445.0), HTML(value='')))
# multiple domain ranges= -CazymeDomain in ATY60367.1, fam=CBM66, subfam=nan- ['219-369', '388-547'] ATY60367.1
# multiple domain ranges= -CazymeDomain in ATY60416.1, fam=GT2, subfam=nan- ['230-398', '375-584'] ATY60416.1
# multiple domain ranges= -CazymeDomain in ATY63255.1, fam=GT57, subfam=nan- ['63-294', '333-565'] ATY63255.1
# multiple domain ranges= -CazymeDomain in ATY66192.1, fam=GT2, subfam=nan- ['487-649', '627-867'] ATY66192.1
# HBox(children=(HTML(value='Parsing Hotpep.out'), FloatProgress(value=0.0, max=320.0), HTML(value='')))
# protein count = 445

# %% [markdown]
# <a id="dbcan_con"></a>

# %% [markdown]
# ### Getting the dbCAN consensus
#
# The column '#ofTools' in the overview.txt file gives the number of tools (out of HMMER, Hotpep and DIAMOND). Therefore, we can quickly check if the consensus of dbCAN is that a protein is not a CAZyme by checking if the value in the '#ofTools' column is 1. The consensus result of dbCAN is the result that at least two of the tools agree upon.

# %%
# Open the overview.txt file
with open("overview.txt", "r") as ofh:
    overview_file = ofh.read().splitlines()

# check if the consensus results is that the protein is a non-CAZyme
for line in tqdm(overview_file[1:], desc="Parsing overview.txt"): # skip the the first line in the file, becuase it contains the 'column' headings
    # separate the line content
    line = line.split("\t")

    protein_accession = line[0]
    print("#ofTools=", line[-1])

    if line[-1] == "1":
        # non-CAZyme
        cazyme_classification = 0  # non-CAZyme
        protein = CazymeProteinPrediction("dbCAN", protein_accession, cazyme_classification)
        print(protein)
# Out:
# HBox(children=(HTML(value='Parsing overview.txt'), FloatProgress(value=0.0, max=445.0), HTML(value='')))
# #ofTools= 2
# #ofTools= 3
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY58395.1, non-CAZyme-
# #ofTools= 2
# #ofTools= 3
# #ofTools= 3
# #ofTools= 3
# #ofTools= 3
# #ofTools= 3
# #ofTools= 2
# #ofTools= 3
# #ofTools= 2
# #ofTools= 3
# #ofTools= 3
# #ofTools= 2
# #ofTools= 2
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY58653.1, non-CAZyme-
# #ofTools= 3
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY58687.1, non-CAZyme-
# #ofTools= 3
# #ofTools= 3
# #ofTools= 3
# #ofTools= 3
# #ofTools= 3
# #ofTools= 3
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY58910.1, non-CAZyme-
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY58915.1, non-CAZyme-
# #ofTools= 3
# #ofTools= 2
# #ofTools= 3
# #ofTools= 3
# #ofTools= 3
# #ofTools= 3
# #ofTools= 3
# #ofTools= 3
# #ofTools= 3
# #ofTools= 2
# #ofTools= 3
# #ofTools= 3
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY59524.1, non-CAZyme-
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY59596.1, non-CAZyme-
# #ofTools= 3
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY59663.1, non-CAZyme-
# #ofTools= 2
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY59673.1, non-CAZyme-
# #ofTools= 3
# #ofTools= 3
# #ofTools= 3
# #ofTools= 3
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY59728.1, non-CAZyme-
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY59756.1, non-CAZyme-
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY59775.1, non-CAZyme-
# #ofTools= 2
# #ofTools= 2
# #ofTools= 3
# #ofTools= 2
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY59918.1, non-CAZyme-
# #ofTools= 2
# #ofTools= 2
# #ofTools= 3
# #ofTools= 3
# #ofTools= 2
# #ofTools= 3
# #ofTools= 3
# #ofTools= 3
# #ofTools= 3
# #ofTools= 3
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY60187.1, non-CAZyme-
# #ofTools= 3
# #ofTools= 2
# #ofTools= 3
# #ofTools= 3
# #ofTools= 3
# #ofTools= 2
# #ofTools= 2
# #ofTools= 3
# #ofTools= 3
# #ofTools= 3
# #ofTools= 3
# #ofTools= 3
# #ofTools= 2
# #ofTools= 2
# #ofTools= 3
# #ofTools= 3
# #ofTools= 3
# #ofTools= 3
# #ofTools= 3
# #ofTools= 3
# #ofTools= 3
# #ofTools= 3
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY60734.1, non-CAZyme-
# #ofTools= 3
# #ofTools= 3
# #ofTools= 2
# #ofTools= 3
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY60943.1, non-CAZyme-
# #ofTools= 3
# #ofTools= 3
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY61013.1, non-CAZyme-
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY61023.1, non-CAZyme-
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY61046.1, non-CAZyme-
# #ofTools= 3
# #ofTools= 3
# #ofTools= 3
# #ofTools= 3
# #ofTools= 2
# #ofTools= 3
# #ofTools= 3
# #ofTools= 2
# #ofTools= 3
# #ofTools= 3
# #ofTools= 2
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY61486.1, non-CAZyme-
# #ofTools= 3
# #ofTools= 2
# #ofTools= 2
# #ofTools= 3
# #ofTools= 3
# #ofTools= 3
# #ofTools= 3
# #ofTools= 3
# #ofTools= 2
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY61822.1, non-CAZyme-
# #ofTools= 3
# #ofTools= 3
# #ofTools= 3
# #ofTools= 3
# #ofTools= 3
# #ofTools= 3
# #ofTools= 3
# #ofTools= 2
# #ofTools= 3
# #ofTools= 3
# #ofTools= 2
# #ofTools= 3
# #ofTools= 3
# #ofTools= 3
# #ofTools= 3
# #ofTools= 3
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY62050.1, non-CAZyme-
# #ofTools= 2
# #ofTools= 3
# #ofTools= 3
# #ofTools= 3
# #ofTools= 3
# #ofTools= 3
# #ofTools= 3
# #ofTools= 3
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY62231.1, non-CAZyme-
# #ofTools= 3
# #ofTools= 3
# #ofTools= 3
# #ofTools= 3
# #ofTools= 2
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY62287.1, non-CAZyme-
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY62309.1, non-CAZyme-
# #ofTools= 2
# #ofTools= 3
# #ofTools= 3
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY62433.1, non-CAZyme-
# #ofTools= 3
# #ofTools= 3
# #ofTools= 3
# #ofTools= 3
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY62592.1, non-CAZyme-
# #ofTools= 3
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY62660.1, non-CAZyme-
# #ofTools= 2
# #ofTools= 3
# #ofTools= 3
# #ofTools= 3
# #ofTools= 3
# #ofTools= 3
# #ofTools= 3
# #ofTools= 3
# #ofTools= 3
# #ofTools= 3
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY62900.1, non-CAZyme-
# #ofTools= 3
# #ofTools= 3
# #ofTools= 2
# #ofTools= 3
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY63199.1, non-CAZyme-
# #ofTools= 3
# #ofTools= 3
# #ofTools= 3
# #ofTools= 3
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY63301.1, non-CAZyme-
# #ofTools= 3
# #ofTools= 3
# #ofTools= 3
# #ofTools= 3
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY63375.1, non-CAZyme-
# #ofTools= 3
# #ofTools= 3
# #ofTools= 2
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY63517.1, non-CAZyme-
# #ofTools= 3
# #ofTools= 3
# #ofTools= 3
# #ofTools= 3
# #ofTools= 3
# #ofTools= 3
# #ofTools= 2
# #ofTools= 2
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY63786.1, non-CAZyme-
# #ofTools= 2
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY63886.1, non-CAZyme-
# #ofTools= 3
# #ofTools= 3
# #ofTools= 2
# #ofTools= 2
# #ofTools= 3
# #ofTools= 3
# #ofTools= 3
# #ofTools= 3
# #ofTools= 3
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY64050.1, non-CAZyme-
# #ofTools= 3
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY64132.1, non-CAZyme-
# #ofTools= 3
# #ofTools= 3
# #ofTools= 3
# #ofTools= 2
# #ofTools= 2
# #ofTools= 3
# #ofTools= 3
# #ofTools= 2
# #ofTools= 3
# #ofTools= 2
# #ofTools= 3
# #ofTools= 3
# #ofTools= 3
# #ofTools= 3
# #ofTools= 3
# #ofTools= 3
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY64579.1, non-CAZyme-
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY64630.1, non-CAZyme-
# #ofTools= 3
# #ofTools= 3
# #ofTools= 3
# #ofTools= 3
# #ofTools= 3
# #ofTools= 2
# #ofTools= 3
# #ofTools= 3
# #ofTools= 3
# #ofTools= 3
# #ofTools= 3
# #ofTools= 3
# #ofTools= 3
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY64989.1, non-CAZyme-
# #ofTools= 3
# #ofTools= 2
# #ofTools= 3
# #ofTools= 3
# #ofTools= 3
# #ofTools= 3
# #ofTools= 3
# #ofTools= 2
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY65188.1, non-CAZyme-
# #ofTools= 3
# #ofTools= 2
# #ofTools= 3
# #ofTools= 3
# #ofTools= 3
# #ofTools= 3
# #ofTools= 2
# #ofTools= 3
# #ofTools= 3
# #ofTools= 2
# #ofTools= 3
# #ofTools= 3
# #ofTools= 2
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY65674.1, non-CAZyme-
# #ofTools= 2
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY65728.1, non-CAZyme-
# #ofTools= 3
# #ofTools= 3
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY65886.1, non-CAZyme-
# #ofTools= 3
# #ofTools= 3
# #ofTools= 3
# #ofTools= 3
# #ofTools= 3
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY66198.1, non-CAZyme-
# #ofTools= 3
# #ofTools= 3
# #ofTools= 3
# #ofTools= 3
# #ofTools= 3
# #ofTools= 3
# #ofTools= 3
# #ofTools= 2
# #ofTools= 3
# #ofTools= 3
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY66531.1, non-CAZyme-
# #ofTools= 3
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY66551.1, non-CAZyme-
# #ofTools= 3
# #ofTools= 3
# #ofTools= 3
# #ofTools= 3
# #ofTools= 3
# #ofTools= 3
# #ofTools= 3
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY66850.1, non-CAZyme-
# #ofTools= 3
# #ofTools= 3
# #ofTools= 2
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY66975.1, non-CAZyme-
# #ofTools= 2
# #ofTools= 3
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY67122.1, non-CAZyme-
# #ofTools= 3
# #ofTools= 2
# #ofTools= 2
# #ofTools= 3
# #ofTools= 3
# #ofTools= 3
# #ofTools= 2
# #ofTools= 3
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY67358.1, non-CAZyme-
# #ofTools= 3
# #ofTools= 3
# #ofTools= 2
# #ofTools= 3
# #ofTools= 2
# #ofTools= 2
# #ofTools= 2
# #ofTools= 2
# #ofTools= 2
# #ofTools= 2
# #ofTools= 2
# #ofTools= 2
# #ofTools= 2
# #ofTools= 2
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY58696.1, non-CAZyme-
# #ofTools= 2
# #ofTools= 2
# #ofTools= 2
# #ofTools= 2
# #ofTools= 2
# #ofTools= 2
# #ofTools= 2
# #ofTools= 2
# #ofTools= 2
# #ofTools= 2
# #ofTools= 2
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY58989.1, non-CAZyme-
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY60723.1, non-CAZyme-
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY59222.1, non-CAZyme-
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY66389.1, non-CAZyme-
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY67114.1, non-CAZyme-
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY64357.1, non-CAZyme-
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY59304.1, non-CAZyme-
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY59125.1, non-CAZyme-
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY64151.1, non-CAZyme-
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY60075.1, non-CAZyme-
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY59281.1, non-CAZyme-
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY67205.1, non-CAZyme-
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY67423.1, non-CAZyme-
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY67158.1, non-CAZyme-
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY67142.1, non-CAZyme-
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY66871.1, non-CAZyme-
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY66532.1, non-CAZyme-
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY66650.1, non-CAZyme-
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY67063.1, non-CAZyme-
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY66815.1, non-CAZyme-
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY66513.1, non-CAZyme-
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY66936.1, non-CAZyme-
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY66588.1, non-CAZyme-
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY66605.1, non-CAZyme-
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY65351.1, non-CAZyme-
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY66370.1, non-CAZyme-
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY66292.1, non-CAZyme-
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY65856.1, non-CAZyme-
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY65614.1, non-CAZyme-
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY65640.1, non-CAZyme-
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY65715.1, non-CAZyme-
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY65800.1, non-CAZyme-
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY66201.1, non-CAZyme-
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY59704.1, non-CAZyme-
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY58302.1, non-CAZyme-
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY59753.1, non-CAZyme-
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY59367.1, non-CAZyme-
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY58953.1, non-CAZyme-
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY58554.1, non-CAZyme-
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY59000.1, non-CAZyme-
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY58522.1, non-CAZyme-
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY59100.1, non-CAZyme-
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY58615.1, non-CAZyme-
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY58749.1, non-CAZyme-
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY64072.1, non-CAZyme-
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY65221.1, non-CAZyme-
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY65222.1, non-CAZyme-
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY64270.1, non-CAZyme-
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY63768.1, non-CAZyme-
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY65096.1, non-CAZyme-
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY65135.1, non-CAZyme-
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY64613.1, non-CAZyme-
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY63956.1, non-CAZyme-
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY64438.1, non-CAZyme-
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY63857.1, non-CAZyme-
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY64414.1, non-CAZyme-
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY64183.1, non-CAZyme-
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY64808.1, non-CAZyme-
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY60156.1, non-CAZyme-
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY61008.1, non-CAZyme-
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY61113.1, non-CAZyme-
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY60691.1, non-CAZyme-
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY61197.1, non-CAZyme-
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY60299.1, non-CAZyme-
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY60767.1, non-CAZyme-
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY59795.1, non-CAZyme-
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY60923.1, non-CAZyme-
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY60283.1, non-CAZyme-
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY60286.1, non-CAZyme-
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY61131.1, non-CAZyme-
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY60572.1, non-CAZyme-
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY62873.1, non-CAZyme-
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY61476.1, non-CAZyme-
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY63559.1, non-CAZyme-
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY61542.1, non-CAZyme-
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY62188.1, non-CAZyme-
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY62193.1, non-CAZyme-
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY62194.1, non-CAZyme-
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY63571.1, non-CAZyme-
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY62227.1, non-CAZyme-
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY62896.1, non-CAZyme-
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY63166.1, non-CAZyme-
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY62297.1, non-CAZyme-
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY61491.1, non-CAZyme-
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY62667.1, non-CAZyme-
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY62782.1, non-CAZyme-
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY62784.1, non-CAZyme-
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY63618.1, non-CAZyme-
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY63554.1, non-CAZyme-
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY63408.1, non-CAZyme-
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY63733.1, non-CAZyme-
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY61789.1, non-CAZyme-
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY61853.1, non-CAZyme-
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY63072.1, non-CAZyme-
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY61716.1, non-CAZyme-
# #ofTools= 1
# -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-

# %% [markdown]
# So the code handles proteins with the consensus prediction of non-CAZyme, but it does not get the consensus CAZyme domain (CAZy family and subfamily) prediction for each protein predicted to be a CAZyme.
#
# To save having to reparse the HMMER, Hotpep and DIAMOND data from current working like from the overview.txt file (remebering each line contains a unique protein, therefore, the current working line == the current working protein), we can parse the `CazymeProteinPrediction` instances representing the protein prediction each for HMMER, Hotpep and DIAMOND.
#
# Each `CazymeProteinPrediciton` instance contains a list of `CazymeDomain` instances, which each contain a CAZy family and subfamily. We can create a `set()` of strings, with each string representing a unique `CazymeDomain` instance (`CazyFam_CazySubfam`). This is because sets cannot contain duplicate entries, therefore, we can use this to check for duplicate entries between the predicted CAZyme domains. Additionally, the `&` operator can be used to find only those elements between multiple sets that are located in all sets.
#
# Using the `&` between three sets will find elements that are present in all three lists. Lets see a practical example. We can create three lists, `a`, `b` and `c`. '4' is common to all 3 lists, but '1' and '8' are common to only 2 of the 3 lists each.

# %%
a = [1,2,3,4]
b = [1,4,8,9]
c = [4,7,6,8]
consensus_a_b_c = list(set(a) & set(b) & set(c))
consensus_a_b_c
# Out:
# [4]

# %% [markdown]
# Above we can see that we have the element, '4', which is common to all 3 lists: `a`, `b` and `c`.
#
# However, we are defining the consensus result of dbCaN being any result that at least two of the prediction tools agree upon. Therefore, we need to compare each of the pairs of prediction tools to find elements that are predicted by at least 2 of the tools. This is the same as comparing:
# - `a` and `b`
# - `b` and `c`
# - `a` and `c`

# %%
a = [1,2,3,4]
b = [1,4,8,9]
c = [4,7,6,8]
consensus_a_b_c = list(set(a) & set(b) & set(c))
consensus_a_b = list(set(a) & set(b))
consensus_b_c = list(set(b) & set(c))
consensus_a_c = list(set(a) & set(c))
print("elements in all three lists =", consensus_a_b_c)
print("elements in a and b =", consensus_a_b)
print("elements in b and c =", consensus_b_c)
print("elements in a and c =", consensus_a_c)
# Out:
# elements in all three lists = [4]
# elements in a and b = [1, 4]
# elements in b and c = [8, 4]
# elements in a and c = [4]

# %% [markdown]
# Each CAZyme domain in the list of CAZyme domains needs to be a string. If a CAZyme domain was represented by a list (`[cazy_family, cazy_subfamily]`) would raise a `TypeError: unhashable type: 'list'` when trying to create a set from a list of CAZyme domains.

# %%
def parse_dbcan_output(overview_path, hotpep_file):
    """Parse the data in the 'overview.txt' files from dbCAN.
    
    The 'overview.txt' file contains the CAZyme predicion data from
    HMMER, Hotpep and DIAMOND. A dbCAN consensus result is retrieved
    by finding predictions that at least to of the prediction tools
    agree upon.
    
    Each protein from the input FASTA file containing all query protein
    sequences parsed by dbCAN is represented by a CazymeProteinprediction
    instance. Each predicted CAZyme domains in each predicted CAZyme is
    represented by a CazymeDomain instance, which are sotred within their
    parent CAZyme's CazymeProteinPrediction instance. A CazymeProteinPrediction
    instance is created for each protein in the inpu FASTA file parsed
    by dbCAN and for each CAZyme prediction tool: dbCAN, HMMER, Hotpep and
    DIAMOND.
    
    :param overview_path: Path, path to dbCAN output overview.txt file
    :param hotpep_file: Path, path to Hotpep.out file
    
    Return 4 lists, each containing the CazymeProteinPrediction instances for
    HMMER, Hotpep, DIAMOND and dbCAN.
    """
    # open the overview.txt file
    with open(overview_path, "r") as ofh:
        overview_file = ofh.read().splitlines()
    
    # create an empty dictionary to store the CazymeProteinPrediction instances
    # {protein_accesion: CazymeProteinPrediction_instance}
    overview_dict = {}

    # skip the the first line in the file, becuase it contains the 'column' headings
    for line in tqdm(overview_file[1:], desc="Parsing overview.txt"):
        # separate the line content
        line = line.split("\t")
        
        protein_accession = line[0]
        
        # create a CazymeProteinPrediction instance each for HMMER, Hotpep and DIAMOND
        hmmer_prediction = get_hmmer_prediction(line[1], protein_accession)
        hotpep_prediction = get_hotpep_prediction(line[2], protein_accession)
        diamond_prediction = get_diamond_prediction(line[3], protein_accession)
        
        # get the dbCAN consensus result
        dbcan_prediction = get_dbcan_consensus(hmmer_prediction, hotpep_prediction, diamond_prediction, protein_accession, line[-1])
        
        # add the CazymeProteinPrediction instances to the overview_dict
        try:
            overview_dict[protein_accession]
            prediction_outputs = [["HMMER", hmmer_prediction], ["Hotpep", hotpep_prediction], ["DIAMOND", diamond_prediction], ["dbCAN", dbcan_prediction]]
            
            for prediction_tool in prediction_outputs:
                try:
                    overview_dict[protein_accession][prediction_tool[0]]
                    print(
                        f"WARNING -- Protein {protein_accession} already catalogued with {prediction_tool[0]}"
                    )
                except KeyError:  # raised if CazymeProteinPrediciton instance not stored for prediction_tool
                    overview_dict[protein_accession][prediction_tool[0]] = prediction_tool[1]
        
        except KeyError:  # raised if protein has not been added yet
            overview_dict[protein_accession] = {
                "HMMER": hmmer_prediction,
                "Hotpep": hotpep_prediction,
                "DIAMOND": diamond_prediction,
                "dbCAN": "dbcan_prediction",
            }
    
    # get EC numbers predicted by Hotpep
    overview_dict = get_hotpep_ec_numbers(overview_dict, hotpep_file)
    return overview_dict
        

def get_dbcan_consensus(hmmer_prediction, hotpep_prediction, diamond_prediction, protein_prediction, no_of_tools):
    """Retrieve the consensus CAZyme and CAZyme domain prediction for dbCAN.
    
    Consensus is defined as a result that at least two of the tools (HMMER, Hotpep and DIAMOND)
    agree upon.
    
    :param hmmer_prediction: CazymeProteinPrediction instance containing the HMMER prediction
    :param hotpep_prediction: CazymeProteinPrediction instance containing the Hotpep prediction
    :param diamond_prediction: CazymeProteinPrediction instance containing the DIAMOND prediction
    :param protein_accession: str
    :param no_of_tools: str, data from the '#ofTools' column from the overview.txt file, it states
        the number of tools that list the protein as a CAZyme
    
    Return CazymeProteinPrediction instance to represent the dbCAN consensus prediction
    """
    # first check if the consensus was that the protein was a non-CAZyme
    if no_of_tools == "1":
        # non-CAZyme
        cazyme_classification = 0  # non-CAZyme
        protein = CazymeProteinPrediction("dbCAN", protein_accession, cazyme_classification)
        print("non_cazyme= ", protein)
        return protein
    
    # get the consensus CAZyme domain predicitons
    
    # first get each of the predicted CAZyme domains for each tool
    print(protein_accession)
    hmmer_domains = get_dbcan_cazyme_domains(hmmer_prediction)
    print("hmmer=", hmmer_domains)
    hotpep_domains = get_dbcan_cazyme_domains(hotpep_prediction)
    print("hotpep=", hotpep_domains)
    diamond_domains = get_dbcan_cazyme_domains(diamond_prediction)
    print("diamond=", diamond_domains)


def get_dbcan_cazyme_domains(cazyme_prediction):
    """Retrieve the predicted CAZyme domains, representing each domains as a string 'fam_subfam'.
    
    :param cazyme_prediction: CazymeProteinPrediction instance.
    
    Return a list of strings with each string representing a single predicted CAZyme domain.
    """
    cazyme_domain_instances = cazyme_prediction.cazyme_domains
    
    cazyme_domains = []  # store list representing CAZyme domains [fam(str), subfam(str)]
    
    # if a prediction tool predicts a protein is a non_CAZyme, non_cazymes == np.nan (a float)
    if type(cazyme_domain_instances) is not float:
        for domain in cazyme_domain_instances:
            cazy_family = domain.cazy_family
            cazy_subfamily = domain.cazy_subfamily
            cazyme_domains.append(f"{cazy_family}_{cazy_subfamily}")
    
    return cazyme_domains


overview_path = "overview.txt"
hotpep_file = "Hotpep.out"
overview_dict = parse_dbcan_output(overview_path, hotpep_file)
print("protein count =", len(list(overview_dict.keys())))
# Out:
# HBox(children=(HTML(value='Parsing overview.txt'), FloatProgress(value=0.0, max=445.0), HTML(value='')))
# ATY62977.1
# hmmer= ['CE5_nan']
# hotpep= []
# diamond= []
# ATY62977.1
# hmmer= ['AA11_nan']
# hotpep= ['AA11_nan']
# diamond= []
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# ATY62977.1
# hmmer= ['AA6_nan']
# hotpep= ['AA6_nan']
# diamond= []
# ATY62977.1
# hmmer= ['AA3_nan']
# hotpep= ['AA3_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GH16_nan']
# hotpep= ['GH16_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GH18_nan']
# hotpep= ['GH18_nan', 'CBM1_nan', 'CBM19_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GH5_nan']
# hotpep= ['GH5_nan']
# diamond= ['GH5_GH5_24']
# ATY62977.1
# hmmer= ['GH55_nan']
# hotpep= ['GH55_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GH16_nan']
# hotpep= []
# diamond= []
# ATY62977.1
# hmmer= ['GH64_nan']
# hotpep= ['GH64_nan', 'CBM6_nan']
# diamond= []
# ATY62977.1
# hmmer= ['CE5_nan']
# hotpep= []
# diamond= []
# ATY62977.1
# hmmer= ['GH76_nan']
# hotpep= ['GH76_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GH38_nan']
# hotpep= ['GH38_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GT2_nan']
# hotpep= []
# diamond= []
# ATY62977.1
# hmmer= ['GH12_nan']
# hotpep= []
# diamond= []
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# ATY62977.1
# hmmer= ['GH75_nan']
# hotpep= ['GH75_nan']
# diamond= []
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# ATY62977.1
# hmmer= ['GH29_nan']
# hotpep= ['GH29_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GT66_nan']
# hotpep= ['GT66_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GH18_nan']
# hotpep= ['GH18_nan', 'CBM12_nan', 'CBM16_nan', 'CBM5_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GH1_nan']
# hotpep= ['GH1_nan']
# diamond= []
# ATY62977.1
# hmmer= ['AA3_nan']
# hotpep= ['AA3_nan']
# diamond= ['AA3_AA3_1']
# ATY62977.1
# hmmer= ['AA3_nan']
# hotpep= ['AA3_nan']
# diamond= ['AA3_AA3_3']
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# ATY62977.1
# hmmer= ['GH16_nan']
# hotpep= ['GH16_nan']
# diamond= []
# ATY62977.1
# hmmer= ['CE5_nan']
# hotpep= []
# diamond= []
# ATY62977.1
# hmmer= ['GH18_nan']
# hotpep= ['GH18_nan', 'CBM18_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GH13_nan']
# hotpep= ['GH13_nan', 'CBM20_nan']
# diamond= ['GH13_GH13_5']
# ATY62977.1
# hmmer= ['GH81_nan']
# hotpep= ['GH81_nan', 'CBM6_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GH18_nan']
# hotpep= ['GH18_nan', 'CBM18_nan', 'CBM5_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GT90_nan']
# hotpep= ['GT90_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GH18_nan', 'CBM66_nan']
# hotpep= ['GH18_nan', 'CBM18_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GH72_nan']
# hotpep= ['GH72_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GT90_nan']
# hotpep= []
# diamond= []
# ATY62977.1
# hmmer= ['GT15_nan']
# hotpep= ['GT15_nan']
# diamond= []
# ATY62977.1
# hmmer= ['AA12_nan']
# hotpep= ['AA12_nan']
# diamond= []
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# ATY62977.1
# hmmer= ['GT21_nan']
# hotpep= ['GT21_nan']
# diamond= []
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# ATY62977.1
# hmmer= ['CE4_nan']
# hotpep= []
# diamond= []
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# ATY62977.1
# hmmer= ['AA1_nan']
# hotpep= ['AA1_nan']
# diamond= ['AA1_AA1_2']
# ATY62977.1
# hmmer= ['GT1_nan']
# hotpep= ['GT1_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GH54_nan', 'CBM42_nan']
# hotpep= ['GH54_nan', 'CBM13_nan', 'CBM42_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GT4_nan']
# hotpep= ['GT4_nan']
# diamond= []
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# ATY62977.1
# hmmer= ['GT1_nan']
# hotpep= []
# diamond= []
# ATY62977.1
# hmmer= ['AA3_nan']
# hotpep= []
# diamond= ['AA3_AA3_1']
# ATY62977.1
# hmmer= ['GH43_nan', 'CBM66_nan']
# hotpep= ['GH43_nan', 'CBM66_nan']
# diamond= ['GH43_GH43_34']
# ATY62977.1
# hmmer= ['AA3_nan']
# hotpep= []
# diamond= ['AA3_AA3_2']
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# ATY62977.1
# hmmer= ['GT2_nan']
# hotpep= []
# diamond= []
# ATY62977.1
# hmmer= ['GH128_nan']
# hotpep= []
# diamond= []
# ATY62977.1
# hmmer= ['GH47_nan']
# hotpep= ['GH47_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GT2_nan']
# hotpep= ['GT2_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GH16_nan']
# hotpep= []
# diamond= []
# ATY62977.1
# hmmer= ['GT17_nan']
# hotpep= ['GT17_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GH55_nan']
# hotpep= ['GH0_nan', 'GH55_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GT4_nan']
# hotpep= ['GT4_nan']
# diamond= []
# ATY62977.1
# hmmer= ['AA1_nan']
# hotpep= ['AA1_nan']
# diamond= ['AA1_AA1_3']
# ATY62977.1
# hmmer= ['AA11_nan']
# hotpep= ['AA11_nan']
# diamond= []
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# ATY62977.1
# hmmer= ['GT22_nan']
# hotpep= ['GT22_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GH16_nan']
# hotpep= []
# diamond= []
# ATY62977.1
# hmmer= ['AA5_nan']
# hotpep= ['AA5_nan']
# diamond= ['AA5_AA5_1']
# ATY62977.1
# hmmer= ['GT4_nan']
# hotpep= ['GT4_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GH92_nan']
# hotpep= ['GH92_nan']
# diamond= []
# multiple domain ranges= -CazymeDomain in ATY60367.1, fam=CBM66, subfam=nan- ['219-369', '388-547'] ATY60367.1
# ATY62977.1
# hmmer= ['CBM66_nan']
# hotpep= []
# diamond= []
# ATY62977.1
# hmmer= ['GH16_nan']
# hotpep= []
# diamond= []
# ATY62977.1
# hmmer= ['GH152_nan']
# hotpep= ['GH152_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GH76_nan']
# hotpep= ['GH76_nan']
# diamond= []
# multiple domain ranges= -CazymeDomain in ATY60416.1, fam=GT2, subfam=nan- ['230-398', '375-584'] ATY60416.1
# ATY62977.1
# hmmer= ['GT2_nan']
# hotpep= ['GT2_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GH31_nan']
# hotpep= ['GH31_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GH18_nan']
# hotpep= ['CBM18_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GH55_nan']
# hotpep= []
# diamond= []
# ATY62977.1
# hmmer= ['PL35_nan']
# hotpep= []
# diamond= []
# ATY62977.1
# hmmer= ['GH2_nan']
# hotpep= ['GH2_nan', 'CBM51_nan', 'CBM67_nan']
# diamond= []
# ATY62977.1
# hmmer= ['AA1_nan']
# hotpep= ['AA1_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GH142_nan', 'CBM13_nan']
# hotpep= ['GH142_nan', 'CBM13_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GH76_nan']
# hotpep= ['GH76_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GH47_nan']
# hotpep= ['GH47_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GH16_nan']
# hotpep= ['GH16_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GH84_nan']
# hotpep= ['GH84_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GH76_nan']
# hotpep= ['GH76_nan']
# diamond= []
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# ATY62977.1
# hmmer= ['AA11_nan']
# hotpep= ['AA11_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GH20_nan']
# hotpep= ['GH20_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GH135_nan']
# hotpep= []
# diamond= []
# ATY62977.1
# hmmer= ['GT2_nan']
# hotpep= ['GT2_nan']
# diamond= []
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# ATY62977.1
# hmmer= ['GT34_nan']
# hotpep= ['GT34_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GH16_nan']
# hotpep= ['GH16_nan']
# diamond= []
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# ATY62977.1
# hmmer= ['GH18_nan']
# hotpep= ['GH18_nan', 'CBM18_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GT64_nan']
# hotpep= ['GT64_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GH3_nan']
# hotpep= ['GH3_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GH89_nan']
# hotpep= ['GH89_nan']
# diamond= []
# ATY62977.1
# hmmer= ['CE1_nan']
# hotpep= []
# diamond= []
# ATY62977.1
# hmmer= ['GH18_nan']
# hotpep= ['GH18_nan', 'CBM1_nan', 'CBM19_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GH13_nan']
# hotpep= ['GH133_nan']
# diamond= ['GH13_GH13_25']
# ATY62977.1
# hmmer= ['AA7_nan']
# hotpep= []
# diamond= []
# ATY62977.1
# hmmer= ['GH16_nan']
# hotpep= ['GH16_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GT69_nan']
# hotpep= ['GT69_nan']
# diamond= []
# ATY62977.1
# hmmer= ['PL20_nan']
# hotpep= []
# diamond= []
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# ATY62977.1
# hmmer= ['GH31_nan']
# hotpep= ['GH31_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GT2_nan']
# hotpep= []
# diamond= []
# ATY62977.1
# hmmer= ['GH79_nan']
# hotpep= []
# diamond= []
# ATY62977.1
# hmmer= ['AA3_nan']
# hotpep= ['AA3_nan']
# diamond= ['AA3_AA3_2']
# ATY62977.1
# hmmer= ['GH18_nan']
# hotpep= ['GH18_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GH18_nan']
# hotpep= ['GH18_nan', 'CBM18_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GT2_nan']
# hotpep= ['GT2_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GT20_nan']
# hotpep= ['GT20_nan', 'CBM20_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GH16_nan']
# hotpep= []
# diamond= []
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# ATY62977.1
# hmmer= ['GH16_nan']
# hotpep= ['GH16_nan', 'CBM18_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GH16_nan']
# hotpep= ['GH16_nan', 'CBM4_nan', 'CBM54_nan', 'CBM6_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GT2_nan']
# hotpep= ['GT0_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GH15_nan']
# hotpep= ['GH15_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GH18_nan']
# hotpep= ['GH18_nan', 'CBM18_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GT59_nan']
# hotpep= ['GT59_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GT15_nan']
# hotpep= ['GT15_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GH18_nan']
# hotpep= []
# diamond= []
# ATY62977.1
# hmmer= ['GH72_nan']
# hotpep= ['GH72_nan', 'CBM43_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GH2_nan']
# hotpep= ['GH2_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GH16_nan']
# hotpep= []
# diamond= []
# ATY62977.1
# hmmer= ['GT22_nan']
# hotpep= ['GT22_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GH13_nan']
# hotpep= ['GH13_nan']
# diamond= ['GH13_GH13_40']
# ATY62977.1
# hmmer= ['GT39_nan']
# hotpep= ['GT39_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GH47_nan']
# hotpep= ['GH47_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GH5_nan']
# hotpep= ['GH5_nan']
# diamond= ['GH5_GH5_11']
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# ATY62977.1
# hmmer= ['GT32_nan']
# hotpep= []
# diamond= []
# ATY62977.1
# hmmer= ['GH132_nan']
# hotpep= ['GH132_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GT22_nan']
# hotpep= ['GT22_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GH5_nan']
# hotpep= ['GH5_nan']
# diamond= ['GH5_GH5_5']
# ATY62977.1
# hmmer= ['GH76_nan']
# hotpep= ['GH0_nan', 'GH76_nan']
# diamond= []
# ATY62977.1
# hmmer= ['AA12_nan']
# hotpep= ['AA12_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GT39_nan']
# hotpep= ['GT39_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GH13_nan']
# hotpep= ['GH13_nan']
# diamond= ['GH13_GH13_40']
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# ATY62977.1
# hmmer= ['AA3_nan']
# hotpep= ['AA3_nan']
# diamond= ['AA3_AA3_2']
# ATY62977.1
# hmmer= ['GT22_nan']
# hotpep= ['GT22_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GT50_nan']
# hotpep= ['GT50_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GH3_nan']
# hotpep= ['GH3_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GT25_nan']
# hotpep= []
# diamond= []
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# ATY62977.1
# hmmer= ['GH136_nan']
# hotpep= []
# diamond= []
# ATY62977.1
# hmmer= ['GH20_nan']
# hotpep= ['GH20_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GT1_nan']
# hotpep= ['GT1_nan']
# diamond= []
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# ATY62977.1
# hmmer= ['GH3_nan']
# hotpep= ['GH3_nan', 'CBM1_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GT58_nan']
# hotpep= ['GT58_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GH15_nan', 'CBM20_nan']
# hotpep= ['GH15_nan', 'CBM20_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GH5_nan']
# hotpep= ['GH5_nan']
# diamond= ['GH5_GH5_15']
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# ATY62977.1
# hmmer= ['GT20_nan']
# hotpep= ['GT20_nan', 'CBM20_nan']
# diamond= []
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# ATY62977.1
# hmmer= ['GT2_nan']
# hotpep= []
# diamond= []
# ATY62977.1
# hmmer= ['GH16_nan']
# hotpep= ['GH16_nan', 'CBM4_nan', 'CBM54_nan', 'CBM6_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GT2_nan']
# hotpep= ['GT0_nan']
# diamond= []
# ATY62977.1
# hmmer= ['CE3_nan']
# hotpep= ['CE3_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GH154_nan']
# hotpep= ['GH154_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GH88_nan']
# hotpep= ['GH88_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GH47_nan']
# hotpep= ['GH47_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GH3_nan']
# hotpep= ['GH3_nan', 'CBM6_nan']
# diamond= []
# ATY62977.1
# hmmer= ['AA3_nan']
# hotpep= ['AA3_nan']
# diamond= ['AA3_AA3_2']
# ATY62977.1
# hmmer= ['AA9_nan']
# hotpep= ['AA9_nan', 'CBM18_nan']
# diamond= []
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# ATY62977.1
# hmmer= ['GH64_nan']
# hotpep= ['GH64_nan', 'CBM6_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GT15_nan']
# hotpep= ['GT15_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GH16_nan']
# hotpep= []
# diamond= []
# ATY62977.1
# hmmer= ['GH18_nan']
# hotpep= ['GH18_nan', 'CBM12_nan', 'CBM2_nan']
# diamond= []
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# ATY62977.1
# hmmer= ['GT69_nan']
# hotpep= ['GT69_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GT71_nan']
# hotpep= ['GT71_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GH63_nan']
# hotpep= ['GH63_nan']
# diamond= []
# multiple domain ranges= -CazymeDomain in ATY63255.1, fam=GT57, subfam=nan- ['63-294', '333-565'] ATY63255.1
# ATY62977.1
# hmmer= ['GT57_nan']
# hotpep= ['GT57_nan']
# diamond= []
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# ATY62977.1
# hmmer= ['GH3_nan']
# hotpep= ['GH3_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GH35_nan']
# hotpep= ['GH35_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GT90_nan']
# hotpep= ['GT90_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GT39_nan']
# hotpep= ['GT39_nan']
# diamond= []
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# ATY62977.1
# hmmer= ['GH16_nan']
# hotpep= ['CBM10_nan', 'CBM2_nan', 'CBM5_nan']
# diamond= []
# ATY62977.1
# hmmer= ['CE4_nan']
# hotpep= ['CE4_nan', 'CBM18_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GH18_nan']
# hotpep= []
# diamond= []
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# ATY62977.1
# hmmer= ['AA11_nan']
# hotpep= ['AA11_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GH18_nan']
# hotpep= ['GH18_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GH3_nan']
# hotpep= ['GH3_nan', 'CBM1_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GH79_nan']
# hotpep= ['GH79_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GT17_nan']
# hotpep= ['GT17_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GH37_nan']
# hotpep= ['GH37_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GT1_nan']
# hotpep= []
# diamond= []
# ATY62977.1
# hmmer= ['GT1_nan']
# hotpep= []
# diamond= []
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# ATY62977.1
# hmmer= ['GH55_nan']
# hotpep= []
# diamond= []
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# ATY62977.1
# hmmer= ['GT35_nan']
# hotpep= ['GT35_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GH92_nan']
# hotpep= ['GH92_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GT1_nan']
# hotpep= []
# diamond= []
# ATY62977.1
# hmmer= ['GH128_nan']
# hotpep= []
# diamond= []
# ATY62977.1
# hmmer= ['GT34_nan']
# hotpep= ['GT34_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GH55_nan']
# hotpep= ['GH55_nan']
# diamond= []
# ATY62977.1
# hmmer= ['AA3_nan']
# hotpep= ['AA3_nan']
# diamond= ['AA3_AA3_2']
# ATY62977.1
# hmmer= ['GH63_nan']
# hotpep= ['GH0_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GH31_nan']
# hotpep= ['GH31_nan']
# diamond= []
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# ATY62977.1
# hmmer= ['GH89_nan']
# hotpep= ['GH89_nan']
# diamond= []
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# ATY62977.1
# hmmer= ['GH55_nan']
# hotpep= ['GH55_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GH72_nan']
# hotpep= ['GH72_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GT90_nan']
# hotpep= ['GT90_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GH16_nan']
# hotpep= []
# diamond= []
# ATY62977.1
# hmmer= ['GT69_nan']
# hotpep= []
# diamond= []
# ATY62977.1
# hmmer= ['GT17_nan']
# hotpep= ['GT17_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GH72_nan']
# hotpep= ['GH72_nan', 'CBM43_nan']
# diamond= []
# ATY62977.1
# hmmer= ['PL8_nan']
# hotpep= []
# diamond= ['PL8_PL8_4']
# ATY62977.1
# hmmer= ['GT57_nan']
# hotpep= ['GT57_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GT4_nan']
# hotpep= []
# diamond= []
# ATY62977.1
# hmmer= ['GT33_nan']
# hotpep= ['GT33_nan']
# diamond= []
# ATY62977.1
# hmmer= ['AA3_nan']
# hotpep= ['AA3_nan']
# diamond= ['AA3_AA3_2']
# ATY62977.1
# hmmer= ['GH3_nan']
# hotpep= ['GH3_nan', 'CBM1_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GH76_nan']
# hotpep= ['GH76_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GH2_nan']
# hotpep= ['GH2_nan', 'CBM42_nan', 'CBM67_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GH92_nan']
# hotpep= ['GH92_nan']
# diamond= []
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# ATY62977.1
# hmmer= ['GH2_nan']
# hotpep= ['GH2_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GH18_nan']
# hotpep= ['GH18_nan', 'CBM18_nan', 'CBM2_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GH55_nan']
# hotpep= ['GH55_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GH5_nan']
# hotpep= ['GH5_nan']
# diamond= ['GH5_GH5_12']
# ATY62977.1
# hmmer= ['GT24_nan']
# hotpep= ['GT24_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GH18_nan']
# hotpep= []
# diamond= []
# ATY62977.1
# hmmer= ['GT20_nan']
# hotpep= ['GT20_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GH17_nan']
# hotpep= ['GH17_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GT48_nan']
# hotpep= ['GT48_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GH35_nan']
# hotpep= ['GH35_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GH47_nan']
# hotpep= ['GH47_nan']
# diamond= []
# ATY62977.1
# hmmer= ['CE4_nan']
# hotpep= ['CE4_nan', 'CBM18_nan']
# diamond= []
# ATY62977.1
# hmmer= ['AA7_nan']
# hotpep= ['AA7_nan', 'CBM18_nan']
# diamond= []
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# ATY62977.1
# hmmer= ['CBM21_nan']
# hotpep= ['CBM21_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GT2_nan']
# hotpep= []
# diamond= []
# ATY62977.1
# hmmer= ['AA1_nan']
# hotpep= ['AA1_nan']
# diamond= ['AA1_AA1_3']
# ATY62977.1
# hmmer= ['CE5_nan']
# hotpep= ['CE5_nan']
# diamond= []
# ATY62977.1
# hmmer= ['CE16_nan']
# hotpep= ['CE16_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GH47_nan']
# hotpep= ['GH47_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GH17_nan']
# hotpep= ['GH17_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GH16_nan']
# hotpep= []
# diamond= []
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# ATY62977.1
# hmmer= ['GH128_nan']
# hotpep= ['GH128_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GH79_nan']
# hotpep= []
# diamond= []
# ATY62977.1
# hmmer= ['GH18_nan']
# hotpep= ['GH18_nan', 'CBM18_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GH76_nan']
# hotpep= ['GH76_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GH76_nan']
# hotpep= ['GH76_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GT62_nan']
# hotpep= ['GT62_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GH28_nan']
# hotpep= []
# diamond= []
# ATY62977.1
# hmmer= ['GH76_nan']
# hotpep= ['GH76_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GT76_nan']
# hotpep= ['GT76_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GH128_nan']
# hotpep= []
# diamond= []
# ATY62977.1
# hmmer= ['GT2_nan']
# hotpep= ['GT2_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GH18_nan']
# hotpep= ['GH18_nan', 'CBM18_nan']
# diamond= []
# ATY62977.1
# hmmer= ['CE5_nan']
# hotpep= []
# diamond= []
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# ATY62977.1
# hmmer= ['GH25_nan']
# hotpep= ['GH25_nan']
# diamond= []
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# ATY62977.1
# hmmer= ['PL7_nan']
# hotpep= ['PL7_nan']
# diamond= ['PL7_PL7_4']
# ATY62977.1
# hmmer= ['GH72_nan']
# hotpep= ['GH72_nan']
# diamond= []
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# ATY62977.1
# hmmer= ['GT90_nan']
# hotpep= ['GT90_nan']
# diamond= []
# ATY62977.1
# hmmer= ['AA1_nan']
# hotpep= ['AA1_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GH3_nan']
# hotpep= ['GH3_nan', 'CBM1_nan']
# diamond= []
# multiple domain ranges= -CazymeDomain in ATY66192.1, fam=GT2, subfam=nan- ['487-649', '627-867'] ATY66192.1
# ATY62977.1
# hmmer= ['GT2_nan']
# hotpep= ['GT2_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GH32_nan']
# hotpep= ['GH32_nan']
# diamond= []
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# ATY62977.1
# hmmer= ['GT2_nan']
# hotpep= ['GT2_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GH18_nan']
# hotpep= ['GH18_nan', 'CBM12_nan', 'CBM16_nan', 'CBM5_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GH125_nan']
# hotpep= ['GH125_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GH114_nan']
# hotpep= ['GH114_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GH75_nan']
# hotpep= ['GH75_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GH18_nan']
# hotpep= ['GH18_nan', 'CBM18_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GH5_nan']
# hotpep= ['GH5_nan']
# diamond= ['GH5_GH5_9']
# ATY62977.1
# hmmer= ['GH16_nan']
# hotpep= []
# diamond= []
# ATY62977.1
# hmmer= ['GT62_nan']
# hotpep= ['GT62_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GH65_nan']
# hotpep= ['GH65_nan', 'CBM32_nan']
# diamond= []
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# ATY62977.1
# hmmer= ['GH125_nan']
# hotpep= ['GH125_nan']
# diamond= []
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# ATY62977.1
# hmmer= ['GT8_nan']
# hotpep= ['GT8_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GT3_nan']
# hotpep= ['GT3_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GT90_nan']
# hotpep= ['GT90_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GT25_nan']
# hotpep= ['GT25_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GH2_nan']
# hotpep= ['GH2_nan', 'CBM51_nan', 'CBM67_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GH2_nan']
# hotpep= ['GH2_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GH92_nan']
# hotpep= ['GH92_nan']
# diamond= []
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# ATY62977.1
# hmmer= ['GT8_nan']
# hotpep= ['GT8_nan']
# diamond= []
# ATY62977.1
# hmmer= ['CE9_nan']
# hotpep= ['CE9_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GH3_nan']
# hotpep= []
# diamond= []
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# ATY62977.1
# hmmer= ['GH5_nan']
# hotpep= []
# diamond= ['GH5_GH5_27']
# ATY62977.1
# hmmer= ['GH20_nan']
# hotpep= ['GH20_nan']
# diamond= []
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# ATY62977.1
# hmmer= ['AA3_nan']
# hotpep= ['AA3_nan']
# diamond= ['AA3_AA3_2']
# ATY62977.1
# hmmer= ['GH114_nan']
# hotpep= []
# diamond= []
# ATY62977.1
# hmmer= ['GH18_nan']
# hotpep= []
# diamond= []
# ATY62977.1
# hmmer= ['GH18_nan']
# hotpep= ['GH18_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GH17_nan']
# hotpep= ['GH17_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GH13_nan']
# hotpep= ['GH13_nan', 'CBM48_nan']
# diamond= ['GH13_GH13_8']
# ATY62977.1
# hmmer= ['GT20_nan']
# hotpep= []
# diamond= []
# ATY62977.1
# hmmer= ['GT32_nan']
# hotpep= ['GT32_nan']
# diamond= []
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# ATY62977.1
# hmmer= ['GH36_nan']
# hotpep= ['GH36_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GT90_nan']
# hotpep= ['GT90_nan']
# diamond= []
# ATY62977.1
# hmmer= ['GH29_nan']
# hotpep= []
# diamond= []
# ATY62977.1
# hmmer= ['AA3_nan']
# hotpep= ['AA3_nan']
# diamond= ['AA3_AA3_2']
# ATY62977.1
# hmmer= []
# hotpep= ['GH0_nan']
# diamond= []
# ATY62977.1
# hmmer= []
# hotpep= ['GH0_nan']
# diamond= []
# ATY62977.1
# hmmer= []
# hotpep= ['GH0_nan']
# diamond= []
# ATY62977.1
# hmmer= []
# hotpep= ['GH0_nan']
# diamond= []
# ATY62977.1
# hmmer= []
# hotpep= ['GH0_nan']
# diamond= []
# ATY62977.1
# hmmer= []
# hotpep= ['GH0_nan']
# diamond= []
# ATY62977.1
# hmmer= []
# hotpep= ['GH17_nan']
# diamond= []
# ATY62977.1
# hmmer= []
# hotpep= ['GH17_nan']
# diamond= []
# ATY62977.1
# hmmer= []
# hotpep= ['GH27_nan']
# diamond= []
# ATY62977.1
# hmmer= []
# hotpep= ['GH36_nan']
# diamond= []
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# ATY62977.1
# hmmer= []
# hotpep= ['AA1_nan']
# diamond= []
# ATY62977.1
# hmmer= []
# hotpep= ['AA1_nan']
# diamond= []
# ATY62977.1
# hmmer= []
# hotpep= ['AA1_nan']
# diamond= []
# ATY62977.1
# hmmer= []
# hotpep= ['AA1_nan']
# diamond= []
# ATY62977.1
# hmmer= []
# hotpep= ['GT31_nan']
# diamond= []
# ATY62977.1
# hmmer= []
# hotpep= ['GT31_nan']
# diamond= []
# ATY62977.1
# hmmer= []
# hotpep= ['GT31_nan']
# diamond= []
# ATY62977.1
# hmmer= []
# hotpep= ['GT31_nan']
# diamond= []
# ATY62977.1
# hmmer= []
# hotpep= ['GT31_nan']
# diamond= []
# ATY62977.1
# hmmer= []
# hotpep= ['GT41_nan']
# diamond= []
# ATY62977.1
# hmmer= []
# hotpep= ['CBM10_nan', 'CBM2_nan']
# diamond= []
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# HBox(children=(HTML(value='Parsing Hotpep.out'), FloatProgress(value=0.0, max=320.0), HTML(value='')))
# protein count = 445

# %% [markdown]
# From the printed statements above we can see the method retrieves a list of strings, with each string representing a unique CAZyme domain.
#
# Now we can add a method to find the consensus (where at least 2 prediction tools agree) between each od the predicted CAZyme domains.

# %%
def parse_dbcan_output(overview_path, hotpep_file):
    """Parse the data in the 'overview.txt' files from dbCAN.
    
    The 'overview.txt' file contains the CAZyme predicion data from
    HMMER, Hotpep and DIAMOND. A dbCAN consensus result is retrieved
    by finding predictions that at least to of the prediction tools
    agree upon.
    
    Each protein from the input FASTA file containing all query protein
    sequences parsed by dbCAN is represented by a CazymeProteinprediction
    instance. Each predicted CAZyme domains in each predicted CAZyme is
    represented by a CazymeDomain instance, which are sotred within their
    parent CAZyme's CazymeProteinPrediction instance. A CazymeProteinPrediction
    instance is created for each protein in the inpu FASTA file parsed
    by dbCAN and for each CAZyme prediction tool: dbCAN, HMMER, Hotpep and
    DIAMOND.
    
    :param overview_path: Path, path to dbCAN output overview.txt file
    :param hotpep_file: Path, path to Hotpep.out file
    
    Return 4 lists, each containing the CazymeProteinPrediction instances for
    HMMER, Hotpep, DIAMOND and dbCAN.
    """
    # open the overview.txt file
    with open(overview_path, "r") as ofh:
        overview_file = ofh.read().splitlines()
    
    # create an empty dictionary to store the CazymeProteinPrediction instances
    # {protein_accesion: CazymeProteinPrediction_instance}
    overview_dict = {}

    # skip the the first line in the file, becuase it contains the 'column' headings
    for line in tqdm(overview_file[1:], desc="Parsing overview.txt"):
        # separate the line content
        line = line.split("\t")
        
        protein_accession = line[0]
        
        # create a CazymeProteinPrediction instance each for HMMER, Hotpep and DIAMOND
        hmmer_prediction = get_hmmer_prediction(line[1], protein_accession)
        hotpep_prediction = get_hotpep_prediction(line[2], protein_accession)
        diamond_prediction = get_diamond_prediction(line[3], protein_accession)
        
        # get the dbCAN consensus result
        dbcan_prediction = get_dbcan_consensus(hmmer_prediction, hotpep_prediction, diamond_prediction, protein_accession, line[-1])
        
        # add the CazymeProteinPrediction instances to the overview_dict
        try:
            overview_dict[protein_accession]
            prediction_outputs = [["HMMER", hmmer_prediction], ["Hotpep", hotpep_prediction], ["DIAMOND", diamond_prediction], ["dbCAN", dbcan_prediction]]
            
            for prediction_tool in prediction_outputs:
                try:
                    overview_dict[protein_accession][prediction_tool[0]]
                    print(
                        f"WARNING -- Protein {protein_accession} already catalogued with {prediction_tool[0]}"
                    )
                except KeyError:  # raised if CazymeProteinPrediciton instance not stored for prediction_tool
                    overview_dict[protein_accession][prediction_tool[0]] = prediction_tool[1]
        
        except KeyError:  # raised if protein has not been added yet
            overview_dict[protein_accession] = {
                "HMMER": hmmer_prediction,
                "Hotpep": hotpep_prediction,
                "DIAMOND": diamond_prediction,
                "dbCAN": dbcan_prediction,
            }
    
    # get EC numbers predicted by Hotpep
    overview_dict = get_hotpep_ec_numbers(overview_dict, hotpep_file)
    return overview_dict
        

def get_dbcan_consensus(hmmer_prediction, hotpep_prediction, diamond_prediction, protein_prediction, no_of_tools):
    """Retrieve the consensus CAZyme and CAZyme domain prediction for dbCAN.
    
    Consensus is defined as a result that at least two of the tools (HMMER, Hotpep and DIAMOND)
    agree upon.
    
    :param hmmer_prediction: CazymeProteinPrediction instance containing the HMMER prediction
    :param hotpep_prediction: CazymeProteinPrediction instance containing the Hotpep prediction
    :param diamond_prediction: CazymeProteinPrediction instance containing the DIAMOND prediction
    :param protein_accession: str
    :param no_of_tools: str, data from the '#ofTools' column from the overview.txt file, it states
        the number of tools that list the protein as a CAZyme
    
    Return CazymeProteinPrediction instance to represent the dbCAN consensus prediction
    """
    # first check if the consensus was that the protein was a non-CAZyme
    if no_of_tools == "1":
        # non-CAZyme
        cazyme_classification = 0  # non-CAZyme
        protein = CazymeProteinPrediction("dbCAN", protein_accession, cazyme_classification)
        print("non_cazyme= ", protein)
        return protein
    
    # get the consensus CAZyme domain predicitons
    
    # first get each of the predicted CAZyme domains for each tool
    hmmer_domains = get_cazyme_domains(hmmer_prediction)
    hotpep_domains = get_cazyme_domains(hotpep_prediction)
    diamond_domains = get_cazyme_domains(diamond_prediction)
    
    print("PROTEIN_ACCESSION=", protein_accession)
    # get the predicted CAZyme domains that are predicted by at two tools
    hmmer_hotpep_consensus = list(set(hmmer_domains) & set(hotpep_domains))
    hotpep_diamond_consensus = list(set(hotpep_domains) & set(diamond_domains))
    hmmer_diamond_consensus = list(set(hmmer_domains) & set(diamond_domains))
    print("hmmer=", hmmer_domains)
    print("hotpep=", hotpep_domains)
    print("diamond=", diamond_domains)
    print("hmmer-hotpep=", hmmer_hotpep_consensus)
    print("hotpep_diamond=", hotpep_diamond_consensus)
    print("hmmer_diamond=", hmmer_diamond_consensus)

    # get the CAZyme domains predicted by all prediction tools
    all_consensus = list(set(hmmer_domains) & set(hotpep_domains) & set(diamond_domains))
    print("all=", all_consensus)

    # combine all consensus results
    combined_consensus = (
        hmmer_hotpep_consensus + hotpep_diamond_consensus + hmmer_diamond_consensus + all_consensus
    )
    # remove duplicate entries
    combined_consensus = list(set(combined_consensus))
    
    # create a CazymeProteinPrediction instance to represent the CAZyme
    cazyme_classification = 1  # CAZyme
    parent_cazyme = CazymeProteinPrediction("dbCAN", protein_accession, cazyme_classification)
    
    # create a CazymeDomain instance for each domain
    cazyme_domains = []  # store CazymeDomain instances
    for domain in combined_consensus:
        domain = domain.split("**")
        cazy_family = domain[0]

        if domain[1] == "nan":
            cazy_subfamily = np.nan
        else:
            cazy_subfamily = domain[1]

        new_domain = CazymeDomain("dbCAN", protein_accession, cazy_family, cazy_subfamily)

        cazyme_domains.append(new_domain)
    
    # add predicted CAZyme domains to the instance representing the CAZyme
    parent_cazyme.cazyme_domains = cazyme_domains
    print("domains=", cazyme_domains)
    print("========================================================================")
    
    return parent_cazyme
    
    
def get_cazyme_domains(cazyme_prediction):
    """Retrieve the predicted CAZyme domains, representing each domains as a string 'fam_subfam'.
    
    :param cazyme_prediction: CazymeProteinPrediction instance.
    
    Return a list of strings with each string representing a single predicted CAZyme domain.
    """
    cazyme_domain_instances = cazyme_prediction.cazyme_domains
    
    cazyme_domains = []  # store list representing CAZyme domains [fam(str), subfam(str)]
    
    # if a prediction tool predicts a protein is a non_CAZyme, non_cazymes == np.nan (a float)
    if type(cazyme_domain_instances) is not float:
        for domain in cazyme_domain_instances:
            cazy_family = domain.cazy_family
            cazy_subfamily = domain.cazy_subfamily
            # separate the family and subfamily '**' becuase these do not appear in the either
            cazyme_domains.append(f"{cazy_family}**{cazy_subfamily}")
    
    return cazyme_domains


overview_path = "overview.txt"
hotpep_file = "Hotpep.out"
overview_dict = parse_dbcan_output(overview_path, hotpep_file)
print("protein count =", len(list(overview_dict.keys())))
# Out:
# HBox(children=(HTML(value='Parsing overview.txt'), FloatProgress(value=0.0, max=445.0), HTML(value='')))
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['CE5**nan']
# hotpep= []
# diamond= []
# hmmer-hotpep= []
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= []
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['AA11**nan']
# hotpep= ['AA11**nan']
# diamond= []
# hmmer-hotpep= ['AA11**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=AA11, subfam=nan>]
# ========================================================================
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['AA6**nan']
# hotpep= ['AA6**nan']
# diamond= []
# hmmer-hotpep= ['AA6**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=AA6, subfam=nan>]
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['AA3**nan']
# hotpep= ['AA3**nan']
# diamond= []
# hmmer-hotpep= ['AA3**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=AA3, subfam=nan>]
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GH16**nan']
# hotpep= ['GH16**nan']
# diamond= []
# hmmer-hotpep= ['GH16**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=GH16, subfam=nan>]
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GH18**nan']
# hotpep= ['GH18**nan', 'CBM1**nan', 'CBM19**nan']
# diamond= []
# hmmer-hotpep= ['GH18**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=GH18, subfam=nan>]
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GH5**nan']
# hotpep= ['GH5**nan']
# diamond= ['GH5**GH5_24']
# hmmer-hotpep= ['GH5**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=GH5, subfam=nan>]
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GH55**nan']
# hotpep= ['GH55**nan']
# diamond= []
# hmmer-hotpep= ['GH55**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=GH55, subfam=nan>]
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GH16**nan']
# hotpep= []
# diamond= []
# hmmer-hotpep= []
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= []
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GH64**nan']
# hotpep= ['GH64**nan', 'CBM6**nan']
# diamond= []
# hmmer-hotpep= ['GH64**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=GH64, subfam=nan>]
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['CE5**nan']
# hotpep= []
# diamond= []
# hmmer-hotpep= []
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= []
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GH76**nan']
# hotpep= ['GH76**nan']
# diamond= []
# hmmer-hotpep= ['GH76**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=GH76, subfam=nan>]
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GH38**nan']
# hotpep= ['GH38**nan']
# diamond= []
# hmmer-hotpep= ['GH38**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=GH38, subfam=nan>]
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GT2**nan']
# hotpep= []
# diamond= []
# hmmer-hotpep= []
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= []
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GH12**nan']
# hotpep= []
# diamond= []
# hmmer-hotpep= []
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= []
# ========================================================================
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GH75**nan']
# hotpep= ['GH75**nan']
# diamond= []
# hmmer-hotpep= ['GH75**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=GH75, subfam=nan>]
# ========================================================================
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GH29**nan']
# hotpep= ['GH29**nan']
# diamond= []
# hmmer-hotpep= ['GH29**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=GH29, subfam=nan>]
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GT66**nan']
# hotpep= ['GT66**nan']
# diamond= []
# hmmer-hotpep= ['GT66**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=GT66, subfam=nan>]
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GH18**nan']
# hotpep= ['GH18**nan', 'CBM12**nan', 'CBM16**nan', 'CBM5**nan']
# diamond= []
# hmmer-hotpep= ['GH18**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=GH18, subfam=nan>]
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GH1**nan']
# hotpep= ['GH1**nan']
# diamond= []
# hmmer-hotpep= ['GH1**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=GH1, subfam=nan>]
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['AA3**nan']
# hotpep= ['AA3**nan']
# diamond= ['AA3**AA3_1']
# hmmer-hotpep= ['AA3**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=AA3, subfam=nan>]
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['AA3**nan']
# hotpep= ['AA3**nan']
# diamond= ['AA3**AA3_3']
# hmmer-hotpep= ['AA3**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=AA3, subfam=nan>]
# ========================================================================
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GH16**nan']
# hotpep= ['GH16**nan']
# diamond= []
# hmmer-hotpep= ['GH16**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=GH16, subfam=nan>]
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['CE5**nan']
# hotpep= []
# diamond= []
# hmmer-hotpep= []
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= []
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GH18**nan']
# hotpep= ['GH18**nan', 'CBM18**nan']
# diamond= []
# hmmer-hotpep= ['GH18**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=GH18, subfam=nan>]
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GH13**nan']
# hotpep= ['GH13**nan', 'CBM20**nan']
# diamond= ['GH13**GH13_5']
# hmmer-hotpep= ['GH13**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=GH13, subfam=nan>]
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GH81**nan']
# hotpep= ['GH81**nan', 'CBM6**nan']
# diamond= []
# hmmer-hotpep= ['GH81**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=GH81, subfam=nan>]
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GH18**nan']
# hotpep= ['GH18**nan', 'CBM18**nan', 'CBM5**nan']
# diamond= []
# hmmer-hotpep= ['GH18**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=GH18, subfam=nan>]
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GT90**nan']
# hotpep= ['GT90**nan']
# diamond= []
# hmmer-hotpep= ['GT90**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=GT90, subfam=nan>]
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GH18**nan', 'CBM66**nan']
# hotpep= ['GH18**nan', 'CBM18**nan']
# diamond= []
# hmmer-hotpep= ['GH18**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=GH18, subfam=nan>]
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GH72**nan']
# hotpep= ['GH72**nan']
# diamond= []
# hmmer-hotpep= ['GH72**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=GH72, subfam=nan>]
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GT90**nan']
# hotpep= []
# diamond= []
# hmmer-hotpep= []
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= []
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GT15**nan']
# hotpep= ['GT15**nan']
# diamond= []
# hmmer-hotpep= ['GT15**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=GT15, subfam=nan>]
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['AA12**nan']
# hotpep= ['AA12**nan']
# diamond= []
# hmmer-hotpep= ['AA12**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=AA12, subfam=nan>]
# ========================================================================
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GT21**nan']
# hotpep= ['GT21**nan']
# diamond= []
# hmmer-hotpep= ['GT21**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=GT21, subfam=nan>]
# ========================================================================
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['CE4**nan']
# hotpep= []
# diamond= []
# hmmer-hotpep= []
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= []
# ========================================================================
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['AA1**nan']
# hotpep= ['AA1**nan']
# diamond= ['AA1**AA1_2']
# hmmer-hotpep= ['AA1**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=AA1, subfam=nan>]
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GT1**nan']
# hotpep= ['GT1**nan']
# diamond= []
# hmmer-hotpep= ['GT1**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=GT1, subfam=nan>]
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GH54**nan', 'CBM42**nan']
# hotpep= ['GH54**nan', 'CBM13**nan', 'CBM42**nan']
# diamond= []
# hmmer-hotpep= ['CBM42**nan', 'GH54**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=CBM42, subfam=nan>, <CazymeDomain parent=ATY62977.1 fam=GH54, subfam=nan>]
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GT4**nan']
# hotpep= ['GT4**nan']
# diamond= []
# hmmer-hotpep= ['GT4**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=GT4, subfam=nan>]
# ========================================================================
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GT1**nan']
# hotpep= []
# diamond= []
# hmmer-hotpep= []
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= []
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['AA3**nan']
# hotpep= []
# diamond= ['AA3**AA3_1']
# hmmer-hotpep= []
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= []
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GH43**nan', 'CBM66**nan']
# hotpep= ['GH43**nan', 'CBM66**nan']
# diamond= ['GH43**GH43_34']
# hmmer-hotpep= ['CBM66**nan', 'GH43**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=CBM66, subfam=nan>, <CazymeDomain parent=ATY62977.1 fam=GH43, subfam=nan>]
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['AA3**nan']
# hotpep= []
# diamond= ['AA3**AA3_2']
# hmmer-hotpep= []
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= []
# ========================================================================
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GT2**nan']
# hotpep= []
# diamond= []
# hmmer-hotpep= []
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= []
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GH128**nan']
# hotpep= []
# diamond= []
# hmmer-hotpep= []
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= []
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GH47**nan']
# hotpep= ['GH47**nan']
# diamond= []
# hmmer-hotpep= ['GH47**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=GH47, subfam=nan>]
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GT2**nan']
# hotpep= ['GT2**nan']
# diamond= []
# hmmer-hotpep= ['GT2**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=GT2, subfam=nan>]
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GH16**nan']
# hotpep= []
# diamond= []
# hmmer-hotpep= []
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= []
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GT17**nan']
# hotpep= ['GT17**nan']
# diamond= []
# hmmer-hotpep= ['GT17**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=GT17, subfam=nan>]
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GH55**nan']
# hotpep= ['GH0**nan', 'GH55**nan']
# diamond= []
# hmmer-hotpep= ['GH55**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=GH55, subfam=nan>]
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GT4**nan']
# hotpep= ['GT4**nan']
# diamond= []
# hmmer-hotpep= ['GT4**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=GT4, subfam=nan>]
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['AA1**nan']
# hotpep= ['AA1**nan']
# diamond= ['AA1**AA1_3']
# hmmer-hotpep= ['AA1**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=AA1, subfam=nan>]
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['AA11**nan']
# hotpep= ['AA11**nan']
# diamond= []
# hmmer-hotpep= ['AA11**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=AA11, subfam=nan>]
# ========================================================================
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GT22**nan']
# hotpep= ['GT22**nan']
# diamond= []
# hmmer-hotpep= ['GT22**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=GT22, subfam=nan>]
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GH16**nan']
# hotpep= []
# diamond= []
# hmmer-hotpep= []
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= []
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['AA5**nan']
# hotpep= ['AA5**nan']
# diamond= ['AA5**AA5_1']
# hmmer-hotpep= ['AA5**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=AA5, subfam=nan>]
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GT4**nan']
# hotpep= ['GT4**nan']
# diamond= []
# hmmer-hotpep= ['GT4**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=GT4, subfam=nan>]
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GH92**nan']
# hotpep= ['GH92**nan']
# diamond= []
# hmmer-hotpep= ['GH92**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=GH92, subfam=nan>]
# ========================================================================
# multiple domain ranges= -CazymeDomain in ATY60367.1, fam=CBM66, subfam=nan- ['219-369', '388-547'] ATY60367.1
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['CBM66**nan']
# hotpep= []
# diamond= []
# hmmer-hotpep= []
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= []
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GH16**nan']
# hotpep= []
# diamond= []
# hmmer-hotpep= []
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= []
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GH152**nan']
# hotpep= ['GH152**nan']
# diamond= []
# hmmer-hotpep= ['GH152**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=GH152, subfam=nan>]
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GH76**nan']
# hotpep= ['GH76**nan']
# diamond= []
# hmmer-hotpep= ['GH76**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=GH76, subfam=nan>]
# ========================================================================
# multiple domain ranges= -CazymeDomain in ATY60416.1, fam=GT2, subfam=nan- ['230-398', '375-584'] ATY60416.1
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GT2**nan']
# hotpep= ['GT2**nan']
# diamond= []
# hmmer-hotpep= ['GT2**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=GT2, subfam=nan>]
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GH31**nan']
# hotpep= ['GH31**nan']
# diamond= []
# hmmer-hotpep= ['GH31**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=GH31, subfam=nan>]
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GH18**nan']
# hotpep= ['CBM18**nan']
# diamond= []
# hmmer-hotpep= []
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= []
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GH55**nan']
# hotpep= []
# diamond= []
# hmmer-hotpep= []
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= []
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['PL35**nan']
# hotpep= []
# diamond= []
# hmmer-hotpep= []
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= []
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GH2**nan']
# hotpep= ['GH2**nan', 'CBM51**nan', 'CBM67**nan']
# diamond= []
# hmmer-hotpep= ['GH2**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=GH2, subfam=nan>]
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['AA1**nan']
# hotpep= ['AA1**nan']
# diamond= []
# hmmer-hotpep= ['AA1**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=AA1, subfam=nan>]
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GH142**nan', 'CBM13**nan']
# hotpep= ['GH142**nan', 'CBM13**nan']
# diamond= []
# hmmer-hotpep= ['GH142**nan', 'CBM13**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=GH142, subfam=nan>, <CazymeDomain parent=ATY62977.1 fam=CBM13, subfam=nan>]
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GH76**nan']
# hotpep= ['GH76**nan']
# diamond= []
# hmmer-hotpep= ['GH76**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=GH76, subfam=nan>]
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GH47**nan']
# hotpep= ['GH47**nan']
# diamond= []
# hmmer-hotpep= ['GH47**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=GH47, subfam=nan>]
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GH16**nan']
# hotpep= ['GH16**nan']
# diamond= []
# hmmer-hotpep= ['GH16**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=GH16, subfam=nan>]
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GH84**nan']
# hotpep= ['GH84**nan']
# diamond= []
# hmmer-hotpep= ['GH84**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=GH84, subfam=nan>]
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GH76**nan']
# hotpep= ['GH76**nan']
# diamond= []
# hmmer-hotpep= ['GH76**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=GH76, subfam=nan>]
# ========================================================================
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['AA11**nan']
# hotpep= ['AA11**nan']
# diamond= []
# hmmer-hotpep= ['AA11**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=AA11, subfam=nan>]
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GH20**nan']
# hotpep= ['GH20**nan']
# diamond= []
# hmmer-hotpep= ['GH20**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=GH20, subfam=nan>]
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GH135**nan']
# hotpep= []
# diamond= []
# hmmer-hotpep= []
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= []
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GT2**nan']
# hotpep= ['GT2**nan']
# diamond= []
# hmmer-hotpep= ['GT2**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=GT2, subfam=nan>]
# ========================================================================
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GT34**nan']
# hotpep= ['GT34**nan']
# diamond= []
# hmmer-hotpep= ['GT34**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=GT34, subfam=nan>]
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GH16**nan']
# hotpep= ['GH16**nan']
# diamond= []
# hmmer-hotpep= ['GH16**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=GH16, subfam=nan>]
# ========================================================================
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GH18**nan']
# hotpep= ['GH18**nan', 'CBM18**nan']
# diamond= []
# hmmer-hotpep= ['GH18**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=GH18, subfam=nan>]
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GT64**nan']
# hotpep= ['GT64**nan']
# diamond= []
# hmmer-hotpep= ['GT64**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=GT64, subfam=nan>]
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GH3**nan']
# hotpep= ['GH3**nan']
# diamond= []
# hmmer-hotpep= ['GH3**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=GH3, subfam=nan>]
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GH89**nan']
# hotpep= ['GH89**nan']
# diamond= []
# hmmer-hotpep= ['GH89**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=GH89, subfam=nan>]
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['CE1**nan']
# hotpep= []
# diamond= []
# hmmer-hotpep= []
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= []
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GH18**nan']
# hotpep= ['GH18**nan', 'CBM1**nan', 'CBM19**nan']
# diamond= []
# hmmer-hotpep= ['GH18**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=GH18, subfam=nan>]
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GH13**nan']
# hotpep= ['GH133**nan']
# diamond= ['GH13**GH13_25']
# hmmer-hotpep= []
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= []
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['AA7**nan']
# hotpep= []
# diamond= []
# hmmer-hotpep= []
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= []
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GH16**nan']
# hotpep= ['GH16**nan']
# diamond= []
# hmmer-hotpep= ['GH16**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=GH16, subfam=nan>]
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GT69**nan']
# hotpep= ['GT69**nan']
# diamond= []
# hmmer-hotpep= ['GT69**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=GT69, subfam=nan>]
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['PL20**nan']
# hotpep= []
# diamond= []
# hmmer-hotpep= []
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= []
# ========================================================================
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GH31**nan']
# hotpep= ['GH31**nan']
# diamond= []
# hmmer-hotpep= ['GH31**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=GH31, subfam=nan>]
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GT2**nan']
# hotpep= []
# diamond= []
# hmmer-hotpep= []
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= []
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GH79**nan']
# hotpep= []
# diamond= []
# hmmer-hotpep= []
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= []
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['AA3**nan']
# hotpep= ['AA3**nan']
# diamond= ['AA3**AA3_2']
# hmmer-hotpep= ['AA3**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=AA3, subfam=nan>]
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GH18**nan']
# hotpep= ['GH18**nan']
# diamond= []
# hmmer-hotpep= ['GH18**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=GH18, subfam=nan>]
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GH18**nan']
# hotpep= ['GH18**nan', 'CBM18**nan']
# diamond= []
# hmmer-hotpep= ['GH18**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=GH18, subfam=nan>]
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GT2**nan']
# hotpep= ['GT2**nan']
# diamond= []
# hmmer-hotpep= ['GT2**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=GT2, subfam=nan>]
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GT20**nan']
# hotpep= ['GT20**nan', 'CBM20**nan']
# diamond= []
# hmmer-hotpep= ['GT20**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=GT20, subfam=nan>]
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GH16**nan']
# hotpep= []
# diamond= []
# hmmer-hotpep= []
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= []
# ========================================================================
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GH16**nan']
# hotpep= ['GH16**nan', 'CBM18**nan']
# diamond= []
# hmmer-hotpep= ['GH16**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=GH16, subfam=nan>]
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GH16**nan']
# hotpep= ['GH16**nan', 'CBM4**nan', 'CBM54**nan', 'CBM6**nan']
# diamond= []
# hmmer-hotpep= ['GH16**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=GH16, subfam=nan>]
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GT2**nan']
# hotpep= ['GT0**nan']
# diamond= []
# hmmer-hotpep= []
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= []
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GH15**nan']
# hotpep= ['GH15**nan']
# diamond= []
# hmmer-hotpep= ['GH15**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=GH15, subfam=nan>]
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GH18**nan']
# hotpep= ['GH18**nan', 'CBM18**nan']
# diamond= []
# hmmer-hotpep= ['GH18**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=GH18, subfam=nan>]
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GT59**nan']
# hotpep= ['GT59**nan']
# diamond= []
# hmmer-hotpep= ['GT59**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=GT59, subfam=nan>]
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GT15**nan']
# hotpep= ['GT15**nan']
# diamond= []
# hmmer-hotpep= ['GT15**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=GT15, subfam=nan>]
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GH18**nan']
# hotpep= []
# diamond= []
# hmmer-hotpep= []
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= []
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GH72**nan']
# hotpep= ['GH72**nan', 'CBM43**nan']
# diamond= []
# hmmer-hotpep= ['GH72**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=GH72, subfam=nan>]
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GH2**nan']
# hotpep= ['GH2**nan']
# diamond= []
# hmmer-hotpep= ['GH2**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=GH2, subfam=nan>]
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GH16**nan']
# hotpep= []
# diamond= []
# hmmer-hotpep= []
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= []
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GT22**nan']
# hotpep= ['GT22**nan']
# diamond= []
# hmmer-hotpep= ['GT22**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=GT22, subfam=nan>]
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GH13**nan']
# hotpep= ['GH13**nan']
# diamond= ['GH13**GH13_40']
# hmmer-hotpep= ['GH13**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=GH13, subfam=nan>]
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GT39**nan']
# hotpep= ['GT39**nan']
# diamond= []
# hmmer-hotpep= ['GT39**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=GT39, subfam=nan>]
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GH47**nan']
# hotpep= ['GH47**nan']
# diamond= []
# hmmer-hotpep= ['GH47**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=GH47, subfam=nan>]
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GH5**nan']
# hotpep= ['GH5**nan']
# diamond= ['GH5**GH5_11']
# hmmer-hotpep= ['GH5**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=GH5, subfam=nan>]
# ========================================================================
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GT32**nan']
# hotpep= []
# diamond= []
# hmmer-hotpep= []
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= []
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GH132**nan']
# hotpep= ['GH132**nan']
# diamond= []
# hmmer-hotpep= ['GH132**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=GH132, subfam=nan>]
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GT22**nan']
# hotpep= ['GT22**nan']
# diamond= []
# hmmer-hotpep= ['GT22**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=GT22, subfam=nan>]
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GH5**nan']
# hotpep= ['GH5**nan']
# diamond= ['GH5**GH5_5']
# hmmer-hotpep= ['GH5**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=GH5, subfam=nan>]
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GH76**nan']
# hotpep= ['GH0**nan', 'GH76**nan']
# diamond= []
# hmmer-hotpep= ['GH76**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=GH76, subfam=nan>]
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['AA12**nan']
# hotpep= ['AA12**nan']
# diamond= []
# hmmer-hotpep= ['AA12**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=AA12, subfam=nan>]
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GT39**nan']
# hotpep= ['GT39**nan']
# diamond= []
# hmmer-hotpep= ['GT39**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=GT39, subfam=nan>]
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GH13**nan']
# hotpep= ['GH13**nan']
# diamond= ['GH13**GH13_40']
# hmmer-hotpep= ['GH13**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=GH13, subfam=nan>]
# ========================================================================
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['AA3**nan']
# hotpep= ['AA3**nan']
# diamond= ['AA3**AA3_2']
# hmmer-hotpep= ['AA3**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=AA3, subfam=nan>]
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GT22**nan']
# hotpep= ['GT22**nan']
# diamond= []
# hmmer-hotpep= ['GT22**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=GT22, subfam=nan>]
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GT50**nan']
# hotpep= ['GT50**nan']
# diamond= []
# hmmer-hotpep= ['GT50**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=GT50, subfam=nan>]
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GH3**nan']
# hotpep= ['GH3**nan']
# diamond= []
# hmmer-hotpep= ['GH3**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=GH3, subfam=nan>]
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GT25**nan']
# hotpep= []
# diamond= []
# hmmer-hotpep= []
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= []
# ========================================================================
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GH136**nan']
# hotpep= []
# diamond= []
# hmmer-hotpep= []
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= []
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GH20**nan']
# hotpep= ['GH20**nan']
# diamond= []
# hmmer-hotpep= ['GH20**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=GH20, subfam=nan>]
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GT1**nan']
# hotpep= ['GT1**nan']
# diamond= []
# hmmer-hotpep= ['GT1**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=GT1, subfam=nan>]
# ========================================================================
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GH3**nan']
# hotpep= ['GH3**nan', 'CBM1**nan']
# diamond= []
# hmmer-hotpep= ['GH3**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=GH3, subfam=nan>]
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GT58**nan']
# hotpep= ['GT58**nan']
# diamond= []
# hmmer-hotpep= ['GT58**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=GT58, subfam=nan>]
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GH15**nan', 'CBM20**nan']
# hotpep= ['GH15**nan', 'CBM20**nan']
# diamond= []
# hmmer-hotpep= ['GH15**nan', 'CBM20**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=GH15, subfam=nan>, <CazymeDomain parent=ATY62977.1 fam=CBM20, subfam=nan>]
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GH5**nan']
# hotpep= ['GH5**nan']
# diamond= ['GH5**GH5_15']
# hmmer-hotpep= ['GH5**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=GH5, subfam=nan>]
# ========================================================================
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GT20**nan']
# hotpep= ['GT20**nan', 'CBM20**nan']
# diamond= []
# hmmer-hotpep= ['GT20**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=GT20, subfam=nan>]
# ========================================================================
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GT2**nan']
# hotpep= []
# diamond= []
# hmmer-hotpep= []
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= []
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GH16**nan']
# hotpep= ['GH16**nan', 'CBM4**nan', 'CBM54**nan', 'CBM6**nan']
# diamond= []
# hmmer-hotpep= ['GH16**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=GH16, subfam=nan>]
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GT2**nan']
# hotpep= ['GT0**nan']
# diamond= []
# hmmer-hotpep= []
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= []
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['CE3**nan']
# hotpep= ['CE3**nan']
# diamond= []
# hmmer-hotpep= ['CE3**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=CE3, subfam=nan>]
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GH154**nan']
# hotpep= ['GH154**nan']
# diamond= []
# hmmer-hotpep= ['GH154**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=GH154, subfam=nan>]
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GH88**nan']
# hotpep= ['GH88**nan']
# diamond= []
# hmmer-hotpep= ['GH88**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=GH88, subfam=nan>]
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GH47**nan']
# hotpep= ['GH47**nan']
# diamond= []
# hmmer-hotpep= ['GH47**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=GH47, subfam=nan>]
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GH3**nan']
# hotpep= ['GH3**nan', 'CBM6**nan']
# diamond= []
# hmmer-hotpep= ['GH3**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=GH3, subfam=nan>]
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['AA3**nan']
# hotpep= ['AA3**nan']
# diamond= ['AA3**AA3_2']
# hmmer-hotpep= ['AA3**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=AA3, subfam=nan>]
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['AA9**nan']
# hotpep= ['AA9**nan', 'CBM18**nan']
# diamond= []
# hmmer-hotpep= ['AA9**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=AA9, subfam=nan>]
# ========================================================================
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GH64**nan']
# hotpep= ['GH64**nan', 'CBM6**nan']
# diamond= []
# hmmer-hotpep= ['GH64**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=GH64, subfam=nan>]
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GT15**nan']
# hotpep= ['GT15**nan']
# diamond= []
# hmmer-hotpep= ['GT15**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=GT15, subfam=nan>]
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GH16**nan']
# hotpep= []
# diamond= []
# hmmer-hotpep= []
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= []
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GH18**nan']
# hotpep= ['GH18**nan', 'CBM12**nan', 'CBM2**nan']
# diamond= []
# hmmer-hotpep= ['GH18**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=GH18, subfam=nan>]
# ========================================================================
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GT69**nan']
# hotpep= ['GT69**nan']
# diamond= []
# hmmer-hotpep= ['GT69**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=GT69, subfam=nan>]
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GT71**nan']
# hotpep= ['GT71**nan']
# diamond= []
# hmmer-hotpep= ['GT71**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=GT71, subfam=nan>]
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GH63**nan']
# hotpep= ['GH63**nan']
# diamond= []
# hmmer-hotpep= ['GH63**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=GH63, subfam=nan>]
# ========================================================================
# multiple domain ranges= -CazymeDomain in ATY63255.1, fam=GT57, subfam=nan- ['63-294', '333-565'] ATY63255.1
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GT57**nan']
# hotpep= ['GT57**nan']
# diamond= []
# hmmer-hotpep= ['GT57**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=GT57, subfam=nan>]
# ========================================================================
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GH3**nan']
# hotpep= ['GH3**nan']
# diamond= []
# hmmer-hotpep= ['GH3**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=GH3, subfam=nan>]
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GH35**nan']
# hotpep= ['GH35**nan']
# diamond= []
# hmmer-hotpep= ['GH35**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=GH35, subfam=nan>]
# ========================================================================
# ...
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GH3**nan']
# hotpep= []
# diamond= []
# hmmer-hotpep= []
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= []
# ========================================================================
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GH5**nan']
# hotpep= []
# diamond= ['GH5**GH5_27']
# hmmer-hotpep= []
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= []
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GH20**nan']
# hotpep= ['GH20**nan']
# diamond= []
# hmmer-hotpep= ['GH20**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=GH20, subfam=nan>]
# ========================================================================
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['AA3**nan']
# hotpep= ['AA3**nan']
# diamond= ['AA3**AA3_2']
# hmmer-hotpep= ['AA3**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=AA3, subfam=nan>]
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GH114**nan']
# hotpep= []
# diamond= []
# hmmer-hotpep= []
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= []
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GH18**nan']
# hotpep= []
# diamond= []
# hmmer-hotpep= []
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= []
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GH18**nan']
# hotpep= ['GH18**nan']
# diamond= []
# hmmer-hotpep= ['GH18**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=GH18, subfam=nan>]
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GH17**nan']
# hotpep= ['GH17**nan']
# diamond= []
# hmmer-hotpep= ['GH17**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=GH17, subfam=nan>]
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GH13**nan']
# hotpep= ['GH13**nan', 'CBM48**nan']
# diamond= ['GH13**GH13_8']
# hmmer-hotpep= ['GH13**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=GH13, subfam=nan>]
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GT20**nan']
# hotpep= []
# diamond= []
# hmmer-hotpep= []
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= []
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GT32**nan']
# hotpep= ['GT32**nan']
# diamond= []
# hmmer-hotpep= ['GT32**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=GT32, subfam=nan>]
# ========================================================================
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GH36**nan']
# hotpep= ['GH36**nan']
# diamond= []
# hmmer-hotpep= ['GH36**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=GH36, subfam=nan>]
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GT90**nan']
# hotpep= ['GT90**nan']
# diamond= []
# hmmer-hotpep= ['GT90**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=GT90, subfam=nan>]
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['GH29**nan']
# hotpep= []
# diamond= []
# hmmer-hotpep= []
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= []
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= ['AA3**nan']
# hotpep= ['AA3**nan']
# diamond= ['AA3**AA3_2']
# hmmer-hotpep= ['AA3**nan']
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= [<CazymeDomain parent=ATY62977.1 fam=AA3, subfam=nan>]
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= []
# hotpep= ['GH0**nan']
# diamond= []
# hmmer-hotpep= []
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= []
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= []
# hotpep= ['GH0**nan']
# diamond= []
# hmmer-hotpep= []
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= []
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= []
# hotpep= ['GH0**nan']
# diamond= []
# hmmer-hotpep= []
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= []
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= []
# hotpep= ['GH0**nan']
# diamond= []
# hmmer-hotpep= []
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= []
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= []
# hotpep= ['GH0**nan']
# diamond= []
# hmmer-hotpep= []
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= []
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= []
# hotpep= ['GH0**nan']
# diamond= []
# hmmer-hotpep= []
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= []
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= []
# hotpep= ['GH17**nan']
# diamond= []
# hmmer-hotpep= []
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= []
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= []
# hotpep= ['GH17**nan']
# diamond= []
# hmmer-hotpep= []
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= []
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= []
# hotpep= ['GH27**nan']
# diamond= []
# hmmer-hotpep= []
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= []
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= []
# hotpep= ['GH36**nan']
# diamond= []
# hmmer-hotpep= []
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= []
# ========================================================================
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= []
# hotpep= ['AA1**nan']
# diamond= []
# hmmer-hotpep= []
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= []
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= []
# hotpep= ['AA1**nan']
# diamond= []
# hmmer-hotpep= []
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= []
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= []
# hotpep= ['AA1**nan']
# diamond= []
# hmmer-hotpep= []
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= []
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= []
# hotpep= ['AA1**nan']
# diamond= []
# hmmer-hotpep= []
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= []
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= []
# hotpep= ['GT31**nan']
# diamond= []
# hmmer-hotpep= []
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= []
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= []
# hotpep= ['GT31**nan']
# diamond= []
# hmmer-hotpep= []
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= []
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= []
# hotpep= ['GT31**nan']
# diamond= []
# hmmer-hotpep= []
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= []
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= []
# hotpep= ['GT31**nan']
# diamond= []
# hmmer-hotpep= []
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= []
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= []
# hotpep= ['GT31**nan']
# diamond= []
# hmmer-hotpep= []
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= []
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= []
# hotpep= ['GT41**nan']
# diamond= []
# hmmer-hotpep= []
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= []
# ========================================================================
# PROTEIN_ACCESSION= ATY62977.1
# hmmer= []
# hotpep= ['CBM10**nan', 'CBM2**nan']
# diamond= []
# hmmer-hotpep= []
# hotpep_diamond= []
# hmmer_diamond= []
# all= []
# domains= []
# ========================================================================
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# non_cazyme=  -CazymeProteinPrediction, protein=ATY62977.1, non-CAZyme-
# HBox(children=(HTML(value='Parsing Hotpep.out'), FloatProgress(value=0.0, max=320.0), HTML(value='')))
# protein count = 445

# %% [markdown]
# We can see from the printed statements that we know generate a consensus result for dbCAN, representing all data that at least two of the three prediction tools (HMMER, Hotpep and DIAMOND). Additionally, this creates a `CazymeProteinPrediction` instance to represent a CAZyme, which is populated with a `CazymeDomain` instance for each consensus CAZyme domain prediction.

# %% [markdown]
# <a id="non-caz"></a>

# %% [markdown]
# ## Get non-CAZymes
#
# The proteins from the input FASTA (which contains all query protein sequences parsed by dbCAN) that were classified as a non-CAZyme are not included in any of the output files from dbCAN and its contained prediction tools. However, it is useful to have a complete dataset of the all CAZyme/non-CAZyme predictions from the input FASTA file of query sequences. Additionally, for the evaluation of the prediction tools we need to know specifically, which proteins were classified as CAZymes and which were classified as non-CAZymes.
#
# Therefore, the final task is to parse the input FASTA file of query protein sequences and create `CazymeProteinPrediction` instances to represent the non-CAZymes predicted by dbCAN.
#
# The dictionary storing the `CazymeProteinPrediction` instances generated by parsing the 'overview.txt' file is keyed by the protein accessions retrieved from the 'overview.txt' file. These 'protein_accessions' are identical to the protein data line (the line prefixed with '>'). Therefore, we can parse the input FASTA file of query protein sequences and check if the protein data from the line prefixed with '>' is a key in our dictionary of `CazymeProteinPrediction` instances. If it is not a key then we can add a new key with a non-CAZyme prediciton for HMMER, Hotpep, DIAMOND and dbCAN.

# %%
def parse_dbcan_output(overview_path, hotpep_file, fasta_file):
    """Parse the data in the 'overview.txt' files from dbCAN.
    
    The 'overview.txt' file contains the CAZyme predicion data from
    HMMER, Hotpep and DIAMOND. A dbCAN consensus result is retrieved
    by finding predictions that at least to of the prediction tools
    agree upon.
    
    Each protein from the input FASTA file containing all query protein
    sequences parsed by dbCAN is represented by a CazymeProteinprediction
    instance. Each predicted CAZyme domains in each predicted CAZyme is
    represented by a CazymeDomain instance, which are sotred within their
    parent CAZyme's CazymeProteinPrediction instance. A CazymeProteinPrediction
    instance is created for each protein in the inpu FASTA file parsed
    by dbCAN and for each CAZyme prediction tool: dbCAN, HMMER, Hotpep and
    DIAMOND.
    
    :param overview_path: Path, path to dbCAN output overview.txt file
    :param hotpep_file: Path, path to Hotpep.out file
    :param fasta_file: Path, path to the input FASTA file containing the query sequences
        parsed by dbCAN, HMMER, Hotpep and DIAMOND
    
    Return 4 lists, each containing the CazymeProteinPrediction instances for
    HMMER, Hotpep, DIAMOND and dbCAN.
    """
    # open the overview.txt file
    with open(overview_path, "r") as ofh:
        overview_file = ofh.read().splitlines()
    
    # create an empty dictionary to store the CazymeProteinPrediction instances
    # {protein_accesion: CazymeProteinPrediction_instance}
    overview_dict = {}

    # skip the the first line in the file, becuase it contains the 'column' headings
    for line in tqdm(overview_file[1:], desc="Parsing overview.txt"):
        # separate the line content
        line = line.split("\t")
        
        protein_accession = line[0].strip()
        
        # create a CazymeProteinPrediction instance each for HMMER, Hotpep and DIAMOND
        hmmer_prediction = get_hmmer_prediction(line[1], protein_accession)
        hotpep_prediction = get_hotpep_prediction(line[2], protein_accession)
        diamond_prediction = get_diamond_prediction(line[3], protein_accession)
        
        # get the dbCAN consensus result
        dbcan_prediction = get_dbcan_consensus(hmmer_prediction, hotpep_prediction, diamond_prediction, protein_accession, line[-1])
        
        # add the CazymeProteinPrediction instances to the overview_dict
        try:
            overview_dict[protein_accession]
            prediction_outputs = [["HMMER", hmmer_prediction], ["Hotpep", hotpep_prediction], ["DIAMOND", diamond_prediction], ["dbCAN", dbcan_prediction]]
            
            for prediction_tool in prediction_outputs:
                try:
                    overview_dict[protein_accession][prediction_tool[0]]
                    print(
                        f"WARNING -- Protein {protein_accession} already catalogued with {prediction_tool[0]}"
                    )
                except KeyError:  # raised if CazymeProteinPrediciton instance not stored for prediction_tool
                    overview_dict[protein_accession][prediction_tool[0]] = prediction_tool[1]
        
        except KeyError:  # raised if protein has not been added yet
            overview_dict[protein_accession] = {
                "HMMER": hmmer_prediction,
                "Hotpep": hotpep_prediction,
                "DIAMOND": diamond_prediction,
                "dbCAN": dbcan_prediction,
            }
    
    # get EC numbers predicted by Hotpep
    # overview_dict = get_hotpep_ec_numbers(overview_dict, hotpep_file)
    
    # get non-CAZymes
    overview_dict = get_non_cazymes(fasta_file, overview_dict)
    return overview_dict
        

def get_dbcan_consensus(hmmer_prediction, hotpep_prediction, diamond_prediction, protein_prediction, no_of_tools):
    """Retrieve the consensus CAZyme and CAZyme domain prediction for dbCAN.
    
    Consensus is defined as a result that at least two of the tools (HMMER, Hotpep and DIAMOND)
    agree upon.
    
    :param hmmer_prediction: CazymeProteinPrediction instance containing the HMMER prediction
    :param hotpep_prediction: CazymeProteinPrediction instance containing the Hotpep prediction
    :param diamond_prediction: CazymeProteinPrediction instance containing the DIAMOND prediction
    :param protein_accession: str
    :param no_of_tools: str, data from the '#ofTools' column from the overview.txt file, it states
        the number of tools that list the protein as a CAZyme
    
    Return CazymeProteinPrediction instance to represent the dbCAN consensus prediction
    """
    # first check if the consensus was that the protein was a non-CAZyme
    if no_of_tools == "1":
        # non-CAZyme
        cazyme_classification = 0  # non-CAZyme
        protein = CazymeProteinPrediction("dbCAN", protein_accession, cazyme_classification)
        return protein
    
    # get the consensus CAZyme domain predicitons
    
    # first get each of the predicted CAZyme domains for each tool
    hmmer_domains = get_cazyme_domains(hmmer_prediction)
    hotpep_domains = get_cazyme_domains(hotpep_prediction)
    diamond_domains = get_cazyme_domains(diamond_prediction)
    
    # get the predicted CAZyme domains that are predicted by at two tools
    hmmer_hotpep_consensus = list(set(hmmer_domains) & set(hotpep_domains))
    hotpep_diamond_consensus = list(set(hotpep_domains) & set(diamond_domains))
    hmmer_diamond_consensus = list(set(hmmer_domains) & set(diamond_domains))

    # get the CAZyme domains predicted by all prediction tools
    all_consensus = list(set(hmmer_domains) & set(hotpep_domains) & set(diamond_domains))

    # combine all consensus results
    combined_consensus = (
        hmmer_hotpep_consensus + hotpep_diamond_consensus + hmmer_diamond_consensus + all_consensus
    )
    # remove duplicate entries
    combined_consensus = list(set(combined_consensus))
    
    # create a CazymeProteinPrediction instance to represent the CAZyme
    cazyme_classification = 1  # CAZyme
    parent_cazyme = CazymeProteinPrediction("dbCAN", protein_accession, cazyme_classification)
    
    # create a CazymeDomain instance for each domain
    cazyme_domains = []  # store CazymeDomain instances
    for domain in combined_consensus:
        domain = domain.split("**")
        cazy_family = domain[0]

        if domain[1] == "nan":
            cazy_subfamily = np.nan
        else:
            cazy_subfamily = domain[1]

        new_domain = CazymeDomain("dbCAN", protein_accession, cazy_family, cazy_subfamily)

        cazyme_domains.append(new_domain)
    
    # add predicted CAZyme domains to the instance representing the CAZyme
    parent_cazyme.cazyme_domains = cazyme_domains
    
    return parent_cazyme
    
    
def get_cazyme_domains(cazyme_prediction):
    """Retrieve the predicted CAZyme domains, representing each domains as a string 'fam_subfam'.
    
    :param cazyme_prediction: CazymeProteinPrediction instance.
    
    Return a list of strings with each string representing a single predicted CAZyme domain.
    """
    cazyme_domain_instances = cazyme_prediction.cazyme_domains
    
    cazyme_domains = []  # store list representing CAZyme domains [fam(str), subfam(str)]
    
    # if a prediction tool predicts a protein is a non_CAZyme, non_cazymes == np.nan (a float)
    if type(cazyme_domain_instances) is not float:
        for domain in cazyme_domain_instances:
            cazy_family = domain.cazy_family
            cazy_subfamily = domain.cazy_subfamily
            # separate the family and subfamily '**' becuase these do not appear in the either
            cazyme_domains.append(f"{cazy_family}**{cazy_subfamily}")
    
    return cazyme_domains


def get_non_cazymes(fasta_path, overview_dict):
    """Add proteins that dbCAN identified as non-CAZymes to the collection of CazymeProteinPrediction instances.
    
    :param fasta_path: Path, FASTA file used as input for CUPP.
    :param overview_dict: dict, key=protein_accession, value=dict valued by prediction tool,
          valued by CazymeProteinPrediction intance
    
    Return a dictionary keyed by protein accessions and valued by dictionary of tool:CazymeProteinPrediction.
    """
    print("len PRE adding non-CAZyme=", len(list(overview_dict.values())))
    # open the FASTA path
    with open(fasta_path) as fh:
        fasta = fh.read().splitlines()
    
    fasta_protein_total = 0

    for line in tqdm(fasta, desc="Adding non-CAZymes"):
        if line.startswith(">"):
            fasta_protein_total += 1
            protein_accession = line[1:].split(" ")[0].strip()
            
            # check if the protein has been listed as a CAZyme by CUPP
            try:
                overview_dict[protein_accession]
            except KeyError:
                # raised if protein not in cupp_predictions, inferring proten was not labelled as CAZyme
                cazyme_classification = 0
                overview_dict[protein_accession] = {}
                for prediction_tool in ["HMMER", "Hotpep", "DIAMOND", "dbCAN"]:
                    overview_dict[protein_accession][prediction_tool] = CazymeProteinPrediction(
                        prediction_tool,
                        protein_accession,
                        cazyme_classification,
                    )
    print("len AFTER adding non-CAZyme=", len(list(overview_dict.values())))
    print("number of proteins in the input FASTA file of query protien sequences=", fasta_protein_total)
    return overview_dict

overview_path = "overview.txt"
hotpep_file = "Hotpep.out"
fasta_file = "genbank_proteins_txid73501_GCA_008080495_1.fasta"
overview_dict = parse_dbcan_output(overview_path, hotpep_file, fasta_file)
print("protein count =", len(list(overview_dict.keys())))
# Out:
# HBox(children=(HTML(value='Parsing overview.txt'), FloatProgress(value=0.0, max=445.0), HTML(value='')))
# multiple domain ranges= -CazymeDomain in ATY60367.1, fam=CBM66, subfam=nan- ['219-369', '388-547'] ATY60367.1
# multiple domain ranges= -CazymeDomain in ATY60416.1, fam=GT2, subfam=nan- ['230-398', '375-584'] ATY60416.1
# multiple domain ranges= -CazymeDomain in ATY63255.1, fam=GT57, subfam=nan- ['63-294', '333-565'] ATY63255.1
# multiple domain ranges= -CazymeDomain in ATY66192.1, fam=GT2, subfam=nan- ['487-649', '627-867'] ATY66192.1
#
# len PRE adding non-CAZyme= 445
# HBox(children=(HTML(value='Adding non-CAZymes'), FloatProgress(value=0.0, max=93219.0), HTML(value='')))
# len AFTER adding non-CAZyme= 9287
# number of proteins in the input FASTA file of query protien sequences= 9287
# protein count = 9287

# %% [markdown]
# From the printed out statements we can see that a `CazymeProteinPrediction` instance is created to represent the CAZyme/non-CAZyme and CAZyme domain prediction by each of the CAZyme prediction tools HMMER, Hotpep, DIAMOND and the consensus dbCAN results.

# %% [markdown]
# <a id="final_fun"></a>

# %% [markdown]
# ## The final functions
#
# The final task to make any last tweaks to the method for parsing the output from dbCAN, HMMER, Hotpep and DIAMOND, and combine these into a series of callable functions.
#
# **Summary of the method:**
# The 'overview.txt' file from dbCAN contains all the desired data from dbCAN, except the EC numbers predicted by Hotpep. Therefore, to reduce the number of files that are required to be parsed, all required data is retrieved from the 'overview.txt' file, and this data is supplemented with the predicted EC numbers from the Hotpep 'Hotpep.out' output file.
#
# The dbCAN result is the consensus result of the CAZyme prediction tools that are incorporated within dbCAN (HMMER, Gotpep, and DIAMOND). Specifically, the consensus result is any result that at least two of the CAZyme prediction tools agree upon. This applies to both the CAZyme/non-CAZyme prediction and the prediction of CAZyme domains (specifically the CAZy family and subfamily prediction for each CAZyme domain).
#
# **Data retrieved from each CAZyme prediction tool**
#
# HMMER:
# - CAZyme/non-CAZyme prediction
# - CAZyme domain prediction (the CAZy family/subfamily prediction)
# - Amino acid domain range prediction
#
#
# Hotpep:
# - CAZyme/non-CAZyme prediction
# - CAZyme domain prediction (the CAZy family/subfamily prediction)
# - EC number prediction per predicted CAZyme domain
#
#
# DIAMOND:
# - CAZyme/non-CAZyme prediction
# - CAZyme domain prediction (the CAZy family/subfamily prediction)
#
#
# dbCAN:
# - CAZyme/non-CAZyme prediction
# - CAZyme domain prediction (the CAZy family/subfamily prediction)
#
# **Last little tweaks**
# When gathering the HMMER predictions, a check is performed to see if the same predicted CAZyme domain is listed more than once for a given protein. This is becusae multiple unique amino acid domain ranges can be predicted for the same CAZyme domain. This check has not been implemented in when retrieving the CAZyme domain predictions from Hotpep and DIAMOND. However, to improve the robustness of the method it is better to include this check (checking if a predicted CAZyme domain has been listed more than once for a given protein) when also parsing Hotpep and DIAMOND.
#
# Moreover, a 'quality check' can be added to the retrieval of EC numbers from the 'Hotpep.out' file, specifically checking that when an EC number is retrieved, it is in the expected format and thus more likely to be an EC number.

# %%
def parse_dbcan_output(overview_path, hotpep_file, fasta_file):
    """Parse the data in the 'overview.txt' files from dbCAN.
    
    The 'overview.txt' file contains the CAZyme predicion data from
    HMMER, Hotpep and DIAMOND. A dbCAN consensus result is retrieved
    by finding predictions that at least to of the prediction tools
    agree upon.
    
    Each protein from the input FASTA file containing all query protein
    sequences parsed by dbCAN is represented by a CazymeProteinprediction
    instance. Each predicted CAZyme domains in each predicted CAZyme is
    represented by a CazymeDomain instance, which are sotred within their
    parent CAZyme's CazymeProteinPrediction instance. A CazymeProteinPrediction
    instance is created for each protein in the inpu FASTA file parsed
    by dbCAN and for each CAZyme prediction tool: dbCAN, HMMER, Hotpep and
    DIAMOND.
    
    :param overview_path: Path, path to dbCAN output overview.txt file
    :param hotpep_file: Path, path to Hotpep.out file
    :param fasta_file: Path, path to fasta file containing query protein sequences
          parsed by dbCAN
    
    Return 4 lists, each containing the CazymeProteinPrediction instances for
    HMMER, Hotpep, DIAMOND and dbCAN.
    """
    # open the overview.txt file
    with open(overview_path, "r") as ofh:
        overview_file = ofh.read().splitlines()
    
    # create an empty dictionary to store the CazymeProteinPrediction instances
    # {protein_accesion: CazymeProteinPrediction_instance}
    overview_dict = {}

    # skip the the first line in the file, becuase it contains the 'column' headings
    for line in tqdm(overview_file[1:], desc="Parsing overview.txt"):
        # separate the line content
        line = line.split("\t")
        
        protein_accession = line[0]
        
        # create a CazymeProteinPrediction instance each for HMMER, Hotpep and DIAMOND
        hmmer_prediction = get_hmmer_prediction(line[1], protein_accession)
        hotpep_prediction = get_hotpep_prediction(line[2], protein_accession)
        diamond_prediction = get_diamond_prediction(line[3], protein_accession)
        
        # get the dbCAN consensus result
        dbcan_prediction = get_dbcan_consensus(hmmer_prediction, hotpep_prediction, diamond_prediction, protein_accession, line[-1])
        
        # add the CazymeProteinPrediction instances to the overview_dict
        try:
            overview_dict[protein_accession]
            prediction_outputs = [["HMMER", hmmer_prediction], ["Hotpep", hotpep_prediction], ["DIAMOND", diamond_prediction], ["dbCAN", dbcan_prediction]]
            
            for prediction_tool in prediction_outputs:
                try:
                    overview_dict[protein_accession][prediction_tool[0]]
                    print(
                        f"WARNING -- Protein {protein_accession} already catalogued with {prediction_tool[0]}"
                    )
                except KeyError:  # raised if CazymeProteinPrediciton instance not stored for prediction_tool
                    overview_dict[protein_accession][prediction_tool[0]] = prediction_tool[1]
        
        except KeyError:  # raised if protein has not been added yet
            overview_dict[protein_accession] = {
                "HMMER": hmmer_prediction,
                "Hotpep": hotpep_prediction,
                "DIAMOND": diamond_prediction,
                "dbCAN": dbcan_prediction,
            }
    
    # get EC numbers predicted by Hotpep
    print("proteins in overview_dict pre EC=", len(list(overview_dict.values())))
    overview_dict = get_hotpep_ec_numbers(overview_dict, hotpep_file)
    print("proteins in overview_dictafter EC, pre non=", len(list(overview_dict.values())))
    
    # add proteins predicted to be non-CAZyme to the overview_dict
    overview_dict = get_non_cazymes(fasta_file, overview_dict)
    print("proteins in overview_dict after non=", len(list(overview_dict.values())))

    # now to retrieve a list each of CazymeProteinPredictions for HMMER, Hotpep, DIAMOND and dbCAN
    print("proteins in overview_dict=", len(list(overview_dict.values())))
    print("accessions=\n", list(overview_dict.keys()))
    hmmer_predictions, hotpep_predictions, diamond_predictions, dbcan_predictions = separate_predictions(overview_dict)
    
    return hmmer_predictions, hotpep_predictions, diamond_predictions, dbcan_predictions
        

def get_hmmer_prediction(hmmer_data, protein_accession):
    """Retrieve HMMER prediciton data from the dbCAN overview.txt file.
    
    :param hmmer_data: str, output data from HMMER written in the overview.txt file.
    :param protein_accession: str
    
    Return a CazymeProteinPrediction instance.
    """
    # check if the protein was classified as a non-CAZyme
    if hmmer_data == "-":
        cazyme_classification = 0  # non-CAZyme
        protein = CazymeProteinPrediction("HMMER", protein_accession, cazyme_classification)
        return protein
    
    # create a CazymeProteinPrediction instance to represent the CAZyme
    cazyme_classification = 1
    parent_cazyme = CazymeProteinPrediction("HMMER", protein_accession, cazyme_classification)

    # HMMER can predicted multiple CAZyme domaisn for a CAZyme
    # HMMER separates each of the predicted CAZyme domains by additiona symbols
    parent_cazyme.cazyme_domains = get_hmmer_cazyme_domains(hmmer_data.split("+"), protein_accession)
    
    return parent_cazyme

    
def get_hmmer_cazyme_domains(predicted_domains, protein_accession):
    """Retrieve the CAZyme domains predicted by HMMER.
    
    :param predicted_domains: list of strings, each string containing a CAZyme domain prediction
    :param protein_accession: str
    
    Return list of CazymeDomain instances. Each instance represents a unique CAZyme domain.
    """
    cazyme_domains = {}  # {"cazyfam-cazysubfam": CazymeDomain_instance}

    for domain in predicted_domains:
        # separate the predicted CAZy family from the domain range
        domain = domain.split("(")
        
        # get the predicted CAZy family(subfamily)
        domain_name = domain[0]  # CAZy (sub)family
        cazy_family, cazy_subfamily = get_hmmer_cazy_family(domain_name)
        
        if cazy_family is None:  # unexpected data format found by get_hmmer_cazy_family()
            continue
        
        # get the predicted amino acid domain range
        domain_range = domain[1][:-1]  # drop the terminal ")"
        # check it matches the expected format and thus is the predicted domain range
        try:
            re.match(r"\d+?-\d+", domain_range).group()
        except AttributeError:  # raised if not correct format
            print(
                f"WARNING -- UNKNOWN DATA TYPE OF {domain_range} FOR {protein_accession}\n"
                f"Not adding domain range for the domain {cazy_family}-{cazy_subfamily}"
            )
            domain_range = np.nan

        # create identifier for the CAZyme domain to check if it has already been catalogued
        domain_identifier = f"{cazy_family}-{cazy_subfamily}"
    
        # check if the CAZyme domain has already been cataglouged
        try:
            existing_domain = cazyme_domains[domain_identifier]

            # CAZyme domain already catalogued, check if the retrieved domain range is the same
            if domain_range not in existing_domain.domain_range:
                # append the new domain_range
                existing_domain.domain_range.append(domain_range)
                print("multiple domain ranges=", existing_domain, existing_domain.domain_range, protein_accession)

        except KeyError:  # raised if the CAZyme domain has not yet been catalogued
            cazyme_domains[domain_identifier] = CazymeDomain(
                prediction_tool="HMMER",
                protein_accession=protein_accession,
                cazy_family=cazy_family,
                cazy_subfamily=cazy_subfamily,
                domain_range=[domain_range],
            )

    return list(cazyme_domains.values())


def get_hmmer_cazy_family(domain_name):
    """Retrieve the name of the CAZyme domain, this is the predicted CAZy family and subfamily.
    
    If a subfamily is not predicted, the CAZy subfamily is set as a null value.
    If the data formate does not match the expected format, the CAZy family will
    be set by None, which will be used to not add the current working domain to
    the parent CazymeProteinPrediction instance.
    
    :param domain_name: str, contains the CAZy (sub)family
    
    Return two strings, the CAZy family and the CAZy subfamily.
    """
    # check if unusal CAZy family format or subfamily was given
    if domain_name.find("_") != -1:
        try:
            re.match(r"\D{2,3}\d+?_\D", domain_name).group()  # check unusal CAZy family formating
            cazy_family = domain_name[:domain_name.find("_")]
            cazy_subfamily = np.nan

        except AttributeError:  # raised if not an usual CAZy family format
            try:
                # check if its a CAZy subfamily
                re.match(r"\D{2,3}\d+?_\d+", domain_name).group()
                cazy_family = domain_name[:domain_name.find("_")]
                cazy_subfamily = np.nan

            except AttributeError:  # raised if it doesn't match the expected CAZy subfamily format
                print(
                    f"WARNING -- UNKNOWN DATA TYPE OF {domain_name} FOR {protein_accession}\n"
                    "Not adding as a domain."
                )
                return None, None

    else:
        # potentially have a CAZy family
        try:
            re.match(r"\D{2,3}\d+", domain_name).group()
            cazy_family = domain_name
            cazy_subfamily = np.nan

        except AttributeError:  # raised if doesn't match expected CAZy family
            print(
                f"WARNING -- UNKNOWN DATA TYPE OF {domain_name} FOR {protein_accession}\n"
                "Not adding as a domain."
            )
            return None, None
    
    return cazy_family, cazy_subfamily


def get_hotpep_prediction(hotpep_data, protein_accession):
    """Retrieve Hotpep prediciton data from the dbCAN overview.txt file.
    
    :param hmmer_data: str, output data from Hotpep written in the overview.txt file.
    :param protein_accession: str
    
    Return a CazymeProteinPrediction instance.
    """
    # check if the protein was classified as a non-CAZyme
    if hotpep_data == "-":
        cazyme_classification = 0  # non-CAZyme
        protein = CazymeProteinPrediction("Hotpep", protein_accession, cazyme_classification)
        return protein
    
    # create a CazymeProteinPrediction instance to represent the CAZyme
    cazyme_classification = 1
    parent_cazyme = CazymeProteinPrediction("Hotpep", protein_accession, cazyme_classification)

    # Hotpep can predicted multiple CAZyme domaisn for a CAZyme
    # Hotpep separates each of the predicted CAZyme domains by additiona symbols
    parent_cazyme.cazyme_domains = get_hotpep_cazyme_domains(hotpep_data.split("+"), protein_accession)
    
    return parent_cazyme


def get_hotpep_cazyme_domains(predicted_domains, protein_accession):
    """Retrieve the CAZyme domains predicted by Hotpep.
    
    :param predicted_domains: list of strings, each string containing a CAZyme domain prediction.
    
    Return list of CazymeDomain instances. Each instance represents a unique CAZyme domain.
    """
    cazyme_domains = {}  # {"cazyfam-cazysubfam": CazymeDomain}
    
    for domain in predicted_domains:
        # remove k-mer group number
        domain = domain.split("(")[0]
        
        # check if a CAZy subfamily was predicted
        if domain.find("_") != -1:  # found a CAZy subfamily
            try:
                # check if its a CAZy subfamily
                re.match(r"\D{2,3}\d+?_\d+", domain).group()
                cazy_family = domain[:domain.find("_")]
                cazy_subfamily = np.nan

            except AttributeError:  # raised if it doesn't match the expected CAZy subfamily format
                print(
                    f"WARNING -- UNKNOWN DATA TYPE OF {domain} FOR {protein_accession}\n"
                    "Not adding as a domain."
                )
                continue
        
        else:  # found a CAZy family
            try:  # check it is a CAZy family
                re.match(r"\D{2,3}\d+", domain).group()
                cazy_family = domain
                cazy_subfamily = np.nan

            except AttributeError:  # raised if doesn't match expected CAZy family
                print(
                    f"WARNING -- UNKNOWN DATA TYPE OF {domain} FOR {protein_accession}\n"
                    "Not adding as a domain."
                )
                continue
        
        new_domain = CazymeDomain("Hotpep", protein_accession, cazy_family, cazy_subfamily)
        
        try:
            cazyme_domains[f"{cazy_family}-{cazy_subfamily}"]
            print(
                f"WARNING -- DUPLICATE CAZYME DOMAIN PREDICTIONS OF CAZy family = {cazy_family},\n"
                f" CAZy subfamily = {cazy_subfamily}, in protein {protein_accession}.\n"
                "Only one CazymeDomain instance being added to the respective CazymeProteinPrediction instance."
            )
        except KeyError:
            cazyme_domains[f"{cazy_family}-{cazy_subfamily}"] = new_domain
    
    return list(cazyme_domains.values())
        

def get_hotpep_ec_numbers(overview_dict, hotpep_file):
    """Retrieve EC numbers from the Hotpep.out file, and add them to the CAZyme domains.
    
    :param overview_dict: dict, keyed by protein accession, valued by dictionary of 
                            predicion_tool:CazymeDomain
    :param hotpep_file: Path, path to Hotpep.out file
    
    Return overview_dict
    """
    with open (hotpep_file, "r") as fh:
        hotpep_file_data = fh.read().splitlines()
    
    for line in tqdm(hotpep_file_data[1:], desc="Parsing Hotpep.out"):  # skip the first line containing headings
        # separate out the data
        line = line.split("\t")
        
        protein_accession = line[2].strip()
        
        # retrieve the EC numbers
        ec_numbers = line[-1]
        ec_numbers = ec_numbers.split(",")

        # strip any remaining white space becuase the separating comma
        # is sometimes followed by a space, and remove the kmer cluster number
        index = 0
        for index in range(len(ec_numbers)):
            ec_numbers[index] = ec_numbers[index].strip()
            # remove k-mer group number (EC:kmer_group#)
            ec_numbers[index] = ec_numbers[index].split(":")[0]
        
            if ec_numbers[index] == "NA":
                ec_numbers[index] = np.nan
                continue

            try:
                re.match(r"\d+?\.(\d+?|-)\.(\d+?|-)\.(\d+?|-)", ec_numbers[index])  # missing digits listed as '-'

            except AttributeError:  # raised if not in the expected EC number format
                print(
                    f"WARNING -- unexpected data format of '{ec_numbers[index]}' for protein "
                    f"{protein_accession}.\n"
                    "Not adding this data to the CAZyme's CazymeProteinPrediction instance."
                )
                ec_numbers.remove(ec_numbers[index])
        
        # get CAZy family and subfamily of the current working domain
        cazy_family = line[0]
        if cazy_family.find("_") != -1:
            cazy_subfamily = cazy_family
            cazy_family = cazy_family[:cazy_family.find("_")]
        else:
            cazy_subfamily = np.nan

        domain_identifer = [cazy_family, cazy_subfamily]
        
        parent_cazyme = overview_dict[protein_accession]["Hotpep"]
        parent_domains = parent_cazyme.cazyme_domains
        
        for domain in parent_domains:
            if domain_identifer == [domain.cazy_family, domain.cazy_subfamily]:
                domain.ec_numbers = ec_numbers
        
        parent_cazyme.cazyme_domains = parent_domains
        overview_dict[protein_accession]["Hotpep"] = parent_cazyme
        
    return overview_dict


def get_diamond_prediction(diamond_data, protein_accession):
    """Retrieve DIAMOND prediction data from dbCAN overview.txt file.
    
    :param diamond_data, str, output data from DIAMOND written in the overview.txt
    :param protein_accession, str
    
    Return a CazymeProteinPrediction instance.
    """
    # check if the protein was classified as a non-CAZyme
    if diamond_data == "-":
        cazyme_classification = 0  # non-CAZyme
        protein = CazymeProteinPrediction("DIAMOND", protein_accession, cazyme_classification)
        return protein
    
    # create a CazymeProteinPrediction instance to represent the CAZyme
    cazyme_classification = 1
    parent_cazyme = CazymeProteinPrediction("DIAMOND", protein_accession, cazyme_classification)
    
    # DIAMOND can predict multiple CAZyme domains per CAZyme, each domain is separated by '+'
    parent_cazyme.cazyme_domains = get_diamond_predicted_domains(diamond_data.split("+"), protein_accession)
 
    return parent_cazyme


def get_diamond_predicted_domains(predicted_domains, protein_accession):
    """Retrieve the CAZyme domains predicted by DIAMOND, from the overview.txt file.
    
    :param predicted_domains: list of strings, each string contains a unique CAZyme domain prediction
    :param protein_accession: str
    
    Return list of CazymeDomain instances, one instance per unique CAZyme domain.
    """
    cazyme_domains = {}  # store CazymeDomain instances, keyed by CAZyme domain "fam-subfam"
    
    for predicted_domain in predicted_domains:
        # check if a subfamily was predicted
        try:
            re.match(r"\D{2,3}\d+?_\d+", predicted_domain).group()
            cazy_family = predicted_domain[:predicted_domain.find("_")]
            cazy_subfamily = predicted_domain
        
        except AttributeError:  # raised if predicted_domain is not a CAZy subfamily
            try:
                # check if a CAZy family was predicted
                re.match(r"\D{2,3}\d+", predicted_domain).group()
                cazy_family = predicted_domain
                cazy_subfamily = np.nan
            
            except AttributeError:  # raised if not a CAZy family
                print(
                    f"WARNING -- Unexpected data formate for '{predicted_domain}' for\n"
                    "DIAMOND in the overview.txt file. Not adding domain to the CAZyme."
                )
            continue
        
        new_domain = CazymeDomain("DIAMOND", protein_accession, cazy_family, cazy_subfamily)
        
        # check if the domain has been parsed before
        try:
            cazyme_domains[f"{cazy_family}-{cazy_subfamily}"]
            print(
                f"WARNING -- duplicate CAZyme domains predicted for protein {protein_accession} "
                " by DIAMOND.\n"
                f"CAZyme domain (CAZy family = {cazy_family}, CAZy subfamily = {cazy_subfamily}),\n"
                "added to the protein once as a single CazymeDomain instance"
            )
            continue
        
        except KeyError:
            cazyme_domains[f"{cazy_family}-{cazy_subfamily}"] = new_domain

    
    return list(cazyme_domains.values())


def get_dbcan_consensus(hmmer_prediction, hotpep_prediction, diamond_prediction, protein_prediction, no_of_tools):
    """Retrieve the consensus CAZyme and CAZyme domain prediction for dbCAN.
    
    Consensus is defined as a result that at least two of the tools (HMMER, Hotpep and DIAMOND)
    agree upon.
    
    :param hmmer_prediction: CazymeProteinPrediction instance containing the HMMER prediction
    :param hotpep_prediction: CazymeProteinPrediction instance containing the Hotpep prediction
    :param diamond_prediction: CazymeProteinPrediction instance containing the DIAMOND prediction
    :param protein_accession: str
    :param no_of_tools: str, data from the '#ofTools' column from the overview.txt file, it states
        the number of tools that list the protein as a CAZyme
    
    Return CazymeProteinPrediction instance to represent the dbCAN consensus prediction
    """
    # first check if the consensus was that the protein was a non-CAZyme
    if no_of_tools == "1":
        # non-CAZyme
        cazyme_classification = 0  # non-CAZyme
        protein = CazymeProteinPrediction("dbCAN", protein_accession, cazyme_classification)
        return protein
    
    # get the consensus CAZyme domain predicitons
    
    # first get each of the predicted CAZyme domains for each tool
    hmmer_domains = get_dbcan_cazyme_domains(hmmer_prediction)
    hotpep_domains = get_dbcan_cazyme_domains(hotpep_prediction)
    diamond_domains = get_dbcan_cazyme_domains(diamond_prediction)

    # get the predicted CAZyme domains that are predicted by at two tools
    hmmer_hotpep_consensus = list(set(hmmer_domains) & set(hotpep_domains))
    hotpep_diamond_consensus = list(set(hotpep_domains) & set(diamond_domains))
    hmmer_diamond_consensus = list(set(hmmer_domains) & set(diamond_domains))

    # get the CAZyme domains predicted by all prediction tools
    all_consensus = list(set(hmmer_domains) & set(hotpep_domains) & set(diamond_domains))

    # combine all consensus results
    combined_consensus = (
        hmmer_hotpep_consensus + hotpep_diamond_consensus + hmmer_diamond_consensus + all_consensus
    )
    # remove duplicate entries
    combined_consensus = list(set(combined_consensus))
    
    # create a CazymeProteinPrediction instance to represent the CAZyme
    cazyme_classification = 1  # CAZyme
    parent_cazyme = CazymeProteinPrediction("dbCAN", protein_accession, cazyme_classification)
    
    # create a CazymeDomain instance for each domain
    cazyme_domains = []  # store CazymeDomain instances
    for domain in combined_consensus:
        domain = domain.split("**")
        cazy_family = domain[0]

        if domain[1] == "nan":
            cazy_subfamily = np.nan
        else:
            cazy_subfamily = domain[1]

        new_domain = CazymeDomain("dbCAN", protein_accession, cazy_family, cazy_subfamily)

        cazyme_domains.append(new_domain)
    
    # add predicted CAZyme domains to the instance representing the CAZyme
    parent_cazyme.cazyme_domains = cazyme_domains
    
    return parent_cazyme
    
    
def get_dbcan_cazyme_domains(cazyme_prediction):
    """Retrieve the predicted CAZyme domains, representing each domains as a string 'fam_subfam'.
    
    :param cazyme_prediction: CazymeProteinPrediction instance.
    
    Return a list of strings with each string representing a single predicted CAZyme domain.
    """
    cazyme_domain_instances = cazyme_prediction.cazyme_domains
    
    cazyme_domains = []  # store list representing CAZyme domains [fam(str), subfam(str)]
    
    # if a prediction tool predicts a protein is a non_CAZyme, non_cazymes == np.nan (a float)
    if type(cazyme_domain_instances) is not float:
        for domain in cazyme_domain_instances:
            cazy_family = domain.cazy_family
            cazy_subfamily = domain.cazy_subfamily
            # separate the family and subfamily '**' becuase these do not appear in the either
            cazyme_domains.append(f"{cazy_family}**{cazy_subfamily}")
    
    return cazyme_domains


def get_non_cazymes(fasta_path, overview_dict):
    """Add proteins that dbCAN identified as non-CAZymes to the collection of CazymeProteinPrediction instances.
    
    :param fasta_path: Path, FASTA file used as input for CUPP.
    :param overview_dict: dict, key=protein_accession, value=dict valued by prediction tool,
          valued by CazymeProteinPrediction intance
    
    Return a dictionary keyed by protein accessions and valued by dictionary of tool:CazymeProteinPrediction.
    """
    # open the FASTA path
    with open(fasta_path) as fh:
        fasta = fh.read().splitlines()

    for line in tqdm(fasta, desc="Adding non-CAZymes"):
        if line.startswith(">"):
            protein_accession = line[1:].strip()
            
            # check if the protein has been listed as a CAZyme by CUPP
            try:
                overview_dict[protein_accession]
            except KeyError:
                # raised if protein not in cupp_predictions, inferring proten was not labelled as CAZyme
                cazyme_classification = 0
                overview_dict[protein_accession] = {}
                for prediction_tool in ["HMMER", "Hotpep", "DIAMOND", "dbCAN"]:
                    overview_dict[protein_accession][prediction_tool] = CazymeProteinPrediction(
                        prediction_tool,
                        protein_accession,
                        cazyme_classification,
                    )

    return overview_dict


def separate_predictions(overview_dict):
    """Create separate lists of CazymeProteinPrediction intances for each prediction tool.
    
    :param overview_dict: dict containing all CazymeProteinPrediciton instances
        {protein_accession: {tool: CazymeProteinPrediction instance}}
    
    Return 4 lists of CazymeProteinPrediction instances    
    """
    hmmer_predictions = []
    hotpep_predictions = []
    diamond_predictions = []
    dbcan_predictions = []
    for protein_accession in list(overview_dict.keys()):
        try:
            hmmer_predictions.append(overview_dict[protein_accession]["HMMER"])
        except KeyError:
            print(
                f"Could not find HMMER prediction for {protein_accession}"
            )

        try:
            hotpep_predictions.append(overview_dict[protein_accession]["Hotpep"])
        except KeyError:
            print(
                f"Could not find HMMER prediction for {protein_accession}"
            )

        try:
            diamond_predictions.append(overview_dict[protein_accession]["DIAMOND"])
        except KeyError:
            print(
                f"Could not find HMMER prediction for {protein_accession}"
            )

        try:
            dbcan_predictions.append(overview_dict[protein_accession]["dbCAN"])
        except KeyError:
            print(
                f"Could not find HMMER prediction for {protein_accession}"
            )
    
    return hmmer_predictions, hotpep_predictions, diamond_predictions, dbcan_predictions
        


overview_path = "overview.txt"
hotpep_file = "Hotpep.out"
fasta_file = "genbank_proteins_txid73501_GCA_008080495_1.fasta"
hmmer_predictions, hotpep_predictions, diamond_predictions, dbcan_predictions = parse_dbcan_output(overview_path, hotpep_file, fasta_file)
print("hmmer=", len(hmmer_predictions))
print("hotpep=", len(hotpep_predictions))
print("diamond=", len(diamond_predictions))
print("dbcan=", len(dbcan_predictions))
# Out:
# HBox(children=(HTML(value='Parsing overview.txt'), FloatProgress(value=0.0, max=445.0), HTML(value='')))
# multiple domain ranges= -CazymeDomain in ATY60367.1, fam=CBM66, subfam=nan- ['219-369', '388-547'] ATY60367.1
# multiple domain ranges= -CazymeDomain in ATY60416.1, fam=GT2, subfam=nan- ['230-398', '375-584'] ATY60416.1
# multiple domain ranges= -CazymeDomain in ATY63255.1, fam=GT57, subfam=nan- ['63-294', '333-565'] ATY63255.1
# multiple domain ranges= -CazymeDomain in ATY66192.1, fam=GT2, subfam=nan- ['487-649', '627-867'] ATY66192.1
#
# proteins in overview_dict pre EC= 445
# HBox(children=(HTML(value='Parsing Hotpep.out'), FloatProgress(value=0.0, max=320.0), HTML(value='')))
# proteins in overview_dictafter EC, pre non= 445
# HBox(children=(HTML(value='Adding non-CAZymes'), FloatProgress(value=0.0, max=93219.0), HTML(value='')))
# proteins in overview_dict after non= 9732
# proteins in overview_dict= 9732
# accessions=
#  ['ATY58323.1', 'ATY58330.1', 'ATY58395.1', 'ATY58396.1', 'ATY58475.1', 'ATY58478.1', 'ATY58486.1', 'ATY58494.1', 'ATY58512.1', 'ATY58528.1', 'ATY58531.1', 'ATY58532.1', 'ATY58571.1', 'ATY58579.1', 'ATY58636.1', 'ATY58637.1', 'ATY58653.1', 'ATY58674.1', 'ATY58687.1', 'ATY58705.1', 'ATY58803.1', 'ATY58848.1', 'ATY58880.1', 'ATY58895.1', 'ATY58902.1', 'ATY58910.1', 'ATY58915.1', 'ATY58949.1', 'ATY58965.1', 'ATY59023.1', 'ATY59031.1', 'ATY59065.1', 'ATY59093.1', 'ATY59185.1', 'ATY59188.1', 'ATY59194.1', 'ATY59202.1', 'ATY59250.1', 'ATY59363.1', 'ATY59524.1', 'ATY59596.1', 'ATY59638.1', 'ATY59663.1', 'ATY59671.1', 'ATY59673.1', 'ATY59688.1', 'ATY59691.1', 'ATY59698.1', 'ATY59714.1', 'ATY59728.1', 'ATY59756.1', 'ATY59775.1', 'ATY59781.1', 'ATY59860.1', 'ATY59890.1', 'ATY59904.1', 'ATY59918.1', 'ATY59933.1', 'ATY59950.1', 'ATY59985.1', 'ATY60044.1', 'ATY60072.1', 'ATY60094.1', 'ATY60133.1', 'ATY60146.1', 'ATY60162.1', 'ATY60186.1', 'ATY60187.1', 'ATY60246.1', 'ATY60251.1', 'ATY60261.1', 'ATY60312.1', 'ATY60330.1', 'ATY60367.1', 'ATY60372.1', 'ATY60381.1', 'ATY60408.1', 'ATY60416.1', 'ATY60491.1', 'ATY60504.1', 'ATY60550.1', 'ATY60555.1', 'ATY60591.1', 'ATY60613.1', 'ATY60620.1', 'ATY60629.1', 'ATY60662.1', 'ATY60681.1', 'ATY60726.1', 'ATY60733.1', 'ATY60734.1', 'ATY60772.1', 'ATY60851.1', 'ATY60853.1', 'ATY60878.1', 'ATY60943.1', 'ATY60976.1', 'ATY60986.1', 'ATY61013.1', 'ATY61023.1', 'ATY61046.1', 'ATY61069.1', 'ATY61117.1', 'ATY61140.1', 'ATY61147.1', 'ATY61152.1', 'ATY61215.1', 'ATY61276.1', 'ATY61280.1', 'ATY61301.1', 'ATY61355.1', 'ATY61441.1', 'ATY61486.1', 'ATY61576.1', 'ATY61595.1', 'ATY61630.1', 'ATY61694.1', 'ATY61713.1', 'ATY61718.1', 'ATY61741.1', 'ATY61753.1', 'ATY61788.1', 'ATY61822.1', 'ATY61824.1', 'ATY61835.1', 'ATY61836.1', 'ATY61850.1', 'ATY61851.1', 'ATY61863.1', 'ATY61865.1', 'ATY61890.1', 'ATY61893.1', 'ATY61914.1', 'ATY61926.1', 'ATY61957.1', 'ATY61965.1', 'ATY61989.1', 'ATY62020.1', 'ATY62039.1', 'ATY62050.1', 'ATY62087.1', 'ATY62092.1', 'ATY62109.1', 'ATY62125.1', 'ATY62132.1', 'ATY62143.1', 'ATY62147.1', 'ATY62175.1', 'ATY62231.1', 'ATY62233.1', 'ATY62235.1', 'ATY62242.1', 'ATY62277.1', 'ATY62278.1', 'ATY62287.1', 'ATY62309.1', 'ATY62338.1', 'ATY62385.1', 'ATY62412.1', 'ATY62433.1', 'ATY62465.1', 'ATY62551.1', 'ATY62564.1', 'ATY62578.1', 'ATY62592.1', 'ATY62614.1', 'ATY62660.1', 'ATY62663.1', 'ATY62684.1', 'ATY62685.1', 'ATY62702.1', 'ATY62739.1', 'ATY62740.1', 'ATY62742.1', 'ATY62757.1', 'ATY62798.1', 'ATY62856.1', 'ATY62900.1', 'ATY62933.1', 'ATY62981.1', 'ATY63039.1', 'ATY63066.1', 'ATY63199.1', 'ATY63210.1', 'ATY63227.1', 'ATY63228.1', 'ATY63255.1', 'ATY63301.1', 'ATY63305.1', 'ATY63319.1', 'ATY63344.1', 'ATY63360.1', 'ATY63375.1', 'ATY63412.1', 'ATY63454.1', 'ATY63468.1', 'ATY63517.1', 'ATY63528.1', 'ATY63573.1', 'ATY63588.1', 'ATY63601.1', 'ATY63636.1', 'ATY63688.1', 'ATY63703.1', 'ATY63705.1', 'ATY63786.1', 'ATY63856.1', 'ATY63886.1', 'ATY63982.1', 'ATY63987.1', 'ATY63993.1', 'ATY63999.1', 'ATY64005.1', 'ATY64012.1', 'ATY64015.1', 'ATY64043.1', 'ATY64047.1', 'ATY64050.1', 'ATY64088.1', 'ATY64132.1', 'ATY64150.1', 'ATY64179.1', 'ATY64186.1', 'ATY64187.1', 'ATY64188.1', 'ATY64233.1', 'ATY64248.1', 'ATY64353.1', 'ATY64416.1', 'ATY64437.1', 'ATY64461.1', 'ATY64478.1', 'ATY64479.1', 'ATY64503.1', 'ATY64517.1', 'ATY64570.1', 'ATY64579.1', 'ATY64630.1', 'ATY64671.1', 'ATY64693.1', 'ATY64695.1', 'ATY64700.1', 'ATY64752.1', 'ATY64774.1', 'ATY64802.1', 'ATY64843.1', 'ATY64850.1', 'ATY64919.1', 'ATY64924.1', 'ATY64953.1', 'ATY64976.1', 'ATY64989.1', 'ATY64996.1', 'ATY65010.1', 'ATY65020.1', 'ATY65055.1', 'ATY65081.1', 'ATY65106.1', 'ATY65116.1', 'ATY65185.1', 'ATY65188.1', 'ATY65191.1', 'ATY65205.1', 'ATY65223.1', 'ATY65449.1', 'ATY65455.1', 'ATY65484.1', 'ATY65544.1', 'ATY65556.1', 'ATY65579.1', 'ATY65604.1', 'ATY65626.1', 'ATY65637.1', 'ATY65665.1', 'ATY65674.1', 'ATY65680.1', 'ATY65728.1', 'ATY65765.1', 'ATY65808.1', 'ATY65886.1', 'ATY65888.1', 'ATY65896.1', 'ATY66055.1', 'ATY66192.1', 'ATY66193.1', 'ATY6619 ...
# hmmer= 9732
# hotpep= 9732
# diamond= 9732
# dbcan= 9732

# %% [markdown]
# Here we can see that all proteins from the input FASTA file are parsed, creating a single `CazymeProteinPrediction` instance per protein. Additionally, we have a robust method for checking if duplicates are found, dealing with those, and also ensuring the returned data matches the expected format.
